# %% [markdown]
# # import data

# %%
from WindPy import *

#Wind API 使用W账户密码登录
w.start() 

#return True and then can go to next operation.
w.isconnected()

import pandas as pd
# Out:
# 22.11.1.52440
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2021 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
# w.wsi("123046.SZ,300587.SZ,113642.SH,603185.SH,110061.SH,600674.SH,128081.SZ,002203.SZ,113016.SH,601127.SH,128017.SZ,002597.SZ",  "close",  "2022-09-06 09:00:00",  "2022-09-09 16:28:08",  "")

# %%
cbond_list = ['123046.SZ','300587.SZ',
# '113642.SH','603185.SH', #转债已退市
'110061.SH','600674.SH',
'128081.SZ','002203.SZ',
'113016.SH','601127.SH',
'128017.SZ','002597.SZ',
'113537.SH','603348.SH',
'123027.SZ','300487.SZ', #转债已退市
'113534.SH','603876.SH',
'113025.SH','601677.SH',
'123031.SZ','300655.SZ',
'128029.SZ','002078.SZ',
'128111.SZ','002738.SZ', #2022-10-14新增4个对子
'128095.SZ','002812.SZ',
'113626.SH','603596.SH',
'123092.SZ','300332.SZ',
'123057.SZ','300586.SZ',#2020-11-18新增3个对子
'123067.SZ','300382.SZ',
'128106.SZ','002840.SZ',
]

# %% [markdown]
# # history trade days

# %%
# ###############################################################
# before_trade_date = '20220908'#监测当日前一个交易日
# present_date = '20220909' #监测当日
# next_trade_date = '20220910' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220909'#监测当日前一个交易日
# present_date = '20220913' #监测当日
# next_trade_date = '20220914' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220913'#监测当日前一个交易日
# present_date = '20220914' #监测当日
# next_trade_date = '20220915' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220914'#监测当日前一个交易日
# present_date = '20220915' #监测当日
# next_trade_date = '20220916' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220915'#监测当日前一个交易日
# present_date = '20220916' #监测当日
# next_trade_date = '20220917' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220916'#监测当日前一个交易日
# present_date = '20220919' #监测当日
# next_trade_date = '20220920' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220919'#监测当日前一个交易日
# present_date = '20220920' #监测当日
# next_trade_date = '20220921' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220920'#监测当日前一个交易日
# present_date = '20220921' #监测当日
# next_trade_date = '20220922' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220921'#监测当日前一个交易日
# present_date = '20220922' #监测当日
# next_trade_date = '20220923' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220922'#监测当日前一个交易日
# present_date = '20220923' #监测当日
# next_trade_date = '20220924' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220923'#监测当日前一个交易日
# present_date = '20220926' #监测当日
# next_trade_date = '20220927' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220926'#监测当日前一个交易日
# present_date = '20220927' #监测当日
# next_trade_date = '20220928' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220927'#监测当日前一个交易日
# present_date = '20220928' #监测当日
# next_trade_date = '20220929' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220928'#监测当日前一个交易日
# present_date = '20220929' #监测当日
# next_trade_date = '20220930' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220929'#监测当日前一个交易日
# present_date = '20220930' #监测当日
# next_trade_date = '20221001' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220930'#监测当日前一个交易日
# present_date = '20221010' #监测当日
# next_trade_date = '20221011' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221010'#监测当日前一个交易日
# present_date = '20221011' #监测当日
# next_trade_date = '20221012' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221011'#监测当日前一个交易日
# present_date = '20221012' #监测当日
# next_trade_date = '20221013' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221012'#监测当日前一个交易日
# present_date = '20221013' #监测当日
# next_trade_date = '20221014' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221013'#监测当日前一个交易日
# present_date = '20221014' #监测当日
# next_trade_date = '20221015' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221014'#监测当日前一个交易日
# present_date = '20221017' #监测当日
# next_trade_date = '20221018' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221017'#监测当日前一个交易日
# present_date = '20221018' #监测当日
# next_trade_date = '20221019' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221018'#监测当日前一个交易日
# present_date = '20221019' #监测当日
# next_trade_date = '20221020' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221019'#监测当日前一个交易日
# present_date = '20221020' #监测当日
# next_trade_date = '20221021' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221020'#监测当日前一个交易日
# present_date = '20221021' #监测当日
# next_trade_date = '20221022' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221021'#监测当日前一个交易日
# present_date = '20221024' #监测当日
# next_trade_date = '20221025' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221024'#监测当日前一个交易日
# present_date = '20221025' #监测当日
# next_trade_date = '20221026' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221025'#监测当日前一个交易日
# present_date = '20221026' #监测当日
# next_trade_date = '20221027' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221026'#监测当日前一个交易日
# present_date = '20221027' #监测当日
# next_trade_date = '20221028' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221027'#监测当日前一个交易日
# present_date = '20221028' #监测当日
# next_trade_date = '20221029' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221028'#监测当日前一个交易日
# present_date = '20221031' #监测当日
# next_trade_date = '20221101' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221031'#监测当日前一个交易日
# present_date = '20221101' #监测当日
# next_trade_date = '20221102' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221101'#监测当日前一个交易日
# present_date = '20221102' #监测当日
# next_trade_date = '20221103' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221102'#监测当日前一个交易日
# present_date = '20221103' #监测当日
# next_trade_date = '20221104' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221103'#监测当日前一个交易日
# present_date = '20221104' #监测当日
# next_trade_date = '20221105' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221104'#监测当日前一个交易日
# present_date = '20221107' #监测当日
# next_trade_date = '20221108' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221107'#监测当日前一个交易日
# present_date = '20221108' #监测当日
# next_trade_date = '20221109' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221108'#监测当日前一个交易日
# present_date = '20221109' #监测当日
# next_trade_date = '20221110' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221109'#监测当日前一个交易日
# present_date = '20221110' #监测当日
# next_trade_date = '20221111' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221110'#监测当日前一个交易日
# present_date = '20221111' #监测当日
# next_trade_date = '20221112' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221111'#监测当日前一个交易日
# present_date = '20221114' #监测当日
# next_trade_date = '20221115' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221114'#监测当日前一个交易日
# present_date = '20221115' #监测当日
# next_trade_date = '20221116' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221115'#监测当日前一个交易日
# present_date = '20221116' #监测当日
# next_trade_date = '20221117' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221116'#监测当日前一个交易日
# present_date = '20221117' #监测当日
# next_trade_date = '20221118' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221117'#监测当日前一个交易日
# present_date = '20221118' #监测当日
# next_trade_date = '20221119' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221118'#监测当日前一个交易日
# present_date = '20221121' #监测当日
# next_trade_date = '20221122' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221121'#监测当日前一个交易日
# present_date = '20221122' #监测当日
# next_trade_date = '20221123' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221122'#监测当日前一个交易日
# present_date = '20221123' #监测当日
# next_trade_date = '20221124' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221123'#监测当日前一个交易日
# present_date = '20221124' #监测当日
# next_trade_date = '20221125' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221124'#监测当日前一个交易日
# present_date = '20221125' #监测当日
# next_trade_date = '20221126' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221125'#监测当日前一个交易日
# present_date = '20221128' #监测当日
# next_trade_date = '20221129' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221128'#监测当日前一个交易日
# present_date = '20221129' #监测当日
# next_trade_date = '20221130' #监测当日下一个自然日
# ###############################################################

# %%
# ###############################################################
# before_trade_date = '20221129'#监测当日前一个交易日
# present_date = '20221130' #监测当日
# next_trade_date = '20221201' #监测当日下一个自然日
# ###############################################################

# ###############################################################
before_trade_date = '20221130'#监测当日前一个交易日
present_date = '20221201' #监测当日
next_trade_date = '20221202' #监测当日下一个自然日
# ###############################################################

# %%
start_date = pd.to_datetime(before_trade_date) 
end_date = pd.to_datetime(next_trade_date)

cbond_price = pd.DataFrame([])
for code in cbond_list:
    price_df = w.wsi(code, "close", start_date, end_date,usedf=True)[1]   #只要了收盘价
    price_df.columns = [code]
    cbond_price = pd.concat([cbond_price,price_df],axis=1)
cbond_price = cbond_price.ffill()    
# cbond_rtn = cbond_price[cbond_price.index.time!=time(15,0,0)]
# cbond_price = cbond_price.loc['2022-09-09 15:00:00':] #从前一个交易日的收盘价开始截取
cbond_price_begin_time = before_trade_date[:4]+'-' + \
                    before_trade_date[4:6]+'-' + \
                    before_trade_date[6:8]+' 15:00:00'
cbond_price = cbond_price.loc[cbond_price_begin_time:]
cbond_price
# Out:
#                      123046.SZ  300587.SZ  110061.SH  600674.SH  128081.SZ  \
# 2022-11-30 15:00:00    367.798      12.58    135.271      11.93    129.299
# 2022-12-01 09:30:00    369.747      12.76    136.260      11.99    130.606
# 2022-12-01 09:31:00    370.337      12.71    135.900      11.97    130.200
# 2022-12-01 09:32:00    367.674      12.64    135.855      11.94    130.095
# 2022-12-01 09:33:00    367.364      12.68    135.711      11.95    130.000
# ...                        ...        ...        ...        ...        ...
# 2022-12-01 14:56:00    376.015      12.93    134.684      11.86    130.203
# 2022-12-01 14:57:00    376.015      12.93    134.685      11.86    130.203
# 2022-12-01 14:58:00    376.015      12.93    134.686      11.86    130.203
# 2022-12-01 14:59:00    376.015      12.93    134.797      11.86    130.203
# 2022-12-01 15:00:00    376.015      12.93    134.748      11.85    130.200
#
#                      002203.SZ  113016.SH  601127.SH  128017.SZ  002597.SZ  \
# 2022-11-30 15:00:00      12.27    346.500      50.25    184.000      34.23
# 2022-12-01 09:30:00      12.43    371.030      52.90    187.315      34.91
# 2022-12-01 09:31:00      12.39    374.988      53.22    187.409      34.95
# 2022-12-01 09:32:00      12.35    367.349      52.33    187.619      34.93
# 2022-12-01 09:33:00      12.33    365.955      51.50    187.443      35.00
# ...                        ...        ...        ...        ...        ...
# 2022-12-01 14:56:00      12.38    353.400      48.85    189.602      35.46
# 2022-12-01 14:57:00      12.38    353.178      48.85    189.602      35.46
# 2022-12-01 14:58:00      12.38    353.580      48.85    189.602      35.46
# 2022-12-01 14:59:00      12.38    353.598      48.85    189.602      35.46
# 2022-12-01 15:00:00      12.37    353.596      48.86    189.600      35.51
#
#                      ...  113626.SH  603596.SH  123092.SZ  300332.SZ  \
# 2022-11-30 15:00:00  ...    232.195      84.83    286.479      13.84
# 2022-12-01 09:30:00  ...    239.050      85.32    288.111      13.84
# 2022-12-01 09:31:00  ...    240.598      85.54    287.178      13.81
# 2022-12-01 09:32:00  ...    238.890      83.88    287.058      13.78
# 2022-12-01 09:33:00  ...    236.254      84.00    284.948      13.75
# ...                  ...        ...        ...        ...        ...
# 2022-12-01 14:56:00  ...    237.988      84.85    270.700      13.00
# 2022-12-01 14:57:00  ...    237.988      84.85    270.700      13.00
# 2022-12-01 14:58:00  ...    237.532      84.85    270.700      13.00
# 2022-12-01 14:59:00  ...    237.988      84.85    270.700      13.00
# 2022-12-01 15:00:00  ...    237.684      84.86    270.359      12.99
#
#                      123057.SZ  300586.SZ  123067.SZ  300382.SZ  128106.SZ  \
# 2022-11-30 15:00:00    224.800      20.37    221.500      20.90    194.921
# 2022-12-01 09:30:00    225.437      20.41    223.604      21.09    196.735
# 2022-12-01 09:31:00    226.638      20.55    225.106      21.20    197.512
# 2022-12-01 09:32:00    229.218      20.72    225.486      21.20    198.250
# 2022-12-01 09:33:00    230.410      20.80    225.382      21.28    197.388
# ...                        ...        ...        ...        ...        ...
# 2022-12-01 14:56:00    236.577      21.09    222.475      21.03    198.600
# 2022-12-01 14:57:00    236.700      21.10    222.453      21.03    198.596
# 2022-12-01 14:58:00    236.700      21.10    222.453      21.03    198.596
# 2022-12-01 14:59:00    236.700      21.10    222.453      21.03    198.596
# 2022-12-01 15:00:00    237.889      21.11    222.697      21.00    198.596
#
#                      002840.SZ
# 2022-11-30 15:00:00      16.42
# 2022-12-01 09:30:00      16.69
# 2022-12-01 09:31:00      16.69
# 2022-12-01 09:32:00      16.74
# 2022-12-01 09:33:00      16.69
# ...                        ...
# 2022-12-01 14:56:00      16.74
# 2022-12-01 14:57:00      16.75
# 2022-12-01 14:58:00      16.75
# 2022-12-01 14:59:00      16.75
# 2022-12-01 15:00:00      16.75
#
# [243 rows x 36 columns]

# %%
# assert False

# %% [markdown]
# # stock pre status

# %%
df_stk_pre_return = w.wss("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return = w.wss("300587.SZ,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
"pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return
df_stk_pre_return
# Out:
#             PCT_CHG
# 300587.SZ -0.158730
# 600674.SH -0.083752
# 002203.SZ -0.243902
# 601127.SH  6.914894
# 002597.SZ -2.200000
# 603348.SH  4.283604
# 300487.SZ -0.999589
# 603876.SH  1.035014
# 601677.SH -2.526186
# 300655.SZ  0.000000
# 002078.SZ  1.385042
# 002738.SZ  4.234222
# 002812.SZ  1.525908
# 603596.SH  8.353557
# 300332.SZ  4.374057
# 300586.SZ  0.791687
# 300382.SZ -1.739539
# 002840.SZ -1.558753

# %%
df_bond_pre_return = w.wss("123046.SZ,113642.SH,110061.SH,128081.SZ,113016.SH,128017.SZ,113537.SH,123027.SZ,113534.SH,113025.SH,123031.SZ,128029.SZ,128111.SZ,128095.SZ,113626.SH,123092.SZ,123057.SZ,123067.SZ,128106.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_bond_pre_return
# Out:
#             PCT_CHG
# 123046.SZ  1.748940
# 113642.SH       NaN
# 110061.SH -0.536029
# 128081.SZ  0.075851
# 113016.SH  7.605020
# 128017.SZ -1.735648
# 113537.SH  3.292275
# 123027.SZ       NaN
# 113534.SH  2.021793
# 113025.SH -2.859947
# 123031.SZ  0.137946
# 128029.SZ  1.440447
# 128111.SZ  3.546614
# 128095.SZ  0.406955
# 113626.SH  5.882004
# 123092.SZ  4.937363
# 123057.SZ  0.875933
# 123067.SZ -1.063511
# 128106.SZ -0.145488

# %%
before_trade_date_trade_status = before_trade_date[:4] +'-'+ before_trade_date[4:6] +'-'+ before_trade_date[6:]
# present_date_trade_status = present_date[:4] +'-'+ present_date[4:6] +'-'+ present_date[6:]
df_stk_pre_trade_status = w.wsd("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ", 
"trade_status", f"{before_trade_date_trade_status}", f"{before_trade_date_trade_status}", "",usedf=True)[1]
df_stk_pre_trade_status
# Out:
#           TRADE_STATUS
# 300587.SZ           交易
# 603185.SH           交易
# 600674.SH           交易
# 002203.SZ           交易
# 601127.SH           交易
# 002597.SZ           交易
# 603348.SH           交易
# 300487.SZ           交易
# 603876.SH           交易
# 601677.SH           交易
# 300655.SZ           交易
# 002078.SZ           交易
# 002738.SZ           交易
# 002812.SZ           交易
# 603596.SH           交易
# 300332.SZ           交易
# 300586.SZ           交易
# 300382.SZ           交易
# 002840.SZ           交易

# %%
df_stk_pre_trade_status.iloc[0,0]
# Out:
# '交易'

# %%
# assert False

# %% [markdown]
# # bond-stock pair

# %%
# cbond_pair = ['113642.SH','603185.SH']  #后面筛选的结果，这组也在里面 转债停止交易了
# open_threshold = 0.023
# close_threshold = 0
# convert_price = 102.4
# operate = True

# cbond_pair = ['123027.SZ','300487.SZ',] # 1019 1020 1021 这几天转债停止交易了
# open_threshold = 0.022
# close_threshold = 0
# convert_price = 19.07
# operate = True

# %%
cbond_pair = ['123046.SZ','300587.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.015
close_threshold = 0
convert_price = 3.94
operate = True

cbond_pair = ['110061.SH','600674.SH']
open_threshold = 0.006
close_threshold = 0
convert_price = 8.8
operate = True

cbond_pair = ['128081.SZ','002203.SZ']
open_threshold = 0.012
close_threshold = 0.002
convert_price = 9.62
operate = True

cbond_pair = ['113016.SH','601127.SH'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.017
close_threshold = 0.003
convert_price = 20.17
operate = True

cbond_pair = ['128017.SZ','002597.SZ']
open_threshold = 0.012
close_threshold = 0
convert_price = 21.33
operate = True

# # $$$$$$$$$$$$$$$$$$$$$$$$以下是新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['113537.SH','603348.SH',]
open_threshold = 0.027
close_threshold = 0.002
convert_price = 19.13
operate = True

cbond_pair = ['113534.SH','603876.SH',]
open_threshold = 0.019
close_threshold = 0.002
convert_price = 14.98
operate = True

cbond_pair = ['113025.SH','601677.SH',]
open_threshold = 0.018
close_threshold = 0
convert_price = 7.66
operate = True

cbond_pair = ['123031.SZ','300655.SZ',]   #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.019
close_threshold = 0
convert_price = 6.25
operate = True

cbond_pair = ['128029.SZ','002078.SZ']
open_threshold = 0.013
close_threshold = 0.002
convert_price = 8.25
operate = True

# # $$$$$$$$$$$$$$$$$$$$$$$$【2022-10-14】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['128111.SZ','002738.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.011
close_threshold = 0.001
convert_price = 10.96
operate = True

cbond_pair = ['128095.SZ','002812.SZ']
open_threshold = 0.013
close_threshold = 0
convert_price = 64.62
operate = True

cbond_pair = ['113626.SH','603596.SH']
open_threshold = 0.02
close_threshold = 0
convert_price = 35.88
operate = True

cbond_pair = ['123092.SZ','300332.SZ']
open_threshold = 0.025
close_threshold = 0.001
convert_price = 5.14
operate = True

# # $$$$$$$$$$$$$$$$$$$$$$$$【2022-11-18】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair =  ['123057.SZ','300586.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.009 
close_threshold = 0.003
convert_price = 9.5
operate = True

cbond_pair =  ['123067.SZ','300382.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.004
close_threshold = 0.002
convert_price = 9.96
operate = True

cbond_pair =  ['128106.SZ','002840.SZ']
open_threshold = 0.01
close_threshold = 0
convert_price = 8.85
operate = True

# %%
# df_signal

# %% [markdown]
# # clip price series

# %%
#从前一个交易日的收盘价开始截取
# cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]].loc['2022-09-08 15:00:00':]
cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]]

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-30 15:00:00    194.921      16.42
# 2022-12-01 09:30:00    196.735      16.69
# 2022-12-01 09:31:00    197.512      16.69
# 2022-12-01 09:32:00    198.250      16.74
# 2022-12-01 09:33:00    197.388      16.69

# %%
cbond_return = pd.DataFrame([])

cbond_preclose = cbond_pair_price.iloc[0,0] # 初始时刻的bond前收盘价
stock_preclose = cbond_pair_price.iloc[0,1] # 初始时刻的stock前收盘价

for index,row in cbond_pair_price.iterrows():
    
    cbond_return.loc[index,cbond_pair[0]] = row[cbond_pair[0]]/cbond_preclose - 1 # 算日内的return
    cbond_return.loc[index,cbond_pair[1]] = row[cbond_pair[1]]/stock_preclose - 1

    if index.time()==time(15,0,0):  #算完日内return，迭代到今日价格的最后一个time bar的时候，将其设为前收盘价
        cbond_preclose = row[cbond_pair[0]]    # 日内return指标用 现价/昨日收盘价 计算
        stock_preclose = row[cbond_pair[1]]
        
# 检查df是否有空值
cbond_return.isnull().sum(axis=0)  # 按列统计
cbond_return.isnull().sum(axis=1) # 按行统计
cbond_return.isnull().sum(axis=1).sum() # 统计整张表
# Out:
# 0

# %%
pd.set_option('display.max_rows', None)
cbond_return['diff'] = cbond_return[cbond_pair[0]] - cbond_return[cbond_pair[1]]
cbond_return.head()
# Out:
#                      128106.SZ  002840.SZ      diff
# 2022-11-30 15:00:00   0.000000   0.000000  0.000000
# 2022-12-01 09:30:00   0.009306   0.016443 -0.007137
# 2022-12-01 09:31:00   0.013293   0.016443 -0.003151
# 2022-12-01 09:32:00   0.017079   0.019488 -0.002410
# 2022-12-01 09:33:00   0.012656   0.016443 -0.003787

# %% [markdown]
# # signal calculate

# %%
################################################################################################
stk_pre_return = df_stk_pre_return.loc[cbond_pair[1]].values[0]
bond_pre_return = df_bond_pre_return.loc[cbond_pair[0]].values[0]
pre_diff = bond_pre_return - stk_pre_return
stk_pre_trade_status = df_stk_pre_trade_status.loc[cbond_pair[1]].values[0]
print(stk_pre_trade_status)
print('pre diff:',pre_diff)
# if abs(stk_pre_return) > 10 or stk_pre_trade_status!='交易':
if abs(pre_diff) > 5 or stk_pre_trade_status!='交易':
    # 如果前一天股票的跌幅小于-10，则今日不做操作
    intraday_open_times = 1
else:
    intraday_open_times = 0
################################################################################################    
open_close_spread = open_threshold - close_threshold
# intraday_open_times = 0
max_open = 1

pos_open_flag = 0
neg_open_flag = 0
cbond_position = pd.DataFrame([])
cbond_position.index = cbond_return.index
for index,row in cbond_return.iterrows():

    if row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff落在A区间，且无仓位，正开
            pos_open_flag = 1
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==1:
        if intraday_open_times < max_open:
            #diff落在A区间，且有负仓，平仓再正开
            pos_open_flag=1
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            print('reverse open +1')
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff落在A区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在B区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在B区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在B区间，且无仓，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在C区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在C区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在C区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在D区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在D区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在D区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且无仓位，反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==1 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且有正仓，平仓反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在E区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    if abs(row['diff'])>2 * open_close_spread and cbond_return.columns[0]!='123057.SZ' and cbond_return.columns[0]!='123067.SZ': 
        #盘中diff超过2倍spread时平仓（价格止损信号）,有两个spread特别小的对子则不用此逻辑进行止损
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if index.time()==time(15,0,0): # 每日收盘时必须平仓（时间止损信号）
    # if index.time()==time(14,59,0): # 每日收盘时必须平仓（时间止损信号）
        intraday_open_times = 0 # 下一天开盘前，把当日记录下来的开仓次数清零
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
# Out:
# 交易
# pre diff: 1.4132649209645025

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-30 15:00:00    194.921      16.42
# 2022-12-01 09:30:00    196.735      16.69
# 2022-12-01 09:31:00    197.512      16.69
# 2022-12-01 09:32:00    198.250      16.74
# 2022-12-01 09:33:00    197.388      16.69

# %%
df_signal = pd.concat([cbond_pair_price,cbond_return,cbond_position],axis=1)
df_signal.columns = ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
print('open threshold',open_threshold,'close threshold',close_threshold)
# df_signal.to_csv('tmp_signal.csv')
# df_signal
# Out:
# open threshold 0.01 close threshold 0

# %% [markdown]
# # backtest

# %%
# 用来记录交易流水的表格,一边遍历df_signal，一边填入内容到流水表格里

import numpy as np
cols = ['balance','signal','bond price','stock price','bond hold','stock hold','commission','tax','reverse open','diff','asset value']
df_trade = pd.DataFrame(
    data = [[0,np.nan,np.nan,np.nan,0,0,0,0,np.nan,np.nan,0]],
    columns=cols
    ) 

balance_last = 0 # 现金账户初始余额

bond_hold = 0 # 债券持有数量
stock_hold = 0 # 股票持有数量


commission_rate = 2/10000 + 0 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 0.5/1000 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 1/1000 # 佣金买卖万二 + 交易滑点

tax_rate = 1/1000 # 卖股票才收印花税千一

# commission_rate = 0/10000 # 佣金买卖万二
# tax_rate = 0/1000 #

for i in range(len(df_signal)-1):
    if df_signal.index[i].time() == time(15,0,0):
    # if df_signal.index[i].time() == time(14,59,0):
        # 修改stock volume 每天固定一个stock volume 应该用债的前收盘价/股票的前收盘价
        stock_volume = df_signal['bond_price'][i]/df_signal['stock_price'][i]

    if df_signal.values[i][-1] != df_signal.values[i+1][-1]:

        index = df_signal.index[i+1]        
        diff = df_signal.values[i+1][-3] #diff在df_signal中的倒数第三列
        
    # df_signal的columns
    # ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
        signal = str(int(df_signal.values[i+1][-2]))+str(int(df_signal.values[i+1][-1]))
        
        bond_price = df_signal.values[i+1][0] 

        stock_price = df_signal.values[i+1][1]
        ########################################################################
        # 增加回测中买卖价差限制，买入价按照现价加0.01卖出价按照现价减0.01，模拟真实交易环境中滑点问题
        slippage = 0
        if signal == '1-1':
            bond_price += slippage
            stock_price -= slippage
        elif signal == '-11':
            bond_price -= slippage
            stock_price += slippage
        elif signal=='00':
            if stock_hold == stock_volume:
                bond_price += slippage
                stock_price -= slippage
            else:
                bond_price -= slippage
                stock_price += slippage
        ########################################################################
        # stock_volume =  bond_price/stock_price # 修改stock volume 每天固定一个stock volume应该用债的前收盘价/股票的前收盘价

        commission = (bond_price + stock_price * stock_volume) * commission_rate

        reverse_open = False #表明这笔交易，是否包含平仓后再反向开仓的操作

        if signal == '00' and stock_hold == stock_volume: #有股票持仓并且需要卖出平仓时，有印花税
            tax = stock_price * tax_rate * stock_volume
        else:
            tax = 0

        if signal == '00':
            balance_last += bond_hold*bond_price
            balance_last += stock_hold*stock_price
            
            bond_hold = 0
            stock_hold = 0
            

        if signal == '1-1':
            '''
            加一个检测之前持仓的模块,如果之前因为-11的信号有持仓,需要先平掉(即买债卖股票),同时再反向开仓
            '''
            reverse_flag = False
            if bond_hold == -1 and stock_hold == 1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last -= bond_price 
                balance_last += stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税
                reverse_flag = True
                reverse_open = True

            bond_hold += 1
            stock_hold += (-1 * stock_volume)
            # stock_hold += stock_volume
            balance_last -= bond_price
            balance_last += stock_price * stock_volume
            
            if reverse_flag:
                tax *= 2 #平仓然后反向开仓的时候 已经计算过tax了，直接double
            else:
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税

        if signal == '-11':
            '''
            加一个检测之前持仓的模块,如果之前因为1-1的信号有持仓,需要先平掉(卖债买股票),同时再反向开仓
            '''
            if bond_hold == 1 and stock_hold == -1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last += bond_price
                balance_last -= stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                                # 买股票无印花税
                reverse_open = True
            bond_hold += -1
            stock_hold += (1 * stock_volume)
            # stock_hold += stock_volume
            balance_last += bond_price
            balance_last -= stock_price * stock_volume
        
        balance_last = balance_last - commission - tax
        balance = balance_last
        asset_value = bond_price*bond_hold + stock_price*stock_hold
        line = [balance,signal,bond_price,stock_price,bond_hold,stock_hold,commission,tax,reverse_open,diff,asset_value]
        # df_trade.loc[index,['balance','asset','signal','bond price','stock price','commission','tax']] = line
        # df_trade.loc[index,cols] = [0,0,np.nan,np.nan,np.nan,0,0,0,0]
        df_trade.loc[index,cols] = line

df_trade.rename(columns={'balance':'cash'},inplace=True)       
df_trade['net value'] = df_trade['cash'] + df_trade['asset value']

# %%
df_trade['operate'] = [operate]*len(df_trade)

# %%
df_trade
# Out:
#    cash  signal  bond price  stock price  bond hold  stock hold  commission  \
# 0     0     NaN         NaN          NaN          0           0           0
#
#    tax  reverse open  diff  asset value  net value  operate
# 0    0           NaN   NaN            0          0     True

# %% [markdown]
# # output to csv

# %%
excel_file_name = './daily_track/'+ present_date+'/' + cbond_pair[0] + '@' + cbond_pair[1] + '.csv'

excel_file_name

df_to_excel = df_trade
df_to_excel['open/close'] = [str(open_threshold)+','+str(close_threshold)]*len(df_to_excel)
df_to_excel['pair'] = [cbond_pair[0] + '@' + cbond_pair[1]]*len(df_to_excel)
df_to_excel = df_to_excel[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_to_excel.to_csv(excel_file_name,)

# %%
present_date
# Out:
# '20221201'

# %% [markdown]
# # conclusion

# %%
import os
single_trade_files = os.listdir('./daily_track'+'/'+present_date)

df_trade_conclusion = pd.DataFrame([])
for file in single_trade_files:
    if file == 'diff':
        continue
    if file == '.DS_Store' or file.split('.')[1] == 'xlsx':
        continue
    tmp_path = './daily_track'+'/'+present_date+'/'+file
    df_tmp = pd.read_csv(tmp_path,index_col=0)
    tmp_col = list(df_tmp.columns)
    df_tmp_head = pd.DataFrame(data=[tmp_col],columns=tmp_col)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp_head)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp)
df_trade_conclusion.columns
df_trade_conclusion = df_trade_conclusion[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_trade_conclusion
tmp_path = './daily_track'+'/'+present_date+'/'+f'{present_date}_conclusion.csv'

df_trade_conclusion.to_csv(tmp_path)

# %% [markdown]
# # intraday signal

# %%
import matplotlib.pyplot as plt

signal_plot_begin_time = present_date[:4]+'-' + \
                         present_date[4:6]+'-' + \
                         present_date[6:8]+' 09:30:00'
df_signal['diff'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' diff',grid=True)

#如果当日有开平仓记录，在图上画出开平仓时刻的标注
if len(df_trade) == 3:
    open_tick = df_trade.index.to_list()[1]
    open_diff = df_trade['diff'].to_list()[1]
    close_tick = df_trade.index.to_list()[2]
    close_diff =  df_trade['diff'].to_list()[2]
    plt.text(open_tick,open_diff,'open')
    plt.text(close_tick,close_diff,'close')
    plt.scatter([open_tick],[open_diff],color='r')

    tmp_nv = df_trade['net value'].to_list()[2]
    if tmp_nv > 0: 
        close_color = 'g' #当天赚钱的话，平仓点位标记为绿色
    else:
        close_color = 'orange' #当天亏钱的话，平仓点位标记为橙色
    plt.scatter([close_tick],[close_diff],color=close_color)
fig_file_name = './daily_track/'+ present_date+'/'+'diff/' + cbond_pair[0] + '@' + cbond_pair[1] + '.png'
plt.savefig(fig_file_name)

plt.show()
df_signal['bond_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+' rtn',grid=True)
plt.show()
df_signal['stock_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[1]+' rtn',grid=True)
plt.show()

# %%
df_tmp = 100/convert_price*df_signal['stock_price']
df_signal['premium rate'] = (df_signal['bond_price'] - df_tmp)/df_tmp
df_signal['premium rate'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' premium rate',grid=True)
# Out:
# <AxesSubplot:title={'center':'128106.SZ@002840.SZ premium rate'}>

# %%
df_signal
# Out:
#                      bond_price  stock_price  bond_rtn  stock_rtn      diff  \
# 2022-11-30 15:00:00     194.921        16.42  0.000000   0.000000  0.000000
# 2022-12-01 09:30:00     196.735        16.69  0.009306   0.016443 -0.007137
# 2022-12-01 09:31:00     197.512        16.69  0.013293   0.016443 -0.003151
# 2022-12-01 09:32:00     198.250        16.74  0.017079   0.019488 -0.002410
# 2022-12-01 09:33:00     197.388        16.69  0.012656   0.016443 -0.003787
# 2022-12-01 09:34:00     197.771        16.71  0.014621   0.017661 -0.003040
# 2022-12-01 09:35:00     197.000        16.64  0.010666   0.013398 -0.002732
# 2022-12-01 09:36:00     196.500        16.60  0.008101   0.010962 -0.002862
# 2022-12-01 09:37:00     198.572        16.73  0.018731   0.018879 -0.000149
# 2022-12-01 09:38:00     198.002        16.69  0.015806   0.016443 -0.000637
# 2022-12-01 09:39:00     199.790        16.79  0.024979   0.022533  0.002446
# 2022-12-01 09:40:00     200.098        16.86  0.026559   0.026797 -0.000237
# 2022-12-01 09:41:00     200.369        16.87  0.027950   0.027406  0.000544
# 2022-12-01 09:42:00     200.060        16.86  0.026365   0.026797 -0.000432
# 2022-12-01 09:43:00     199.441        16.84  0.023189   0.025579 -0.002390
# 2022-12-01 09:44:00     199.988        16.90  0.025995   0.029233 -0.003237
# 2022-12-01 09:45:00     199.500        16.89  0.023492   0.028624 -0.005132
# 2022-12-01 09:46:00     198.644        16.78  0.019100   0.021924 -0.002824
# 2022-12-01 09:47:00     199.128        16.83  0.021583   0.024970 -0.003386
# 2022-12-01 09:48:00     198.750        16.81  0.019644   0.023752 -0.004108
# 2022-12-01 09:49:00     199.990        16.92  0.026005   0.030451 -0.004445
# 2022-12-01 09:50:00     200.100        16.96  0.026570   0.032887 -0.006317
# 2022-12-01 09:51:00     199.193        16.86  0.021917   0.026797 -0.004880
# 2022-12-01 09:52:00     199.400        16.89  0.022979   0.028624 -0.005645
# 2022-12-01 09:53:00     199.161        16.87  0.021752   0.027406 -0.005653
# 2022-12-01 09:54:00     200.079        16.91  0.026462   0.029842 -0.003380
# 2022-12-01 09:55:00     200.150        16.92  0.026826   0.030451 -0.003624
# 2022-12-01 09:56:00     199.820        16.88  0.025133   0.028015 -0.002881
# 2022-12-01 09:57:00     200.500        16.91  0.028622   0.029842 -0.001220
# 2022-12-01 09:58:00     200.001        16.89  0.026062   0.028624 -0.002562
# 2022-12-01 09:59:00     200.802        16.94  0.030171   0.031669 -0.001497
# 2022-12-01 10:00:00     201.700        16.97  0.034778   0.033496  0.001282
# 2022-12-01 10:01:00     200.729        16.88  0.029797   0.028015  0.001782
# 2022-12-01 10:02:00     199.722        16.87  0.024630   0.027406 -0.002775
# 2022-12-01 10:03:00     200.514        16.86  0.028694   0.026797  0.001897
# 2022-12-01 10:04:00     200.757        16.87  0.029940   0.027406  0.002535
# 2022-12-01 10:05:00     201.221        16.93  0.032321   0.031060  0.001261
# 2022-12-01 10:06:00     200.925        16.91  0.030802   0.029842  0.000961
# 2022-12-01 10:07:00     201.247        16.91  0.032454   0.029842  0.002613
# 2022-12-01 10:08:00     200.312        16.90  0.027657   0.029233 -0.001575
# 2022-12-01 10:09:00     200.967        16.90  0.031018   0.029233  0.001785
# 2022-12-01 10:10:00     200.892        16.88  0.030633   0.028015  0.002618
# 2022-12-01 10:11:00     201.352        16.95  0.032993   0.032278  0.000715
# 2022-12-01 10:12:00     201.417        16.93  0.033326   0.031060  0.002267
# 2022-12-01 10:13:00     201.445        16.91  0.033470   0.029842  0.003628
# 2022-12-01 10:14:00     200.715        16.83  0.029725   0.024970  0.004755
# 2022-12-01 10:15:00     200.596        16.83  0.029114   0.024970  0.004145
# 2022-12-01 10:16:00     199.851        16.76  0.025292   0.020706  0.004586
# 2022-12-01 10:17:00     200.145        16.80  0.026801   0.023143  0.003658
# 2022-12-01 10:18:00     199.854        16.76  0.025308   0.020706  0.004601
# 2022-12-01 10:19:00     199.791        16.74  0.024984   0.019488  0.005496
# 2022-12-01 10:20:00     199.800        16.71  0.025031   0.017661  0.007369
# 2022-12-01 10:21:00     200.006        16.76  0.026087   0.020706  0.005381
# 2022-12-01 10:22:00     200.000        16.74  0.026057   0.019488  0.006568
# 2022-12-01 10:23:00     199.800        16.73  0.025031   0.018879  0.006151
# 2022-12-01 10:24:00     199.064        16.73  0.021255   0.018879  0.002375
# 2022-12-01 10:25:00     199.103        16.75  0.021455   0.020097  0.001357
# 2022-12-01 10:26:00     199.509        16.75  0.023538   0.020097  0.003440
# 2022-12-01 10:27:00     199.180        16.75  0.021850   0.020097  0.001752
# 2022-12-01 10:28:00     199.324        16.75  0.022589   0.020097  0.002491
# 2022-12-01 10:29:00     199.889        16.81  0.025487   0.023752  0.001736
# 2022-12-01 10:30:00     200.017        16.83  0.026144   0.024970  0.001174
# 2022-12-01 10:31:00     199.611        16.81  0.024061   0.023752  0.000310
# 2022-12-01 10:32:00     199.300        16.80  0.022466   0.023143 -0.000677
# 2022-12-01 10:33:00     199.350        16.79  0.022722   0.022533  0.000189
# 2022-12-01 10:34:00     199.035        16.77  0.021106   0.021315 -0.000209
# 2022-12-01 10:35:00     198.900        16.76  0.020413   0.020706 -0.000293
# 2022-12-01 10:36:00     198.780        16.74  0.019798   0.019488  0.000309
# 2022-12-01 10:37:00     198.519        16.76  0.018459   0.020706 -0.002248
# 2022-12-01 10:38:00     198.854        16.75  0.020177   0.020097  0.000080
# 2022-12-01 10:39:00     198.762        16.76  0.019705   0.020706 -0.001001
# 2022-12-01 10:40:00     198.900        16.77  0.020413   0.021315 -0.000902
# 2022-12-01 10:41:00     198.700        16.79  0.019387   0.022533 -0.003146
# 2022-12-01 10:42:00     199.068        16.79  0.021275   0.022533 -0.001258
# 2022-12-01 10:43:00     199.000        16.80  0.020926   0.023143 -0.002216
# 2022-12-01 10:44:00     198.861        16.78  0.020213   0.021924 -0.001711
# 2022-12-01 10:45:00     198.605        16.78  0.018900   0.021924 -0.003025
# 2022-12-01 10:46:00     199.189        16.81  0.021896   0.023752 -0.001855
# 2022-12-01 10:47:00     198.990        16.80  0.020875   0.023143 -0.002267
# 2022-12-01 10:48:00     198.765        16.79  0.019721   0.022533 -0.002813
# 2022-12-01 10:49:00     198.948        16.78  0.020660   0.021924 -0.001265
# 2022-12-01 10:50:00     199.000        16.78  0.020926   0.021924 -0.000998
# 2022-12-01 10:51:00     198.770        16.77  0.019746   0.021315 -0.001569
# 2022-12-01 10:52:00     198.900        16.77  0.020413   0.021315 -0.000902
# 2022-12-01 10:53:00     198.800        16.75  0.019900   0.020097 -0.000197
# 2022-12-01 10:54:00     198.777        16.75  0.019782   0.020097 -0.000315
# 2022-12-01 10:55:00     198.680        16.75  0.019285   0.020097 -0.000813
# 2022-12-01 10:56:00     198.643        16.77  0.019095   0.021315 -0.002221
# 2022-12-01 10:57:00     198.610        16.77  0.018926   0.021315 -0.002390
# 2022-12-01 10:58:00     198.765        16.79  0.019721   0.022533 -0.002813
# 2022-12-01 10:59:00     198.933        16.80  0.020583   0.023143 -0.002560
# 2022-12-01 11:00:00     198.700        16.78  0.019387   0.021924 -0.002537
# 2022-12-01 11:01:00     198.582        16.78  0.018782   0.021924 -0.003143
# 2022-12-01 11:02:00     198.300        16.77  0.017335   0.021315 -0.003980
# 2022-12-01 11:03:00     198.452        16.76  0.018115   0.020706 -0.002591
# 2022-12-01 11:04:00     198.550        16.79  0.018618   0.022533 -0.003916
# 2022-12-01 11:05:00     198.722        16.79  0.019500   0.022533 -0.003033
# 2022-12-01 11:06:00     198.582        16.78  0.018782   0.021924 -0.003143
# 2022-12-01 11:07:00     198.475        16.78  0.018233   0.021924 -0.003691
# 2022-12-01 11:08:00     198.540        16.79  0.018566   0.022533 -0.003967
# 2022-12-01 11:09:00     198.830        16.79  0.020054   0.022533 -0.002479
# 2022-12-01 11:10:00     198.760        16.78  0.019695   0.021924 -0.002229
# 2022-12-01 11:11:00     198.545        16.78  0.018592   0.021924 -0.003332
# 2022-12-01 11:12:00     198.442        16.76  0.018064   0.020706 -0.002643
# 2022-12-01 11:13:00     198.507        16.77  0.018397   0.021315 -0.002918
# 2022-12-01 11:14:00     198.639        16.76  0.019074   0.020706 -0.001632
# 2022-12-01 11:15:00     198.337        16.74  0.017525   0.019488 -0.001963
# 2022-12-01 11:16:00     198.400        16.74  0.017848   0.019488 -0.001640
# 2022-12-01 11:17:00     198.373        16.74  0.017710   0.019488 -0.001779
# 2022-12-01 11:18:00     198.230        16.73  0.016976   0.018879 -0.001903
# 2022-12-01 11:19:00     197.799        16.70  0.014765   0.017052 -0.002287
# 2022-12-01 11:20:00     197.988        16.68  0.015735   0.015834 -0.000100
# 2022-12-01 11:21:00     198.000        16.68  0.015796   0.015834 -0.000038
# 2022-12-01 11:22:00     198.002        16.69  0.015806   0.016443 -0.000637
# 2022-12-01 11:23:00     198.002        16.70  0.015806   0.017052 -0.001246
# 2022-12-01 11:24:00     197.691        16.68  0.014211   0.015834 -0.001623
# 2022-12-01 11:25:00     197.827        16.67  0.014909   0.015225 -0.000317
# 2022-12-01 11:26:00     197.739        16.68  0.014457   0.015834 -0.001377
# 2022-12-01 11:27:00     197.900        16.69  0.015283   0.016443 -0.001160
# 2022-12-01 11:28:00     197.954        16.66  0.015560   0.014616  0.000944
# 2022-12-01 11:29:00     197.559        16.62  0.013534   0.012180  0.001353
# 2022-12-01 11:30:00     197.322        16.62  0.012318   0.012180  0.000138
# 2022-12-01 13:00:00     197.761        16.66  0.014570   0.014616 -0.000046
# 2022-12-01 13:01:00     198.051        16.67  0.016058   0.015225  0.000832
# 2022-12-01 13:02:00     197.839        16.65  0.014970   0.014007  0.000963
# 2022-12-01 13:03:00     197.700        16.62  0.014257   0.012180  0.002077
# 2022-12-01 13:04:00     197.673        16.62  0.014119   0.012180  0.001938
# 2022-12-01 13:05:00     197.596        16.61  0.013724   0.011571  0.002152
# 2022-12-01 13:06:00     197.674        16.62  0.014124   0.012180  0.001943
# 2022-12-01 13:07:00     197.793        16.62  0.014734   0.012180  0.002554
# 2022-12-01 13:08:00     198.000        16.63  0.015796   0.012789  0.003007
# 2022-12-01 13:09:00     198.123        16.63  0.016427   0.012789  0.003638
# 2022-12-01 13:10:00     197.900        16.63  0.015283   0.012789  0.002494
# 2022-12-01 13:11:00     197.914        16.64  0.015355   0.013398  0.001957
# 2022-12-01 13:12:00     197.922        16.65  0.015396   0.014007  0.001389
# 2022-12-01 13:13:00     197.870        16.65  0.015129   0.014007  0.001122
# 2022-12-01 13:14:00     197.916        16.67  0.015365   0.015225  0.000140
# 2022-12-01 13:15:00     197.863        16.65  0.015093   0.014007  0.001086
# 2022-12-01 13:16:00     198.260        16.65  0.017130   0.014007  0.003123
# 2022-12-01 13:17:00     198.129        16.69  0.016458   0.016443  0.000015
# 2022-12-01 13:18:00     198.213        16.68  0.016889   0.015834  0.001055
# 2022-12-01 13:19:00     198.200        16.68  0.016822   0.015834  0.000988
# 2022-12-01 13:20:00     198.378        16.69  0.017735   0.016443  0.001292
# 2022-12-01 13:21:00     198.805        16.71  0.019926   0.017661  0.002265
# 2022-12-01 13:22:00     199.190        16.77  0.021901   0.021315  0.000586
# 2022-12-01 13:23:00     198.730        16.74  0.019541   0.019488  0.000053
# 2022-12-01 13:24:00     198.870        16.73  0.020259   0.018879  0.001380
# 2022-12-01 13:25:00     198.571        16.71  0.018726   0.017661  0.001064
# 2022-12-01 13:26:00     198.521        16.72  0.018469   0.018270  0.000199
# 2022-12-01 13:27:00     198.700        16.72  0.019387   0.018270  0.001117
# 2022-12-01 13:28:00     198.910        16.73  0.020465   0.018879  0.001585
# 2022-12-01 13:29:00     198.701        16.69  0.019392   0.016443  0.002949
# 2022-12-01 13:30:00     198.695        16.70  0.019362   0.017052  0.002309
# 2022-12-01 13:31:00     198.790        16.70  0.019849   0.017052  0.002797
# 2022-12-01 13:32:00     198.482        16.68  0.018269   0.015834  0.002435
# 2022-12-01 13:33:00     198.402        16.69  0.017859   0.016443  0.001415
# 2022-12-01 13:34:00     198.400        16.68  0.017848   0.015834  0.002014
# 2022-12-01 13:35:00     198.600        16.70  0.018874   0.017052  0.001822
# 2022-12-01 13:36:00     198.531        16.69  0.018520   0.016443  0.002077
# 2022-12-01 13:37:00     198.434        16.69  0.018023   0.016443  0.001579
# 2022-12-01 13:38:00     198.310        16.69  0.017387   0.016443  0.000943
# 2022-12-01 13:39:00     198.310        16.70  0.017387   0.017052  0.000334
# 2022-12-01 13:40:00     198.500        16.70  0.018361   0.017052  0.001309
# 2022-12-01 13:41:00     198.350        16.71  0.017592   0.017661 -0.000070
# 2022-12-01 13:42:00     198.472        16.70  0.018218   0.017052  0.001165
# 2022-12-01 13:43:00     198.487        16.71  0.018295   0.017661  0.000633
# 2022-12-01 13:44:00     198.403        16.71  0.017864   0.017661  0.000202
# 2022-12-01 13:45:00     198.460        16.72  0.018156   0.018270 -0.000114
# 2022-12-01 13:46:00     198.700        16.74  0.019387   0.019488 -0.000101
# 2022-12-01 13:47:00     198.700        16.73  0.019387   0.018879  0.000508
# 2022-12-01 13:48:00     198.698        16.73  0.019377   0.018879  0.000498
# 2022-12-01 13:49:00     198.552        16.72  0.018628   0.018270  0.000358
# 2022-12-01 13:50:00     198.321        16.72  0.017443   0.018270 -0.000827
# 2022-12-01 13:51:00     198.343        16.71  0.017556   0.017661 -0.000106
# 2022-12-01 13:52:00     198.207        16.69  0.016858   0.016443  0.000415
# 2022-12-01 13:53:00     198.350        16.69  0.017592   0.016443  0.001148
# 2022-12-01 13:54:00     198.250        16.69  0.017079   0.016443  0.000635
# 2022-12-01 13:55:00     198.250        16.68  0.017079   0.015834  0.001244
# 2022-12-01 13:56:00     198.380        16.68  0.017746   0.015834  0.001911
# 2022-12-01 13:57:00     198.329        16.68  0.017484   0.015834  0.001650
# 2022-12-01 13:58:00     198.210        16.68  0.016874   0.015834  0.001039
# 2022-12-01 13:59:00     198.330        16.67  0.017489   0.015225  0.002264
# 2022-12-01 14:00:00     198.080        16.66  0.016207   0.014616  0.001590
# 2022-12-01 14:01:00     198.234        16.69  0.016997   0.016443  0.000553
# 2022-12-01 14:02:00     198.208        16.69  0.016863   0.016443  0.000420
# 2022-12-01 14:03:00     198.206        16.69  0.016853   0.016443  0.000410
# 2022-12-01 14:04:00     198.260        16.68  0.017130   0.015834  0.001296
# 2022-12-01 14:05:00     198.182        16.67  0.016730   0.015225  0.001505
# 2022-12-01 14:06:00     198.395        16.68  0.017823   0.015834  0.001988
# 2022-12-01 14:07:00     198.470        16.69  0.018207   0.016443  0.001764
# 2022-12-01 14:08:00     198.400        16.69  0.017848   0.016443  0.001405
# 2022-12-01 14:09:00     198.310        16.68  0.017387   0.015834  0.001552
# 2022-12-01 14:10:00     198.307        16.68  0.017371   0.015834  0.001537
# 2022-12-01 14:11:00     198.226        16.70  0.016956   0.017052 -0.000097
# 2022-12-01 14:12:00     198.317        16.69  0.017422   0.016443  0.000979
# 2022-12-01 14:13:00     198.400        16.70  0.017848   0.017052  0.000796
# 2022-12-01 14:14:00     198.800        16.72  0.019900   0.018270  0.001630
# 2022-12-01 14:15:00     198.703        16.72  0.019403   0.018270  0.001132
# 2022-12-01 14:16:00     198.700        16.72  0.019387   0.018270  0.001117
# 2022-12-01 14:17:00     198.654        16.72  0.019151   0.018270  0.000881
# 2022-12-01 14:18:00     198.799        16.71  0.019895   0.017661  0.002234
# 2022-12-01 14:19:00     198.600        16.70  0.018874   0.017052  0.001822
# 2022-12-01 14:20:00     198.800        16.73  0.019900   0.018879  0.001021
# 2022-12-01 14:21:00     199.026        16.73  0.021060   0.018879  0.002180
# 2022-12-01 14:22:00     199.006        16.75  0.020957   0.020097  0.000860
# 2022-12-01 14:23:00     198.800        16.73  0.019900   0.018879  0.001021
# 2022-12-01 14:24:00     198.700        16.73  0.019387   0.018879  0.000508
# 2022-12-01 14:25:00     198.856        16.74  0.020188   0.019488  0.000699
# 2022-12-01 14:26:00     198.817        16.73  0.019988   0.018879  0.001108
# 2022-12-01 14:27:00     198.778        16.73  0.019788   0.018879  0.000908
# 2022-12-01 14:28:00     198.756        16.73  0.019675   0.018879  0.000795
# 2022-12-01 14:29:00     198.800        16.72  0.019900   0.018270  0.001630
# 2022-12-01 14:30:00     199.175        16.73  0.021824   0.018879  0.002945
# 2022-12-01 14:31:00     198.800        16.72  0.019900   0.018270  0.001630
# 2022-12-01 14:32:00     198.829        16.71  0.020049   0.017661  0.002388
# 2022-12-01 14:33:00     198.837        16.72  0.020090   0.018270  0.001820
# 2022-12-01 14:34:00     198.978        16.71  0.020814   0.017661  0.003152
# 2022-12-01 14:35:00     198.597        16.69  0.018859   0.016443  0.002416
# 2022-12-01 14:36:00     198.473        16.69  0.018223   0.016443  0.001779
# 2022-12-01 14:37:00     198.526        16.69  0.018495   0.016443  0.002051
# 2022-12-01 14:38:00     198.589        16.69  0.018818   0.016443  0.002375
# 2022-12-01 14:39:00     198.531        16.69  0.018520   0.016443  0.002077
# 2022-12-01 14:40:00     198.673        16.69  0.019249   0.016443  0.002805
# 2022-12-01 14:41:00     198.642        16.68  0.019090   0.015834  0.003255
# 2022-12-01 14:42:00     198.579        16.68  0.018767   0.015834  0.002932
# 2022-12-01 14:43:00     198.650        16.68  0.019131   0.015834  0.003296
# 2022-12-01 14:44:00     198.532        16.69  0.018525   0.016443  0.002082
# 2022-12-01 14:45:00     198.707        16.70  0.019423   0.017052  0.002371
# 2022-12-01 14:46:00     198.797        16.71  0.019885   0.017661  0.002224
# 2022-12-01 14:47:00     198.747        16.71  0.019628   0.017661  0.001967
# 2022-12-01 14:48:00     198.670        16.72  0.019233   0.018270  0.000963
# 2022-12-01 14:49:00     198.319        16.69  0.017433   0.016443  0.000989
# 2022-12-01 14:50:00     198.699        16.69  0.019382   0.016443  0.002939
# 2022-12-01 14:51:00     198.770        16.68  0.019746   0.015834  0.003912
# 2022-12-01 14:52:00     198.975        16.70  0.020798   0.017052  0.003746
# 2022-12-01 14:53:00     198.816        16.71  0.019982   0.017661  0.002321
# 2022-12-01 14:54:00     199.000        16.74  0.020926   0.019488  0.001438
# 2022-12-01 14:55:00     198.936        16.75  0.020598   0.020097  0.000501
# 2022-12-01 14:56:00     198.600        16.74  0.018874   0.019488 -0.000614
# 2022-12-01 14:57:00     198.596        16.75  0.018854   0.020097 -0.001244
# 2022-12-01 14:58:00     198.596        16.75  0.018854   0.020097 -0.001244
# 2022-12-01 14:59:00     198.596        16.75  0.018854   0.020097 -0.001244
# 2022-12-01 15:00:00     198.596        16.75  0.018854   0.020097 -0.001244
#
#                      bond_pos  stock_pos  premium rate
# 2022-11-30 15:00:00       0.0        0.0      0.050579
# 2022-12-01 09:30:00       0.0        0.0      0.043202
# 2022-12-01 09:31:00       0.0        0.0      0.047322
# 2022-12-01 09:32:00       0.0        0.0      0.048096
# 2022-12-01 09:33:00       0.0        0.0      0.046665
# 2022-12-01 09:34:00       0.0        0.0      0.047441
# 2022-12-01 09:35:00       0.0        0.0      0.047746
# 2022-12-01 09:36:00       0.0        0.0      0.047605
# 2022-12-01 09:37:00       0.0        0.0      0.050426
# 2022-12-01 09:38:00       0.0        0.0      0.049921
# 2022-12-01 09:39:00       0.0        0.0      0.053092
# 2022-12-01 09:40:00       0.0        0.0      0.050336
# 2022-12-01 09:41:00       0.0        0.0      0.051136
# 2022-12-01 09:42:00       0.0        0.0      0.050137
# 2022-12-01 09:43:00       0.0        0.0      0.048131
# 2022-12-01 09:44:00       0.0        0.0      0.047274
# 2022-12-01 09:45:00       0.0        0.0      0.045337
# 2022-12-01 09:46:00       0.0        0.0      0.047675
# 2022-12-01 09:47:00       0.0        0.0      0.047108
# 2022-12-01 09:48:00       0.0        0.0      0.046364
# 2022-12-01 09:49:00       0.0        0.0      0.046047
# 2022-12-01 09:50:00       0.0        0.0      0.044154
# 2022-12-01 09:51:00       0.0        0.0      0.045586
# 2022-12-01 09:52:00       0.0        0.0      0.044813
# 2022-12-01 09:53:00       0.0        0.0      0.044798
# 2022-12-01 09:54:00       0.0        0.0      0.047131
# 2022-12-01 09:55:00       0.0        0.0      0.046884
# 2022-12-01 09:56:00       0.0        0.0      0.047634
# 2022-12-01 09:57:00       0.0        0.0      0.049335
# 2022-12-01 09:58:00       0.0        0.0      0.047963
# 2022-12-01 09:59:00       0.0        0.0      0.049054
# 2022-12-01 10:00:00       0.0        0.0      0.051883
# 2022-12-01 10:01:00       0.0        0.0      0.052400
# 2022-12-01 10:02:00       0.0        0.0      0.047741
# 2022-12-01 10:03:00       0.0        0.0      0.052520
# 2022-12-01 10:04:00       0.0        0.0      0.053171
# 2022-12-01 10:05:00       0.0        0.0      0.051864
# 2022-12-01 10:06:00       0.0        0.0      0.051559
# 2022-12-01 10:07:00       0.0        0.0      0.053244
# 2022-12-01 10:08:00       0.0        0.0      0.048971
# 2022-12-01 10:09:00       0.0        0.0      0.052401
# 2022-12-01 10:10:00       0.0        0.0      0.053255
# 2022-12-01 10:11:00       0.0        0.0      0.051307
# 2022-12-01 10:12:00       0.0        0.0      0.052889
# 2022-12-01 10:13:00       0.0        0.0      0.054280
# 2022-12-01 10:14:00       0.0        0.0      0.055453
# 2022-12-01 10:15:00       0.0        0.0      0.054827
# 2022-12-01 10:16:00       0.0        0.0      0.055299
# 2022-12-01 10:17:00       0.0        0.0      0.054335
# 2022-12-01 10:18:00       0.0        0.0      0.055315
# 2022-12-01 10:19:00       0.0        0.0      0.056243
# 2022-12-01 10:20:00       0.0        0.0      0.058187
# 2022-12-01 10:21:00       0.0        0.0      0.056118
# 2022-12-01 10:22:00       0.0        0.0      0.057348
# 2022-12-01 10:23:00       0.0        0.0      0.056922
# 2022-12-01 10:24:00       0.0        0.0      0.053028
# 2022-12-01 10:25:00       0.0        0.0      0.051977
# 2022-12-01 10:26:00       0.0        0.0      0.054122
# 2022-12-01 10:27:00       0.0        0.0      0.052384
# 2022-12-01 10:28:00       0.0        0.0      0.053145
# 2022-12-01 10:29:00       0.0        0.0      0.052360
# 2022-12-01 10:30:00       0.0        0.0      0.051783
# 2022-12-01 10:31:00       0.0        0.0      0.050897
# 2022-12-01 10:32:00       0.0        0.0      0.049884
# 2022-12-01 10:33:00       0.0        0.0      0.050773
# 2022-12-01 10:34:00       0.0        0.0      0.050364
# 2022-12-01 10:35:00       0.0        0.0      0.050277
# 2022-12-01 10:36:00       0.0        0.0      0.050898
# 2022-12-01 10:37:00       0.0        0.0      0.048266
# 2022-12-01 10:38:00       0.0        0.0      0.050661
# 2022-12-01 10:39:00       0.0        0.0      0.049549
# 2022-12-01 10:40:00       0.0        0.0      0.049651
# 2022-12-01 10:41:00       0.0        0.0      0.047347
# 2022-12-01 10:42:00       0.0        0.0      0.049286
# 2022-12-01 10:43:00       0.0        0.0      0.048304
# 2022-12-01 10:44:00       0.0        0.0      0.048820
# 2022-12-01 10:45:00       0.0        0.0      0.047470
# 2022-12-01 10:46:00       0.0        0.0      0.048675
# 2022-12-01 10:47:00       0.0        0.0      0.048251
# 2022-12-01 10:48:00       0.0        0.0      0.047689
# 2022-12-01 10:49:00       0.0        0.0      0.049279
# 2022-12-01 10:50:00       0.0        0.0      0.049553
# 2022-12-01 10:51:00       0.0        0.0      0.048965
# 2022-12-01 10:52:00       0.0        0.0      0.049651
# 2022-12-01 10:53:00       0.0        0.0      0.050376
# 2022-12-01 10:54:00       0.0        0.0      0.050255
# 2022-12-01 10:55:00       0.0        0.0      0.049742
# 2022-12-01 10:56:00       0.0        0.0      0.048295
# 2022-12-01 10:57:00       0.0        0.0      0.048121
# 2022-12-01 10:58:00       0.0        0.0      0.047689
# 2022-12-01 10:59:00       0.0        0.0      0.047951
# 2022-12-01 11:00:00       0.0        0.0      0.047971
# 2022-12-01 11:01:00       0.0        0.0      0.047348
# 2022-12-01 11:02:00       0.0        0.0      0.046485
# 2022-12-01 11:03:00       0.0        0.0      0.047912
# 2022-12-01 11:04:00       0.0        0.0      0.046556
# 2022-12-01 11:05:00       0.0        0.0      0.047463
# 2022-12-01 11:06:00       0.0        0.0      0.047348
# 2022-12-01 11:07:00       0.0        0.0      0.046784
# 2022-12-01 11:08:00       0.0        0.0      0.046503
# 2022-12-01 11:09:00       0.0        0.0      0.048032
# 2022-12-01 11:10:00       0.0        0.0      0.048287
# 2022-12-01 11:11:00       0.0        0.0      0.047153
# 2022-12-01 11:12:00       0.0        0.0      0.047859
# 2022-12-01 11:13:00       0.0        0.0      0.047577
# 2022-12-01 11:14:00       0.0        0.0      0.048899
# 2022-12-01 11:15:00       0.0        0.0      0.048556
# 2022-12-01 11:16:00       0.0        0.0      0.048889
# 2022-12-01 11:17:00       0.0        0.0      0.048746
# 2022-12-01 11:18:00       0.0        0.0      0.048617
# 2022-12-01 11:19:00       0.0        0.0      0.048216
# 2022-12-01 11:20:00       0.0        0.0      0.050476
# 2022-12-01 11:21:00       0.0        0.0      0.050540
# 2022-12-01 11:22:00       0.0        0.0      0.049921
# 2022-12-01 11:23:00       0.0        0.0      0.049292
# 2022-12-01 11:24:00       0.0        0.0      0.048900
# 2022-12-01 11:25:00       0.0        0.0      0.050251
# 2022-12-01 11:26:00       0.0        0.0      0.049155
# 2022-12-01 11:27:00       0.0        0.0      0.049380
# 2022-12-01 11:28:00       0.0        0.0      0.051556
# 2022-12-01 11:29:00       0.0        0.0      0.051984
# 2022-12-01 11:30:00       0.0        0.0      0.050722
# 2022-12-01 13:00:00       0.0        0.0      0.050531
# 2022-12-01 13:01:00       0.0        0.0      0.051441
# 2022-12-01 13:02:00       0.0        0.0      0.051577
# 2022-12-01 13:03:00       0.0        0.0      0.052735
# 2022-12-01 13:04:00       0.0        0.0      0.052591
# 2022-12-01 13:05:00       0.0        0.0      0.052814
# 2022-12-01 13:06:00       0.0        0.0      0.052596
# 2022-12-01 13:07:00       0.0        0.0      0.053230
# 2022-12-01 13:08:00       0.0        0.0      0.053698
# 2022-12-01 13:09:00       0.0        0.0      0.054353
# 2022-12-01 13:10:00       0.0        0.0      0.053166
# 2022-12-01 13:11:00       0.0        0.0      0.052608
# 2022-12-01 13:12:00       0.0        0.0      0.052018
# 2022-12-01 13:13:00       0.0        0.0      0.051741
# 2022-12-01 13:14:00       0.0        0.0      0.050724
# 2022-12-01 13:15:00       0.0        0.0      0.051704
# 2022-12-01 13:16:00       0.0        0.0      0.053814
# 2022-12-01 13:17:00       0.0        0.0      0.050594
# 2022-12-01 13:18:00       0.0        0.0      0.051670
# 2022-12-01 13:19:00       0.0        0.0      0.051601
# 2022-12-01 13:20:00       0.0        0.0      0.051914
# 2022-12-01 13:21:00       0.0        0.0      0.052917
# 2022-12-01 13:22:00       0.0        0.0      0.051182
# 2022-12-01 13:23:00       0.0        0.0      0.050634
# 2022-12-01 13:24:00       0.0        0.0      0.052002
# 2022-12-01 13:25:00       0.0        0.0      0.051678
# 2022-12-01 13:26:00       0.0        0.0      0.050784
# 2022-12-01 13:27:00       0.0        0.0      0.051731
# 2022-12-01 13:28:00       0.0        0.0      0.052214
# 2022-12-01 13:29:00       0.0        0.0      0.053627
# 2022-12-01 13:30:00       0.0        0.0      0.052965
# 2022-12-01 13:31:00       0.0        0.0      0.053468
# 2022-12-01 13:32:00       0.0        0.0      0.053097
# 2022-12-01 13:33:00       0.0        0.0      0.052042
# 2022-12-01 13:34:00       0.0        0.0      0.052662
# 2022-12-01 13:35:00       0.0        0.0      0.052461
# 2022-12-01 13:36:00       0.0        0.0      0.052726
# 2022-12-01 13:37:00       0.0        0.0      0.052211
# 2022-12-01 13:38:00       0.0        0.0      0.051554
# 2022-12-01 13:39:00       0.0        0.0      0.050924
# 2022-12-01 13:40:00       0.0        0.0      0.051931
# 2022-12-01 13:41:00       0.0        0.0      0.050507
# 2022-12-01 13:42:00       0.0        0.0      0.051783
# 2022-12-01 13:43:00       0.0        0.0      0.051233
# 2022-12-01 13:44:00       0.0        0.0      0.050788
# 2022-12-01 13:45:00       0.0        0.0      0.050461
# 2022-12-01 13:46:00       0.0        0.0      0.050475
# 2022-12-01 13:47:00       0.0        0.0      0.051103
# 2022-12-01 13:48:00       0.0        0.0      0.051092
# 2022-12-01 13:49:00       0.0        0.0      0.050948
# 2022-12-01 13:50:00       0.0        0.0      0.049725
# 2022-12-01 13:51:00       0.0        0.0      0.050470
# 2022-12-01 13:52:00       0.0        0.0      0.051008
# 2022-12-01 13:53:00       0.0        0.0      0.051766
# 2022-12-01 13:54:00       0.0        0.0      0.051236
# 2022-12-01 13:55:00       0.0        0.0      0.051866
# 2022-12-01 13:56:00       0.0        0.0      0.052556
# 2022-12-01 13:57:00       0.0        0.0      0.052285
# 2022-12-01 13:58:00       0.0        0.0      0.051654
# 2022-12-01 13:59:00       0.0        0.0      0.052922
# 2022-12-01 14:00:00       0.0        0.0      0.052226
# 2022-12-01 14:01:00       0.0        0.0      0.051151
# 2022-12-01 14:02:00       0.0        0.0      0.051013
# 2022-12-01 14:03:00       0.0        0.0      0.051002
# 2022-12-01 14:04:00       0.0        0.0      0.051919
# 2022-12-01 14:05:00       0.0        0.0      0.052136
# 2022-12-01 14:06:00       0.0        0.0      0.052635
# 2022-12-01 14:07:00       0.0        0.0      0.052402
# 2022-12-01 14:08:00       0.0        0.0      0.052031
# 2022-12-01 14:09:00       0.0        0.0      0.052184
# 2022-12-01 14:10:00       0.0        0.0      0.052168
# 2022-12-01 14:11:00       0.0        0.0      0.050479
# 2022-12-01 14:12:00       0.0        0.0      0.051591
# 2022-12-01 14:13:00       0.0        0.0      0.051401
# 2022-12-01 14:14:00       0.0        0.0      0.052261
# 2022-12-01 14:15:00       0.0        0.0      0.051747
# 2022-12-01 14:16:00       0.0        0.0      0.051731
# 2022-12-01 14:17:00       0.0        0.0      0.051488
# 2022-12-01 14:18:00       0.0        0.0      0.052885
# 2022-12-01 14:19:00       0.0        0.0      0.052461
# 2022-12-01 14:20:00       0.0        0.0      0.051632
# 2022-12-01 14:21:00       0.0        0.0      0.052827
# 2022-12-01 14:22:00       0.0        0.0      0.051465
# 2022-12-01 14:23:00       0.0        0.0      0.051632
# 2022-12-01 14:24:00       0.0        0.0      0.051103
# 2022-12-01 14:25:00       0.0        0.0      0.051300
# 2022-12-01 14:26:00       0.0        0.0      0.051722
# 2022-12-01 14:27:00       0.0        0.0      0.051515
# 2022-12-01 14:28:00       0.0        0.0      0.051399
# 2022-12-01 14:29:00       0.0        0.0      0.052261
# 2022-12-01 14:30:00       0.0        0.0      0.053616
# 2022-12-01 14:31:00       0.0        0.0      0.052261
# 2022-12-01 14:32:00       0.0        0.0      0.053044
# 2022-12-01 14:33:00       0.0        0.0      0.052457
# 2022-12-01 14:34:00       0.0        0.0      0.053833
# 2022-12-01 14:35:00       0.0        0.0      0.053076
# 2022-12-01 14:36:00       0.0        0.0      0.052418
# 2022-12-01 14:37:00       0.0        0.0      0.052699
# 2022-12-01 14:38:00       0.0        0.0      0.053033
# 2022-12-01 14:39:00       0.0        0.0      0.052726
# 2022-12-01 14:40:00       0.0        0.0      0.053479
# 2022-12-01 14:41:00       0.0        0.0      0.053946
# 2022-12-01 14:42:00       0.0        0.0      0.053612
# 2022-12-01 14:43:00       0.0        0.0      0.053988
# 2022-12-01 14:44:00       0.0        0.0      0.052731
# 2022-12-01 14:45:00       0.0        0.0      0.053028
# 2022-12-01 14:46:00       0.0        0.0      0.052875
# 2022-12-01 14:47:00       0.0        0.0      0.052610
# 2022-12-01 14:48:00       0.0        0.0      0.051573
# 2022-12-01 14:49:00       0.0        0.0      0.051602
# 2022-12-01 14:50:00       0.0        0.0      0.053617
# 2022-12-01 14:51:00       0.0        0.0      0.054625
# 2022-12-01 14:52:00       0.0        0.0      0.054448
# 2022-12-01 14:53:00       0.0        0.0      0.052975
# 2022-12-01 14:54:00       0.0        0.0      0.052061
# 2022-12-01 14:55:00       0.0        0.0      0.051095
# 2022-12-01 14:56:00       0.0        0.0      0.049946
# 2022-12-01 14:57:00       0.0        0.0      0.049298
# 2022-12-01 14:58:00       0.0        0.0      0.049298
# 2022-12-01 14:59:00       0.0        0.0      0.049298
# 2022-12-01 15:00:00       0.0        0.0      0.049298

# %%
# 到期时间很短，且价内50%的时候，转债近似等价于正股
def cal_premium_rate(bond_price,stock_price,convert_price):
    tmp = 100/convert_price*stock_price
    res = (bond_price - tmp)/tmp
    return res
cal_premium_rate(200,140,70)
# Out:
# 0.0
