# %% [markdown]
# # import data

# %%
from WindPy import *

#Wind API 使用W账户密码登录
w.start() 

#return True and then can go to next operation.
w.isconnected()

import pandas as pd
# Out:
# 22.9.1.52437
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2021 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
# w.wsi("123046.SZ,300587.SZ,113642.SH,603185.SH,110061.SH,600674.SH,128081.SZ,002203.SZ,113016.SH,601127.SH,128017.SZ,002597.SZ",  "close",  "2022-09-06 09:00:00",  "2022-09-09 16:28:08",  "")

# %%
cbond_list = ['123046.SZ','300587.SZ',
'113642.SH','603185.SH', #转债已退市
'110061.SH','600674.SH',
'128081.SZ','002203.SZ',
'113016.SH','601127.SH',
'128017.SZ','002597.SZ',
'113537.SH','603348.SH',
'123027.SZ','300487.SZ', #转债已退市
'113534.SH','603876.SH',
'113025.SH','601677.SH',
'123031.SZ','300655.SZ',
'128029.SZ','002078.SZ',
'128111.SZ','002738.SZ', #2022-10-14新增4个对子
'128095.SZ','002812.SZ',
'113626.SH','603596.SH',
'123092.SZ','300332.SZ',
'123057.SZ','300586.SZ',#2020-11-18新增3个对子
'123067.SZ','300382.SZ',
'128106.SZ','002840.SZ',
]

# %% [markdown]
# # history trade days

# %%
# ###############################################################
# before_trade_date = '20220908'#监测当日前一个交易日
# present_date = '20220909' #监测当日
# next_trade_date = '20220910' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220909'#监测当日前一个交易日
# present_date = '20220913' #监测当日
# next_trade_date = '20220914' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220913'#监测当日前一个交易日
# present_date = '20220914' #监测当日
# next_trade_date = '20220915' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220914'#监测当日前一个交易日
# present_date = '20220915' #监测当日
# next_trade_date = '20220916' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220915'#监测当日前一个交易日
# present_date = '20220916' #监测当日
# next_trade_date = '20220917' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220916'#监测当日前一个交易日
# present_date = '20220919' #监测当日
# next_trade_date = '20220920' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220919'#监测当日前一个交易日
# present_date = '20220920' #监测当日
# next_trade_date = '20220921' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220920'#监测当日前一个交易日
# present_date = '20220921' #监测当日
# next_trade_date = '20220922' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220921'#监测当日前一个交易日
# present_date = '20220922' #监测当日
# next_trade_date = '20220923' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220922'#监测当日前一个交易日
# present_date = '20220923' #监测当日
# next_trade_date = '20220924' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220923'#监测当日前一个交易日
# present_date = '20220926' #监测当日
# next_trade_date = '20220927' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220926'#监测当日前一个交易日
# present_date = '20220927' #监测当日
# next_trade_date = '20220928' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220927'#监测当日前一个交易日
# present_date = '20220928' #监测当日
# next_trade_date = '20220929' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220928'#监测当日前一个交易日
# present_date = '20220929' #监测当日
# next_trade_date = '20220930' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220929'#监测当日前一个交易日
# present_date = '20220930' #监测当日
# next_trade_date = '20221001' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220930'#监测当日前一个交易日
# present_date = '20221010' #监测当日
# next_trade_date = '20221011' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221010'#监测当日前一个交易日
# present_date = '20221011' #监测当日
# next_trade_date = '20221012' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221011'#监测当日前一个交易日
# present_date = '20221012' #监测当日
# next_trade_date = '20221013' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221012'#监测当日前一个交易日
# present_date = '20221013' #监测当日
# next_trade_date = '20221014' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221013'#监测当日前一个交易日
# present_date = '20221014' #监测当日
# next_trade_date = '20221015' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221014'#监测当日前一个交易日
# present_date = '20221017' #监测当日
# next_trade_date = '20221018' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221017'#监测当日前一个交易日
# present_date = '20221018' #监测当日
# next_trade_date = '20221019' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221018'#监测当日前一个交易日
# present_date = '20221019' #监测当日
# next_trade_date = '20221020' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221019'#监测当日前一个交易日
# present_date = '20221020' #监测当日
# next_trade_date = '20221021' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221020'#监测当日前一个交易日
# present_date = '20221021' #监测当日
# next_trade_date = '20221022' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221021'#监测当日前一个交易日
# present_date = '20221024' #监测当日
# next_trade_date = '20221025' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221024'#监测当日前一个交易日
# present_date = '20221025' #监测当日
# next_trade_date = '20221026' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221025'#监测当日前一个交易日
# present_date = '20221026' #监测当日
# next_trade_date = '20221027' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221026'#监测当日前一个交易日
# present_date = '20221027' #监测当日
# next_trade_date = '20221028' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221027'#监测当日前一个交易日
# present_date = '20221028' #监测当日
# next_trade_date = '20221029' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221028'#监测当日前一个交易日
# present_date = '20221031' #监测当日
# next_trade_date = '20221101' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221031'#监测当日前一个交易日
# present_date = '20221101' #监测当日
# next_trade_date = '20221102' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221101'#监测当日前一个交易日
# present_date = '20221102' #监测当日
# next_trade_date = '20221103' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221102'#监测当日前一个交易日
# present_date = '20221103' #监测当日
# next_trade_date = '20221104' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221103'#监测当日前一个交易日
# present_date = '20221104' #监测当日
# next_trade_date = '20221105' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221104'#监测当日前一个交易日
# present_date = '20221107' #监测当日
# next_trade_date = '20221108' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221107'#监测当日前一个交易日
# present_date = '20221108' #监测当日
# next_trade_date = '20221109' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221108'#监测当日前一个交易日
# present_date = '20221109' #监测当日
# next_trade_date = '20221110' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221109'#监测当日前一个交易日
# present_date = '20221110' #监测当日
# next_trade_date = '20221111' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221110'#监测当日前一个交易日
# present_date = '20221111' #监测当日
# next_trade_date = '20221112' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221111'#监测当日前一个交易日
# present_date = '20221114' #监测当日
# next_trade_date = '20221115' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221114'#监测当日前一个交易日
# present_date = '20221115' #监测当日
# next_trade_date = '20221116' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221115'#监测当日前一个交易日
# present_date = '20221116' #监测当日
# next_trade_date = '20221117' #监测当日下一个自然日
# ###############################################################

# %%
# ###############################################################
# before_trade_date = '20221116'#监测当日前一个交易日
# present_date = '20221117' #监测当日
# next_trade_date = '20221118' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221117'#监测当日前一个交易日
# present_date = '20221118' #监测当日
# next_trade_date = '20221119' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221118'#监测当日前一个交易日
# present_date = '20221121' #监测当日
# next_trade_date = '20221122' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221121'#监测当日前一个交易日
# present_date = '20221122' #监测当日
# next_trade_date = '20221123' #监测当日下一个自然日
# ###############################################################

# ###############################################################
before_trade_date = '20221122'#监测当日前一个交易日
present_date = '20221123' #监测当日
next_trade_date = '20221124' #监测当日下一个自然日
# ###############################################################

# %%
start_date = pd.to_datetime(before_trade_date) 
end_date = pd.to_datetime(next_trade_date)

cbond_price = pd.DataFrame([])
for code in cbond_list:
    price_df = w.wsi(code, "close", start_date, end_date,usedf=True)[1]   #只要了收盘价
    price_df.columns = [code]
    cbond_price = pd.concat([cbond_price,price_df],axis=1)
cbond_price = cbond_price.ffill()    
# cbond_rtn = cbond_price[cbond_price.index.time!=time(15,0,0)]
# cbond_price = cbond_price.loc['2022-09-09 15:00:00':] #从前一个交易日的收盘价开始截取
cbond_price_begin_time = before_trade_date[:4]+'-' + \
                    before_trade_date[4:6]+'-' + \
                    before_trade_date[6:8]+' 15:00:00'
cbond_price = cbond_price.loc[cbond_price_begin_time:]
cbond_price
# Out:
#                      123046.SZ  300587.SZ  113642.SH  603185.SH  110061.SH  \
# 2022-11-22 15:00:00    351.104      12.18        NaN     121.05    133.578
# 2022-11-23 09:30:00    349.989      12.12        NaN     120.88    133.670
# 2022-11-23 09:31:00    349.967      12.15        NaN     121.00    133.729
# 2022-11-23 09:32:00    353.250      12.22        NaN     121.76    133.870
# 2022-11-23 09:33:00    352.100      12.22        NaN     122.00    133.724
# ...                        ...        ...        ...        ...        ...
# 2022-11-23 14:56:00    349.058      12.05        NaN     124.69    134.241
# 2022-11-23 14:57:00    349.057      12.05        NaN     124.65    134.240
# 2022-11-23 14:58:00    349.057      12.05        NaN     124.65    134.239
# 2022-11-23 14:59:00    349.057      12.05        NaN     124.65    134.220
# 2022-11-23 15:00:00    349.873      12.05        NaN     124.69    134.221
#
#                      600674.SH  128081.SZ  002203.SZ  113016.SH  601127.SH  \
# 2022-11-22 15:00:00      11.67    126.300      12.14    323.144      48.40
# 2022-11-23 09:30:00      11.66    126.349      12.06    322.527      48.01
# 2022-11-23 09:31:00      11.68    126.019      12.10    323.043      48.31
# 2022-11-23 09:32:00      11.70    126.204      12.15    325.449      48.49
# 2022-11-23 09:33:00      11.67    126.325      12.11    325.316      48.56
# ...                        ...        ...        ...        ...        ...
# 2022-11-23 14:56:00      11.67    126.523      12.10    323.800      47.20
# 2022-11-23 14:57:00      11.67    126.523      12.12    323.890      47.20
# 2022-11-23 14:58:00      11.67    126.523      12.12    323.806      47.20
# 2022-11-23 14:59:00      11.67    126.523      12.12    323.990      47.20
# 2022-11-23 15:00:00      11.68    126.600      12.13    323.945      47.20
#
#                      ...  113626.SH  603596.SH  123092.SZ  300332.SZ  \
# 2022-11-22 15:00:00  ...    229.869      82.90    260.550      12.85
# 2022-11-23 09:30:00  ...    225.428      81.00    260.753      12.92
# 2022-11-23 09:31:00  ...    225.200      81.26    259.601      12.90
# 2022-11-23 09:32:00  ...    226.900      81.50    261.626      12.95
# 2022-11-23 09:33:00  ...    227.232      81.86    261.054      12.95
# ...                  ...        ...        ...        ...        ...
# 2022-11-23 14:56:00  ...    225.081      81.19    267.499      13.20
# 2022-11-23 14:57:00  ...    225.294      81.19    267.383      13.20
# 2022-11-23 14:58:00  ...    225.229      81.19    267.383      13.20
# 2022-11-23 14:59:00  ...    225.165      81.19    267.383      13.20
# 2022-11-23 15:00:00  ...    225.190      81.10    267.500      13.20
#
#                      123057.SZ  300586.SZ  123067.SZ  300382.SZ  128106.SZ  \
# 2022-11-22 15:00:00    228.001      21.26    229.890      22.64    192.428
# 2022-11-23 09:30:00    224.815      20.79    227.034      22.25    191.382
# 2022-11-23 09:31:00    223.064      20.57    225.762      22.23    190.200
# 2022-11-23 09:32:00    226.035      20.80    227.415      22.31    190.279
# 2022-11-23 09:33:00    224.404      20.58    227.232      22.30    189.944
# ...                        ...        ...        ...        ...        ...
# 2022-11-23 14:56:00    233.573      20.58    235.720      22.63    190.699
# 2022-11-23 14:57:00    233.573      20.59    235.775      22.64    190.700
# 2022-11-23 14:58:00    233.573      20.59    235.775      22.64    190.700
# 2022-11-23 14:59:00    233.573      20.59    235.775      22.64    190.700
# 2022-11-23 15:00:00    234.040      20.57    236.000      22.61    190.699
#
#                      002840.SZ
# 2022-11-22 15:00:00      16.67
# 2022-11-23 09:30:00      16.54
# 2022-11-23 09:31:00      16.58
# 2022-11-23 09:32:00      16.45
# 2022-11-23 09:33:00      16.45
# ...                        ...
# 2022-11-23 14:56:00      16.44
# 2022-11-23 14:57:00      16.43
# 2022-11-23 14:58:00      16.43
# 2022-11-23 14:59:00      16.43
# 2022-11-23 15:00:00      16.45
#
# [243 rows x 38 columns]

# %%
# assert False

# %% [markdown]
# # stock pre status

# %%
df_stk_pre_return = w.wss("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return
# Out:
#             PCT_CHG
# 300587.SZ -1.535974
# 603185.SH -2.771084
# 600674.SH  2.910053
# 002203.SZ  0.496689
# 601127.SH -3.853794
# 002597.SZ -0.833333
# 603348.SH -2.360451
# 300487.SZ -1.687259
# 603876.SH -0.404341
# 601677.SH -0.862069
# 300655.SZ -2.292264
# 002078.SZ  0.374532
# 002738.SZ -1.195320
# 002812.SZ -9.997432
# 603596.SH  5.203046
# 300332.SZ -1.229823
# 300586.SZ -0.885781
# 300382.SZ -2.033752
# 002840.SZ -1.709906

# %%
df_bond_pre_return = w.wss("123046.SZ,113642.SH,110061.SH,128081.SZ,113016.SH,128017.SZ,113537.SH,123027.SZ,113534.SH,113025.SH,123031.SZ,128029.SZ,128111.SZ,128095.SZ,113626.SH,123092.SZ,123057.SZ,123067.SZ,128106.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_bond_pre_return
# Out:
#              PCT_CHG
# 123046.SZ  -1.568825
# 113642.SH        NaN
# 110061.SH   2.485844
# 128081.SZ   0.103036
# 113016.SH  -4.109296
# 128017.SZ  -0.773179
# 113537.SH  -2.551546
# 123027.SZ        NaN
# 113534.SH  -3.363507
# 113025.SH  -2.048172
# 123031.SZ  -0.733491
# 128029.SZ   0.079662
# 128111.SZ  -1.225674
# 128095.SZ -20.000000
# 113626.SH   4.524868
# 123092.SZ  -1.229747
# 123057.SZ  -1.127060
# 123067.SZ  -3.116505
# 128106.SZ  -0.243135

# %%
before_trade_date_trade_status = before_trade_date[:4] +'-'+ before_trade_date[4:6] +'-'+ before_trade_date[6:]
# present_date_trade_status = present_date[:4] +'-'+ present_date[4:6] +'-'+ present_date[6:]
df_stk_pre_trade_status = w.wsd("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ", 
"trade_status", f"{before_trade_date_trade_status}", f"{before_trade_date_trade_status}", "",usedf=True)[1]
df_stk_pre_trade_status
# Out:
#           TRADE_STATUS
# 300587.SZ           交易
# 603185.SH           交易
# 600674.SH           交易
# 002203.SZ           交易
# 601127.SH           交易
# 002597.SZ           交易
# 603348.SH           交易
# 300487.SZ           交易
# 603876.SH           交易
# 601677.SH           交易
# 300655.SZ           交易
# 002078.SZ           交易
# 002738.SZ           交易
# 002812.SZ           交易
# 603596.SH           交易
# 300332.SZ           交易
# 300586.SZ           交易
# 300382.SZ           交易
# 002840.SZ           交易

# %%
# assert False

# %% [markdown]
# # bond-stock pair

# %%
# cbond_pair = ['113642.SH','603185.SH']  #后面筛选的结果，这组也在里面 转债停止交易了
# open_threshold = 0.023
# close_threshold = 0
# convert_price = 102.4
# operate = True

# cbond_pair = ['123027.SZ','300487.SZ',] # 1019 1020 1021 这几天转债停止交易了
# open_threshold = 0.022
# close_threshold = 0
# convert_price = 19.07
# operate = True

# %%
cbond_pair = ['123046.SZ','300587.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.015
close_threshold = 0
convert_price = 3.94
operate = True

cbond_pair = ['110061.SH','600674.SH']
open_threshold = 0.006
close_threshold = 0
convert_price = 8.8
operate = True

cbond_pair = ['128081.SZ','002203.SZ']
open_threshold = 0.012
close_threshold = 0.002
convert_price = 9.62
operate = True

cbond_pair = ['113016.SH','601127.SH'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.017
close_threshold = 0.003
convert_price = 20.17
operate = True

cbond_pair = ['128017.SZ','002597.SZ']
open_threshold = 0.012
close_threshold = 0
convert_price = 21.33
operate = True

# # # # # $$$$$$$$$$$$$$$$$$$$$$$$以下是新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['113537.SH','603348.SH',]
open_threshold = 0.027
close_threshold = 0.002
convert_price = 19.13
operate = True

cbond_pair = ['113534.SH','603876.SH',]
open_threshold = 0.019
close_threshold = 0.002
convert_price = 14.98
operate = True

cbond_pair = ['113025.SH','601677.SH',]
open_threshold = 0.018
close_threshold = 0
convert_price = 7.66
operate = True

cbond_pair = ['123031.SZ','300655.SZ',]   #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.019
close_threshold = 0
convert_price = 6.25
operate = True

cbond_pair = ['128029.SZ','002078.SZ']
open_threshold = 0.013
close_threshold = 0.002
convert_price = 8.25
operate = True

# # # # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-10-14】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['128111.SZ','002738.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.011
close_threshold = 0.001
convert_price = 10.96
operate = True

cbond_pair = ['128095.SZ','002812.SZ']
open_threshold = 0.013
close_threshold = 0
convert_price = 64.62
operate = False

cbond_pair = ['113626.SH','603596.SH']
open_threshold = 0.02
close_threshold = 0
convert_price = 35.88
operate = True

cbond_pair = ['123092.SZ','300332.SZ']
open_threshold = 0.025
close_threshold = 0.001
convert_price = 5.14
operate = True

# # # # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-11-18】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair =  ['123057.SZ','300586.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.009 
close_threshold = 0.003
convert_price = 9.5
operate = True

cbond_pair =  ['123067.SZ','300382.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.004
close_threshold = 0.002
convert_price = 9.96
operate = True

cbond_pair =  ['128106.SZ','002840.SZ']
open_threshold = 0.01
close_threshold = 0
convert_price = 8.85
operate = True

# %%
# df_signal

# %% [markdown]
# # clip price series

# %%
#从前一个交易日的收盘价开始截取
# cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]].loc['2022-09-08 15:00:00':]
cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]]

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-22 15:00:00    192.428      16.67
# 2022-11-23 09:30:00    191.382      16.54
# 2022-11-23 09:31:00    190.200      16.58
# 2022-11-23 09:32:00    190.279      16.45
# 2022-11-23 09:33:00    189.944      16.45

# %%
cbond_return = pd.DataFrame([])

cbond_preclose = cbond_pair_price.iloc[0,0] # 初始时刻的bond前收盘价
stock_preclose = cbond_pair_price.iloc[0,1] # 初始时刻的stock前收盘价

for index,row in cbond_pair_price.iterrows():
    
    cbond_return.loc[index,cbond_pair[0]] = row[cbond_pair[0]]/cbond_preclose - 1 # 算日内的return
    cbond_return.loc[index,cbond_pair[1]] = row[cbond_pair[1]]/stock_preclose - 1

    if index.time()==time(15,0,0):  #算完日内return，迭代到今日价格的最后一个time bar的时候，将其设为前收盘价
        cbond_preclose = row[cbond_pair[0]]    # 日内return指标用 现价/昨日收盘价 计算
        stock_preclose = row[cbond_pair[1]]
        
# 检查df是否有空值
cbond_return.isnull().sum(axis=0)  # 按列统计
cbond_return.isnull().sum(axis=1) # 按行统计
cbond_return.isnull().sum(axis=1).sum() # 统计整张表
# Out:
# 0

# %%
pd.set_option('display.max_rows', None)
cbond_return['diff'] = cbond_return[cbond_pair[0]] - cbond_return[cbond_pair[1]]
cbond_return.head()
# Out:
#                      128106.SZ  002840.SZ      diff
# 2022-11-22 15:00:00   0.000000   0.000000  0.000000
# 2022-11-23 09:30:00  -0.005436  -0.007798  0.002363
# 2022-11-23 09:31:00  -0.011578  -0.005399 -0.006179
# 2022-11-23 09:32:00  -0.011168  -0.013197  0.002030
# 2022-11-23 09:33:00  -0.012909  -0.013197  0.000289

# %% [markdown]
# # signal calculate

# %%
################################################################################################
stk_pre_return = df_stk_pre_return.loc[cbond_pair[1]].values[0]
bond_pre_return = df_bond_pre_return.loc[cbond_pair[0]].values[0]
pre_diff = bond_pre_return - stk_pre_return
stk_pre_trade_status = df_stk_pre_trade_status.loc[cbond_pair[1]].values[0]
print(stk_pre_trade_status)
print('pre diff:',pre_diff)
# if abs(stk_pre_return) > 10 or stk_pre_trade_status!='交易':
if abs(pre_diff) > 5 or stk_pre_trade_status!='交易':
    # 如果前一天股票的跌幅小于-10，则今日不做操作
    intraday_open_times = 1
else:
    intraday_open_times = 0
################################################################################################    
open_close_spread = open_threshold - close_threshold
# intraday_open_times = 0
max_open = 1

pos_open_flag = 0
neg_open_flag = 0
cbond_position = pd.DataFrame([])
cbond_position.index = cbond_return.index
for index,row in cbond_return.iterrows():

    if row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff落在A区间，且无仓位，正开
            pos_open_flag = 1
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==1:
        if intraday_open_times < max_open:
            #diff落在A区间，且有负仓，平仓再正开
            pos_open_flag=1
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            print('reverse open +1')
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff落在A区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在B区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在B区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在B区间，且无仓，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在C区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在C区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在C区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在D区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在D区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在D区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且无仓位，反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==1 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且有正仓，平仓反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在E区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    if abs(row['diff'])>2 * open_close_spread and cbond_return.columns[0]!='123057.SZ' and cbond_return.columns[0]!='123067.SZ': 
        #盘中diff超过2倍spread时平仓（价格止损信号）,有两个spread特别小的对子则不用此逻辑进行止损
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if index.time()==time(15,0,0): # 每日收盘时必须平仓（时间止损信号）
    # if index.time()==time(14,59,0): # 每日收盘时必须平仓（时间止损信号）
        intraday_open_times = 0 # 下一天开盘前，把当日记录下来的开仓次数清零
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
# Out:
# 交易
# pre diff: 1.4667707230792195

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-22 15:00:00    192.428      16.67
# 2022-11-23 09:30:00    191.382      16.54
# 2022-11-23 09:31:00    190.200      16.58
# 2022-11-23 09:32:00    190.279      16.45
# 2022-11-23 09:33:00    189.944      16.45

# %%
df_signal = pd.concat([cbond_pair_price,cbond_return,cbond_position],axis=1)
df_signal.columns = ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
print('open threshold',open_threshold,'close threshold',close_threshold)
# df_signal.to_csv('tmp_signal.csv')
# df_signal
# Out:
# open threshold 0.01 close threshold 0

# %% [markdown]
# # backtest

# %%
# 用来记录交易流水的表格,一边遍历df_signal，一边填入内容到流水表格里

import numpy as np
cols = ['balance','signal','bond price','stock price','bond hold','stock hold','commission','tax','reverse open','diff','asset value']
df_trade = pd.DataFrame(
    data = [[0,np.nan,np.nan,np.nan,0,0,0,0,np.nan,np.nan,0]],
    columns=cols
    ) 

balance_last = 0 # 现金账户初始余额

bond_hold = 0 # 债券持有数量
stock_hold = 0 # 股票持有数量


commission_rate = 2/10000 + 0 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 0.5/1000 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 1/1000 # 佣金买卖万二 + 交易滑点

tax_rate = 1/1000 # 卖股票才收印花税千一

# commission_rate = 0/10000 # 佣金买卖万二
# tax_rate = 0/1000 #

for i in range(len(df_signal)-1):
    if df_signal.index[i].time() == time(15,0,0):
    # if df_signal.index[i].time() == time(14,59,0):
        # 修改stock volume 每天固定一个stock volume 应该用债的前收盘价/股票的前收盘价
        stock_volume = df_signal['bond_price'][i]/df_signal['stock_price'][i]

    if df_signal.values[i][-1] != df_signal.values[i+1][-1]:

        index = df_signal.index[i+1]        
        diff = df_signal.values[i+1][-3] #diff在df_signal中的倒数第三列
        
    # df_signal的columns
    # ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
        signal = str(int(df_signal.values[i+1][-2]))+str(int(df_signal.values[i+1][-1]))
        
        bond_price = df_signal.values[i+1][0] 

        stock_price = df_signal.values[i+1][1]

        # stock_volume =  bond_price/stock_price # 修改stock volume 每天固定一个stock volume应该用债的前收盘价/股票的前收盘价

        commission = (bond_price + stock_price * stock_volume) * commission_rate

        reverse_open = False #表明这笔交易，是否包含平仓后再反向开仓的操作

        if signal == '00' and stock_hold == stock_volume: #有股票持仓并且需要卖出平仓时，有印花税
            tax = stock_price * tax_rate * stock_volume
        else:
            tax = 0

        if signal == '00':
            balance_last += bond_hold*bond_price
            balance_last += stock_hold*stock_price
            
            bond_hold = 0
            stock_hold = 0
            

        if signal == '1-1':
            '''
            加一个检测之前持仓的模块,如果之前因为-11的信号有持仓,需要先平掉(即买债卖股票),同时再反向开仓
            '''
            reverse_flag = False
            if bond_hold == -1 and stock_hold == 1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last -= bond_price 
                balance_last += stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税
                reverse_flag = True
                reverse_open = True

            bond_hold += 1
            stock_hold += (-1 * stock_volume)
            # stock_hold += stock_volume
            balance_last -= bond_price
            balance_last += stock_price * stock_volume
            
            if reverse_flag:
                tax *= 2 #平仓然后反向开仓的时候 已经计算过tax了，直接double
            else:
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税

        if signal == '-11':
            '''
            加一个检测之前持仓的模块,如果之前因为1-1的信号有持仓,需要先平掉(卖债买股票),同时再反向开仓
            '''
            if bond_hold == 1 and stock_hold == -1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last += bond_price
                balance_last -= stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                                # 买股票无印花税
                reverse_open = True
            bond_hold += -1
            stock_hold += (1 * stock_volume)
            # stock_hold += stock_volume
            balance_last += bond_price
            balance_last -= stock_price * stock_volume
        
        balance_last = balance_last - commission - tax
        balance = balance_last
        asset_value = bond_price*bond_hold + stock_price*stock_hold
        line = [balance,signal,bond_price,stock_price,bond_hold,stock_hold,commission,tax,reverse_open,diff,asset_value]
        # df_trade.loc[index,['balance','asset','signal','bond price','stock price','commission','tax']] = line
        # df_trade.loc[index,cols] = [0,0,np.nan,np.nan,np.nan,0,0,0,0]
        df_trade.loc[index,cols] = line

df_trade.rename(columns={'balance':'cash'},inplace=True)       
df_trade['net value'] = df_trade['cash'] + df_trade['asset value']

# %%
df_trade['operate'] = [operate]*len(df_trade)

# %%
df_trade
# Out:
#                          cash signal  bond price  stock price  bond hold  \
# 0                    0.000000    NaN         NaN          NaN        0.0
# 2022-11-23 10:59:00  1.915705    -11     189.109        16.21       -1.0
# 2022-11-23 15:00:00  0.839158     00     190.699        16.45        0.0
#
#                      stock hold  commission       tax reverse open      diff  \
# 0                      0.000000    0.000000  0.000000          NaN       NaN
# 2022-11-23 10:59:00   11.543371    0.075245  0.000000        False  0.010346
# 2022-11-23 15:00:00    0.000000    0.076117  0.189888        False  0.004212
#
#                      asset value  net value  operate
# 0                       0.000000   0.000000     True
# 2022-11-23 10:59:00    -1.990951  -0.075245     True
# 2022-11-23 15:00:00     0.000000   0.839158     True

# %% [markdown]
# # output to csv

# %%
excel_file_name = './daily_track/'+ present_date+'/' + cbond_pair[0] + '@' + cbond_pair[1] + '.csv'

excel_file_name

df_to_excel = df_trade
df_to_excel['open/close'] = [str(open_threshold)+','+str(close_threshold)]*len(df_to_excel)
df_to_excel['pair'] = [cbond_pair[0] + '@' + cbond_pair[1]]*len(df_to_excel)
df_to_excel = df_to_excel[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_to_excel.to_csv(excel_file_name,)

# %%
present_date
# Out:
# '20221123'

# %% [markdown]
# # conclusion

# %%
import os
single_trade_files = os.listdir('./daily_track'+'/'+present_date)

df_trade_conclusion = pd.DataFrame([])
for file in single_trade_files:
    if file == 'diff':
        continue
    if file == '.DS_Store' or file.split('.')[1] == 'xlsx':
        continue
    tmp_path = './daily_track'+'/'+present_date+'/'+file
    df_tmp = pd.read_csv(tmp_path,index_col=0)
    tmp_col = list(df_tmp.columns)
    df_tmp_head = pd.DataFrame(data=[tmp_col],columns=tmp_col)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp_head)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp)
df_trade_conclusion.columns
df_trade_conclusion = df_trade_conclusion[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_trade_conclusion
tmp_path = './daily_track'+'/'+present_date+'/'+f'{present_date}_conclusion.csv'

df_trade_conclusion.to_csv(tmp_path)

# %% [markdown]
# # intraday signal

# %%
import matplotlib.pyplot as plt

signal_plot_begin_time = present_date[:4]+'-' + \
                         present_date[4:6]+'-' + \
                         present_date[6:8]+' 09:30:00'
df_signal['diff'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' diff',grid=True)

#如果当日有开平仓记录，在图上画出开平仓时刻的标注
if len(df_trade) == 3:
    open_tick = df_trade.index.to_list()[1]
    open_diff = df_trade['diff'].to_list()[1]
    close_tick = df_trade.index.to_list()[2]
    close_diff =  df_trade['diff'].to_list()[2]
    plt.text(open_tick,open_diff,'open')
    plt.text(close_tick,close_diff,'close')
    plt.scatter([open_tick],[open_diff],color='r')

    tmp_nv = df_trade['net value'].to_list()[2]
    if tmp_nv > 0: 
        close_color = 'g' #当天赚钱的话，平仓点位标记为绿色
    else:
        close_color = 'orange' #当天亏钱的话，平仓点位标记为橙色
    plt.scatter([close_tick],[close_diff],color=close_color)
fig_file_name = './daily_track/'+ present_date+'/'+'diff/' + cbond_pair[0] + '@' + cbond_pair[1] + '.png'
plt.savefig(fig_file_name)

plt.show()
df_signal['bond_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+' rtn',grid=True)
plt.show()
df_signal['stock_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[1]+' rtn',grid=True)
plt.show()

# %%
df_tmp = 100/convert_price*df_signal['stock_price']
df_signal['premium rate'] = (df_signal['bond_price'] - df_tmp)/df_tmp
df_signal['premium rate'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' premium rate',grid=True)
# Out:
# <AxesSubplot:title={'center':'128106.SZ@002840.SZ premium rate'}>

# %%
df_signal
# Out:
#                      bond_price  stock_price  bond_rtn  stock_rtn      diff  \
# 2022-11-22 15:00:00     192.428        16.67  0.000000   0.000000  0.000000
# 2022-11-23 09:30:00     191.382        16.54 -0.005436  -0.007798  0.002363
# 2022-11-23 09:31:00     190.200        16.58 -0.011578  -0.005399 -0.006179
# 2022-11-23 09:32:00     190.279        16.45 -0.011168  -0.013197  0.002030
# 2022-11-23 09:33:00     189.944        16.45 -0.012909  -0.013197  0.000289
# 2022-11-23 09:34:00     190.852        16.50 -0.008190  -0.010198  0.002008
# 2022-11-23 09:35:00     189.383        16.33 -0.015824  -0.020396  0.004572
# 2022-11-23 09:36:00     188.934        16.29 -0.018157  -0.022795  0.004638
# 2022-11-23 09:37:00     189.512        16.40 -0.015154  -0.016197  0.001043
# 2022-11-23 09:38:00     190.125        16.38 -0.011968  -0.017397  0.005428
# 2022-11-23 09:39:00     189.585        16.43 -0.014774  -0.014397 -0.000377
# 2022-11-23 09:40:00     190.491        16.51 -0.010066  -0.009598 -0.000468
# 2022-11-23 09:41:00     189.743        16.44 -0.013953  -0.013797 -0.000156
# 2022-11-23 09:42:00     189.272        16.38 -0.016401  -0.017397  0.000996
# 2022-11-23 09:43:00     189.053        16.36 -0.017539  -0.018596  0.001057
# 2022-11-23 09:44:00     189.577        16.35 -0.014816  -0.019196  0.004380
# 2022-11-23 09:45:00     189.281        16.35 -0.016354  -0.019196  0.002842
# 2022-11-23 09:46:00     188.506        16.31 -0.020382  -0.021596  0.001214
# 2022-11-23 09:47:00     188.629        16.30 -0.019742  -0.022196  0.002453
# 2022-11-23 09:48:00     187.714        16.28 -0.024497  -0.023395 -0.001102
# 2022-11-23 09:49:00     188.345        16.30 -0.021218  -0.022196  0.000977
# 2022-11-23 09:50:00     188.186        16.28 -0.022045  -0.023395  0.001351
# 2022-11-23 09:51:00     188.543        16.26 -0.020189  -0.024595  0.004406
# 2022-11-23 09:52:00     188.236        16.26 -0.021785  -0.024595  0.002810
# 2022-11-23 09:53:00     188.306        16.24 -0.021421  -0.025795  0.004374
# 2022-11-23 09:54:00     188.460        16.29 -0.020621  -0.022795  0.002175
# 2022-11-23 09:55:00     188.988        16.35 -0.017877  -0.019196  0.001319
# 2022-11-23 09:56:00     188.703        16.33 -0.019358  -0.020396  0.001038
# 2022-11-23 09:57:00     188.990        16.36 -0.017866  -0.018596  0.000730
# 2022-11-23 09:58:00     188.606        16.32 -0.019862  -0.020996  0.001134
# 2022-11-23 09:59:00     188.050        16.27 -0.022751  -0.023995  0.001244
# 2022-11-23 10:00:00     187.801        16.23 -0.024045  -0.026395  0.002349
# 2022-11-23 10:01:00     187.500        16.18 -0.025610  -0.029394  0.003785
# 2022-11-23 10:02:00     187.615        16.19 -0.025012  -0.028794  0.003782
# 2022-11-23 10:03:00     187.590        16.15 -0.025142  -0.031194  0.006052
# 2022-11-23 10:04:00     187.487        16.14 -0.025677  -0.031794  0.006117
# 2022-11-23 10:05:00     187.300        16.14 -0.026649  -0.031794  0.005145
# 2022-11-23 10:06:00     188.232        16.24 -0.021806  -0.025795  0.003989
# 2022-11-23 10:07:00     188.123        16.18 -0.022372  -0.029394  0.007022
# 2022-11-23 10:08:00     187.832        16.24 -0.023884  -0.025795  0.001911
# 2022-11-23 10:09:00     188.170        16.25 -0.022128  -0.025195  0.003067
# 2022-11-23 10:10:00     187.880        16.24 -0.023635  -0.025795  0.002160
# 2022-11-23 10:11:00     188.048        16.27 -0.022762  -0.023995  0.001233
# 2022-11-23 10:12:00     188.290        16.28 -0.021504  -0.023395  0.001891
# 2022-11-23 10:13:00     188.800        16.32 -0.018854  -0.020996  0.002142
# 2022-11-23 10:14:00     188.389        16.31 -0.020990  -0.021596  0.000606
# 2022-11-23 10:15:00     188.368        16.27 -0.021099  -0.023995  0.002896
# 2022-11-23 10:16:00     188.302        16.23 -0.021442  -0.026395  0.004953
# 2022-11-23 10:17:00     188.487        16.23 -0.020480  -0.026395  0.005914
# 2022-11-23 10:18:00     188.115        16.22 -0.022414  -0.026995  0.004581
# 2022-11-23 10:19:00     188.033        16.22 -0.022840  -0.026995  0.004155
# 2022-11-23 10:20:00     188.172        16.25 -0.022117  -0.025195  0.003078
# 2022-11-23 10:21:00     188.150        16.29 -0.022232  -0.022795  0.000564
# 2022-11-23 10:22:00     188.400        16.27 -0.020933  -0.023995  0.003063
# 2022-11-23 10:23:00     188.437        16.26 -0.020740  -0.024595  0.003855
# 2022-11-23 10:24:00     188.506        16.29 -0.020382  -0.022795  0.002414
# 2022-11-23 10:25:00     188.497        16.31 -0.020428  -0.021596  0.001167
# 2022-11-23 10:26:00     188.588        16.29 -0.019956  -0.022795  0.002840
# 2022-11-23 10:27:00     188.499        16.29 -0.020418  -0.022795  0.002377
# 2022-11-23 10:28:00     188.579        16.30 -0.020002  -0.022196  0.002193
# 2022-11-23 10:29:00     188.432        16.28 -0.020766  -0.023395  0.002629
# 2022-11-23 10:30:00     188.655        16.29 -0.019607  -0.022795  0.003188
# 2022-11-23 10:31:00     188.434        16.25 -0.020756  -0.025195  0.004439
# 2022-11-23 10:32:00     188.307        16.22 -0.021416  -0.026995  0.005579
# 2022-11-23 10:33:00     187.758        16.21 -0.024269  -0.027594  0.003326
# 2022-11-23 10:34:00     188.009        16.20 -0.022964  -0.028194  0.005230
# 2022-11-23 10:35:00     187.602        16.17 -0.025080  -0.029994  0.004914
# 2022-11-23 10:36:00     187.698        16.16 -0.024581  -0.030594  0.006013
# 2022-11-23 10:37:00     187.336        16.17 -0.026462  -0.029994  0.003532
# 2022-11-23 10:38:00     187.455        16.15 -0.025843  -0.031194  0.005350
# 2022-11-23 10:39:00     187.713        16.11 -0.024503  -0.033593  0.009091
# 2022-11-23 10:40:00     187.675        16.16 -0.024700  -0.030594  0.005894
# 2022-11-23 10:41:00     187.933        16.16 -0.023359  -0.030594  0.007234
# 2022-11-23 10:42:00     187.754        16.17 -0.024290  -0.029994  0.005704
# 2022-11-23 10:43:00     187.698        16.18 -0.024581  -0.029394  0.004813
# 2022-11-23 10:44:00     187.650        16.17 -0.024830  -0.029994  0.005164
# 2022-11-23 10:45:00     187.723        16.17 -0.024451  -0.029994  0.005543
# 2022-11-23 10:46:00     187.755        16.17 -0.024284  -0.029994  0.005710
# 2022-11-23 10:47:00     187.757        16.17 -0.024274  -0.029994  0.005720
# 2022-11-23 10:48:00     187.831        16.19 -0.023889  -0.028794  0.004905
# 2022-11-23 10:49:00     188.068        16.19 -0.022658  -0.028794  0.006136
# 2022-11-23 10:50:00     188.068        16.22 -0.022658  -0.026995  0.004337
# 2022-11-23 10:51:00     188.264        16.24 -0.021639  -0.025795  0.004156
# 2022-11-23 10:52:00     188.200        16.23 -0.021972  -0.026395  0.004423
# 2022-11-23 10:53:00     188.123        16.20 -0.022372  -0.028194  0.005822
# 2022-11-23 10:54:00     187.811        16.17 -0.023993  -0.029994  0.006001
# 2022-11-23 10:55:00     187.922        16.18 -0.023417  -0.029394  0.005978
# 2022-11-23 10:56:00     188.405        16.22 -0.020907  -0.026995  0.006088
# 2022-11-23 10:57:00     188.958        16.24 -0.018033  -0.025795  0.007762
# 2022-11-23 10:58:00     188.860        16.22 -0.018542  -0.026995  0.008453
# 2022-11-23 10:59:00     189.109        16.21 -0.017248  -0.027594  0.010346
# 2022-11-23 11:00:00     188.817        16.22 -0.018765  -0.026995  0.008229
# 2022-11-23 11:01:00     188.499        16.20 -0.020418  -0.028194  0.007776
# 2022-11-23 11:02:00     188.660        16.18 -0.019581  -0.029394  0.009813
# 2022-11-23 11:03:00     188.534        16.22 -0.020236  -0.026995  0.006758
# 2022-11-23 11:04:00     188.353        16.18 -0.021177  -0.029394  0.008217
# 2022-11-23 11:05:00     188.205        16.17 -0.021946  -0.029994  0.008048
# 2022-11-23 11:06:00     188.420        16.18 -0.020829  -0.029394  0.008566
# 2022-11-23 11:07:00     188.122        16.18 -0.022377  -0.029394  0.007017
# 2022-11-23 11:08:00     188.124        16.19 -0.022367  -0.028794  0.006427
# 2022-11-23 11:09:00     188.346        16.18 -0.021213  -0.029394  0.008181
# 2022-11-23 11:10:00     188.550        16.23 -0.020153  -0.026395  0.006242
# 2022-11-23 11:11:00     188.616        16.21 -0.019810  -0.027594  0.007784
# 2022-11-23 11:12:00     188.629        16.24 -0.019742  -0.025795  0.006052
# 2022-11-23 11:13:00     188.696        16.22 -0.019394  -0.026995  0.007600
# 2022-11-23 11:14:00     188.461        16.19 -0.020616  -0.028794  0.008179
# 2022-11-23 11:15:00     188.263        16.21 -0.021644  -0.027594  0.005950
# 2022-11-23 11:16:00     188.561        16.17 -0.020096  -0.029994  0.009898
# 2022-11-23 11:17:00     188.240        16.17 -0.021764  -0.029994  0.008230
# 2022-11-23 11:18:00     188.012        16.16 -0.022949  -0.030594  0.007645
# 2022-11-23 11:19:00     188.096        16.22 -0.022512  -0.026995  0.004482
# 2022-11-23 11:20:00     188.308        16.21 -0.021411  -0.027594  0.006184
# 2022-11-23 11:21:00     188.200        16.20 -0.021972  -0.028194  0.006223
# 2022-11-23 11:22:00     188.087        16.19 -0.022559  -0.028794  0.006235
# 2022-11-23 11:23:00     188.040        16.21 -0.022803  -0.027594  0.004791
# 2022-11-23 11:24:00     188.205        16.21 -0.021946  -0.027594  0.005649
# 2022-11-23 11:25:00     188.200        16.21 -0.021972  -0.027594  0.005623
# 2022-11-23 11:26:00     188.108        16.20 -0.022450  -0.028194  0.005744
# 2022-11-23 11:27:00     188.352        16.23 -0.021182  -0.026395  0.005213
# 2022-11-23 11:28:00     188.335        16.20 -0.021270  -0.028194  0.006924
# 2022-11-23 11:29:00     188.220        16.22 -0.021868  -0.026995  0.005127
# 2022-11-23 11:30:00     188.164        16.22 -0.022159  -0.026995  0.004836
# 2022-11-23 13:00:00     188.291        16.18 -0.021499  -0.029394  0.007895
# 2022-11-23 13:01:00     188.697        16.23 -0.019389  -0.026395  0.007006
# 2022-11-23 13:02:00     188.880        16.24 -0.018438  -0.025795  0.007357
# 2022-11-23 13:03:00     189.154        16.28 -0.017014  -0.023395  0.006381
# 2022-11-23 13:04:00     188.700        16.22 -0.019373  -0.026995  0.007621
# 2022-11-23 13:05:00     188.789        16.19 -0.018911  -0.028794  0.009883
# 2022-11-23 13:06:00     188.484        16.18 -0.020496  -0.029394  0.008898
# 2022-11-23 13:07:00     188.243        16.19 -0.021748  -0.028794  0.007046
# 2022-11-23 13:08:00     188.150        16.17 -0.022232  -0.029994  0.007762
# 2022-11-23 13:09:00     188.238        16.17 -0.021774  -0.029994  0.008220
# 2022-11-23 13:10:00     188.335        16.18 -0.021270  -0.029394  0.008124
# 2022-11-23 13:11:00     188.218        16.17 -0.021878  -0.029994  0.008116
# 2022-11-23 13:12:00     187.926        16.16 -0.023396  -0.030594  0.007198
# 2022-11-23 13:13:00     188.090        16.15 -0.022543  -0.031194  0.008650
# 2022-11-23 13:14:00     188.479        16.17 -0.020522  -0.029994  0.009472
# 2022-11-23 13:15:00     188.549        16.21 -0.020158  -0.027594  0.007436
# 2022-11-23 13:16:00     188.700        16.19 -0.019373  -0.028794  0.009421
# 2022-11-23 13:17:00     188.460        16.17 -0.020621  -0.029994  0.009373
# 2022-11-23 13:18:00     188.309        16.18 -0.021405  -0.029394  0.007989
# 2022-11-23 13:19:00     188.420        16.17 -0.020829  -0.029994  0.009165
# 2022-11-23 13:20:00     188.966        16.18 -0.017991  -0.029394  0.011403
# 2022-11-23 13:21:00     188.773        16.20 -0.018994  -0.028194  0.009200
# 2022-11-23 13:22:00     188.707        16.21 -0.019337  -0.027594  0.008257
# 2022-11-23 13:23:00     188.893        16.20 -0.018371  -0.028194  0.009824
# 2022-11-23 13:24:00     189.100        16.24 -0.017295  -0.025795  0.008500
# 2022-11-23 13:25:00     188.908        16.22 -0.018293  -0.026995  0.008702
# 2022-11-23 13:26:00     188.771        16.21 -0.019005  -0.027594  0.008590
# 2022-11-23 13:27:00     188.999        16.22 -0.017820  -0.026995  0.009175
# 2022-11-23 13:28:00     188.998        16.22 -0.017825  -0.026995  0.009170
# 2022-11-23 13:29:00     189.031        16.24 -0.017653  -0.025795  0.008141
# 2022-11-23 13:30:00     189.248        16.28 -0.016526  -0.023395  0.006870
# 2022-11-23 13:31:00     189.099        16.24 -0.017300  -0.025795  0.008495
# 2022-11-23 13:32:00     188.800        16.23 -0.018854  -0.026395  0.007541
# 2022-11-23 13:33:00     188.995        16.24 -0.017840  -0.025795  0.007954
# 2022-11-23 13:34:00     188.728        16.21 -0.019228  -0.027594  0.008367
# 2022-11-23 13:35:00     188.910        16.22 -0.018282  -0.026995  0.008712
# 2022-11-23 13:36:00     189.100        16.22 -0.017295  -0.026995  0.009700
# 2022-11-23 13:37:00     189.004        16.23 -0.017794  -0.026395  0.008601
# 2022-11-23 13:38:00     188.912        16.21 -0.018272  -0.027594  0.009323
# 2022-11-23 13:39:00     188.845        16.21 -0.018620  -0.027594  0.008975
# 2022-11-23 13:40:00     188.995        16.21 -0.017840  -0.027594  0.009754
# 2022-11-23 13:41:00     189.104        16.26 -0.017274  -0.024595  0.007321
# 2022-11-23 13:42:00     189.194        16.29 -0.016806  -0.022795  0.005989
# 2022-11-23 13:43:00     189.322        16.29 -0.016141  -0.022795  0.006654
# 2022-11-23 13:44:00     189.253        16.29 -0.016500  -0.022795  0.006296
# 2022-11-23 13:45:00     189.577        16.32 -0.014816  -0.020996  0.006180
# 2022-11-23 13:46:00     189.509        16.33 -0.015169  -0.020396  0.005227
# 2022-11-23 13:47:00     189.106        16.30 -0.017264  -0.022196  0.004932
# 2022-11-23 13:48:00     189.266        16.28 -0.016432  -0.023395  0.006963
# 2022-11-23 13:49:00     189.194        16.28 -0.016806  -0.023395  0.006589
# 2022-11-23 13:50:00     189.234        16.31 -0.016598  -0.021596  0.004997
# 2022-11-23 13:51:00     189.387        16.30 -0.015803  -0.022196  0.006392
# 2022-11-23 13:52:00     189.188        16.29 -0.016837  -0.022795  0.005958
# 2022-11-23 13:53:00     189.109        16.29 -0.017248  -0.022795  0.005547
# 2022-11-23 13:54:00     189.186        16.29 -0.016848  -0.022795  0.005948
# 2022-11-23 13:55:00     188.888        16.29 -0.018396  -0.022795  0.004399
# 2022-11-23 13:56:00     188.900        16.29 -0.018334  -0.022795  0.004461
# 2022-11-23 13:57:00     188.901        16.28 -0.018329  -0.023395  0.005066
# 2022-11-23 13:58:00     188.965        16.26 -0.017996  -0.024595  0.006599
# 2022-11-23 13:59:00     189.136        16.24 -0.017108  -0.025795  0.008687
# 2022-11-23 14:00:00     189.221        16.26 -0.016666  -0.024595  0.007929
# 2022-11-23 14:01:00     189.194        16.27 -0.016806  -0.023995  0.007189
# 2022-11-23 14:02:00     189.027        16.26 -0.017674  -0.024595  0.006921
# 2022-11-23 14:03:00     188.800        16.24 -0.018854  -0.025795  0.006941
# 2022-11-23 14:04:00     188.831        16.23 -0.018693  -0.026395  0.007702
# 2022-11-23 14:05:00     189.030        16.23 -0.017659  -0.026395  0.008736
# 2022-11-23 14:06:00     189.038        16.24 -0.017617  -0.025795  0.008178
# 2022-11-23 14:07:00     188.863        16.23 -0.018526  -0.026395  0.007868
# 2022-11-23 14:08:00     189.072        16.23 -0.017440  -0.026395  0.008954
# 2022-11-23 14:09:00     189.136        16.26 -0.017108  -0.024595  0.007487
# 2022-11-23 14:10:00     189.244        16.26 -0.016546  -0.024595  0.008049
# 2022-11-23 14:11:00     189.220        16.25 -0.016671  -0.025195  0.008524
# 2022-11-23 14:12:00     189.258        16.28 -0.016474  -0.023395  0.006922
# 2022-11-23 14:13:00     189.234        16.27 -0.016598  -0.023995  0.007397
# 2022-11-23 14:14:00     189.341        16.28 -0.016042  -0.023395  0.007353
# 2022-11-23 14:15:00     189.246        16.29 -0.016536  -0.022795  0.006259
# 2022-11-23 14:16:00     189.251        16.30 -0.016510  -0.022196  0.005685
# 2022-11-23 14:17:00     189.250        16.29 -0.016515  -0.022795  0.006280
# 2022-11-23 14:18:00     189.200        16.30 -0.016775  -0.022196  0.005420
# 2022-11-23 14:19:00     189.729        16.38 -0.014026  -0.017397  0.003370
# 2022-11-23 14:20:00     189.990        16.35 -0.012670  -0.019196  0.006526
# 2022-11-23 14:21:00     190.016        16.35 -0.012535  -0.019196  0.006662
# 2022-11-23 14:22:00     189.830        16.34 -0.013501  -0.019796  0.006295
# 2022-11-23 14:23:00     189.925        16.35 -0.013007  -0.019196  0.006189
# 2022-11-23 14:24:00     190.000        16.34 -0.012618  -0.019796  0.007178
# 2022-11-23 14:25:00     189.919        16.34 -0.013039  -0.019796  0.006757
# 2022-11-23 14:26:00     189.712        16.33 -0.014114  -0.020396  0.006282
# 2022-11-23 14:27:00     189.713        16.33 -0.014109  -0.020396  0.006287
# 2022-11-23 14:28:00     189.538        16.32 -0.015019  -0.020996  0.005977
# 2022-11-23 14:29:00     189.697        16.34 -0.014192  -0.019796  0.005604
# 2022-11-23 14:30:00     189.965        16.32 -0.012800  -0.020996  0.008196
# 2022-11-23 14:31:00     190.199        16.36 -0.011584  -0.018596  0.007013
# 2022-11-23 14:32:00     190.200        16.38 -0.011578  -0.017397  0.005818
# 2022-11-23 14:33:00     190.400        16.37 -0.010539  -0.017996  0.007457
# 2022-11-23 14:34:00     190.882        16.40 -0.008034  -0.016197  0.008163
# 2022-11-23 14:35:00     190.460        16.36 -0.010227  -0.018596  0.008369
# 2022-11-23 14:36:00     190.451        16.38 -0.010274  -0.017397  0.007123
# 2022-11-23 14:37:00     191.199        16.46 -0.006387  -0.012597  0.006211
# 2022-11-23 14:38:00     191.712        16.49 -0.003721  -0.010798  0.007077
# 2022-11-23 14:39:00     191.497        16.45 -0.004838  -0.013197  0.008359
# 2022-11-23 14:40:00     191.070        16.45 -0.007057  -0.013197  0.006140
# 2022-11-23 14:41:00     191.531        16.50 -0.004661  -0.010198  0.005536
# 2022-11-23 14:42:00     191.128        16.47 -0.006756  -0.011998  0.005242
# 2022-11-23 14:43:00     191.580        16.51 -0.004407  -0.009598  0.005191
# 2022-11-23 14:44:00     191.493        16.53 -0.004859  -0.008398  0.003539
# 2022-11-23 14:45:00     191.500        16.49 -0.004823  -0.010798  0.005975
# 2022-11-23 14:46:00     191.000        16.44 -0.007421  -0.013797  0.006376
# 2022-11-23 14:47:00     191.000        16.42 -0.007421  -0.014997  0.007576
# 2022-11-23 14:48:00     190.625        16.40 -0.009370  -0.016197  0.006827
# 2022-11-23 14:49:00     190.739        16.42 -0.008777  -0.014997  0.006220
# 2022-11-23 14:50:00     190.551        16.42 -0.009754  -0.014997  0.005243
# 2022-11-23 14:51:00     190.595        16.43 -0.009526  -0.014397  0.004871
# 2022-11-23 14:52:00     190.870        16.43 -0.008097  -0.014397  0.006301
# 2022-11-23 14:53:00     191.298        16.44 -0.005872  -0.013797  0.007925
# 2022-11-23 14:54:00     191.316        16.43 -0.005779  -0.014397  0.008618
# 2022-11-23 14:55:00     190.891        16.42 -0.007987  -0.014997  0.007010
# 2022-11-23 14:56:00     190.699        16.44 -0.008985  -0.013797  0.004812
# 2022-11-23 14:57:00     190.700        16.43 -0.008980  -0.014397  0.005417
# 2022-11-23 14:58:00     190.700        16.43 -0.008980  -0.014397  0.005417
# 2022-11-23 14:59:00     190.700        16.43 -0.008980  -0.014397  0.005417
# 2022-11-23 15:00:00     190.699        16.45 -0.008985  -0.013197  0.004212
#
#                      bond_pos  stock_pos  premium rate
# 2022-11-22 15:00:00       0.0        0.0      0.021588
# 2022-11-23 09:30:00       0.0        0.0      0.024021
# 2022-11-23 09:31:00       0.0        0.0      0.015241
# 2022-11-23 09:32:00       0.0        0.0      0.023689
# 2022-11-23 09:33:00       0.0        0.0      0.021887
# 2022-11-23 09:34:00       0.0        0.0      0.023661
# 2022-11-23 09:35:00       0.0        0.0      0.026356
# 2022-11-23 09:36:00       0.0        0.0      0.026437
# 2022-11-23 09:37:00       0.0        0.0      0.022671
# 2022-11-23 09:38:00       0.0        0.0      0.027232
# 2022-11-23 09:39:00       0.0        0.0      0.021197
# 2022-11-23 09:40:00       0.0        0.0      0.021106
# 2022-11-23 09:41:00       0.0        0.0      0.021427
# 2022-11-23 09:42:00       0.0        0.0      0.022623
# 2022-11-23 09:43:00       0.0        0.0      0.022689
# 2022-11-23 09:44:00       0.0        0.0      0.026151
# 2022-11-23 09:45:00       0.0        0.0      0.024549
# 2022-11-23 09:46:00       0.0        0.0      0.022856
# 2022-11-23 09:47:00       0.0        0.0      0.024151
# 2022-11-23 09:48:00       0.0        0.0      0.020435
# 2022-11-23 09:49:00       0.0        0.0      0.022609
# 2022-11-23 09:50:00       0.0        0.0      0.023001
# 2022-11-23 09:51:00       0.0        0.0      0.026203
# 2022-11-23 09:52:00       0.0        0.0      0.024532
# 2022-11-23 09:53:00       0.0        0.0      0.026175
# 2022-11-23 09:54:00       0.0        0.0      0.023862
# 2022-11-23 09:55:00       0.0        0.0      0.022963
# 2022-11-23 09:56:00       0.0        0.0      0.022671
# 2022-11-23 09:57:00       0.0        0.0      0.022348
# 2022-11-23 09:58:00       0.0        0.0      0.022772
# 2022-11-23 09:59:00       0.0        0.0      0.022890
# 2022-11-23 10:00:00       0.0        0.0      0.024054
# 2022-11-23 10:01:00       0.0        0.0      0.025572
# 2022-11-23 10:02:00       0.0        0.0      0.025567
# 2022-11-23 10:03:00       0.0        0.0      0.027970
# 2022-11-23 10:04:00       0.0        0.0      0.028042
# 2022-11-23 10:05:00       0.0        0.0      0.027017
# 2022-11-23 10:06:00       0.0        0.0      0.025772
# 2022-11-23 10:07:00       0.0        0.0      0.028979
# 2022-11-23 10:08:00       0.0        0.0      0.023592
# 2022-11-23 10:09:00       0.0        0.0      0.024803
# 2022-11-23 10:10:00       0.0        0.0      0.023853
# 2022-11-23 10:11:00       0.0        0.0      0.022879
# 2022-11-23 10:12:00       0.0        0.0      0.023567
# 2022-11-23 10:13:00       0.0        0.0      0.023824
# 2022-11-23 10:14:00       0.0        0.0      0.022221
# 2022-11-23 10:15:00       0.0        0.0      0.024620
# 2022-11-23 10:16:00       0.0        0.0      0.026785
# 2022-11-23 10:17:00       0.0        0.0      0.027794
# 2022-11-23 10:18:00       0.0        0.0      0.026398
# 2022-11-23 10:19:00       0.0        0.0      0.025951
# 2022-11-23 10:20:00       0.0        0.0      0.024814
# 2022-11-23 10:21:00       0.0        0.0      0.022178
# 2022-11-23 10:22:00       0.0        0.0      0.024794
# 2022-11-23 10:23:00       0.0        0.0      0.025626
# 2022-11-23 10:24:00       0.0        0.0      0.024112
# 2022-11-23 10:25:00       0.0        0.0      0.022807
# 2022-11-23 10:26:00       0.0        0.0      0.024557
# 2022-11-23 10:27:00       0.0        0.0      0.024074
# 2022-11-23 10:28:00       0.0        0.0      0.023880
# 2022-11-23 10:29:00       0.0        0.0      0.024339
# 2022-11-23 10:30:00       0.0        0.0      0.024921
# 2022-11-23 10:31:00       0.0        0.0      0.026241
# 2022-11-23 10:32:00       0.0        0.0      0.027446
# 2022-11-23 10:33:00       0.0        0.0      0.025082
# 2022-11-23 10:34:00       0.0        0.0      0.027086
# 2022-11-23 10:35:00       0.0        0.0      0.026764
# 2022-11-23 10:36:00       0.0        0.0      0.027925
# 2022-11-23 10:37:00       0.0        0.0      0.025308
# 2022-11-23 10:38:00       0.0        0.0      0.027230
# 2022-11-23 10:39:00       0.0        0.0      0.031198
# 2022-11-23 10:40:00       0.0        0.0      0.027799
# 2022-11-23 10:41:00       0.0        0.0      0.029212
# 2022-11-23 10:42:00       0.0        0.0      0.027596
# 2022-11-23 10:43:00       0.0        0.0      0.026655
# 2022-11-23 10:44:00       0.0        0.0      0.027027
# 2022-11-23 10:45:00       0.0        0.0      0.027426
# 2022-11-23 10:46:00       0.0        0.0      0.027602
# 2022-11-23 10:47:00       0.0        0.0      0.027613
# 2022-11-23 10:48:00       0.0        0.0      0.026748
# 2022-11-23 10:49:00       0.0        0.0      0.028043
# 2022-11-23 10:50:00       0.0        0.0      0.026142
# 2022-11-23 10:51:00       0.0        0.0      0.025946
# 2022-11-23 10:52:00       0.0        0.0      0.026229
# 2022-11-23 10:53:00       0.0        0.0      0.027709
# 2022-11-23 10:54:00       0.0        0.0      0.027908
# 2022-11-23 10:55:00       0.0        0.0      0.027880
# 2022-11-23 10:56:00       0.0        0.0      0.027980
# 2022-11-23 10:57:00       0.0        0.0      0.029728
# 2022-11-23 10:58:00       0.0        0.0      0.030463
# 2022-11-23 10:59:00      -1.0        1.0      0.032458
# 2022-11-23 11:00:00      -1.0        1.0      0.030228
# 2022-11-23 11:01:00      -1.0        1.0      0.029763
# 2022-11-23 11:02:00      -1.0        1.0      0.031917
# 2022-11-23 11:03:00      -1.0        1.0      0.028684
# 2022-11-23 11:04:00      -1.0        1.0      0.030237
# 2022-11-23 11:05:00      -1.0        1.0      0.030064
# 2022-11-23 11:06:00      -1.0        1.0      0.030604
# 2022-11-23 11:07:00      -1.0        1.0      0.028974
# 2022-11-23 11:08:00      -1.0        1.0      0.028349
# 2022-11-23 11:09:00      -1.0        1.0      0.030199
# 2022-11-23 11:10:00      -1.0        1.0      0.028138
# 2022-11-23 11:11:00      -1.0        1.0      0.029767
# 2022-11-23 11:12:00      -1.0        1.0      0.027935
# 2022-11-23 11:13:00      -1.0        1.0      0.029568
# 2022-11-23 11:14:00      -1.0        1.0      0.030191
# 2022-11-23 11:15:00      -1.0        1.0      0.027839
# 2022-11-23 11:16:00      -1.0        1.0      0.032013
# 2022-11-23 11:17:00      -1.0        1.0      0.030256
# 2022-11-23 11:18:00      -1.0        1.0      0.029645
# 2022-11-23 11:19:00      -1.0        1.0      0.026294
# 2022-11-23 11:20:00      -1.0        1.0      0.028085
# 2022-11-23 11:21:00      -1.0        1.0      0.028130
# 2022-11-23 11:22:00      -1.0        1.0      0.028147
# 2022-11-23 11:23:00      -1.0        1.0      0.026622
# 2022-11-23 11:24:00      -1.0        1.0      0.027523
# 2022-11-23 11:25:00      -1.0        1.0      0.027495
# 2022-11-23 11:26:00      -1.0        1.0      0.027627
# 2022-11-23 11:27:00      -1.0        1.0      0.027058
# 2022-11-23 11:28:00      -1.0        1.0      0.028867
# 2022-11-23 11:29:00      -1.0        1.0      0.026971
# 2022-11-23 11:30:00      -1.0        1.0      0.026665
# 2022-11-23 13:00:00      -1.0        1.0      0.029898
# 2022-11-23 13:01:00      -1.0        1.0      0.028939
# 2022-11-23 13:02:00      -1.0        1.0      0.029303
# 2022-11-23 13:03:00      -1.0        1.0      0.028263
# 2022-11-23 13:04:00      -1.0        1.0      0.029590
# 2022-11-23 13:05:00      -1.0        1.0      0.031984
# 2022-11-23 13:06:00      -1.0        1.0      0.030954
# 2022-11-23 13:07:00      -1.0        1.0      0.029000
# 2022-11-23 13:08:00      -1.0        1.0      0.029763
# 2022-11-23 13:09:00      -1.0        1.0      0.030245
# 2022-11-23 13:10:00      -1.0        1.0      0.030139
# 2022-11-23 13:11:00      -1.0        1.0      0.030136
# 2022-11-23 13:12:00      -1.0        1.0      0.029174
# 2022-11-23 13:13:00      -1.0        1.0      0.030710
# 2022-11-23 13:14:00      -1.0        1.0      0.031564
# 2022-11-23 13:15:00      -1.0        1.0      0.029401
# 2022-11-23 13:16:00      -1.0        1.0      0.031498
# 2022-11-23 13:17:00      -1.0        1.0      0.031460
# 2022-11-23 13:18:00      -1.0        1.0      0.029997
# 2022-11-23 13:19:00      -1.0        1.0      0.031241
# 2022-11-23 13:20:00      -1.0        1.0      0.033590
# 2022-11-23 13:21:00      -1.0        1.0      0.031260
# 2022-11-23 13:22:00      -1.0        1.0      0.030263
# 2022-11-23 13:23:00      -1.0        1.0      0.031915
# 2022-11-23 13:24:00      -1.0        1.0      0.030502
# 2022-11-23 13:25:00      -1.0        1.0      0.030725
# 2022-11-23 13:26:00      -1.0        1.0      0.030613
# 2022-11-23 13:27:00      -1.0        1.0      0.031221
# 2022-11-23 13:28:00      -1.0        1.0      0.031216
# 2022-11-23 13:29:00      -1.0        1.0      0.030126
# 2022-11-23 13:30:00      -1.0        1.0      0.028774
# 2022-11-23 13:31:00      -1.0        1.0      0.030496
# 2022-11-23 13:32:00      -1.0        1.0      0.029501
# 2022-11-23 13:33:00      -1.0        1.0      0.029930
# 2022-11-23 13:34:00      -1.0        1.0      0.030378
# 2022-11-23 13:35:00      -1.0        1.0      0.030736
# 2022-11-23 13:36:00      -1.0        1.0      0.031773
# 2022-11-23 13:37:00      -1.0        1.0      0.030613
# 2022-11-23 13:38:00      -1.0        1.0      0.031383
# 2022-11-23 13:39:00      -1.0        1.0      0.031017
# 2022-11-23 13:40:00      -1.0        1.0      0.031836
# 2022-11-23 13:41:00      -1.0        1.0      0.029256
# 2022-11-23 13:42:00      -1.0        1.0      0.027850
# 2022-11-23 13:43:00      -1.0        1.0      0.028545
# 2022-11-23 13:44:00      -1.0        1.0      0.028170
# 2022-11-23 13:45:00      -1.0        1.0      0.028037
# 2022-11-23 13:46:00      -1.0        1.0      0.027039
# 2022-11-23 13:47:00      -1.0        1.0      0.026741
# 2022-11-23 13:48:00      -1.0        1.0      0.028872
# 2022-11-23 13:49:00      -1.0        1.0      0.028481
# 2022-11-23 13:50:00      -1.0        1.0      0.026806
# 2022-11-23 13:51:00      -1.0        1.0      0.028267
# 2022-11-23 13:52:00      -1.0        1.0      0.027817
# 2022-11-23 13:53:00      -1.0        1.0      0.027388
# 2022-11-23 13:54:00      -1.0        1.0      0.027806
# 2022-11-23 13:55:00      -1.0        1.0      0.026187
# 2022-11-23 13:56:00      -1.0        1.0      0.026252
# 2022-11-23 13:57:00      -1.0        1.0      0.026888
# 2022-11-23 13:58:00      -1.0        1.0      0.028500
# 2022-11-23 13:59:00      -1.0        1.0      0.030698
# 2022-11-23 14:00:00      -1.0        1.0      0.029893
# 2022-11-23 14:01:00      -1.0        1.0      0.029113
# 2022-11-23 14:02:00      -1.0        1.0      0.028837
# 2022-11-23 14:03:00      -1.0        1.0      0.028867
# 2022-11-23 14:04:00      -1.0        1.0      0.029670
# 2022-11-23 14:05:00      -1.0        1.0      0.030755
# 2022-11-23 14:06:00      -1.0        1.0      0.030164
# 2022-11-23 14:07:00      -1.0        1.0      0.029844
# 2022-11-23 14:08:00      -1.0        1.0      0.030984
# 2022-11-23 14:09:00      -1.0        1.0      0.029430
# 2022-11-23 14:10:00      -1.0        1.0      0.030018
# 2022-11-23 14:11:00      -1.0        1.0      0.030521
# 2022-11-23 14:12:00      -1.0        1.0      0.028829
# 2022-11-23 14:13:00      -1.0        1.0      0.029331
# 2022-11-23 14:14:00      -1.0        1.0      0.029280
# 2022-11-23 14:15:00      -1.0        1.0      0.028132
# 2022-11-23 14:16:00      -1.0        1.0      0.027528
# 2022-11-23 14:17:00      -1.0        1.0      0.028154
# 2022-11-23 14:18:00      -1.0        1.0      0.027252
# 2022-11-23 14:19:00      -1.0        1.0      0.025093
# 2022-11-23 14:20:00      -1.0        1.0      0.028386
# 2022-11-23 14:21:00      -1.0        1.0      0.028527
# 2022-11-23 14:22:00      -1.0        1.0      0.028149
# 2022-11-23 14:23:00      -1.0        1.0      0.028034
# 2022-11-23 14:24:00      -1.0        1.0      0.029070
# 2022-11-23 14:25:00      -1.0        1.0      0.028631
# 2022-11-23 14:26:00      -1.0        1.0      0.028139
# 2022-11-23 14:27:00      -1.0        1.0      0.028145
# 2022-11-23 14:28:00      -1.0        1.0      0.027826
# 2022-11-23 14:29:00      -1.0        1.0      0.027429
# 2022-11-23 14:30:00      -1.0        1.0      0.030141
# 2022-11-23 14:31:00      -1.0        1.0      0.028888
# 2022-11-23 14:32:00      -1.0        1.0      0.027637
# 2022-11-23 14:33:00      -1.0        1.0      0.029346
# 2022-11-23 14:34:00      -1.0        1.0      0.030064
# 2022-11-23 14:35:00      -1.0        1.0      0.030300
# 2022-11-23 14:36:00      -1.0        1.0      0.028993
# 2022-11-23 14:37:00      -1.0        1.0      0.028014
# 2022-11-23 14:38:00      -1.0        1.0      0.028897
# 2022-11-23 14:39:00      -1.0        1.0      0.030242
# 2022-11-23 14:40:00      -1.0        1.0      0.027945
# 2022-11-23 14:41:00      -1.0        1.0      0.027303
# 2022-11-23 14:42:00      -1.0        1.0      0.027008
# 2022-11-23 14:43:00      -1.0        1.0      0.026943
# 2022-11-23 14:44:00      -1.0        1.0      0.025235
# 2022-11-23 14:45:00      -1.0        1.0      0.027759
# 2022-11-23 14:46:00      -1.0        1.0      0.028193
# 2022-11-23 14:47:00      -1.0        1.0      0.029446
# 2022-11-23 14:48:00      -1.0        1.0      0.028678
# 2022-11-23 14:49:00      -1.0        1.0      0.028039
# 2022-11-23 14:50:00      -1.0        1.0      0.027026
# 2022-11-23 14:51:00      -1.0        1.0      0.026638
# 2022-11-23 14:52:00      -1.0        1.0      0.028119
# 2022-11-23 14:53:00      -1.0        1.0      0.029798
# 2022-11-23 14:54:00      -1.0        1.0      0.030521
# 2022-11-23 14:55:00      -1.0        1.0      0.028858
# 2022-11-23 14:56:00      -1.0        1.0      0.026573
# 2022-11-23 14:57:00      -1.0        1.0      0.027203
# 2022-11-23 14:58:00      -1.0        1.0      0.027203
# 2022-11-23 14:59:00      -1.0        1.0      0.027203
# 2022-11-23 15:00:00       0.0        0.0      0.025949

# %%
# 到期时间很短，且价内50%的时候，转债近似等价于正股
def cal_premium_rate(bond_price,stock_price,convert_price):
    tmp = 100/convert_price*stock_price
    res = (bond_price - tmp)/tmp
    return res
cal_premium_rate(200,140,70)
# Out:
# 0.0
