# %% [markdown]
# # import data

# %%
from WindPy import *

#Wind API 使用W账户密码登录
w.start() 

#return True and then can go to next operation.
w.isconnected()

import pandas as pd
# Out:
# 22.9.1.52437
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2021 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
# w.wsi("123046.SZ,300587.SZ,113642.SH,603185.SH,110061.SH,600674.SH,128081.SZ,002203.SZ,113016.SH,601127.SH,128017.SZ,002597.SZ",  "close",  "2022-09-06 09:00:00",  "2022-09-09 16:28:08",  "")

# %%
cbond_list = ['123046.SZ','300587.SZ',
'113642.SH','603185.SH', #转债已退市
'110061.SH','600674.SH',
'128081.SZ','002203.SZ',
'113016.SH','601127.SH',
'128017.SZ','002597.SZ',
'113537.SH','603348.SH',
'123027.SZ','300487.SZ', #转债已退市
'113534.SH','603876.SH',
'113025.SH','601677.SH',
'123031.SZ','300655.SZ',
'128029.SZ','002078.SZ',
'128111.SZ','002738.SZ', #2022-10-14新增4个对子
'128095.SZ','002812.SZ',
'113626.SH','603596.SH',
'123092.SZ','300332.SZ',
'123057.SZ','300586.SZ',#2020-11-18新增3个对子
'123067.SZ','300382.SZ',
'128106.SZ','002840.SZ',
]

# %% [markdown]
# # history trade days

# %%
# ###############################################################
# before_trade_date = '20220908'#监测当日前一个交易日
# present_date = '20220909' #监测当日
# next_trade_date = '20220910' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220909'#监测当日前一个交易日
# present_date = '20220913' #监测当日
# next_trade_date = '20220914' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220913'#监测当日前一个交易日
# present_date = '20220914' #监测当日
# next_trade_date = '20220915' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220914'#监测当日前一个交易日
# present_date = '20220915' #监测当日
# next_trade_date = '20220916' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220915'#监测当日前一个交易日
# present_date = '20220916' #监测当日
# next_trade_date = '20220917' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220916'#监测当日前一个交易日
# present_date = '20220919' #监测当日
# next_trade_date = '20220920' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220919'#监测当日前一个交易日
# present_date = '20220920' #监测当日
# next_trade_date = '20220921' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220920'#监测当日前一个交易日
# present_date = '20220921' #监测当日
# next_trade_date = '20220922' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220921'#监测当日前一个交易日
# present_date = '20220922' #监测当日
# next_trade_date = '20220923' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220922'#监测当日前一个交易日
# present_date = '20220923' #监测当日
# next_trade_date = '20220924' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220923'#监测当日前一个交易日
# present_date = '20220926' #监测当日
# next_trade_date = '20220927' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220926'#监测当日前一个交易日
# present_date = '20220927' #监测当日
# next_trade_date = '20220928' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220927'#监测当日前一个交易日
# present_date = '20220928' #监测当日
# next_trade_date = '20220929' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220928'#监测当日前一个交易日
# present_date = '20220929' #监测当日
# next_trade_date = '20220930' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220929'#监测当日前一个交易日
# present_date = '20220930' #监测当日
# next_trade_date = '20221001' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220930'#监测当日前一个交易日
# present_date = '20221010' #监测当日
# next_trade_date = '20221011' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221010'#监测当日前一个交易日
# present_date = '20221011' #监测当日
# next_trade_date = '20221012' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221011'#监测当日前一个交易日
# present_date = '20221012' #监测当日
# next_trade_date = '20221013' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221012'#监测当日前一个交易日
# present_date = '20221013' #监测当日
# next_trade_date = '20221014' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221013'#监测当日前一个交易日
# present_date = '20221014' #监测当日
# next_trade_date = '20221015' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221014'#监测当日前一个交易日
# present_date = '20221017' #监测当日
# next_trade_date = '20221018' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221017'#监测当日前一个交易日
# present_date = '20221018' #监测当日
# next_trade_date = '20221019' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221018'#监测当日前一个交易日
# present_date = '20221019' #监测当日
# next_trade_date = '20221020' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221019'#监测当日前一个交易日
# present_date = '20221020' #监测当日
# next_trade_date = '20221021' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221020'#监测当日前一个交易日
# present_date = '20221021' #监测当日
# next_trade_date = '20221022' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221021'#监测当日前一个交易日
# present_date = '20221024' #监测当日
# next_trade_date = '20221025' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221024'#监测当日前一个交易日
# present_date = '20221025' #监测当日
# next_trade_date = '20221026' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221025'#监测当日前一个交易日
# present_date = '20221026' #监测当日
# next_trade_date = '20221027' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221026'#监测当日前一个交易日
# present_date = '20221027' #监测当日
# next_trade_date = '20221028' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221027'#监测当日前一个交易日
# present_date = '20221028' #监测当日
# next_trade_date = '20221029' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221028'#监测当日前一个交易日
# present_date = '20221031' #监测当日
# next_trade_date = '20221101' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221031'#监测当日前一个交易日
# present_date = '20221101' #监测当日
# next_trade_date = '20221102' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221101'#监测当日前一个交易日
# present_date = '20221102' #监测当日
# next_trade_date = '20221103' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221102'#监测当日前一个交易日
# present_date = '20221103' #监测当日
# next_trade_date = '20221104' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221103'#监测当日前一个交易日
# present_date = '20221104' #监测当日
# next_trade_date = '20221105' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221104'#监测当日前一个交易日
# present_date = '20221107' #监测当日
# next_trade_date = '20221108' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221107'#监测当日前一个交易日
# present_date = '20221108' #监测当日
# next_trade_date = '20221109' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221108'#监测当日前一个交易日
# present_date = '20221109' #监测当日
# next_trade_date = '20221110' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221109'#监测当日前一个交易日
# present_date = '20221110' #监测当日
# next_trade_date = '20221111' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221110'#监测当日前一个交易日
# present_date = '20221111' #监测当日
# next_trade_date = '20221112' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221111'#监测当日前一个交易日
# present_date = '20221114' #监测当日
# next_trade_date = '20221115' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221114'#监测当日前一个交易日
# present_date = '20221115' #监测当日
# next_trade_date = '20221116' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221115'#监测当日前一个交易日
# present_date = '20221116' #监测当日
# next_trade_date = '20221117' #监测当日下一个自然日
# ###############################################################

# %%
# ###############################################################
# before_trade_date = '20221116'#监测当日前一个交易日
# present_date = '20221117' #监测当日
# next_trade_date = '20221118' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221117'#监测当日前一个交易日
# present_date = '20221118' #监测当日
# next_trade_date = '20221119' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221118'#监测当日前一个交易日
# present_date = '20221121' #监测当日
# next_trade_date = '20221122' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221121'#监测当日前一个交易日
# present_date = '20221122' #监测当日
# next_trade_date = '20221123' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221122'#监测当日前一个交易日
# present_date = '20221123' #监测当日
# next_trade_date = '20221124' #监测当日下一个自然日
# ###############################################################

# ###############################################################
before_trade_date = '20221123'#监测当日前一个交易日
present_date = '20221124' #监测当日
next_trade_date = '20221125' #监测当日下一个自然日
# ###############################################################

# %%
start_date = pd.to_datetime(before_trade_date) 
end_date = pd.to_datetime(next_trade_date)

cbond_price = pd.DataFrame([])
for code in cbond_list:
    price_df = w.wsi(code, "close", start_date, end_date,usedf=True)[1]   #只要了收盘价
    price_df.columns = [code]
    cbond_price = pd.concat([cbond_price,price_df],axis=1)
cbond_price = cbond_price.ffill()    
# cbond_rtn = cbond_price[cbond_price.index.time!=time(15,0,0)]
# cbond_price = cbond_price.loc['2022-09-09 15:00:00':] #从前一个交易日的收盘价开始截取
cbond_price_begin_time = before_trade_date[:4]+'-' + \
                    before_trade_date[4:6]+'-' + \
                    before_trade_date[6:8]+' 15:00:00'
cbond_price = cbond_price.loc[cbond_price_begin_time:]
cbond_price
# Out:
#                      123046.SZ  300587.SZ  113642.SH  603185.SH  110061.SH  \
# 2022-11-23 15:00:00    349.873      12.05        NaN     124.69    134.221
# 2022-11-24 09:30:00    351.833      12.12        NaN     123.69    134.920
# 2022-11-24 09:31:00    353.746      12.12        NaN     124.50    135.487
# 2022-11-24 09:32:00    356.096      12.15        NaN     124.15    135.897
# 2022-11-24 09:33:00    355.972      12.13        NaN     123.78    135.500
# ...                        ...        ...        ...        ...        ...
# 2022-11-24 14:56:00    371.987      12.97        NaN     122.97    135.350
# 2022-11-24 14:57:00    371.988      12.97        NaN     122.97    135.300
# 2022-11-24 14:58:00    371.988      12.97        NaN     122.97    135.400
# 2022-11-24 14:59:00    371.988      12.97        NaN     122.97    135.404
# 2022-11-24 15:00:00    371.988      12.97        NaN     122.98    135.399
#
#                      600674.SH  128081.SZ  002203.SZ  113016.SH  601127.SH  \
# 2022-11-23 15:00:00      11.68    126.600      12.13    323.945      47.20
# 2022-11-24 09:30:00      11.79    126.882      12.12    331.000      47.70
# 2022-11-24 09:31:00      11.84    126.786      12.12    336.530      47.92
# 2022-11-24 09:32:00      11.87    126.817      12.13    332.988      47.87
# 2022-11-24 09:33:00      11.83    126.972      12.13    333.768      48.04
# ...                        ...        ...        ...        ...        ...
# 2022-11-24 14:56:00      11.78    127.051      12.18    329.400      47.52
# 2022-11-24 14:57:00      11.78    127.051      12.19    329.353      47.52
# 2022-11-24 14:58:00      11.78    127.051      12.19    329.440      47.52
# 2022-11-24 14:59:00      11.78    127.051      12.19    329.743      47.52
# 2022-11-24 15:00:00      11.80    127.300      12.20    329.512      47.50
#
#                      ...  113626.SH  603596.SH  123092.SZ  300332.SZ  \
# 2022-11-23 15:00:00  ...    225.190      81.10    267.500      13.20
# 2022-11-24 09:30:00  ...    227.920      82.27    267.789      13.20
# 2022-11-24 09:31:00  ...    228.456      81.97    267.862      13.24
# 2022-11-24 09:32:00  ...    227.964      81.76    269.465      13.24
# 2022-11-24 09:33:00  ...    228.758      82.24    268.498      13.25
# ...                  ...        ...        ...        ...        ...
# 2022-11-24 14:56:00  ...    224.471      80.65    268.297      13.22
# 2022-11-24 14:57:00  ...    224.900      80.65    268.297      13.21
# 2022-11-24 14:58:00  ...    224.873      80.65    268.297      13.21
# 2022-11-24 14:59:00  ...    224.947      80.65    268.297      13.21
# 2022-11-24 15:00:00  ...    224.863      80.65    268.389      13.24
#
#                      123057.SZ  300586.SZ  123067.SZ  300382.SZ  128106.SZ  \
# 2022-11-23 15:00:00    234.040      20.57    236.000      22.61    190.699
# 2022-11-24 09:30:00    229.598      20.44    233.667      22.42    191.368
# 2022-11-24 09:31:00    228.732      20.47    232.628      22.40    191.166
# 2022-11-24 09:32:00    230.291      20.45    235.700      22.56    191.259
# 2022-11-24 09:33:00    230.567      20.50    236.402      22.66    191.560
# ...                        ...        ...        ...        ...        ...
# 2022-11-24 14:56:00    242.700      21.90    230.905      22.28    194.112
# 2022-11-24 14:57:00    242.680      21.89    230.899      22.28    194.090
# 2022-11-24 14:58:00    242.680      21.89    230.899      22.28    194.090
# 2022-11-24 14:59:00    242.680      21.89    230.899      22.28    194.090
# 2022-11-24 15:00:00    242.990      21.89    230.400      22.24    194.120
#
#                      002840.SZ
# 2022-11-23 15:00:00      16.45
# 2022-11-24 09:30:00      16.42
# 2022-11-24 09:31:00      16.42
# 2022-11-24 09:32:00      16.41
# 2022-11-24 09:33:00      16.45
# ...                        ...
# 2022-11-24 14:56:00      16.70
# 2022-11-24 14:57:00      16.70
# 2022-11-24 14:58:00      16.70
# 2022-11-24 14:59:00      16.70
# 2022-11-24 15:00:00      16.69
#
# [243 rows x 38 columns]

# %%
# assert False

# %% [markdown]
# # stock pre status

# %%
df_stk_pre_return = w.wss("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return
# Out:
#             PCT_CHG
# 300587.SZ -1.067323
# 603185.SH  3.007022
# 600674.SH  0.085690
# 002203.SZ -0.082372
# 601127.SH -2.479339
# 002597.SZ -0.463634
# 603348.SH  0.091227
# 300487.SZ -0.162162
# 603876.SH  1.645299
# 601677.SH -0.200669
# 300655.SZ -0.351906
# 002078.SZ -0.279851
# 002738.SZ -1.158301
# 002812.SZ -6.998645
# 603596.SH -2.171291
# 300332.SZ  2.723735
# 300586.SZ -3.245532
# 300382.SZ -0.132509
# 002840.SZ -1.319736

# %%
df_bond_pre_return = w.wss("123046.SZ,113642.SH,110061.SH,128081.SZ,113016.SH,128017.SZ,113537.SH,123027.SZ,113534.SH,113025.SH,123031.SZ,128029.SZ,128111.SZ,128095.SZ,113626.SH,123092.SZ,123057.SZ,123067.SZ,128106.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_bond_pre_return
# Out:
#             PCT_CHG
# 123046.SZ -0.350608
# 113642.SH       NaN
# 110061.SH  0.481367
# 128081.SZ  0.237530
# 113016.SH  0.247877
# 128017.SZ  0.596778
# 113537.SH  0.289853
# 123027.SZ       NaN
# 113534.SH  1.380496
# 113025.SH  0.542222
# 123031.SZ -0.297708
# 128029.SZ -0.132148
# 128111.SZ -0.874166
# 128095.SZ  6.564850
# 113626.SH -2.035507
# 123092.SZ  2.667434
# 123057.SZ  2.648673
# 123067.SZ  2.657793
# 128106.SZ -0.898518

# %%
before_trade_date_trade_status = before_trade_date[:4] +'-'+ before_trade_date[4:6] +'-'+ before_trade_date[6:]
# present_date_trade_status = present_date[:4] +'-'+ present_date[4:6] +'-'+ present_date[6:]
df_stk_pre_trade_status = w.wsd("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ", 
"trade_status", f"{before_trade_date_trade_status}", f"{before_trade_date_trade_status}", "",usedf=True)[1]
df_stk_pre_trade_status
# Out:
#           TRADE_STATUS
# 300587.SZ           交易
# 603185.SH           交易
# 600674.SH           交易
# 002203.SZ           交易
# 601127.SH           交易
# 002597.SZ           交易
# 603348.SH           交易
# 300487.SZ           交易
# 603876.SH           交易
# 601677.SH           交易
# 300655.SZ           交易
# 002078.SZ           交易
# 002738.SZ           交易
# 002812.SZ           交易
# 603596.SH           交易
# 300332.SZ           交易
# 300586.SZ           交易
# 300382.SZ           交易
# 002840.SZ           交易

# %%
# assert False

# %% [markdown]
# # bond-stock pair

# %%
# cbond_pair = ['113642.SH','603185.SH']  #后面筛选的结果，这组也在里面 转债停止交易了
# open_threshold = 0.023
# close_threshold = 0
# convert_price = 102.4
# operate = True

# cbond_pair = ['123027.SZ','300487.SZ',] # 1019 1020 1021 这几天转债停止交易了
# open_threshold = 0.022
# close_threshold = 0
# convert_price = 19.07
# operate = True

# %%
cbond_pair = ['123046.SZ','300587.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.015
close_threshold = 0
convert_price = 3.94
operate = True

cbond_pair = ['110061.SH','600674.SH']
open_threshold = 0.006
close_threshold = 0
convert_price = 8.8
operate = True

cbond_pair = ['128081.SZ','002203.SZ']
open_threshold = 0.012
close_threshold = 0.002
convert_price = 9.62
operate = True

cbond_pair = ['113016.SH','601127.SH'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.017
close_threshold = 0.003
convert_price = 20.17
operate = True

cbond_pair = ['128017.SZ','002597.SZ']
open_threshold = 0.012
close_threshold = 0
convert_price = 21.33
operate = True

# # # # # # $$$$$$$$$$$$$$$$$$$$$$$$以下是新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['113537.SH','603348.SH',]
open_threshold = 0.027
close_threshold = 0.002
convert_price = 19.13
operate = True

cbond_pair = ['113534.SH','603876.SH',]
open_threshold = 0.019
close_threshold = 0.002
convert_price = 14.98
operate = True

cbond_pair = ['113025.SH','601677.SH',]
open_threshold = 0.018
close_threshold = 0
convert_price = 7.66
operate = True

cbond_pair = ['123031.SZ','300655.SZ',]   #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.019
close_threshold = 0
convert_price = 6.25
operate = True

cbond_pair = ['128029.SZ','002078.SZ']
open_threshold = 0.013
close_threshold = 0.002
convert_price = 8.25
operate = True

# # # # # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-10-14】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['128111.SZ','002738.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.011
close_threshold = 0.001
convert_price = 10.96
operate = True

cbond_pair = ['128095.SZ','002812.SZ']
open_threshold = 0.013
close_threshold = 0
convert_price = 64.62
operate = False

cbond_pair = ['113626.SH','603596.SH']
open_threshold = 0.02
close_threshold = 0
convert_price = 35.88
operate = True

cbond_pair = ['123092.SZ','300332.SZ']
open_threshold = 0.025
close_threshold = 0.001
convert_price = 5.14
operate = True

# # # # # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-11-18】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair =  ['123057.SZ','300586.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.009 
close_threshold = 0.003
convert_price = 9.5
operate = True

cbond_pair =  ['123067.SZ','300382.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.004
close_threshold = 0.002
convert_price = 9.96
operate = True

cbond_pair =  ['128106.SZ','002840.SZ']
open_threshold = 0.01
close_threshold = 0
convert_price = 8.85
operate = True

# %%
# df_signal

# %% [markdown]
# # clip price series

# %%
#从前一个交易日的收盘价开始截取
# cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]].loc['2022-09-08 15:00:00':]
cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]]

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-23 15:00:00    190.699      16.45
# 2022-11-24 09:30:00    191.368      16.42
# 2022-11-24 09:31:00    191.166      16.42
# 2022-11-24 09:32:00    191.259      16.41
# 2022-11-24 09:33:00    191.560      16.45

# %%
cbond_return = pd.DataFrame([])

cbond_preclose = cbond_pair_price.iloc[0,0] # 初始时刻的bond前收盘价
stock_preclose = cbond_pair_price.iloc[0,1] # 初始时刻的stock前收盘价

for index,row in cbond_pair_price.iterrows():
    
    cbond_return.loc[index,cbond_pair[0]] = row[cbond_pair[0]]/cbond_preclose - 1 # 算日内的return
    cbond_return.loc[index,cbond_pair[1]] = row[cbond_pair[1]]/stock_preclose - 1

    if index.time()==time(15,0,0):  #算完日内return，迭代到今日价格的最后一个time bar的时候，将其设为前收盘价
        cbond_preclose = row[cbond_pair[0]]    # 日内return指标用 现价/昨日收盘价 计算
        stock_preclose = row[cbond_pair[1]]
        
# 检查df是否有空值
cbond_return.isnull().sum(axis=0)  # 按列统计
cbond_return.isnull().sum(axis=1) # 按行统计
cbond_return.isnull().sum(axis=1).sum() # 统计整张表
# Out:
# 0

# %%
pd.set_option('display.max_rows', None)
cbond_return['diff'] = cbond_return[cbond_pair[0]] - cbond_return[cbond_pair[1]]
cbond_return.head()
# Out:
#                      128106.SZ  002840.SZ      diff
# 2022-11-23 15:00:00   0.000000   0.000000  0.000000
# 2022-11-24 09:30:00   0.003508  -0.001824  0.005332
# 2022-11-24 09:31:00   0.002449  -0.001824  0.004273
# 2022-11-24 09:32:00   0.002937  -0.002432  0.005368
# 2022-11-24 09:33:00   0.004515   0.000000  0.004515

# %% [markdown]
# # signal calculate

# %%
################################################################################################
stk_pre_return = df_stk_pre_return.loc[cbond_pair[1]].values[0]
bond_pre_return = df_bond_pre_return.loc[cbond_pair[0]].values[0]
pre_diff = bond_pre_return - stk_pre_return
stk_pre_trade_status = df_stk_pre_trade_status.loc[cbond_pair[1]].values[0]
print(stk_pre_trade_status)
print('pre diff:',pre_diff)
# if abs(stk_pre_return) > 10 or stk_pre_trade_status!='交易':
if abs(pre_diff) > 5 or stk_pre_trade_status!='交易':
    # 如果前一天股票的跌幅小于-10，则今日不做操作
    intraday_open_times = 1
else:
    intraday_open_times = 0
################################################################################################    
open_close_spread = open_threshold - close_threshold
# intraday_open_times = 0
max_open = 1

pos_open_flag = 0
neg_open_flag = 0
cbond_position = pd.DataFrame([])
cbond_position.index = cbond_return.index
for index,row in cbond_return.iterrows():

    if row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff落在A区间，且无仓位，正开
            pos_open_flag = 1
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==1:
        if intraday_open_times < max_open:
            #diff落在A区间，且有负仓，平仓再正开
            pos_open_flag=1
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            print('reverse open +1')
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff落在A区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在B区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在B区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在B区间，且无仓，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在C区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在C区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在C区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在D区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在D区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在D区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且无仓位，反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==1 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且有正仓，平仓反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在E区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    if abs(row['diff'])>2 * open_close_spread and cbond_return.columns[0]!='123057.SZ' and cbond_return.columns[0]!='123067.SZ': 
        #盘中diff超过2倍spread时平仓（价格止损信号）,有两个spread特别小的对子则不用此逻辑进行止损
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if index.time()==time(15,0,0): # 每日收盘时必须平仓（时间止损信号）
    # if index.time()==time(14,59,0): # 每日收盘时必须平仓（时间止损信号）
        intraday_open_times = 0 # 下一天开盘前，把当日记录下来的开仓次数清零
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
# Out:
# 交易
# pre diff: 0.4212181655797106

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-23 15:00:00    190.699      16.45
# 2022-11-24 09:30:00    191.368      16.42
# 2022-11-24 09:31:00    191.166      16.42
# 2022-11-24 09:32:00    191.259      16.41
# 2022-11-24 09:33:00    191.560      16.45

# %%
df_signal = pd.concat([cbond_pair_price,cbond_return,cbond_position],axis=1)
df_signal.columns = ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
print('open threshold',open_threshold,'close threshold',close_threshold)
# df_signal.to_csv('tmp_signal.csv')
# df_signal
# Out:
# open threshold 0.01 close threshold 0

# %% [markdown]
# # backtest

# %%
# 用来记录交易流水的表格,一边遍历df_signal，一边填入内容到流水表格里

import numpy as np
cols = ['balance','signal','bond price','stock price','bond hold','stock hold','commission','tax','reverse open','diff','asset value']
df_trade = pd.DataFrame(
    data = [[0,np.nan,np.nan,np.nan,0,0,0,0,np.nan,np.nan,0]],
    columns=cols
    ) 

balance_last = 0 # 现金账户初始余额

bond_hold = 0 # 债券持有数量
stock_hold = 0 # 股票持有数量


commission_rate = 2/10000 + 0 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 0.5/1000 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 1/1000 # 佣金买卖万二 + 交易滑点

tax_rate = 1/1000 # 卖股票才收印花税千一

# commission_rate = 0/10000 # 佣金买卖万二
# tax_rate = 0/1000 #

for i in range(len(df_signal)-1):
    if df_signal.index[i].time() == time(15,0,0):
    # if df_signal.index[i].time() == time(14,59,0):
        # 修改stock volume 每天固定一个stock volume 应该用债的前收盘价/股票的前收盘价
        stock_volume = df_signal['bond_price'][i]/df_signal['stock_price'][i]

    if df_signal.values[i][-1] != df_signal.values[i+1][-1]:

        index = df_signal.index[i+1]        
        diff = df_signal.values[i+1][-3] #diff在df_signal中的倒数第三列
        
    # df_signal的columns
    # ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
        signal = str(int(df_signal.values[i+1][-2]))+str(int(df_signal.values[i+1][-1]))
        
        bond_price = df_signal.values[i+1][0] 

        stock_price = df_signal.values[i+1][1]

        # stock_volume =  bond_price/stock_price # 修改stock volume 每天固定一个stock volume应该用债的前收盘价/股票的前收盘价

        commission = (bond_price + stock_price * stock_volume) * commission_rate

        reverse_open = False #表明这笔交易，是否包含平仓后再反向开仓的操作

        if signal == '00' and stock_hold == stock_volume: #有股票持仓并且需要卖出平仓时，有印花税
            tax = stock_price * tax_rate * stock_volume
        else:
            tax = 0

        if signal == '00':
            balance_last += bond_hold*bond_price
            balance_last += stock_hold*stock_price
            
            bond_hold = 0
            stock_hold = 0
            

        if signal == '1-1':
            '''
            加一个检测之前持仓的模块,如果之前因为-11的信号有持仓,需要先平掉(即买债卖股票),同时再反向开仓
            '''
            reverse_flag = False
            if bond_hold == -1 and stock_hold == 1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last -= bond_price 
                balance_last += stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税
                reverse_flag = True
                reverse_open = True

            bond_hold += 1
            stock_hold += (-1 * stock_volume)
            # stock_hold += stock_volume
            balance_last -= bond_price
            balance_last += stock_price * stock_volume
            
            if reverse_flag:
                tax *= 2 #平仓然后反向开仓的时候 已经计算过tax了，直接double
            else:
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税

        if signal == '-11':
            '''
            加一个检测之前持仓的模块,如果之前因为1-1的信号有持仓,需要先平掉(卖债买股票),同时再反向开仓
            '''
            if bond_hold == 1 and stock_hold == -1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last += bond_price
                balance_last -= stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                                # 买股票无印花税
                reverse_open = True
            bond_hold += -1
            stock_hold += (1 * stock_volume)
            # stock_hold += stock_volume
            balance_last += bond_price
            balance_last -= stock_price * stock_volume
        
        balance_last = balance_last - commission - tax
        balance = balance_last
        asset_value = bond_price*bond_hold + stock_price*stock_hold
        line = [balance,signal,bond_price,stock_price,bond_hold,stock_hold,commission,tax,reverse_open,diff,asset_value]
        # df_trade.loc[index,['balance','asset','signal','bond price','stock price','commission','tax']] = line
        # df_trade.loc[index,cols] = [0,0,np.nan,np.nan,np.nan,0,0,0,0]
        df_trade.loc[index,cols] = line

df_trade.rename(columns={'balance':'cash'},inplace=True)       
df_trade['net value'] = df_trade['cash'] + df_trade['asset value']

# %%
df_trade['operate'] = [operate]*len(df_trade)

# %%
df_trade
# Out:
#    cash  signal  bond price  stock price  bond hold  stock hold  commission  \
# 0     0     NaN         NaN          NaN          0           0           0
#
#    tax  reverse open  diff  asset value  net value  operate
# 0    0           NaN   NaN            0          0     True

# %% [markdown]
# # output to csv

# %%
excel_file_name = './daily_track/'+ present_date+'/' + cbond_pair[0] + '@' + cbond_pair[1] + '.csv'

excel_file_name

df_to_excel = df_trade
df_to_excel['open/close'] = [str(open_threshold)+','+str(close_threshold)]*len(df_to_excel)
df_to_excel['pair'] = [cbond_pair[0] + '@' + cbond_pair[1]]*len(df_to_excel)
df_to_excel = df_to_excel[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_to_excel.to_csv(excel_file_name,)

# %%
present_date
# Out:
# '20221124'

# %% [markdown]
# # conclusion

# %%
import os
single_trade_files = os.listdir('./daily_track'+'/'+present_date)

df_trade_conclusion = pd.DataFrame([])
for file in single_trade_files:
    if file == 'diff':
        continue
    if file == '.DS_Store' or file.split('.')[1] == 'xlsx':
        continue
    tmp_path = './daily_track'+'/'+present_date+'/'+file
    df_tmp = pd.read_csv(tmp_path,index_col=0)
    tmp_col = list(df_tmp.columns)
    df_tmp_head = pd.DataFrame(data=[tmp_col],columns=tmp_col)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp_head)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp)
df_trade_conclusion.columns
df_trade_conclusion = df_trade_conclusion[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_trade_conclusion
tmp_path = './daily_track'+'/'+present_date+'/'+f'{present_date}_conclusion.csv'

df_trade_conclusion.to_csv(tmp_path)

# %% [markdown]
# # intraday signal

# %%
import matplotlib.pyplot as plt

signal_plot_begin_time = present_date[:4]+'-' + \
                         present_date[4:6]+'-' + \
                         present_date[6:8]+' 09:30:00'
df_signal['diff'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' diff',grid=True)

#如果当日有开平仓记录，在图上画出开平仓时刻的标注
if len(df_trade) == 3:
    open_tick = df_trade.index.to_list()[1]
    open_diff = df_trade['diff'].to_list()[1]
    close_tick = df_trade.index.to_list()[2]
    close_diff =  df_trade['diff'].to_list()[2]
    plt.text(open_tick,open_diff,'open')
    plt.text(close_tick,close_diff,'close')
    plt.scatter([open_tick],[open_diff],color='r')

    tmp_nv = df_trade['net value'].to_list()[2]
    if tmp_nv > 0: 
        close_color = 'g' #当天赚钱的话，平仓点位标记为绿色
    else:
        close_color = 'orange' #当天亏钱的话，平仓点位标记为橙色
    plt.scatter([close_tick],[close_diff],color=close_color)
fig_file_name = './daily_track/'+ present_date+'/'+'diff/' + cbond_pair[0] + '@' + cbond_pair[1] + '.png'
plt.savefig(fig_file_name)

plt.show()
df_signal['bond_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+' rtn',grid=True)
plt.show()
df_signal['stock_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[1]+' rtn',grid=True)
plt.show()

# %%
df_tmp = 100/convert_price*df_signal['stock_price']
df_signal['premium rate'] = (df_signal['bond_price'] - df_tmp)/df_tmp
df_signal['premium rate'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' premium rate',grid=True)
# Out:
# <AxesSubplot:title={'center':'128106.SZ@002840.SZ premium rate'}>

# %%
df_signal
# Out:
#                      bond_price  stock_price  bond_rtn  stock_rtn      diff  \
# 2022-11-23 15:00:00     190.699        16.45  0.000000   0.000000  0.000000
# 2022-11-24 09:30:00     191.368        16.42  0.003508  -0.001824  0.005332
# 2022-11-24 09:31:00     191.166        16.42  0.002449  -0.001824  0.004273
# 2022-11-24 09:32:00     191.259        16.41  0.002937  -0.002432  0.005368
# 2022-11-24 09:33:00     191.560        16.45  0.004515   0.000000  0.004515
# 2022-11-24 09:34:00     191.932        16.52  0.006466   0.004255  0.002210
# 2022-11-24 09:35:00     192.200        16.56  0.007871   0.006687  0.001184
# 2022-11-24 09:36:00     192.257        16.58  0.008170   0.007903  0.000267
# 2022-11-24 09:37:00     193.097        16.61  0.012575   0.009726  0.002848
# 2022-11-24 09:38:00     192.604        16.60  0.009990   0.009119  0.000871
# 2022-11-24 09:39:00     193.745        16.75  0.015973   0.018237 -0.002264
# 2022-11-24 09:40:00     194.050        16.82  0.017572   0.022492 -0.004920
# 2022-11-24 09:41:00     195.158        16.90  0.023382   0.027356 -0.003973
# 2022-11-24 09:42:00     196.000        17.01  0.027798   0.034043 -0.006245
# 2022-11-24 09:43:00     195.186        16.91  0.023529   0.027964 -0.004434
# 2022-11-24 09:44:00     194.330        16.83  0.019040   0.023100 -0.004060
# 2022-11-24 09:45:00     194.282        16.80  0.018789   0.021277 -0.002488
# 2022-11-24 09:46:00     194.186        16.80  0.018285   0.021277 -0.002991
# 2022-11-24 09:47:00     193.720        16.72  0.015842   0.016413 -0.000572
# 2022-11-24 09:48:00     192.829        16.62  0.011169   0.010334  0.000835
# 2022-11-24 09:49:00     192.752        16.61  0.010766   0.009726  0.001039
# 2022-11-24 09:50:00     193.602        16.72  0.015223   0.016413 -0.001190
# 2022-11-24 09:51:00     193.500        16.75  0.014688   0.018237 -0.003549
# 2022-11-24 09:52:00     193.108        16.70  0.012632   0.015198 -0.002565
# 2022-11-24 09:53:00     193.900        16.78  0.016786   0.020061 -0.003275
# 2022-11-24 09:54:00     194.242        16.77  0.018579   0.019453 -0.000874
# 2022-11-24 09:55:00     193.907        16.77  0.016822   0.019453 -0.002631
# 2022-11-24 09:56:00     194.036        16.76  0.017499   0.018845 -0.001346
# 2022-11-24 09:57:00     194.522        16.80  0.020047   0.021277 -0.001229
# 2022-11-24 09:58:00     194.438        16.76  0.019607   0.018845  0.000762
# 2022-11-24 09:59:00     194.927        16.82  0.022171   0.022492 -0.000321
# 2022-11-24 10:00:00     193.997        16.69  0.017294   0.014590  0.002705
# 2022-11-24 10:01:00     193.562        16.65  0.015013   0.012158  0.002855
# 2022-11-24 10:02:00     193.750        16.69  0.015999   0.014590  0.001409
# 2022-11-24 10:03:00     193.586        16.65  0.015139   0.012158  0.002981
# 2022-11-24 10:04:00     193.510        16.67  0.014741   0.013374  0.001367
# 2022-11-24 10:05:00     193.419        16.67  0.014263   0.013374  0.000889
# 2022-11-24 10:06:00     193.840        16.67  0.016471   0.013374  0.003097
# 2022-11-24 10:07:00     194.102        16.71  0.017845   0.015805  0.002039
# 2022-11-24 10:08:00     194.000        16.69  0.017310   0.014590  0.002720
# 2022-11-24 10:09:00     194.111        16.71  0.017892   0.015805  0.002087
# 2022-11-24 10:10:00     193.819        16.70  0.016361   0.015198  0.001163
# 2022-11-24 10:11:00     193.707        16.70  0.015774   0.015198  0.000576
# 2022-11-24 10:12:00     193.481        16.70  0.014588   0.015198 -0.000609
# 2022-11-24 10:13:00     194.454        16.72  0.019691   0.016413  0.003277
# 2022-11-24 10:14:00     194.011        16.68  0.017368   0.013982  0.003386
# 2022-11-24 10:15:00     193.908        16.69  0.016828   0.014590  0.002238
# 2022-11-24 10:16:00     193.936        16.66  0.016974   0.012766  0.004208
# 2022-11-24 10:17:00     193.779        16.62  0.016151   0.010334  0.005817
# 2022-11-24 10:18:00     193.803        16.62  0.016277   0.010334  0.005943
# 2022-11-24 10:19:00     194.153        16.65  0.018112   0.012158  0.005954
# 2022-11-24 10:20:00     193.965        16.63  0.017126   0.010942  0.006184
# 2022-11-24 10:21:00     194.126        16.65  0.017971   0.012158  0.005813
# 2022-11-24 10:22:00     194.046        16.64  0.017551   0.011550  0.006001
# 2022-11-24 10:23:00     193.897        16.62  0.016770   0.010334  0.006436
# 2022-11-24 10:24:00     193.921        16.62  0.016896   0.010334  0.006561
# 2022-11-24 10:25:00     193.932        16.60  0.016953   0.009119  0.007835
# 2022-11-24 10:26:00     193.800        16.59  0.016261   0.008511  0.007751
# 2022-11-24 10:27:00     193.754        16.62  0.016020   0.010334  0.005686
# 2022-11-24 10:28:00     193.888        16.59  0.016723   0.008511  0.008212
# 2022-11-24 10:29:00     194.122        16.65  0.017950   0.012158  0.005792
# 2022-11-24 10:30:00     193.847        16.62  0.016508   0.010334  0.006173
# 2022-11-24 10:31:00     194.000        16.66  0.017310   0.012766  0.004544
# 2022-11-24 10:32:00     193.750        16.64  0.015999   0.011550  0.004449
# 2022-11-24 10:33:00     193.750        16.61  0.015999   0.009726  0.006273
# 2022-11-24 10:34:00     193.650        16.62  0.015475   0.010334  0.005140
# 2022-11-24 10:35:00     193.510        16.61  0.014741   0.009726  0.005014
# 2022-11-24 10:36:00     193.848        16.67  0.016513   0.013374  0.003139
# 2022-11-24 10:37:00     193.880        16.65  0.016681   0.012158  0.004523
# 2022-11-24 10:38:00     194.200        16.66  0.018359   0.012766  0.005593
# 2022-11-24 10:39:00     193.958        16.65  0.017090   0.012158  0.004932
# 2022-11-24 10:40:00     194.004        16.66  0.017331   0.012766  0.004565
# 2022-11-24 10:41:00     194.294        16.68  0.018852   0.013982  0.004870
# 2022-11-24 10:42:00     194.391        16.72  0.019360   0.016413  0.002947
# 2022-11-24 10:43:00     194.300        16.71  0.018883   0.015805  0.003078
# 2022-11-24 10:44:00     194.216        16.70  0.018443   0.015198  0.003245
# 2022-11-24 10:45:00     194.410        16.72  0.019460   0.016413  0.003047
# 2022-11-24 10:46:00     195.094        16.77  0.023047   0.019453  0.003594
# 2022-11-24 10:47:00     194.804        16.76  0.021526   0.018845  0.002681
# 2022-11-24 10:48:00     194.948        16.76  0.022281   0.018845  0.003436
# 2022-11-24 10:49:00     195.199        16.75  0.023597   0.018237  0.005360
# 2022-11-24 10:50:00     195.349        16.74  0.024384   0.017629  0.006755
# 2022-11-24 10:51:00     195.200        16.73  0.023603   0.017021  0.006581
# 2022-11-24 10:52:00     195.853        16.83  0.027027   0.023100  0.003927
# 2022-11-24 10:53:00     195.563        16.82  0.025506   0.022492  0.003014
# 2022-11-24 10:54:00     196.200        16.88  0.028847   0.026140  0.002707
# 2022-11-24 10:55:00     195.999        16.89  0.027792   0.026748  0.001045
# 2022-11-24 10:56:00     195.438        16.85  0.024851   0.024316  0.000535
# 2022-11-24 10:57:00     195.680        16.90  0.026120   0.027356 -0.001236
# 2022-11-24 10:58:00     195.813        16.93  0.026817   0.029179 -0.002362
# 2022-11-24 10:59:00     195.101        16.83  0.023083   0.023100 -0.000017
# 2022-11-24 11:00:00     195.300        16.84  0.024127   0.023708  0.000419
# 2022-11-24 11:01:00     195.000        16.79  0.022554   0.020669  0.001885
# 2022-11-24 11:02:00     195.234        16.79  0.023781   0.020669  0.003112
# 2022-11-24 11:03:00     195.013        16.75  0.022622   0.018237  0.004385
# 2022-11-24 11:04:00     195.183        16.73  0.023513   0.017021  0.006492
# 2022-11-24 11:05:00     195.219        16.75  0.023702   0.018237  0.005465
# 2022-11-24 11:06:00     194.801        16.73  0.021510   0.017021  0.004489
# 2022-11-24 11:07:00     194.759        16.72  0.021290   0.016413  0.004877
# 2022-11-24 11:08:00     194.689        16.73  0.020923   0.017021  0.003902
# 2022-11-24 11:09:00     194.344        16.70  0.019114   0.015198  0.003916
# 2022-11-24 11:10:00     194.606        16.71  0.020488   0.015805  0.004682
# 2022-11-24 11:11:00     194.518        16.72  0.020026   0.016413  0.003613
# 2022-11-24 11:12:00     194.315        16.72  0.018962   0.016413  0.002548
# 2022-11-24 11:13:00     194.702        16.73  0.020991   0.017021  0.003970
# 2022-11-24 11:14:00     194.650        16.73  0.020719   0.017021  0.003697
# 2022-11-24 11:15:00     194.506        16.74  0.019963   0.017629  0.002334
# 2022-11-24 11:16:00     194.400        16.71  0.019408   0.015805  0.003602
# 2022-11-24 11:17:00     194.357        16.70  0.019182   0.015198  0.003984
# 2022-11-24 11:18:00     194.320        16.70  0.018988   0.015198  0.003790
# 2022-11-24 11:19:00     194.262        16.69  0.018684   0.014590  0.004094
# 2022-11-24 11:20:00     194.569        16.72  0.020294   0.016413  0.003880
# 2022-11-24 11:21:00     194.637        16.72  0.020650   0.016413  0.004237
# 2022-11-24 11:22:00     194.600        16.73  0.020456   0.017021  0.003435
# 2022-11-24 11:23:00     194.497        16.73  0.019916   0.017021  0.002895
# 2022-11-24 11:24:00     194.327        16.71  0.019025   0.015805  0.003219
# 2022-11-24 11:25:00     194.085        16.70  0.017756   0.015198  0.002558
# 2022-11-24 11:26:00     194.100        16.70  0.017834   0.015198  0.002637
# 2022-11-24 11:27:00     194.337        16.74  0.019077   0.017629  0.001448
# 2022-11-24 11:28:00     194.296        16.72  0.018862   0.016413  0.002449
# 2022-11-24 11:29:00     194.343        16.73  0.019109   0.017021  0.002087
# 2022-11-24 11:30:00     194.366        16.73  0.019229   0.017021  0.002208
# 2022-11-24 13:00:00     194.480        16.70  0.019827   0.015198  0.004629
# 2022-11-24 13:01:00     194.311        16.71  0.018941   0.015805  0.003135
# 2022-11-24 13:02:00     194.200        16.70  0.018359   0.015198  0.003161
# 2022-11-24 13:03:00     193.692        16.67  0.015695   0.013374  0.002321
# 2022-11-24 13:04:00     193.786        16.66  0.016188   0.012766  0.003422
# 2022-11-24 13:05:00     193.996        16.66  0.017289   0.012766  0.004523
# 2022-11-24 13:06:00     193.600        16.63  0.015212   0.010942  0.004270
# 2022-11-24 13:07:00     193.694        16.64  0.015705   0.011550  0.004155
# 2022-11-24 13:08:00     193.200        16.60  0.013115   0.009119  0.003996
# 2022-11-24 13:09:00     193.367        16.58  0.013991   0.007903  0.006088
# 2022-11-24 13:10:00     193.512        16.60  0.014751   0.009119  0.005632
# 2022-11-24 13:11:00     193.496        16.60  0.014667   0.009119  0.005549
# 2022-11-24 13:12:00     193.300        16.62  0.013639   0.010334  0.003305
# 2022-11-24 13:13:00     193.250        16.62  0.013377   0.010334  0.003043
# 2022-11-24 13:14:00     193.200        16.61  0.013115   0.009726  0.003388
# 2022-11-24 13:15:00     193.102        16.62  0.012601   0.010334  0.002267
# 2022-11-24 13:16:00     193.393        16.64  0.014127   0.011550  0.002577
# 2022-11-24 13:17:00     193.540        16.63  0.014898   0.010942  0.003956
# 2022-11-24 13:18:00     193.603        16.63  0.015228   0.010942  0.004286
# 2022-11-24 13:19:00     193.394        16.62  0.014132   0.010334  0.003798
# 2022-11-24 13:20:00     193.200        16.62  0.013115   0.010334  0.002781
# 2022-11-24 13:21:00     193.155        16.62  0.012879   0.010334  0.002545
# 2022-11-24 13:22:00     193.319        16.62  0.013739   0.010334  0.003405
# 2022-11-24 13:23:00     193.311        16.63  0.013697   0.010942  0.002755
# 2022-11-24 13:24:00     193.316        16.60  0.013723   0.009119  0.004605
# 2022-11-24 13:25:00     193.401        16.62  0.014169   0.010334  0.003835
# 2022-11-24 13:26:00     193.620        16.66  0.015317   0.012766  0.002551
# 2022-11-24 13:27:00     193.608        16.63  0.015254   0.010942  0.004312
# 2022-11-24 13:28:00     193.405        16.64  0.014190   0.011550  0.002640
# 2022-11-24 13:29:00     193.180        16.61  0.013010   0.009726  0.003284
# 2022-11-24 13:30:00     193.102        16.58  0.012601   0.007903  0.004698
# 2022-11-24 13:31:00     193.183        16.58  0.013026   0.007903  0.005123
# 2022-11-24 13:32:00     193.401        16.61  0.014169   0.009726  0.004442
# 2022-11-24 13:33:00     193.330        16.62  0.013797   0.010334  0.003462
# 2022-11-24 13:34:00     193.475        16.60  0.014557   0.009119  0.005438
# 2022-11-24 13:35:00     193.473        16.61  0.014546   0.009726  0.004820
# 2022-11-24 13:36:00     193.848        16.64  0.016513   0.011550  0.004963
# 2022-11-24 13:37:00     193.682        16.64  0.015642   0.011550  0.004092
# 2022-11-24 13:38:00     193.596        16.62  0.015191   0.010334  0.004857
# 2022-11-24 13:39:00     193.562        16.63  0.015013   0.010942  0.004071
# 2022-11-24 13:40:00     193.889        16.64  0.016728   0.011550  0.005178
# 2022-11-24 13:41:00     194.156        16.67  0.018128   0.013374  0.004754
# 2022-11-24 13:42:00     194.000        16.68  0.017310   0.013982  0.003328
# 2022-11-24 13:43:00     193.993        16.66  0.017273   0.012766  0.004507
# 2022-11-24 13:44:00     193.800        16.66  0.016261   0.012766  0.003495
# 2022-11-24 13:45:00     193.704        16.63  0.015758   0.010942  0.004816
# 2022-11-24 13:46:00     193.715        16.63  0.015815   0.010942  0.004873
# 2022-11-24 13:47:00     193.979        16.63  0.017200   0.010942  0.006258
# 2022-11-24 13:48:00     193.815        16.63  0.016340   0.010942  0.005398
# 2022-11-24 13:49:00     193.819        16.66  0.016361   0.012766  0.003595
# 2022-11-24 13:50:00     193.959        16.69  0.017095   0.014590  0.002505
# 2022-11-24 13:51:00     193.978        16.67  0.017195   0.013374  0.003821
# 2022-11-24 13:52:00     194.276        16.70  0.018757   0.015198  0.003560
# 2022-11-24 13:53:00     194.330        16.67  0.019040   0.013374  0.005667
# 2022-11-24 13:54:00     194.299        16.72  0.018878   0.016413  0.002465
# 2022-11-24 13:55:00     194.491        16.73  0.019885   0.017021  0.002863
# 2022-11-24 13:56:00     194.803        16.72  0.021521   0.016413  0.005107
# 2022-11-24 13:57:00     194.628        16.71  0.020603   0.015805  0.004798
# 2022-11-24 13:58:00     194.436        16.71  0.019596   0.015805  0.003791
# 2022-11-24 13:59:00     194.817        16.72  0.021594   0.016413  0.005181
# 2022-11-24 14:00:00     194.686        16.73  0.020907   0.017021  0.003886
# 2022-11-24 14:01:00     195.002        16.75  0.022564   0.018237  0.004327
# 2022-11-24 14:02:00     194.812        16.75  0.021568   0.018237  0.003331
# 2022-11-24 14:03:00     194.490        16.73  0.019879   0.017021  0.002858
# 2022-11-24 14:04:00     194.560        16.73  0.020247   0.017021  0.003225
# 2022-11-24 14:05:00     194.520        16.73  0.020037   0.017021  0.003016
# 2022-11-24 14:06:00     194.292        16.71  0.018841   0.015805  0.003036
# 2022-11-24 14:07:00     194.506        16.73  0.019963   0.017021  0.002942
# 2022-11-24 14:08:00     194.482        16.72  0.019838   0.016413  0.003424
# 2022-11-24 14:09:00     194.300        16.70  0.018883   0.015198  0.003686
# 2022-11-24 14:10:00     194.491        16.72  0.019885   0.016413  0.003471
# 2022-11-24 14:11:00     194.522        16.72  0.020047   0.016413  0.003634
# 2022-11-24 14:12:00     194.380        16.72  0.019303   0.016413  0.002889
# 2022-11-24 14:13:00     194.023        16.70  0.017431   0.015198  0.002233
# 2022-11-24 14:14:00     194.411        16.70  0.019465   0.015198  0.004268
# 2022-11-24 14:15:00     194.216        16.69  0.018443   0.014590  0.003853
# 2022-11-24 14:16:00     194.202        16.65  0.018369   0.012158  0.006211
# 2022-11-24 14:17:00     194.096        16.65  0.017813   0.012158  0.005655
# 2022-11-24 14:18:00     194.293        16.68  0.018846   0.013982  0.004865
# 2022-11-24 14:19:00     194.326        16.68  0.019020   0.013982  0.005038
# 2022-11-24 14:20:00     194.380        16.68  0.019303   0.013982  0.005321
# 2022-11-24 14:21:00     194.380        16.70  0.019303   0.015198  0.004105
# 2022-11-24 14:22:00     194.360        16.68  0.019198   0.013982  0.005216
# 2022-11-24 14:23:00     194.434        16.69  0.019586   0.014590  0.004996
# 2022-11-24 14:24:00     194.322        16.68  0.018999   0.013982  0.005017
# 2022-11-24 14:25:00     194.290        16.69  0.018831   0.014590  0.004241
# 2022-11-24 14:26:00     194.072        16.67  0.017688   0.013374  0.004314
# 2022-11-24 14:27:00     194.011        16.68  0.017368   0.013982  0.003386
# 2022-11-24 14:28:00     194.130        16.65  0.017992   0.012158  0.005834
# 2022-11-24 14:29:00     194.049        16.63  0.017567   0.010942  0.006625
# 2022-11-24 14:30:00     193.976        16.61  0.017184   0.009726  0.007458
# 2022-11-24 14:31:00     193.897        16.62  0.016770   0.010334  0.006436
# 2022-11-24 14:32:00     194.291        16.68  0.018836   0.013982  0.004854
# 2022-11-24 14:33:00     194.375        16.69  0.019276   0.014590  0.004687
# 2022-11-24 14:34:00     194.437        16.70  0.019602   0.015198  0.004404
# 2022-11-24 14:35:00     194.345        16.68  0.019119   0.013982  0.005137
# 2022-11-24 14:36:00     194.407        16.69  0.019444   0.014590  0.004855
# 2022-11-24 14:37:00     194.345        16.68  0.019119   0.013982  0.005137
# 2022-11-24 14:38:00     193.918        16.66  0.016880   0.012766  0.004114
# 2022-11-24 14:39:00     194.058        16.66  0.017614   0.012766  0.004848
# 2022-11-24 14:40:00     194.206        16.68  0.018390   0.013982  0.004408
# 2022-11-24 14:41:00     194.002        16.67  0.017320   0.013374  0.003947
# 2022-11-24 14:42:00     193.870        16.67  0.016628   0.013374  0.003254
# 2022-11-24 14:43:00     193.808        16.68  0.016303   0.013982  0.002321
# 2022-11-24 14:44:00     193.636        16.68  0.015401   0.013982  0.001419
# 2022-11-24 14:45:00     193.948        16.67  0.017037   0.013374  0.003663
# 2022-11-24 14:46:00     194.095        16.67  0.017808   0.013374  0.004434
# 2022-11-24 14:47:00     193.943        16.67  0.017011   0.013374  0.003637
# 2022-11-24 14:48:00     193.910        16.67  0.016838   0.013374  0.003464
# 2022-11-24 14:49:00     193.992        16.66  0.017268   0.012766  0.004502
# 2022-11-24 14:50:00     194.189        16.69  0.018301   0.014590  0.003711
# 2022-11-24 14:51:00     194.200        16.69  0.018359   0.014590  0.003769
# 2022-11-24 14:52:00     194.274        16.69  0.018747   0.014590  0.004157
# 2022-11-24 14:53:00     194.322        16.70  0.018999   0.015198  0.003801
# 2022-11-24 14:54:00     194.390        16.71  0.019355   0.015805  0.003550
# 2022-11-24 14:55:00     194.275        16.70  0.018752   0.015198  0.003554
# 2022-11-24 14:56:00     194.112        16.70  0.017897   0.015198  0.002700
# 2022-11-24 14:57:00     194.090        16.70  0.017782   0.015198  0.002584
# 2022-11-24 14:58:00     194.090        16.70  0.017782   0.015198  0.002584
# 2022-11-24 14:59:00     194.090        16.70  0.017782   0.015198  0.002584
# 2022-11-24 15:00:00     194.120        16.69  0.017939   0.014590  0.003350
#
#                      bond_pos  stock_pos  premium rate
# 2022-11-23 15:00:00       0.0        0.0      0.025949
# 2022-11-24 09:30:00       0.0        0.0      0.031429
# 2022-11-24 09:31:00       0.0        0.0      0.030340
# 2022-11-24 09:32:00       0.0        0.0      0.031470
# 2022-11-24 09:33:00       0.0        0.0      0.030581
# 2022-11-24 09:34:00       0.0        0.0      0.028207
# 2022-11-24 09:35:00       0.0        0.0      0.027156
# 2022-11-24 09:36:00       0.0        0.0      0.026221
# 2022-11-24 09:37:00       0.0        0.0      0.028843
# 2022-11-24 09:38:00       0.0        0.0      0.026835
# 2022-11-24 09:39:00       0.0        0.0      0.023668
# 2022-11-24 09:40:00       0.0        0.0      0.021012
# 2022-11-24 09:41:00       0.0        0.0      0.021981
# 2022-11-24 09:42:00       0.0        0.0      0.019753
# 2022-11-24 09:43:00       0.0        0.0      0.021523
# 2022-11-24 09:44:00       0.0        0.0      0.021878
# 2022-11-24 09:45:00       0.0        0.0      0.023450
# 2022-11-24 09:46:00       0.0        0.0      0.022944
# 2022-11-24 09:47:00       0.0        0.0      0.025372
# 2022-11-24 09:48:00       0.0        0.0      0.026797
# 2022-11-24 09:49:00       0.0        0.0      0.027005
# 2022-11-24 09:50:00       0.0        0.0      0.024747
# 2022-11-24 09:51:00       0.0        0.0      0.022373
# 2022-11-24 09:52:00       0.0        0.0      0.023357
# 2022-11-24 09:53:00       0.0        0.0      0.022655
# 2022-11-24 09:54:00       0.0        0.0      0.025070
# 2022-11-24 09:55:00       0.0        0.0      0.023302
# 2022-11-24 09:56:00       0.0        0.0      0.024593
# 2022-11-24 09:57:00       0.0        0.0      0.024714
# 2022-11-24 09:58:00       0.0        0.0      0.026716
# 2022-11-24 09:59:00       0.0        0.0      0.025627
# 2022-11-24 10:00:00       0.0        0.0      0.028684
# 2022-11-24 10:01:00       0.0        0.0      0.028843
# 2022-11-24 10:02:00       0.0        0.0      0.027374
# 2022-11-24 10:03:00       0.0        0.0      0.028971
# 2022-11-24 10:04:00       0.0        0.0      0.027333
# 2022-11-24 10:05:00       0.0        0.0      0.026850
# 2022-11-24 10:06:00       0.0        0.0      0.029085
# 2022-11-24 10:07:00       0.0        0.0      0.028009
# 2022-11-24 10:08:00       0.0        0.0      0.028700
# 2022-11-24 10:09:00       0.0        0.0      0.028056
# 2022-11-24 10:10:00       0.0        0.0      0.027125
# 2022-11-24 10:11:00       0.0        0.0      0.026531
# 2022-11-24 10:12:00       0.0        0.0      0.025333
# 2022-11-24 10:13:00       0.0        0.0      0.029257
# 2022-11-24 10:14:00       0.0        0.0      0.029375
# 2022-11-24 10:15:00       0.0        0.0      0.028212
# 2022-11-24 10:16:00       0.0        0.0      0.030212
# 2022-11-24 10:17:00       0.0        0.0      0.031856
# 2022-11-24 10:18:00       0.0        0.0      0.031983
# 2022-11-24 10:19:00       0.0        0.0      0.031984
# 2022-11-24 10:20:00       0.0        0.0      0.032225
# 2022-11-24 10:21:00       0.0        0.0      0.031841
# 2022-11-24 10:22:00       0.0        0.0      0.032036
# 2022-11-24 10:23:00       0.0        0.0      0.032484
# 2022-11-24 10:24:00       0.0        0.0      0.032612
# 2022-11-24 10:25:00       0.0        0.0      0.033915
# 2022-11-24 10:26:00       0.0        0.0      0.033834
# 2022-11-24 10:27:00       0.0        0.0      0.031723
# 2022-11-24 10:28:00       0.0        0.0      0.034303
# 2022-11-24 10:29:00       0.0        0.0      0.031820
# 2022-11-24 10:30:00       0.0        0.0      0.032218
# 2022-11-24 10:31:00       0.0        0.0      0.030552
# 2022-11-24 10:32:00       0.0        0.0      0.030461
# 2022-11-24 10:33:00       0.0        0.0      0.032322
# 2022-11-24 10:34:00       0.0        0.0      0.031169
# 2022-11-24 10:35:00       0.0        0.0      0.031044
# 2022-11-24 10:36:00       0.0        0.0      0.029127
# 2022-11-24 10:37:00       0.0        0.0      0.030533
# 2022-11-24 10:38:00       0.0        0.0      0.031615
# 2022-11-24 10:39:00       0.0        0.0      0.030948
# 2022-11-24 10:40:00       0.0        0.0      0.030573
# 2022-11-24 10:41:00       0.0        0.0      0.030876
# 2022-11-24 10:42:00       0.0        0.0      0.028924
# 2022-11-24 10:43:00       0.0        0.0      0.029057
# 2022-11-24 10:44:00       0.0        0.0      0.029229
# 2022-11-24 10:45:00       0.0        0.0      0.029024
# 2022-11-24 10:46:00       0.0        0.0      0.029566
# 2022-11-24 10:47:00       0.0        0.0      0.028649
# 2022-11-24 10:48:00       0.0        0.0      0.029409
# 2022-11-24 10:49:00       0.0        0.0      0.031350
# 2022-11-24 10:50:00       0.0        0.0      0.032759
# 2022-11-24 10:51:00       0.0        0.0      0.032588
# 2022-11-24 10:52:00       0.0        0.0      0.029887
# 2022-11-24 10:53:00       0.0        0.0      0.028973
# 2022-11-24 10:54:00       0.0        0.0      0.028655
# 2022-11-24 10:55:00       0.0        0.0      0.026993
# 2022-11-24 10:56:00       0.0        0.0      0.026484
# 2022-11-24 10:57:00       0.0        0.0      0.024715
# 2022-11-24 10:58:00       0.0        0.0      0.023594
# 2022-11-24 10:59:00       0.0        0.0      0.025932
# 2022-11-24 11:00:00       0.0        0.0      0.026369
# 2022-11-24 11:01:00       0.0        0.0      0.027844
# 2022-11-24 11:02:00       0.0        0.0      0.029077
# 2022-11-24 11:03:00       0.0        0.0      0.030367
# 2022-11-24 11:04:00       0.0        0.0      0.032498
# 2022-11-24 11:05:00       0.0        0.0      0.031456
# 2022-11-24 11:06:00       0.0        0.0      0.030477
# 2022-11-24 11:07:00       0.0        0.0      0.030872
# 2022-11-24 11:08:00       0.0        0.0      0.029885
# 2022-11-24 11:09:00       0.0        0.0      0.029907
# 2022-11-24 11:10:00       0.0        0.0      0.030678
# 2022-11-24 11:11:00       0.0        0.0      0.029596
# 2022-11-24 11:12:00       0.0        0.0      0.028521
# 2022-11-24 11:13:00       0.0        0.0      0.029954
# 2022-11-24 11:14:00       0.0        0.0      0.029679
# 2022-11-24 11:15:00       0.0        0.0      0.028302
# 2022-11-24 11:16:00       0.0        0.0      0.029587
# 2022-11-24 11:17:00       0.0        0.0      0.029976
# 2022-11-24 11:18:00       0.0        0.0      0.029780
# 2022-11-24 11:19:00       0.0        0.0      0.030089
# 2022-11-24 11:20:00       0.0        0.0      0.029866
# 2022-11-24 11:21:00       0.0        0.0      0.030226
# 2022-11-24 11:22:00       0.0        0.0      0.029414
# 2022-11-24 11:23:00       0.0        0.0      0.028869
# 2022-11-24 11:24:00       0.0        0.0      0.029200
# 2022-11-24 11:25:00       0.0        0.0      0.028534
# 2022-11-24 11:26:00       0.0        0.0      0.028614
# 2022-11-24 11:27:00       0.0        0.0      0.027409
# 2022-11-24 11:28:00       0.0        0.0      0.028421
# 2022-11-24 11:29:00       0.0        0.0      0.028055
# 2022-11-24 11:30:00       0.0        0.0      0.028176
# 2022-11-24 13:00:00       0.0        0.0      0.030628
# 2022-11-24 13:01:00       0.0        0.0      0.029116
# 2022-11-24 13:02:00       0.0        0.0      0.029144
# 2022-11-24 13:03:00       0.0        0.0      0.028299
# 2022-11-24 13:04:00       0.0        0.0      0.029415
# 2022-11-24 13:05:00       0.0        0.0      0.030531
# 2022-11-24 13:06:00       0.0        0.0      0.030283
# 2022-11-24 13:07:00       0.0        0.0      0.030163
# 2022-11-24 13:08:00       0.0        0.0      0.030012
# 2022-11-24 13:09:00       0.0        0.0      0.032146
# 2022-11-24 13:10:00       0.0        0.0      0.031675
# 2022-11-24 13:11:00       0.0        0.0      0.031590
# 2022-11-24 13:12:00       0.0        0.0      0.029305
# 2022-11-24 13:13:00       0.0        0.0      0.029039
# 2022-11-24 13:14:00       0.0        0.0      0.029392
# 2022-11-24 13:15:00       0.0        0.0      0.028251
# 2022-11-24 13:16:00       0.0        0.0      0.028563
# 2022-11-24 13:17:00       0.0        0.0      0.029963
# 2022-11-24 13:18:00       0.0        0.0      0.030299
# 2022-11-24 13:19:00       0.0        0.0      0.029806
# 2022-11-24 13:20:00       0.0        0.0      0.028773
# 2022-11-24 13:21:00       0.0        0.0      0.028533
# 2022-11-24 13:22:00       0.0        0.0      0.029406
# 2022-11-24 13:23:00       0.0        0.0      0.028745
# 2022-11-24 13:24:00       0.0        0.0      0.030630
# 2022-11-24 13:25:00       0.0        0.0      0.029843
# 2022-11-24 13:26:00       0.0        0.0      0.028534
# 2022-11-24 13:27:00       0.0        0.0      0.030325
# 2022-11-24 13:28:00       0.0        0.0      0.028626
# 2022-11-24 13:29:00       0.0        0.0      0.029285
# 2022-11-24 13:30:00       0.0        0.0      0.030731
# 2022-11-24 13:31:00       0.0        0.0      0.031164
# 2022-11-24 13:32:00       0.0        0.0      0.030463
# 2022-11-24 13:33:00       0.0        0.0      0.029465
# 2022-11-24 13:34:00       0.0        0.0      0.031478
# 2022-11-24 13:35:00       0.0        0.0      0.030847
# 2022-11-24 13:36:00       0.0        0.0      0.030982
# 2022-11-24 13:37:00       0.0        0.0      0.030100
# 2022-11-24 13:38:00       0.0        0.0      0.030881
# 2022-11-24 13:39:00       0.0        0.0      0.030080
# 2022-11-24 13:40:00       0.0        0.0      0.031201
# 2022-11-24 13:41:00       0.0        0.0      0.030762
# 2022-11-24 13:42:00       0.0        0.0      0.029317
# 2022-11-24 13:43:00       0.0        0.0      0.030515
# 2022-11-24 13:44:00       0.0        0.0      0.029490
# 2022-11-24 13:45:00       0.0        0.0      0.030836
# 2022-11-24 13:46:00       0.0        0.0      0.030895
# 2022-11-24 13:47:00       0.0        0.0      0.032300
# 2022-11-24 13:48:00       0.0        0.0      0.031427
# 2022-11-24 13:49:00       0.0        0.0      0.029591
# 2022-11-24 13:50:00       0.0        0.0      0.028482
# 2022-11-24 13:51:00       0.0        0.0      0.029817
# 2022-11-24 13:52:00       0.0        0.0      0.029546
# 2022-11-24 13:53:00       0.0        0.0      0.031686
# 2022-11-24 13:54:00       0.0        0.0      0.028437
# 2022-11-24 13:55:00       0.0        0.0      0.028838
# 2022-11-24 13:56:00       0.0        0.0      0.031104
# 2022-11-24 13:57:00       0.0        0.0      0.030795
# 2022-11-24 13:58:00       0.0        0.0      0.029778
# 2022-11-24 13:59:00       0.0        0.0      0.031178
# 2022-11-24 14:00:00       0.0        0.0      0.029869
# 2022-11-24 14:01:00       0.0        0.0      0.030309
# 2022-11-24 14:02:00       0.0        0.0      0.029305
# 2022-11-24 14:03:00       0.0        0.0      0.028832
# 2022-11-24 14:04:00       0.0        0.0      0.029203
# 2022-11-24 14:05:00       0.0        0.0      0.028991
# 2022-11-24 14:06:00       0.0        0.0      0.029015
# 2022-11-24 14:07:00       0.0        0.0      0.028917
# 2022-11-24 14:08:00       0.0        0.0      0.029405
# 2022-11-24 14:09:00       0.0        0.0      0.029674
# 2022-11-24 14:10:00       0.0        0.0      0.029453
# 2022-11-24 14:11:00       0.0        0.0      0.029617
# 2022-11-24 14:12:00       0.0        0.0      0.028865
# 2022-11-24 14:13:00       0.0        0.0      0.028206
# 2022-11-24 14:14:00       0.0        0.0      0.030262
# 2022-11-24 14:15:00       0.0        0.0      0.029845
# 2022-11-24 14:16:00       0.0        0.0      0.032245
# 2022-11-24 14:17:00       0.0        0.0      0.031681
# 2022-11-24 14:18:00       0.0        0.0      0.030871
# 2022-11-24 14:19:00       0.0        0.0      0.031046
# 2022-11-24 14:20:00       0.0        0.0      0.031333
# 2022-11-24 14:21:00       0.0        0.0      0.030098
# 2022-11-24 14:22:00       0.0        0.0      0.031227
# 2022-11-24 14:23:00       0.0        0.0      0.031001
# 2022-11-24 14:24:00       0.0        0.0      0.031025
# 2022-11-24 14:25:00       0.0        0.0      0.030238
# 2022-11-24 14:26:00       0.0        0.0      0.030316
# 2022-11-24 14:27:00       0.0        0.0      0.029375
# 2022-11-24 14:28:00       0.0        0.0      0.031862
# 2022-11-24 14:29:00       0.0        0.0      0.032672
# 2022-11-24 14:30:00       0.0        0.0      0.033527
# 2022-11-24 14:31:00       0.0        0.0      0.032484
# 2022-11-24 14:32:00       0.0        0.0      0.030861
# 2022-11-24 14:33:00       0.0        0.0      0.030688
# 2022-11-24 14:34:00       0.0        0.0      0.030400
# 2022-11-24 14:35:00       0.0        0.0      0.031147
# 2022-11-24 14:36:00       0.0        0.0      0.030858
# 2022-11-24 14:37:00       0.0        0.0      0.031147
# 2022-11-24 14:38:00       0.0        0.0      0.030117
# 2022-11-24 14:39:00       0.0        0.0      0.030860
# 2022-11-24 14:40:00       0.0        0.0      0.030410
# 2022-11-24 14:41:00       0.0        0.0      0.029945
# 2022-11-24 14:42:00       0.0        0.0      0.029244
# 2022-11-24 14:43:00       0.0        0.0      0.028298
# 2022-11-24 14:44:00       0.0        0.0      0.027385
# 2022-11-24 14:45:00       0.0        0.0      0.029658
# 2022-11-24 14:46:00       0.0        0.0      0.030438
# 2022-11-24 14:47:00       0.0        0.0      0.029631
# 2022-11-24 14:48:00       0.0        0.0      0.029456
# 2022-11-24 14:49:00       0.0        0.0      0.030510
# 2022-11-24 14:50:00       0.0        0.0      0.029702
# 2022-11-24 14:51:00       0.0        0.0      0.029760
# 2022-11-24 14:52:00       0.0        0.0      0.030153
# 2022-11-24 14:53:00       0.0        0.0      0.029790
# 2022-11-24 14:54:00       0.0        0.0      0.029534
# 2022-11-24 14:55:00       0.0        0.0      0.029541
# 2022-11-24 14:56:00       0.0        0.0      0.028677
# 2022-11-24 14:57:00       0.0        0.0      0.028561
# 2022-11-24 14:58:00       0.0        0.0      0.028561
# 2022-11-24 14:59:00       0.0        0.0      0.028561
# 2022-11-24 15:00:00       0.0        0.0      0.029336

# %%
# 到期时间很短，且价内50%的时候，转债近似等价于正股
def cal_premium_rate(bond_price,stock_price,convert_price):
    tmp = 100/convert_price*stock_price
    res = (bond_price - tmp)/tmp
    return res
cal_premium_rate(200,140,70)
# Out:
# 0.0
