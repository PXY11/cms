# %% [markdown]
# # import data

# %%
from WindPy import *

#Wind API 使用W账户密码登录
w.start() 

#return True and then can go to next operation.
w.isconnected()

import pandas as pd
# Out:
# 22.9.1.52437
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2021 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
# w.wsi("123046.SZ,300587.SZ,113642.SH,603185.SH,110061.SH,600674.SH,128081.SZ,002203.SZ,113016.SH,601127.SH,128017.SZ,002597.SZ",  "close",  "2022-09-06 09:00:00",  "2022-09-09 16:28:08",  "")

# %%
cbond_list = ['123046.SZ','300587.SZ',
'113642.SH','603185.SH', #转债已退市
'110061.SH','600674.SH',
'128081.SZ','002203.SZ',
'113016.SH','601127.SH',
'128017.SZ','002597.SZ',
'113537.SH','603348.SH',
'123027.SZ','300487.SZ', #转债已退市
'113534.SH','603876.SH',
'113025.SH','601677.SH',
'123031.SZ','300655.SZ',
'128029.SZ','002078.SZ',
'128111.SZ','002738.SZ', #2022-10-14新增4个对子
'128095.SZ','002812.SZ',
'113626.SH','603596.SH',
'123092.SZ','300332.SZ',
'123057.SZ','300586.SZ',#2020-11-18新增3个对子
'123067.SZ','300382.SZ',
'128106.SZ','002840.SZ',
]

# %% [markdown]
# # history trade days

# %%
# ###############################################################
# before_trade_date = '20220908'#监测当日前一个交易日
# present_date = '20220909' #监测当日
# next_trade_date = '20220910' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220909'#监测当日前一个交易日
# present_date = '20220913' #监测当日
# next_trade_date = '20220914' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220913'#监测当日前一个交易日
# present_date = '20220914' #监测当日
# next_trade_date = '20220915' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220914'#监测当日前一个交易日
# present_date = '20220915' #监测当日
# next_trade_date = '20220916' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220915'#监测当日前一个交易日
# present_date = '20220916' #监测当日
# next_trade_date = '20220917' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220916'#监测当日前一个交易日
# present_date = '20220919' #监测当日
# next_trade_date = '20220920' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220919'#监测当日前一个交易日
# present_date = '20220920' #监测当日
# next_trade_date = '20220921' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220920'#监测当日前一个交易日
# present_date = '20220921' #监测当日
# next_trade_date = '20220922' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220921'#监测当日前一个交易日
# present_date = '20220922' #监测当日
# next_trade_date = '20220923' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220922'#监测当日前一个交易日
# present_date = '20220923' #监测当日
# next_trade_date = '20220924' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220923'#监测当日前一个交易日
# present_date = '20220926' #监测当日
# next_trade_date = '20220927' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220926'#监测当日前一个交易日
# present_date = '20220927' #监测当日
# next_trade_date = '20220928' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220927'#监测当日前一个交易日
# present_date = '20220928' #监测当日
# next_trade_date = '20220929' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220928'#监测当日前一个交易日
# present_date = '20220929' #监测当日
# next_trade_date = '20220930' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220929'#监测当日前一个交易日
# present_date = '20220930' #监测当日
# next_trade_date = '20221001' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220930'#监测当日前一个交易日
# present_date = '20221010' #监测当日
# next_trade_date = '20221011' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221010'#监测当日前一个交易日
# present_date = '20221011' #监测当日
# next_trade_date = '20221012' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221011'#监测当日前一个交易日
# present_date = '20221012' #监测当日
# next_trade_date = '20221013' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221012'#监测当日前一个交易日
# present_date = '20221013' #监测当日
# next_trade_date = '20221014' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221013'#监测当日前一个交易日
# present_date = '20221014' #监测当日
# next_trade_date = '20221015' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221014'#监测当日前一个交易日
# present_date = '20221017' #监测当日
# next_trade_date = '20221018' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221017'#监测当日前一个交易日
# present_date = '20221018' #监测当日
# next_trade_date = '20221019' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221018'#监测当日前一个交易日
# present_date = '20221019' #监测当日
# next_trade_date = '20221020' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221019'#监测当日前一个交易日
# present_date = '20221020' #监测当日
# next_trade_date = '20221021' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221020'#监测当日前一个交易日
# present_date = '20221021' #监测当日
# next_trade_date = '20221022' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221021'#监测当日前一个交易日
# present_date = '20221024' #监测当日
# next_trade_date = '20221025' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221024'#监测当日前一个交易日
# present_date = '20221025' #监测当日
# next_trade_date = '20221026' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221025'#监测当日前一个交易日
# present_date = '20221026' #监测当日
# next_trade_date = '20221027' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221026'#监测当日前一个交易日
# present_date = '20221027' #监测当日
# next_trade_date = '20221028' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221027'#监测当日前一个交易日
# present_date = '20221028' #监测当日
# next_trade_date = '20221029' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221028'#监测当日前一个交易日
# present_date = '20221031' #监测当日
# next_trade_date = '20221101' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221031'#监测当日前一个交易日
# present_date = '20221101' #监测当日
# next_trade_date = '20221102' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221101'#监测当日前一个交易日
# present_date = '20221102' #监测当日
# next_trade_date = '20221103' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221102'#监测当日前一个交易日
# present_date = '20221103' #监测当日
# next_trade_date = '20221104' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221103'#监测当日前一个交易日
# present_date = '20221104' #监测当日
# next_trade_date = '20221105' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221104'#监测当日前一个交易日
# present_date = '20221107' #监测当日
# next_trade_date = '20221108' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221107'#监测当日前一个交易日
# present_date = '20221108' #监测当日
# next_trade_date = '20221109' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221108'#监测当日前一个交易日
# present_date = '20221109' #监测当日
# next_trade_date = '20221110' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221109'#监测当日前一个交易日
# present_date = '20221110' #监测当日
# next_trade_date = '20221111' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221110'#监测当日前一个交易日
# present_date = '20221111' #监测当日
# next_trade_date = '20221112' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221111'#监测当日前一个交易日
# present_date = '20221114' #监测当日
# next_trade_date = '20221115' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221114'#监测当日前一个交易日
# present_date = '20221115' #监测当日
# next_trade_date = '20221116' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221115'#监测当日前一个交易日
# present_date = '20221116' #监测当日
# next_trade_date = '20221117' #监测当日下一个自然日
# ###############################################################

# %%
# ###############################################################
# before_trade_date = '20221116'#监测当日前一个交易日
# present_date = '20221117' #监测当日
# next_trade_date = '20221118' #监测当日下一个自然日
# ###############################################################

# ###############################################################
before_trade_date = '20221117'#监测当日前一个交易日
present_date = '20221118' #监测当日
next_trade_date = '20221119' #监测当日下一个自然日
# ###############################################################

# %%
start_date = pd.to_datetime(before_trade_date) 
end_date = pd.to_datetime(next_trade_date)

cbond_price = pd.DataFrame([])
for code in cbond_list:
    price_df = w.wsi(code, "close", start_date, end_date,usedf=True)[1]   #只要了收盘价
    price_df.columns = [code]
    cbond_price = pd.concat([cbond_price,price_df],axis=1)
cbond_price = cbond_price.ffill()    
# cbond_rtn = cbond_price[cbond_price.index.time!=time(15,0,0)]
# cbond_price = cbond_price.loc['2022-09-09 15:00:00':] #从前一个交易日的收盘价开始截取
cbond_price_begin_time = before_trade_date[:4]+'-' + \
                    before_trade_date[4:6]+'-' + \
                    before_trade_date[6:8]+' 15:00:00'
cbond_price = cbond_price.loc[cbond_price_begin_time:]
cbond_price
# Out:
#                      123046.SZ  300587.SZ  113642.SH  603185.SH  110061.SH  \
# 2022-11-17 15:00:00    351.400      12.10        NaN     126.26    129.764
# 2022-11-18 09:30:00    354.108      12.20        NaN     125.56    130.124
# 2022-11-18 09:31:00    351.042      12.09        NaN     124.92    130.016
# 2022-11-18 09:32:00    354.747      12.18        NaN     124.89    130.370
# 2022-11-18 09:33:00    355.998      12.20        NaN     124.39    129.950
# ...                        ...        ...        ...        ...        ...
# 2022-11-18 14:56:00    352.250      12.18        NaN     125.25    130.619
# 2022-11-18 14:57:00    352.242      12.18        NaN     125.27    130.500
# 2022-11-18 14:58:00    352.242      12.18        NaN     125.27    130.500
# 2022-11-18 14:59:00    352.242      12.18        NaN     125.27    130.639
# 2022-11-18 15:00:00    352.368      12.19        NaN     125.28    130.565
#
#                      600674.SH  128081.SZ  002203.SZ  113016.SH  601127.SH  \
# 2022-11-17 15:00:00      11.27    129.163      12.36    332.017      50.98
# 2022-11-18 09:30:00      11.27    128.500      12.22    335.979      50.90
# 2022-11-18 09:31:00      11.27    128.535      12.16    333.777      50.45
# 2022-11-18 09:32:00      11.30    128.160      12.20    333.312      50.55
# 2022-11-18 09:33:00      11.27    128.022      12.21    330.661      49.98
# ...                        ...        ...        ...        ...        ...
# 2022-11-18 14:56:00      11.36    127.177      12.12    327.005      49.07
# 2022-11-18 14:57:00      11.36    127.177      12.12    327.101      49.08
# 2022-11-18 14:58:00      11.36    127.177      12.12    327.100      49.08
# 2022-11-18 14:59:00      11.36    127.177      12.12    327.225      49.08
# 2022-11-18 15:00:00      11.37    127.100      12.15    327.187      49.07
#
#                      ...  113626.SH  603596.SH  123092.SZ  300332.SZ  \
# 2022-11-17 15:00:00  ...    228.875      80.72    254.750      12.66
# 2022-11-18 09:30:00  ...    228.482      80.17    254.984      12.68
# 2022-11-18 09:31:00  ...    225.817      79.64    254.368      12.61
# 2022-11-18 09:32:00  ...    224.885      79.66    253.855      12.65
# 2022-11-18 09:33:00  ...    223.108      78.81    253.100      12.60
# ...                  ...        ...        ...        ...        ...
# 2022-11-18 14:56:00  ...    221.729      79.31    253.115      12.54
# 2022-11-18 14:57:00  ...    222.194      79.31    253.115      12.54
# 2022-11-18 14:58:00  ...    222.008      79.31    253.115      12.54
# 2022-11-18 14:59:00  ...    221.143      79.31    253.115      12.54
# 2022-11-18 15:00:00  ...    221.760      79.49    253.900      12.54
#
#                      123057.SZ  300586.SZ  123067.SZ  300382.SZ  128106.SZ  \
# 2022-11-17 15:00:00    221.600      20.99    240.310      23.85    197.000
# 2022-11-18 09:30:00    219.564      20.80    240.539      23.75    196.068
# 2022-11-18 09:31:00    218.135      20.60    239.496      23.46    196.011
# 2022-11-18 09:32:00    217.581      20.56    239.443      23.58    196.319
# 2022-11-18 09:33:00    215.585      20.34    238.415      23.46    196.090
# ...                        ...        ...        ...        ...        ...
# 2022-11-18 14:56:00    216.080      20.38    234.244      23.03    193.706
# 2022-11-18 14:57:00    216.418      20.39    234.247      23.07    193.853
# 2022-11-18 14:58:00    216.418      20.39    234.247      23.07    193.853
# 2022-11-18 14:59:00    216.418      20.39    234.247      23.07    193.853
# 2022-11-18 15:00:00    216.800      20.39    233.101      23.18    194.300
#
#                      002840.SZ
# 2022-11-17 15:00:00      17.18
# 2022-11-18 09:30:00      17.21
# 2022-11-18 09:31:00      17.24
# 2022-11-18 09:32:00      17.29
# 2022-11-18 09:33:00      17.25
# ...                        ...
# 2022-11-18 14:56:00      17.06
# 2022-11-18 14:57:00      17.05
# 2022-11-18 14:58:00      17.05
# 2022-11-18 14:59:00      17.05
# 2022-11-18 15:00:00      17.05
#
# [243 rows x 38 columns]

# %%
# assert False

# %% [markdown]
# # stock pre status

# %%
df_stk_pre_return = w.wss("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return
# Out:
#             PCT_CHG
# 300587.SZ -2.419355
# 603185.SH -2.547082
# 600674.SH -1.657941
# 002203.SZ -4.408353
# 601127.SH -3.829466
# 002597.SZ -0.254381
# 603348.SH -6.386067
# 300487.SZ -3.760252
# 603876.SH -5.001042
# 601677.SH -2.142407
# 300655.SZ  5.241215
# 002078.SZ -1.120448
# 002738.SZ -4.376209
# 002812.SZ -2.399093
# 603596.SH -5.700935
# 300332.SZ -2.012384
# 300586.SZ  1.400966
# 300382.SZ -2.294142
# 002840.SZ  9.987196

# %%
df_bond_pre_return = w.wss("123046.SZ,113642.SH,110061.SH,128081.SZ,113016.SH,128017.SZ,113537.SH,123027.SZ,113534.SH,113025.SH,123031.SZ,128029.SZ,128111.SZ,128095.SZ,113626.SH,123092.SZ,123057.SZ,123067.SZ,128106.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_bond_pre_return
# Out:
#             PCT_CHG
# 123046.SZ -2.928177
# 113642.SH       NaN
# 110061.SH -1.683512
# 128081.SZ -3.680144
# 113016.SH -4.000821
# 128017.SZ -3.759683
# 113537.SH -5.618412
# 123027.SZ       NaN
# 113534.SH -5.268454
# 113025.SH -4.009891
# 123031.SZ  0.583090
# 128029.SZ -1.073359
# 128111.SZ -4.804561
# 128095.SZ -6.145003
# 113626.SH -5.962134
# 123092.SZ -2.394636
# 123057.SZ  1.520982
# 123067.SZ -4.067864
# 128106.SZ  7.065217

# %%
before_trade_date_trade_status = before_trade_date[:4] +'-'+ before_trade_date[4:6] +'-'+ before_trade_date[6:]
# present_date_trade_status = present_date[:4] +'-'+ present_date[4:6] +'-'+ present_date[6:]
df_stk_pre_trade_status = w.wsd("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ", 
"trade_status", f"{before_trade_date_trade_status}", f"{before_trade_date_trade_status}", "",usedf=True)[1]
df_stk_pre_trade_status
# Out:
#           TRADE_STATUS
# 300587.SZ           交易
# 603185.SH           交易
# 600674.SH           交易
# 002203.SZ           交易
# 601127.SH           交易
# 002597.SZ           交易
# 603348.SH           交易
# 300487.SZ           交易
# 603876.SH           交易
# 601677.SH           交易
# 300655.SZ           交易
# 002078.SZ           交易
# 002738.SZ           交易
# 002812.SZ           交易
# 603596.SH           交易
# 300332.SZ           交易
# 300586.SZ           交易
# 300382.SZ           交易
# 002840.SZ           交易

# %%
# assert False

# %% [markdown]
# # bond-stock pair

# %%
# cbond_pair = ['113642.SH','603185.SH']  #后面筛选的结果，这组也在里面 转债停止交易了
# open_threshold = 0.023
# close_threshold = 0
# convert_price = 102.4
# operate = True

# cbond_pair = ['123027.SZ','300487.SZ',] # 1019 1020 1021 这几天转债停止交易了
# open_threshold = 0.022
# close_threshold = 0
# convert_price = 19.07
# operate = True

# %%
# cbond_pair = ['123046.SZ','300587.SZ'] #这个被操纵了，每日总结的时候剔除掉
# open_threshold = 0.015
# close_threshold = 0
# convert_price = 3.94
# operate = True

# cbond_pair = ['110061.SH','600674.SH']
# open_threshold = 0.006
# close_threshold = 0
# convert_price = 8.8
# operate = False

# cbond_pair = ['128081.SZ','002203.SZ']
# open_threshold = 0.012
# close_threshold = 0.002
# convert_price = 9.62
# operate = False

# cbond_pair = ['113016.SH','601127.SH'] #这个被操纵了，每日总结的时候剔除掉
# open_threshold = 0.017
# close_threshold = 0.003
# convert_price = 20.17
# operate = True

# cbond_pair = ['128017.SZ','002597.SZ']
# open_threshold = 0.012
# close_threshold = 0
# convert_price = 21.33
# operate = True

# # $$$$$$$$$$$$$$$$$$$$$$$$以下是新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
# cbond_pair = ['113537.SH','603348.SH',]
# open_threshold = 0.027
# close_threshold = 0.002
# convert_price = 19.13
# operate = True

# cbond_pair = ['113534.SH','603876.SH',]
# open_threshold = 0.019
# close_threshold = 0.002
# convert_price = 14.98
# operate = True

# cbond_pair = ['113025.SH','601677.SH',]
# open_threshold = 0.018
# close_threshold = 0
# convert_price = 7.66
# operate = True

# cbond_pair = ['123031.SZ','300655.SZ',]   #这个被操纵了，每日总结的时候剔除掉
# open_threshold = 0.019
# close_threshold = 0
# convert_price = 6.25
# operate = True

# cbond_pair = ['128029.SZ','002078.SZ']
# open_threshold = 0.013
# close_threshold = 0.002
# convert_price = 8.25
# operate = True

# # $$$$$$$$$$$$$$$$$$$$$$$$【2022-10-14】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
# cbond_pair = ['128111.SZ','002738.SZ'] #这个被操纵了，每日总结的时候剔除掉
# open_threshold = 0.011
# close_threshold = 0.001
# convert_price = 10.96
# operate = True

# cbond_pair = ['128095.SZ','002812.SZ']
# open_threshold = 0.013
# close_threshold = 0
# convert_price = 64.62
# operate = True

# cbond_pair = ['113626.SH','603596.SH']
# open_threshold = 0.02
# close_threshold = 0
# convert_price = 35.88
# operate = True

# cbond_pair = ['123092.SZ','300332.SZ']
# open_threshold = 0.025
# close_threshold = 0.001
# convert_price = 5.14
# operate = True

# # $$$$$$$$$$$$$$$$$$$$$$$$【2022-11-18】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair =  ['123057.SZ','300586.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.009 
close_threshold = 0.003
convert_price = 9.5
operate = True

cbond_pair =  ['123067.SZ','300382.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.004
close_threshold = 0.002
convert_price = 9.96
operate = True

cbond_pair =  ['128106.SZ','002840.SZ']
open_threshold = 0.01
close_threshold = 0
convert_price = 8.85
operate = True

# %%
# df_signal

# %% [markdown]
# # clip price series

# %%
#从前一个交易日的收盘价开始截取
# cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]].loc['2022-09-08 15:00:00':]
cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]]

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-17 15:00:00    197.000      17.18
# 2022-11-18 09:30:00    196.068      17.21
# 2022-11-18 09:31:00    196.011      17.24
# 2022-11-18 09:32:00    196.319      17.29
# 2022-11-18 09:33:00    196.090      17.25

# %%
cbond_return = pd.DataFrame([])

cbond_preclose = cbond_pair_price.iloc[0,0] # 初始时刻的bond前收盘价
stock_preclose = cbond_pair_price.iloc[0,1] # 初始时刻的stock前收盘价

for index,row in cbond_pair_price.iterrows():
    
    cbond_return.loc[index,cbond_pair[0]] = row[cbond_pair[0]]/cbond_preclose - 1 # 算日内的return
    cbond_return.loc[index,cbond_pair[1]] = row[cbond_pair[1]]/stock_preclose - 1

    if index.time()==time(15,0,0):  #算完日内return，迭代到今日价格的最后一个time bar的时候，将其设为前收盘价
        cbond_preclose = row[cbond_pair[0]]    # 日内return指标用 现价/昨日收盘价 计算
        stock_preclose = row[cbond_pair[1]]
        
# 检查df是否有空值
cbond_return.isnull().sum(axis=0)  # 按列统计
cbond_return.isnull().sum(axis=1) # 按行统计
cbond_return.isnull().sum(axis=1).sum() # 统计整张表
# Out:
# 0

# %%
pd.set_option('display.max_rows', None)
cbond_return['diff'] = cbond_return[cbond_pair[0]] - cbond_return[cbond_pair[1]]
cbond_return.head()
# Out:
#                      128106.SZ  002840.SZ      diff
# 2022-11-17 15:00:00   0.000000   0.000000  0.000000
# 2022-11-18 09:30:00  -0.004731   0.001746 -0.006477
# 2022-11-18 09:31:00  -0.005020   0.003492 -0.008513
# 2022-11-18 09:32:00  -0.003457   0.006403 -0.009860
# 2022-11-18 09:33:00  -0.004619   0.004075 -0.008694

# %% [markdown]
# # signal calculate

# %%
################################################################################################
stk_pre_return = df_stk_pre_return.loc[cbond_pair[1]].values[0]
bond_pre_return = df_bond_pre_return.loc[cbond_pair[0]].values[0]
pre_diff = bond_pre_return - stk_pre_return
stk_pre_trade_status = df_stk_pre_trade_status.loc[cbond_pair[1]].values[0]
print(stk_pre_trade_status)
print('pre diff:',pre_diff)
# if abs(stk_pre_return) > 10 or stk_pre_trade_status!='交易':
if abs(pre_diff) > 5 or stk_pre_trade_status!='交易':
    # 如果前一天股票的跌幅小于-10，则今日不做操作
    intraday_open_times = 1
else:
    intraday_open_times = 0
################################################################################################    
open_close_spread = open_threshold - close_threshold
# intraday_open_times = 0
max_open = 1

pos_open_flag = 0
neg_open_flag = 0
cbond_position = pd.DataFrame([])
cbond_position.index = cbond_return.index
for index,row in cbond_return.iterrows():

    if row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff落在A区间，且无仓位，正开
            pos_open_flag = 1
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==1:
        if intraday_open_times < max_open:
            #diff落在A区间，且有负仓，平仓再正开
            pos_open_flag=1
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            print('reverse open +1')
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff落在A区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在B区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在B区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在B区间，且无仓，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在C区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在C区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在C区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在D区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在D区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在D区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且无仓位，反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==1 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且有正仓，平仓反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在E区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    if abs(row['diff'])>2 * open_close_spread and cbond_return.columns[0]!='123057.SZ' and cbond_return.columns[0]!='123067.SZ': 
        #盘中diff超过2倍spread时平仓（价格止损信号）,有两个spread特别小的对子则不用此逻辑进行止损
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if index.time()==time(15,0,0): # 每日收盘时必须平仓（时间止损信号）
    # if index.time()==time(14,59,0): # 每日收盘时必须平仓（时间止损信号）
        intraday_open_times = 0 # 下一天开盘前，把当日记录下来的开仓次数清零
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
# Out:
# 交易
# pre diff: -2.921978511384525

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-17 15:00:00    197.000      17.18
# 2022-11-18 09:30:00    196.068      17.21
# 2022-11-18 09:31:00    196.011      17.24
# 2022-11-18 09:32:00    196.319      17.29
# 2022-11-18 09:33:00    196.090      17.25

# %%
df_signal = pd.concat([cbond_pair_price,cbond_return,cbond_position],axis=1)
df_signal.columns = ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
print('open threshold',open_threshold,'close threshold',close_threshold)
# df_signal.to_csv('tmp_signal.csv')
# df_signal
# Out:
# open threshold 0.01 close threshold 0

# %% [markdown]
# # backtest

# %%
# 用来记录交易流水的表格,一边遍历df_signal，一边填入内容到流水表格里

import numpy as np
cols = ['balance','signal','bond price','stock price','bond hold','stock hold','commission','tax','reverse open','diff','asset value']
df_trade = pd.DataFrame(
    data = [[0,np.nan,np.nan,np.nan,0,0,0,0,np.nan,np.nan,0]],
    columns=cols
    ) 

balance_last = 0 # 现金账户初始余额

bond_hold = 0 # 债券持有数量
stock_hold = 0 # 股票持有数量


commission_rate = 2/10000 + 0 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 0.5/1000 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 1/1000 # 佣金买卖万二 + 交易滑点

tax_rate = 1/1000 # 卖股票才收印花税千一

# commission_rate = 0/10000 # 佣金买卖万二
# tax_rate = 0/1000 #

for i in range(len(df_signal)-1):
    if df_signal.index[i].time() == time(15,0,0):
    # if df_signal.index[i].time() == time(14,59,0):
        # 修改stock volume 每天固定一个stock volume 应该用债的前收盘价/股票的前收盘价
        stock_volume = df_signal['bond_price'][i]/df_signal['stock_price'][i]

    if df_signal.values[i][-1] != df_signal.values[i+1][-1]:

        index = df_signal.index[i+1]        
        diff = df_signal.values[i+1][-3] #diff在df_signal中的倒数第三列
        
    # df_signal的columns
    # ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
        signal = str(int(df_signal.values[i+1][-2]))+str(int(df_signal.values[i+1][-1]))
        
        bond_price = df_signal.values[i+1][0] 

        stock_price = df_signal.values[i+1][1]

        # stock_volume =  bond_price/stock_price # 修改stock volume 每天固定一个stock volume应该用债的前收盘价/股票的前收盘价

        commission = (bond_price + stock_price * stock_volume) * commission_rate

        reverse_open = False #表明这笔交易，是否包含平仓后再反向开仓的操作

        if signal == '00' and stock_hold == stock_volume: #有股票持仓并且需要卖出平仓时，有印花税
            tax = stock_price * tax_rate * stock_volume
        else:
            tax = 0

        if signal == '00':
            balance_last += bond_hold*bond_price
            balance_last += stock_hold*stock_price
            
            bond_hold = 0
            stock_hold = 0
            

        if signal == '1-1':
            '''
            加一个检测之前持仓的模块,如果之前因为-11的信号有持仓,需要先平掉(即买债卖股票),同时再反向开仓
            '''
            reverse_flag = False
            if bond_hold == -1 and stock_hold == 1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last -= bond_price 
                balance_last += stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税
                reverse_flag = True
                reverse_open = True

            bond_hold += 1
            stock_hold += (-1 * stock_volume)
            # stock_hold += stock_volume
            balance_last -= bond_price
            balance_last += stock_price * stock_volume
            
            if reverse_flag:
                tax *= 2 #平仓然后反向开仓的时候 已经计算过tax了，直接double
            else:
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税

        if signal == '-11':
            '''
            加一个检测之前持仓的模块,如果之前因为1-1的信号有持仓,需要先平掉(卖债买股票),同时再反向开仓
            '''
            if bond_hold == 1 and stock_hold == -1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last += bond_price
                balance_last -= stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                                # 买股票无印花税
                reverse_open = True
            bond_hold += -1
            stock_hold += (1 * stock_volume)
            # stock_hold += stock_volume
            balance_last += bond_price
            balance_last -= stock_price * stock_volume
        
        balance_last = balance_last - commission - tax
        balance = balance_last
        asset_value = bond_price*bond_hold + stock_price*stock_hold
        line = [balance,signal,bond_price,stock_price,bond_hold,stock_hold,commission,tax,reverse_open,diff,asset_value]
        # df_trade.loc[index,['balance','asset','signal','bond price','stock price','commission','tax']] = line
        # df_trade.loc[index,cols] = [0,0,np.nan,np.nan,np.nan,0,0,0,0]
        df_trade.loc[index,cols] = line

df_trade.rename(columns={'balance':'cash'},inplace=True)       
df_trade['net value'] = df_trade['cash'] + df_trade['asset value']

# %%
df_trade['operate'] = [operate]*len(df_trade)

# %%
df_trade
# Out:
#                          cash signal  bond price  stock price  bond hold  \
# 0                    0.000000    NaN         NaN          NaN        0.0
# 2022-11-18 09:34:00  2.624826    1-1     194.787        17.24        1.0
# 2022-11-18 13:05:00  2.937510     00     192.000        16.71        0.0
#
#                      stock hold  commission       tax reverse open      diff  \
# 0                      0.000000    0.000000  0.000000          NaN       NaN
# 2022-11-18 09:34:00  -11.466822    0.078495  0.197688        False -0.014726
# 2022-11-18 13:05:00    0.000000    0.076722  0.000000        False  0.001977
#
#                      asset value  net value  operate
# 0                       0.000000   0.000000     True
# 2022-11-18 09:34:00    -2.901009  -0.276183     True
# 2022-11-18 13:05:00     0.000000   2.937510     True

# %% [markdown]
# # output to csv

# %%
# excel_file_name = './daily_track/'+ present_date+'/' + cbond_pair[0] + '@' + cbond_pair[1] + '.csv'

# excel_file_name

# df_to_excel = df_trade
# df_to_excel['open/close'] = [str(open_threshold)+','+str(close_threshold)]*len(df_to_excel)
# df_to_excel['pair'] = [cbond_pair[0] + '@' + cbond_pair[1]]*len(df_to_excel)
# df_to_excel = df_to_excel[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
#                                             'stock hold', 'commission', 'tax', 'reverse open', 'diff',
#                                             'asset value', 'net value', 'open/close','operate']]
# df_to_excel.to_csv(excel_file_name,)

# %%
present_date
# Out:
# '20221118'

# %% [markdown]
# # conclusion

# %%
# import os
# single_trade_files = os.listdir('./daily_track'+'/'+present_date)

# df_trade_conclusion = pd.DataFrame([])
# for file in single_trade_files:
#     if file == 'diff':
#         continue
#     if file == '.DS_Store' or file.split('.')[1] == 'xlsx':
#         continue
#     tmp_path = './daily_track'+'/'+present_date+'/'+file
#     df_tmp = pd.read_csv(tmp_path,index_col=0)
#     tmp_col = list(df_tmp.columns)
#     df_tmp_head = pd.DataFrame(data=[tmp_col],columns=tmp_col)
#     df_trade_conclusion = df_trade_conclusion.append(df_tmp_head)
#     df_trade_conclusion = df_trade_conclusion.append(df_tmp)
# df_trade_conclusion.columns
# df_trade_conclusion = df_trade_conclusion[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
#                                             'stock hold', 'commission', 'tax', 'reverse open', 'diff',
#                                             'asset value', 'net value', 'open/close','operate']]
# df_trade_conclusion
# tmp_path = './daily_track'+'/'+present_date+'/'+f'{present_date}_conclusion.csv'

# df_trade_conclusion.to_csv(tmp_path)

# %% [markdown]
# # intraday signal

# %%
import matplotlib.pyplot as plt

signal_plot_begin_time = present_date[:4]+'-' + \
                         present_date[4:6]+'-' + \
                         present_date[6:8]+' 09:30:00'
df_signal['diff'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' diff',grid=True)

#如果当日有开平仓记录，在图上画出开平仓时刻的标注
if len(df_trade) == 3:
    open_tick = df_trade.index.to_list()[1]
    open_diff = df_trade['diff'].to_list()[1]
    close_tick = df_trade.index.to_list()[2]
    close_diff =  df_trade['diff'].to_list()[2]
    plt.text(open_tick,open_diff,'open')
    plt.text(close_tick,close_diff,'close')
    plt.scatter([open_tick],[open_diff],color='r')

    tmp_nv = df_trade['net value'].to_list()[2]
    if tmp_nv > 0: 
        close_color = 'g' #当天赚钱的话，平仓点位标记为绿色
    else:
        close_color = 'orange' #当天亏钱的话，平仓点位标记为橙色
    plt.scatter([close_tick],[close_diff],color=close_color)
fig_file_name = './daily_track/'+ present_date+'/'+'diff/' + cbond_pair[0] + '@' + cbond_pair[1] + '.png'
plt.savefig(fig_file_name)

plt.show()
df_signal['bond_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+' rtn',grid=True)
plt.show()
df_signal['stock_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[1]+' rtn',grid=True)
plt.show()

# %%
df_tmp = 100/convert_price*df_signal['stock_price']
df_signal['premium rate'] = (df_signal['bond_price'] - df_tmp)/df_tmp
df_signal['premium rate'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' premium rate',grid=True)
# Out:
# <AxesSubplot:title={'center':'128106.SZ@002840.SZ premium rate'}>

# %%
df_signal
# Out:
#                      bond_price  stock_price  bond_rtn  stock_rtn      diff  \
# 2022-11-17 15:00:00     197.000        17.18  0.000000   0.000000  0.000000
# 2022-11-18 09:30:00     196.068        17.21 -0.004731   0.001746 -0.006477
# 2022-11-18 09:31:00     196.011        17.24 -0.005020   0.003492 -0.008513
# 2022-11-18 09:32:00     196.319        17.29 -0.003457   0.006403 -0.009860
# 2022-11-18 09:33:00     196.090        17.25 -0.004619   0.004075 -0.008694
# 2022-11-18 09:34:00     194.787        17.24 -0.011234   0.003492 -0.014726
# 2022-11-18 09:35:00     195.692        17.19 -0.006640   0.000582 -0.007222
# 2022-11-18 09:36:00     195.658        17.24 -0.006812   0.003492 -0.010305
# 2022-11-18 09:37:00     195.795        17.21 -0.006117   0.001746 -0.007863
# 2022-11-18 09:38:00     195.275        17.19 -0.008756   0.000582 -0.009338
# 2022-11-18 09:39:00     194.221        17.07 -0.014107  -0.006403 -0.007704
# 2022-11-18 09:40:00     194.254        17.01 -0.013939  -0.009895 -0.004044
# 2022-11-18 09:41:00     194.738        17.01 -0.011482  -0.009895 -0.001587
# 2022-11-18 09:42:00     194.595        17.00 -0.012208  -0.010477 -0.001731
# 2022-11-18 09:43:00     194.000        16.94 -0.015228  -0.013970 -0.001259
# 2022-11-18 09:44:00     193.966        16.98 -0.015401  -0.011641 -0.003760
# 2022-11-18 09:45:00     194.592        17.07 -0.012223  -0.006403 -0.005821
# 2022-11-18 09:46:00     194.516        17.09 -0.012609  -0.005239 -0.007370
# 2022-11-18 09:47:00     194.954        17.13 -0.010386  -0.002910 -0.007475
# 2022-11-18 09:48:00     195.407        17.16 -0.008086  -0.001164 -0.006922
# 2022-11-18 09:49:00     195.054        17.11 -0.009878  -0.004075 -0.005804
# 2022-11-18 09:50:00     194.572        17.05 -0.012325  -0.007567 -0.004758
# 2022-11-18 09:51:00     194.750        17.10 -0.011421  -0.004657 -0.006765
# 2022-11-18 09:52:00     195.456        17.11 -0.007838  -0.004075 -0.003763
# 2022-11-18 09:53:00     195.499        17.13 -0.007619  -0.002910 -0.004709
# 2022-11-18 09:54:00     195.385        17.14 -0.008198  -0.002328 -0.005870
# 2022-11-18 09:55:00     195.092        17.15 -0.009685  -0.001746 -0.007939
# 2022-11-18 09:56:00     195.241        17.17 -0.008929  -0.000582 -0.008347
# 2022-11-18 09:57:00     194.902        17.12 -0.010650  -0.003492 -0.007157
# 2022-11-18 09:58:00     194.440        17.06 -0.012995  -0.006985 -0.006010
# 2022-11-18 09:59:00     194.104        17.02 -0.014701  -0.009313 -0.005387
# 2022-11-18 10:00:00     193.233        17.00 -0.019122  -0.010477 -0.008645
# 2022-11-18 10:01:00     193.260        17.08 -0.018985  -0.005821 -0.013164
# 2022-11-18 10:02:00     193.541        17.05 -0.017558  -0.007567 -0.009991
# 2022-11-18 10:03:00     193.792        17.11 -0.016284  -0.004075 -0.012210
# 2022-11-18 10:04:00     194.000        17.05 -0.015228  -0.007567 -0.007661
# 2022-11-18 10:05:00     194.002        17.10 -0.015218  -0.004657 -0.010562
# 2022-11-18 10:06:00     193.748        17.06 -0.016508  -0.006985 -0.009523
# 2022-11-18 10:07:00     194.449        17.09 -0.012949  -0.005239 -0.007711
# 2022-11-18 10:08:00     194.914        17.15 -0.010589  -0.001746 -0.008843
# 2022-11-18 10:09:00     194.307        17.12 -0.013670  -0.003492 -0.010178
# 2022-11-18 10:10:00     194.296        17.13 -0.013726  -0.002910 -0.010816
# 2022-11-18 10:11:00     194.399        17.12 -0.013203  -0.003492 -0.009711
# 2022-11-18 10:12:00     194.349        17.12 -0.013457  -0.003492 -0.009964
# 2022-11-18 10:13:00     194.167        17.07 -0.014381  -0.006403 -0.007978
# 2022-11-18 10:14:00     194.463        17.10 -0.012878  -0.004657 -0.008222
# 2022-11-18 10:15:00     194.000        17.04 -0.015228  -0.008149 -0.007079
# 2022-11-18 10:16:00     194.300        17.09 -0.013706  -0.005239 -0.008467
# 2022-11-18 10:17:00     194.341        17.11 -0.013497  -0.004075 -0.009423
# 2022-11-18 10:18:00     194.400        17.11 -0.013198  -0.004075 -0.009123
# 2022-11-18 10:19:00     194.006        17.11 -0.015198  -0.004075 -0.011123
# 2022-11-18 10:20:00     194.264        17.14 -0.013888  -0.002328 -0.011560
# 2022-11-18 10:21:00     195.073        17.25 -0.009782   0.004075 -0.013856
# 2022-11-18 10:22:00     194.650        17.19 -0.011929   0.000582 -0.012511
# 2022-11-18 10:23:00     195.177        17.24 -0.009254   0.003492 -0.012746
# 2022-11-18 10:24:00     195.700        17.28 -0.006599   0.005821 -0.012420
# 2022-11-18 10:25:00     195.411        17.27 -0.008066   0.005239 -0.013305
# 2022-11-18 10:26:00     196.070        17.32 -0.004721   0.008149 -0.012870
# 2022-11-18 10:27:00     196.386        17.37 -0.003117   0.011059 -0.014176
# 2022-11-18 10:28:00     196.022        17.33 -0.004964   0.008731 -0.013696
# 2022-11-18 10:29:00     195.800        17.26 -0.006091   0.004657 -0.010748
# 2022-11-18 10:30:00     195.285        17.22 -0.008706   0.002328 -0.011034
# 2022-11-18 10:31:00     195.213        17.21 -0.009071   0.001746 -0.010817
# 2022-11-18 10:32:00     195.335        17.22 -0.008452   0.002328 -0.010780
# 2022-11-18 10:33:00     195.436        17.23 -0.007939   0.002910 -0.010849
# 2022-11-18 10:34:00     195.458        17.24 -0.007827   0.003492 -0.011320
# 2022-11-18 10:35:00     194.573        17.19 -0.012320   0.000582 -0.012902
# 2022-11-18 10:36:00     194.268        17.15 -0.013868  -0.001746 -0.012122
# 2022-11-18 10:37:00     194.342        17.14 -0.013492  -0.002328 -0.011164
# 2022-11-18 10:38:00     194.364        17.15 -0.013381  -0.001746 -0.011634
# 2022-11-18 10:39:00     194.298        17.13 -0.013716  -0.002910 -0.010805
# 2022-11-18 10:40:00     194.796        17.19 -0.011188   0.000582 -0.011770
# 2022-11-18 10:41:00     195.478        17.24 -0.007726   0.003492 -0.011218
# 2022-11-18 10:42:00     195.180        17.19 -0.009239   0.000582 -0.009821
# 2022-11-18 10:43:00     195.162        17.20 -0.009330   0.001164 -0.010494
# 2022-11-18 10:44:00     194.800        17.18 -0.011168   0.000000 -0.011168
# 2022-11-18 10:45:00     194.728        17.17 -0.011533  -0.000582 -0.010951
# 2022-11-18 10:46:00     194.815        17.17 -0.011091  -0.000582 -0.010509
# 2022-11-18 10:47:00     194.500        17.13 -0.012690  -0.002910 -0.009780
# 2022-11-18 10:48:00     194.442        17.12 -0.012985  -0.003492 -0.009492
# 2022-11-18 10:49:00     194.558        17.13 -0.012396  -0.002910 -0.009486
# 2022-11-18 10:50:00     194.529        17.13 -0.012543  -0.002910 -0.009633
# 2022-11-18 10:51:00     194.990        17.17 -0.010203  -0.000582 -0.009621
# 2022-11-18 10:52:00     194.550        17.14 -0.012437  -0.002328 -0.010108
# 2022-11-18 10:53:00     194.407        17.12 -0.013162  -0.003492 -0.009670
# 2022-11-18 10:54:00     194.000        17.10 -0.015228  -0.004657 -0.010572
# 2022-11-18 10:55:00     194.201        17.08 -0.014208  -0.005821 -0.008387
# 2022-11-18 10:56:00     194.463        17.10 -0.012878  -0.004657 -0.008222
# 2022-11-18 10:57:00     194.583        17.10 -0.012269  -0.004657 -0.007612
# 2022-11-18 10:58:00     194.300        17.08 -0.013706  -0.005821 -0.007885
# 2022-11-18 10:59:00     194.300        17.07 -0.013706  -0.006403 -0.007303
# 2022-11-18 11:00:00     194.543        17.08 -0.012472  -0.005821 -0.006651
# 2022-11-18 11:01:00     194.344        17.09 -0.013482  -0.005239 -0.008244
# 2022-11-18 11:02:00     194.100        17.05 -0.014721  -0.007567 -0.007154
# 2022-11-18 11:03:00     194.378        17.05 -0.013310  -0.007567 -0.005743
# 2022-11-18 11:04:00     194.100        17.04 -0.014721  -0.008149 -0.006572
# 2022-11-18 11:05:00     193.700        17.02 -0.016751  -0.009313 -0.007438
# 2022-11-18 11:06:00     193.719        17.02 -0.016655  -0.009313 -0.007342
# 2022-11-18 11:07:00     193.980        17.00 -0.015330  -0.010477 -0.004853
# 2022-11-18 11:08:00     194.254        17.05 -0.013939  -0.007567 -0.006372
# 2022-11-18 11:09:00     194.077        17.05 -0.014838  -0.007567 -0.007271
# 2022-11-18 11:10:00     194.200        17.03 -0.014213  -0.008731 -0.005482
# 2022-11-18 11:11:00     194.054        17.01 -0.014954  -0.009895 -0.005059
# 2022-11-18 11:12:00     193.800        16.98 -0.016244  -0.011641 -0.004602
# 2022-11-18 11:13:00     193.582        16.97 -0.017350  -0.012224 -0.005127
# 2022-11-18 11:14:00     193.699        16.96 -0.016756  -0.012806 -0.003951
# 2022-11-18 11:15:00     193.233        16.95 -0.019122  -0.013388 -0.005734
# 2022-11-18 11:16:00     192.734        16.94 -0.021655  -0.013970 -0.007685
# 2022-11-18 11:17:00     192.865        16.91 -0.020990  -0.015716 -0.005274
# 2022-11-18 11:18:00     193.104        16.94 -0.019777  -0.013970 -0.005807
# 2022-11-18 11:19:00     192.822        16.89 -0.021208  -0.016880 -0.004328
# 2022-11-18 11:20:00     192.500        16.88 -0.022843  -0.017462 -0.005380
# 2022-11-18 11:21:00     192.727        16.88 -0.021690  -0.017462 -0.004228
# 2022-11-18 11:22:00     193.084        16.90 -0.019878  -0.016298 -0.003580
# 2022-11-18 11:23:00     193.049        16.91 -0.020056  -0.015716 -0.004340
# 2022-11-18 11:24:00     192.874        16.89 -0.020944  -0.016880 -0.004064
# 2022-11-18 11:25:00     192.671        16.87 -0.021975  -0.018044 -0.003930
# 2022-11-18 11:26:00     192.800        16.86 -0.021320  -0.018626 -0.002693
# 2022-11-18 11:27:00     192.537        16.85 -0.022655  -0.019208 -0.003446
# 2022-11-18 11:28:00     192.482        16.88 -0.022934  -0.017462 -0.005472
# 2022-11-18 11:29:00     192.224        16.83 -0.024244  -0.020373 -0.003871
# 2022-11-18 11:30:00     192.281        16.83 -0.023954  -0.020373 -0.003582
# 2022-11-18 13:00:00     192.130        16.81 -0.024721  -0.021537 -0.003184
# 2022-11-18 13:01:00     192.136        16.80 -0.024690  -0.022119 -0.002572
# 2022-11-18 13:02:00     191.897        16.78 -0.025904  -0.023283 -0.002621
# 2022-11-18 13:03:00     192.192        16.79 -0.024406  -0.022701 -0.001705
# 2022-11-18 13:04:00     191.610        16.71 -0.027360  -0.027357 -0.000003
# 2022-11-18 13:05:00     192.000        16.71 -0.025381  -0.027357  0.001977
# 2022-11-18 13:06:00     191.701        16.74 -0.026898  -0.025611 -0.001287
# 2022-11-18 13:07:00     191.701        16.77 -0.026898  -0.023865 -0.003034
# 2022-11-18 13:08:00     191.549        16.73 -0.027670  -0.026193 -0.001477
# 2022-11-18 13:09:00     191.800        16.78 -0.026396  -0.023283 -0.003113
# 2022-11-18 13:10:00     192.120        16.80 -0.024772  -0.022119 -0.002653
# 2022-11-18 13:11:00     191.991        16.80 -0.025426  -0.022119 -0.003308
# 2022-11-18 13:12:00     191.865        16.81 -0.026066  -0.021537 -0.004529
# 2022-11-18 13:13:00     192.253        16.84 -0.024096  -0.019790 -0.004306
# 2022-11-18 13:14:00     192.631        16.84 -0.022178  -0.019790 -0.002387
# 2022-11-18 13:15:00     192.645        16.86 -0.022107  -0.018626 -0.003480
# 2022-11-18 13:16:00     192.880        16.89 -0.020914  -0.016880 -0.004034
# 2022-11-18 13:17:00     192.787        16.90 -0.021386  -0.016298 -0.005088
# 2022-11-18 13:18:00     192.198        16.84 -0.024376  -0.019790 -0.004585
# 2022-11-18 13:19:00     192.577        16.80 -0.022452  -0.022119 -0.000333
# 2022-11-18 13:20:00     192.800        16.83 -0.021320  -0.020373 -0.000947
# 2022-11-18 13:21:00     192.857        16.86 -0.021030  -0.018626 -0.002404
# 2022-11-18 13:22:00     192.375        16.80 -0.023477  -0.022119 -0.001358
# 2022-11-18 13:23:00     192.506        16.81 -0.022812  -0.021537 -0.001276
# 2022-11-18 13:24:00     192.329        16.78 -0.023711  -0.023283 -0.000428
# 2022-11-18 13:25:00     192.325        16.79 -0.023731  -0.022701 -0.001030
# 2022-11-18 13:26:00     192.485        16.78 -0.022919  -0.023283  0.000364
# 2022-11-18 13:27:00     192.111        16.77 -0.024817  -0.023865 -0.000952
# 2022-11-18 13:28:00     192.449        16.79 -0.023102  -0.022701 -0.000401
# 2022-11-18 13:29:00     192.329        16.80 -0.023711  -0.022119 -0.001592
# 2022-11-18 13:30:00     192.213        16.77 -0.024299  -0.023865 -0.000435
# 2022-11-18 13:31:00     192.318        16.79 -0.023766  -0.022701 -0.001066
# 2022-11-18 13:32:00     192.212        16.73 -0.024305  -0.026193  0.001889
# 2022-11-18 13:33:00     192.000        16.78 -0.025381  -0.023283 -0.002098
# 2022-11-18 13:34:00     192.194        16.77 -0.024396  -0.023865 -0.000531
# 2022-11-18 13:35:00     192.400        16.80 -0.023350  -0.022119 -0.001232
# 2022-11-18 13:36:00     192.568        16.81 -0.022497  -0.021537 -0.000961
# 2022-11-18 13:37:00     192.345        16.80 -0.023629  -0.022119 -0.001511
# 2022-11-18 13:38:00     192.132        16.79 -0.024711  -0.022701 -0.002010
# 2022-11-18 13:39:00     192.000        16.79 -0.025381  -0.022701 -0.002680
# 2022-11-18 13:40:00     191.786        16.76 -0.026467  -0.024447 -0.002020
# 2022-11-18 13:41:00     191.808        16.76 -0.026355  -0.024447 -0.001908
# 2022-11-18 13:42:00     191.800        16.75 -0.026396  -0.025029 -0.001367
# 2022-11-18 13:43:00     192.017        16.77 -0.025294  -0.023865 -0.001429
# 2022-11-18 13:44:00     192.045        16.77 -0.025152  -0.023865 -0.001287
# 2022-11-18 13:45:00     191.803        16.75 -0.026381  -0.025029 -0.001352
# 2022-11-18 13:46:00     191.787        16.75 -0.026462  -0.025029 -0.001433
# 2022-11-18 13:47:00     191.729        16.76 -0.026756  -0.024447 -0.002309
# 2022-11-18 13:48:00     191.800        16.77 -0.026396  -0.023865 -0.002531
# 2022-11-18 13:49:00     192.402        16.78 -0.023340  -0.023283 -0.000057
# 2022-11-18 13:50:00     193.659        16.85 -0.016959  -0.019208  0.002249
# 2022-11-18 13:51:00     193.104        16.86 -0.019777  -0.018626 -0.001150
# 2022-11-18 13:52:00     193.094        16.88 -0.019827  -0.017462 -0.002365
# 2022-11-18 13:53:00     193.647        16.94 -0.017020  -0.013970 -0.003051
# 2022-11-18 13:54:00     193.243        16.92 -0.019071  -0.015134 -0.003937
# 2022-11-18 13:55:00     192.950        16.91 -0.020558  -0.015716 -0.004842
# 2022-11-18 13:56:00     192.854        16.89 -0.021046  -0.016880 -0.004166
# 2022-11-18 13:57:00     193.260        16.94 -0.018985  -0.013970 -0.005015
# 2022-11-18 13:58:00     192.797        16.90 -0.021335  -0.016298 -0.005037
# 2022-11-18 13:59:00     192.800        16.90 -0.021320  -0.016298 -0.005022
# 2022-11-18 14:00:00     192.500        16.88 -0.022843  -0.017462 -0.005380
# 2022-11-18 14:01:00     192.822        16.90 -0.021208  -0.016298 -0.004910
# 2022-11-18 14:02:00     192.638        16.90 -0.022142  -0.016298 -0.005844
# 2022-11-18 14:03:00     192.243        16.88 -0.024147  -0.017462 -0.006685
# 2022-11-18 14:04:00     192.151        16.85 -0.024614  -0.019208 -0.005406
# 2022-11-18 14:05:00     192.438        16.84 -0.023157  -0.019790 -0.003367
# 2022-11-18 14:06:00     192.135        16.83 -0.024695  -0.020373 -0.004323
# 2022-11-18 14:07:00     192.197        16.83 -0.024381  -0.020373 -0.004008
# 2022-11-18 14:08:00     192.146        16.81 -0.024640  -0.021537 -0.003103
# 2022-11-18 14:09:00     192.300        16.84 -0.023858  -0.019790 -0.004067
# 2022-11-18 14:10:00     192.251        16.83 -0.024107  -0.020373 -0.003734
# 2022-11-18 14:11:00     192.347        16.85 -0.023619  -0.019208 -0.004411
# 2022-11-18 14:12:00     192.600        16.88 -0.022335  -0.017462 -0.004873
# 2022-11-18 14:13:00     192.500        16.86 -0.022843  -0.018626 -0.004216
# 2022-11-18 14:14:00     192.680        16.87 -0.021929  -0.018044 -0.003885
# 2022-11-18 14:15:00     192.500        16.86 -0.022843  -0.018626 -0.004216
# 2022-11-18 14:16:00     192.341        16.87 -0.023650  -0.018044 -0.005606
# 2022-11-18 14:17:00     192.302        16.88 -0.023848  -0.017462 -0.006386
# 2022-11-18 14:18:00     192.423        16.89 -0.023234  -0.016880 -0.006353
# 2022-11-18 14:19:00     192.395        16.88 -0.023376  -0.017462 -0.005913
# 2022-11-18 14:20:00     192.420        16.89 -0.023249  -0.016880 -0.006369
# 2022-11-18 14:21:00     193.044        16.90 -0.020081  -0.016298 -0.003783
# 2022-11-18 14:22:00     193.029        16.94 -0.020157  -0.013970 -0.006188
# 2022-11-18 14:23:00     193.000        16.95 -0.020305  -0.013388 -0.006917
# 2022-11-18 14:24:00     192.668        16.92 -0.021990  -0.015134 -0.006856
# 2022-11-18 14:25:00     192.961        16.95 -0.020503  -0.013388 -0.007115
# 2022-11-18 14:26:00     193.401        17.01 -0.018269  -0.009895 -0.008374
# 2022-11-18 14:27:00     193.094        17.01 -0.019827  -0.009895 -0.009932
# 2022-11-18 14:28:00     193.301        17.02 -0.018777  -0.009313 -0.009463
# 2022-11-18 14:29:00     193.000        16.96 -0.020305  -0.012806 -0.007499
# 2022-11-18 14:30:00     192.969        16.97 -0.020462  -0.012224 -0.008238
# 2022-11-18 14:31:00     193.140        16.99 -0.019594  -0.011059 -0.008535
# 2022-11-18 14:32:00     193.299        17.00 -0.018787  -0.010477 -0.008310
# 2022-11-18 14:33:00     194.009        17.05 -0.015183  -0.007567 -0.007616
# 2022-11-18 14:34:00     194.107        17.08 -0.014685  -0.005821 -0.008865
# 2022-11-18 14:35:00     194.000        17.08 -0.015228  -0.005821 -0.009408
# 2022-11-18 14:36:00     193.830        17.06 -0.016091  -0.006985 -0.009107
# 2022-11-18 14:37:00     193.637        17.04 -0.017071  -0.008149 -0.008922
# 2022-11-18 14:38:00     194.400        17.10 -0.013198  -0.004657 -0.008541
# 2022-11-18 14:39:00     194.142        17.07 -0.014508  -0.006403 -0.008105
# 2022-11-18 14:40:00     194.642        17.10 -0.011970  -0.004657 -0.007313
# 2022-11-18 14:41:00     194.097        17.07 -0.014736  -0.006403 -0.008333
# 2022-11-18 14:42:00     193.903        17.05 -0.015721  -0.007567 -0.008154
# 2022-11-18 14:43:00     193.756        17.05 -0.016467  -0.007567 -0.008900
# 2022-11-18 14:44:00     193.504        17.05 -0.017746  -0.007567 -0.010179
# 2022-11-18 14:45:00     193.464        17.03 -0.017949  -0.008731 -0.009218
# 2022-11-18 14:46:00     193.125        17.02 -0.019670  -0.009313 -0.010357
# 2022-11-18 14:47:00     192.796        17.00 -0.021340  -0.010477 -0.010863
# 2022-11-18 14:48:00     192.751        17.01 -0.021569  -0.009895 -0.011673
# 2022-11-18 14:49:00     193.048        17.01 -0.020061  -0.009895 -0.010166
# 2022-11-18 14:50:00     193.742        17.03 -0.016538  -0.008731 -0.007807
# 2022-11-18 14:51:00     193.886        17.03 -0.015807  -0.008731 -0.007076
# 2022-11-18 14:52:00     193.762        17.02 -0.016437  -0.009313 -0.007123
# 2022-11-18 14:53:00     193.916        17.00 -0.015655  -0.010477 -0.005178
# 2022-11-18 14:54:00     193.989        17.01 -0.015284  -0.009895 -0.005389
# 2022-11-18 14:55:00     194.200        17.01 -0.014213  -0.009895 -0.004318
# 2022-11-18 14:56:00     193.706        17.06 -0.016721  -0.006985 -0.009736
# 2022-11-18 14:57:00     193.853        17.05 -0.015975  -0.007567 -0.008408
# 2022-11-18 14:58:00     193.853        17.05 -0.015975  -0.007567 -0.008408
# 2022-11-18 14:59:00     193.853        17.05 -0.015975  -0.007567 -0.008408
# 2022-11-18 15:00:00     194.300        17.05 -0.013706  -0.007567 -0.006139
#
#                      bond_pos  stock_pos  premium rate
# 2022-11-17 15:00:00       0.0        0.0      0.014814
# 2022-11-18 09:30:00       0.0        0.0      0.008252
# 2022-11-18 09:31:00       0.0        0.0      0.006205
# 2022-11-18 09:32:00       0.0        0.0      0.004872
# 2022-11-18 09:33:00       0.0        0.0      0.006027
# 2022-11-18 09:34:00       1.0       -1.0     -0.000078
# 2022-11-18 09:35:00       1.0       -1.0      0.007489
# 2022-11-18 09:36:00       1.0       -1.0      0.004393
# 2022-11-18 09:37:00       1.0       -1.0      0.006848
# 2022-11-18 09:38:00       1.0       -1.0      0.005342
# 2022-11-18 09:39:00       1.0       -1.0      0.006945
# 2022-11-18 09:40:00       1.0       -1.0      0.010669
# 2022-11-18 09:41:00       1.0       -1.0      0.013187
# 2022-11-18 09:42:00       1.0       -1.0      0.013039
# 2022-11-18 09:43:00       1.0       -1.0      0.013518
# 2022-11-18 09:44:00       1.0       -1.0      0.010954
# 2022-11-18 09:45:00       1.0       -1.0      0.008869
# 2022-11-18 09:46:00       1.0       -1.0      0.007295
# 2022-11-18 09:47:00       1.0       -1.0      0.007205
# 2022-11-18 09:48:00       1.0       -1.0      0.007781
# 2022-11-18 09:49:00       1.0       -1.0      0.008900
# 2022-11-18 09:50:00       1.0       -1.0      0.009949
# 2022-11-18 09:51:00       1.0       -1.0      0.007917
# 2022-11-18 09:52:00       1.0       -1.0      0.010979
# 2022-11-18 09:53:00       1.0       -1.0      0.010021
# 2022-11-18 09:54:00       1.0       -1.0      0.008843
# 2022-11-18 09:55:00       1.0       -1.0      0.006743
# 2022-11-18 09:56:00       1.0       -1.0      0.006338
# 2022-11-18 09:57:00       1.0       -1.0      0.007525
# 2022-11-18 09:58:00       1.0       -1.0      0.008672
# 2022-11-18 09:59:00       1.0       -1.0      0.009295
# 2022-11-18 10:00:00       1.0       -1.0      0.005948
# 2022-11-18 10:01:00       1.0       -1.0      0.001376
# 2022-11-18 10:02:00       1.0       -1.0      0.004597
# 2022-11-18 10:03:00       1.0       -1.0      0.002372
# 2022-11-18 10:04:00       1.0       -1.0      0.006979
# 2022-11-18 10:05:00       1.0       -1.0      0.004045
# 2022-11-18 10:06:00       1.0       -1.0      0.005082
# 2022-11-18 10:07:00       1.0       -1.0      0.006948
# 2022-11-18 10:08:00       1.0       -1.0      0.005824
# 2022-11-18 10:09:00       1.0       -1.0      0.004449
# 2022-11-18 10:10:00       1.0       -1.0      0.003806
# 2022-11-18 10:11:00       1.0       -1.0      0.004925
# 2022-11-18 10:12:00       1.0       -1.0      0.004666
# 2022-11-18 10:13:00       1.0       -1.0      0.006665
# 2022-11-18 10:14:00       1.0       -1.0      0.006431
# 2022-11-18 10:15:00       1.0       -1.0      0.007570
# 2022-11-18 10:16:00       1.0       -1.0      0.006176
# 2022-11-18 10:17:00       1.0       -1.0      0.005212
# 2022-11-18 10:18:00       1.0       -1.0      0.005517
# 2022-11-18 10:19:00       1.0       -1.0      0.003479
# 2022-11-18 10:20:00       1.0       -1.0      0.003055
# 2022-11-18 10:21:00       1.0       -1.0      0.000809
# 2022-11-18 10:22:00       1.0       -1.0      0.002125
# 2022-11-18 10:23:00       1.0       -1.0      0.001924
# 2022-11-18 10:24:00       1.0       -1.0      0.002283
# 2022-11-18 10:25:00       1.0       -1.0      0.001382
# 2022-11-18 10:26:00       1.0       -1.0      0.001859
# 2022-11-18 10:27:00       1.0       -1.0      0.000585
# 2022-11-18 10:28:00       1.0       -1.0      0.001036
# 2022-11-18 10:29:00       1.0       -1.0      0.003957
# 2022-11-18 10:30:00       1.0       -1.0      0.003642
# 2022-11-18 10:31:00       1.0       -1.0      0.003855
# 2022-11-18 10:32:00       1.0       -1.0      0.003899
# 2022-11-18 10:33:00       1.0       -1.0      0.003836
# 2022-11-18 10:34:00       1.0       -1.0      0.003366
# 2022-11-18 10:35:00       1.0       -1.0      0.001728
# 2022-11-18 10:36:00       1.0       -1.0      0.002491
# 2022-11-18 10:37:00       1.0       -1.0      0.003458
# 2022-11-18 10:38:00       1.0       -1.0      0.002986
# 2022-11-18 10:39:00       1.0       -1.0      0.003816
# 2022-11-18 10:40:00       1.0       -1.0      0.002876
# 2022-11-18 10:41:00       1.0       -1.0      0.003469
# 2022-11-18 10:42:00       1.0       -1.0      0.004853
# 2022-11-18 10:43:00       1.0       -1.0      0.004177
# 2022-11-18 10:44:00       1.0       -1.0      0.003481
# 2022-11-18 10:45:00       1.0       -1.0      0.003694
# 2022-11-18 10:46:00       1.0       -1.0      0.004143
# 2022-11-18 10:47:00       1.0       -1.0      0.004860
# 2022-11-18 10:48:00       1.0       -1.0      0.005147
# 2022-11-18 10:49:00       1.0       -1.0      0.005160
# 2022-11-18 10:50:00       1.0       -1.0      0.005010
# 2022-11-18 10:51:00       1.0       -1.0      0.005045
# 2022-11-18 10:52:00       1.0       -1.0      0.004532
# 2022-11-18 10:53:00       1.0       -1.0      0.004966
# 2022-11-18 10:54:00       1.0       -1.0      0.004035
# 2022-11-18 10:55:00       1.0       -1.0      0.006252
# 2022-11-18 10:56:00       1.0       -1.0      0.006431
# 2022-11-18 10:57:00       1.0       -1.0      0.007052
# 2022-11-18 10:58:00       1.0       -1.0      0.006765
# 2022-11-18 10:59:00       1.0       -1.0      0.007355
# 2022-11-18 11:00:00       1.0       -1.0      0.008024
# 2022-11-18 11:01:00       1.0       -1.0      0.006404
# 2022-11-18 11:02:00       1.0       -1.0      0.007499
# 2022-11-18 11:03:00       1.0       -1.0      0.008942
# 2022-11-18 11:04:00       1.0       -1.0      0.008090
# 2022-11-18 11:05:00       1.0       -1.0      0.007194
# 2022-11-18 11:06:00       1.0       -1.0      0.007293
# 2022-11-18 11:07:00       1.0       -1.0      0.009837
# 2022-11-18 11:08:00       1.0       -1.0      0.008298
# 2022-11-18 11:09:00       1.0       -1.0      0.007379
# 2022-11-18 11:10:00       1.0       -1.0      0.009201
# 2022-11-18 11:11:00       1.0       -1.0      0.009628
# 2022-11-18 11:12:00       1.0       -1.0      0.010088
# 2022-11-18 11:13:00       1.0       -1.0      0.009547
# 2022-11-18 11:14:00       1.0       -1.0      0.010752
# 2022-11-18 11:15:00       1.0       -1.0      0.008916
# 2022-11-18 11:16:00       1.0       -1.0      0.006904
# 2022-11-18 11:17:00       1.0       -1.0      0.009376
# 2022-11-18 11:18:00       1.0       -1.0      0.008837
# 2022-11-18 11:19:00       1.0       -1.0      0.010346
# 2022-11-18 11:20:00       1.0       -1.0      0.009257
# 2022-11-18 11:21:00       1.0       -1.0      0.010447
# 2022-11-18 11:22:00       1.0       -1.0      0.011120
# 2022-11-18 11:23:00       1.0       -1.0      0.010339
# 2022-11-18 11:24:00       1.0       -1.0      0.010619
# 2022-11-18 11:25:00       1.0       -1.0      0.010752
# 2022-11-18 11:26:00       1.0       -1.0      0.012028
# 2022-11-18 11:27:00       1.0       -1.0      0.011248
# 2022-11-18 11:28:00       1.0       -1.0      0.009162
# 2022-11-18 11:29:00       1.0       -1.0      0.010804
# 2022-11-18 11:30:00       1.0       -1.0      0.011103
# 2022-11-18 13:00:00       1.0       -1.0      0.011511
# 2022-11-18 13:01:00       1.0       -1.0      0.012145
# 2022-11-18 13:02:00       1.0       -1.0      0.012091
# 2022-11-18 13:03:00       1.0       -1.0      0.013043
# 2022-11-18 13:04:00       1.0       -1.0      0.014811
# 2022-11-18 13:05:00       0.0        0.0      0.016876
# 2022-11-18 13:06:00       0.0        0.0      0.013473
# 2022-11-18 13:07:00       0.0        0.0      0.011660
# 2022-11-18 13:08:00       0.0        0.0      0.013275
# 2022-11-18 13:09:00       0.0        0.0      0.011579
# 2022-11-18 13:10:00       0.0        0.0      0.012061
# 2022-11-18 13:11:00       0.0        0.0      0.011381
# 2022-11-18 13:12:00       0.0        0.0      0.010116
# 2022-11-18 13:13:00       0.0        0.0      0.010356
# 2022-11-18 13:14:00       0.0        0.0      0.012342
# 2022-11-18 13:15:00       0.0        0.0      0.011215
# 2022-11-18 13:16:00       0.0        0.0      0.010650
# 2022-11-18 13:17:00       0.0        0.0      0.009565
# 2022-11-18 13:18:00       0.0        0.0      0.010067
# 2022-11-18 13:19:00       0.0        0.0      0.014468
# 2022-11-18 13:20:00       0.0        0.0      0.013832
# 2022-11-18 13:21:00       0.0        0.0      0.012328
# 2022-11-18 13:22:00       0.0        0.0      0.013404
# 2022-11-18 13:23:00       0.0        0.0      0.013491
# 2022-11-18 13:24:00       0.0        0.0      0.014369
# 2022-11-18 13:25:00       0.0        0.0      0.013744
# 2022-11-18 13:26:00       0.0        0.0      0.015192
# 2022-11-18 13:27:00       0.0        0.0      0.013824
# 2022-11-18 13:28:00       0.0        0.0      0.014398
# 2022-11-18 13:29:00       0.0        0.0      0.013162
# 2022-11-18 13:30:00       0.0        0.0      0.014362
# 2022-11-18 13:31:00       0.0        0.0      0.013707
# 2022-11-18 13:32:00       0.0        0.0      0.016782
# 2022-11-18 13:33:00       0.0        0.0      0.012634
# 2022-11-18 13:34:00       0.0        0.0      0.014262
# 2022-11-18 13:35:00       0.0        0.0      0.013536
# 2022-11-18 13:36:00       0.0        0.0      0.013817
# 2022-11-18 13:37:00       0.0        0.0      0.013246
# 2022-11-18 13:38:00       0.0        0.0      0.012727
# 2022-11-18 13:39:00       0.0        0.0      0.012031
# 2022-11-18 13:40:00       0.0        0.0      0.012712
# 2022-11-18 13:41:00       0.0        0.0      0.012829
# 2022-11-18 13:42:00       0.0        0.0      0.013391
# 2022-11-18 13:43:00       0.0        0.0      0.013328
# 2022-11-18 13:44:00       0.0        0.0      0.013475
# 2022-11-18 13:45:00       0.0        0.0      0.013407
# 2022-11-18 13:46:00       0.0        0.0      0.013322
# 2022-11-18 13:47:00       0.0        0.0      0.012411
# 2022-11-18 13:48:00       0.0        0.0      0.012182
# 2022-11-18 13:49:00       0.0        0.0      0.014754
# 2022-11-18 13:50:00       0.0        0.0      0.017141
# 2022-11-18 13:51:00       0.0        0.0      0.013624
# 2022-11-18 13:52:00       0.0        0.0      0.012371
# 2022-11-18 13:53:00       0.0        0.0      0.011674
# 2022-11-18 13:54:00       0.0        0.0      0.010757
# 2022-11-18 13:55:00       0.0        0.0      0.009821
# 2022-11-18 13:56:00       0.0        0.0      0.010514
# 2022-11-18 13:57:00       0.0        0.0      0.009652
# 2022-11-18 13:58:00       0.0        0.0      0.009617
# 2022-11-18 13:59:00       0.0        0.0      0.009633
# 2022-11-18 14:00:00       0.0        0.0      0.009257
# 2022-11-18 14:01:00       0.0        0.0      0.009748
# 2022-11-18 14:02:00       0.0        0.0      0.008785
# 2022-11-18 14:03:00       0.0        0.0      0.007909
# 2022-11-18 14:04:00       0.0        0.0      0.009220
# 2022-11-18 14:05:00       0.0        0.0      0.011328
# 2022-11-18 14:06:00       0.0        0.0      0.010336
# 2022-11-18 14:07:00       0.0        0.0      0.010662
# 2022-11-18 14:08:00       0.0        0.0      0.011596
# 2022-11-18 14:09:00       0.0        0.0      0.010603
# 2022-11-18 14:10:00       0.0        0.0      0.010946
# 2022-11-18 14:11:00       0.0        0.0      0.010250
# 2022-11-18 14:12:00       0.0        0.0      0.009781
# 2022-11-18 14:13:00       0.0        0.0      0.010454
# 2022-11-18 14:14:00       0.0        0.0      0.010799
# 2022-11-18 14:15:00       0.0        0.0      0.010454
# 2022-11-18 14:16:00       0.0        0.0      0.009021
# 2022-11-18 14:17:00       0.0        0.0      0.008218
# 2022-11-18 14:18:00       0.0        0.0      0.008256
# 2022-11-18 14:19:00       0.0        0.0      0.008706
# 2022-11-18 14:20:00       0.0        0.0      0.008240
# 2022-11-18 14:21:00       0.0        0.0      0.010911
# 2022-11-18 14:22:00       0.0        0.0      0.008445
# 2022-11-18 14:23:00       0.0        0.0      0.007699
# 2022-11-18 14:24:00       0.0        0.0      0.007749
# 2022-11-18 14:25:00       0.0        0.0      0.007495
# 2022-11-18 14:26:00       0.0        0.0      0.006231
# 2022-11-18 14:27:00       0.0        0.0      0.004634
# 2022-11-18 14:28:00       0.0        0.0      0.005120
# 2022-11-18 14:29:00       0.0        0.0      0.007105
# 2022-11-18 14:30:00       0.0        0.0      0.006350
# 2022-11-18 14:31:00       0.0        0.0      0.006056
# 2022-11-18 14:32:00       0.0        0.0      0.006292
# 2022-11-18 14:33:00       0.0        0.0      0.007026
# 2022-11-18 14:34:00       0.0        0.0      0.005765
# 2022-11-18 14:35:00       0.0        0.0      0.005211
# 2022-11-18 14:36:00       0.0        0.0      0.005507
# 2022-11-18 14:37:00       0.0        0.0      0.005685
# 2022-11-18 14:38:00       0.0        0.0      0.006105
# 2022-11-18 14:39:00       0.0        0.0      0.006536
# 2022-11-18 14:40:00       0.0        0.0      0.007358
# 2022-11-18 14:41:00       0.0        0.0      0.006303
# 2022-11-18 14:42:00       0.0        0.0      0.006476
# 2022-11-18 14:43:00       0.0        0.0      0.005713
# 2022-11-18 14:44:00       0.0        0.0      0.004405
# 2022-11-18 14:45:00       0.0        0.0      0.005377
# 2022-11-18 14:46:00       0.0        0.0      0.004205
# 2022-11-18 14:47:00       0.0        0.0      0.003673
# 2022-11-18 14:48:00       0.0        0.0      0.002849
# 2022-11-18 14:49:00       0.0        0.0      0.004394
# 2022-11-18 14:50:00       0.0        0.0      0.006821
# 2022-11-18 14:51:00       0.0        0.0      0.007570
# 2022-11-18 14:52:00       0.0        0.0      0.007517
# 2022-11-18 14:53:00       0.0        0.0      0.009504
# 2022-11-18 14:54:00       0.0        0.0      0.009290
# 2022-11-18 14:55:00       0.0        0.0      0.010388
# 2022-11-18 14:56:00       0.0        0.0      0.004864
# 2022-11-18 14:57:00       0.0        0.0      0.006216
# 2022-11-18 14:58:00       0.0        0.0      0.006216
# 2022-11-18 14:59:00       0.0        0.0      0.006216
# 2022-11-18 15:00:00       0.0        0.0      0.008537

# %%
# 到期时间很短，且价内50%的时候，转债近似等价于正股
def cal_premium_rate(bond_price,stock_price,convert_price):
    tmp = 100/convert_price*stock_price
    res = (bond_price - tmp)/tmp
    return res
cal_premium_rate(200,140,70)
# Out:
# 0.0
