# %% [markdown]
# # import data

# %%
from WindPy import *

#Wind API 使用W账户密码登录
w.start() 

#return True and then can go to next operation.
w.isconnected()

import pandas as pd
# Out:
# 22.11.1.52440
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2021 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
# w.wsi("123046.SZ,300587.SZ,113642.SH,603185.SH,110061.SH,600674.SH,128081.SZ,002203.SZ,113016.SH,601127.SH,128017.SZ,002597.SZ",  "close",  "2022-09-06 09:00:00",  "2022-09-09 16:28:08",  "")

# %%
cbond_list = ['123046.SZ','300587.SZ',
'113642.SH','603185.SH', #转债已退市
'110061.SH','600674.SH',
'128081.SZ','002203.SZ',
'113016.SH','601127.SH',
'128017.SZ','002597.SZ',
'113537.SH','603348.SH',
'123027.SZ','300487.SZ', #转债已退市
'113534.SH','603876.SH',
'113025.SH','601677.SH',
'123031.SZ','300655.SZ',
'128029.SZ','002078.SZ',
'128111.SZ','002738.SZ', #2022-10-14新增4个对子
'128095.SZ','002812.SZ',
'113626.SH','603596.SH',
'123092.SZ','300332.SZ',
'123057.SZ','300586.SZ',#2020-11-18新增3个对子
'123067.SZ','300382.SZ',
'128106.SZ','002840.SZ',
]

# %% [markdown]
# # history trade days

# %%
# ###############################################################
# before_trade_date = '20220908'#监测当日前一个交易日
# present_date = '20220909' #监测当日
# next_trade_date = '20220910' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220909'#监测当日前一个交易日
# present_date = '20220913' #监测当日
# next_trade_date = '20220914' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220913'#监测当日前一个交易日
# present_date = '20220914' #监测当日
# next_trade_date = '20220915' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220914'#监测当日前一个交易日
# present_date = '20220915' #监测当日
# next_trade_date = '20220916' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220915'#监测当日前一个交易日
# present_date = '20220916' #监测当日
# next_trade_date = '20220917' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220916'#监测当日前一个交易日
# present_date = '20220919' #监测当日
# next_trade_date = '20220920' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220919'#监测当日前一个交易日
# present_date = '20220920' #监测当日
# next_trade_date = '20220921' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220920'#监测当日前一个交易日
# present_date = '20220921' #监测当日
# next_trade_date = '20220922' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220921'#监测当日前一个交易日
# present_date = '20220922' #监测当日
# next_trade_date = '20220923' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220922'#监测当日前一个交易日
# present_date = '20220923' #监测当日
# next_trade_date = '20220924' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220923'#监测当日前一个交易日
# present_date = '20220926' #监测当日
# next_trade_date = '20220927' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220926'#监测当日前一个交易日
# present_date = '20220927' #监测当日
# next_trade_date = '20220928' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220927'#监测当日前一个交易日
# present_date = '20220928' #监测当日
# next_trade_date = '20220929' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220928'#监测当日前一个交易日
# present_date = '20220929' #监测当日
# next_trade_date = '20220930' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220929'#监测当日前一个交易日
# present_date = '20220930' #监测当日
# next_trade_date = '20221001' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220930'#监测当日前一个交易日
# present_date = '20221010' #监测当日
# next_trade_date = '20221011' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221010'#监测当日前一个交易日
# present_date = '20221011' #监测当日
# next_trade_date = '20221012' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221011'#监测当日前一个交易日
# present_date = '20221012' #监测当日
# next_trade_date = '20221013' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221012'#监测当日前一个交易日
# present_date = '20221013' #监测当日
# next_trade_date = '20221014' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221013'#监测当日前一个交易日
# present_date = '20221014' #监测当日
# next_trade_date = '20221015' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221014'#监测当日前一个交易日
# present_date = '20221017' #监测当日
# next_trade_date = '20221018' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221017'#监测当日前一个交易日
# present_date = '20221018' #监测当日
# next_trade_date = '20221019' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221018'#监测当日前一个交易日
# present_date = '20221019' #监测当日
# next_trade_date = '20221020' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221019'#监测当日前一个交易日
# present_date = '20221020' #监测当日
# next_trade_date = '20221021' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221020'#监测当日前一个交易日
# present_date = '20221021' #监测当日
# next_trade_date = '20221022' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221021'#监测当日前一个交易日
# present_date = '20221024' #监测当日
# next_trade_date = '20221025' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221024'#监测当日前一个交易日
# present_date = '20221025' #监测当日
# next_trade_date = '20221026' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221025'#监测当日前一个交易日
# present_date = '20221026' #监测当日
# next_trade_date = '20221027' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221026'#监测当日前一个交易日
# present_date = '20221027' #监测当日
# next_trade_date = '20221028' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221027'#监测当日前一个交易日
# present_date = '20221028' #监测当日
# next_trade_date = '20221029' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221028'#监测当日前一个交易日
# present_date = '20221031' #监测当日
# next_trade_date = '20221101' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221031'#监测当日前一个交易日
# present_date = '20221101' #监测当日
# next_trade_date = '20221102' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221101'#监测当日前一个交易日
# present_date = '20221102' #监测当日
# next_trade_date = '20221103' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221102'#监测当日前一个交易日
# present_date = '20221103' #监测当日
# next_trade_date = '20221104' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221103'#监测当日前一个交易日
# present_date = '20221104' #监测当日
# next_trade_date = '20221105' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221104'#监测当日前一个交易日
# present_date = '20221107' #监测当日
# next_trade_date = '20221108' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221107'#监测当日前一个交易日
# present_date = '20221108' #监测当日
# next_trade_date = '20221109' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221108'#监测当日前一个交易日
# present_date = '20221109' #监测当日
# next_trade_date = '20221110' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221109'#监测当日前一个交易日
# present_date = '20221110' #监测当日
# next_trade_date = '20221111' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221110'#监测当日前一个交易日
# present_date = '20221111' #监测当日
# next_trade_date = '20221112' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221111'#监测当日前一个交易日
# present_date = '20221114' #监测当日
# next_trade_date = '20221115' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221114'#监测当日前一个交易日
# present_date = '20221115' #监测当日
# next_trade_date = '20221116' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221115'#监测当日前一个交易日
# present_date = '20221116' #监测当日
# next_trade_date = '20221117' #监测当日下一个自然日
# ###############################################################

# %%
# ###############################################################
# before_trade_date = '20221116'#监测当日前一个交易日
# present_date = '20221117' #监测当日
# next_trade_date = '20221118' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221117'#监测当日前一个交易日
# present_date = '20221118' #监测当日
# next_trade_date = '20221119' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221118'#监测当日前一个交易日
# present_date = '20221121' #监测当日
# next_trade_date = '20221122' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221121'#监测当日前一个交易日
# present_date = '20221122' #监测当日
# next_trade_date = '20221123' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221122'#监测当日前一个交易日
# present_date = '20221123' #监测当日
# next_trade_date = '20221124' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221123'#监测当日前一个交易日
# present_date = '20221124' #监测当日
# next_trade_date = '20221125' #监测当日下一个自然日
# ###############################################################

# ###############################################################
before_trade_date = '20221124'#监测当日前一个交易日
present_date = '20221125' #监测当日
next_trade_date = '20221126' #监测当日下一个自然日
# ###############################################################

# %%
start_date = pd.to_datetime(before_trade_date) 
end_date = pd.to_datetime(next_trade_date)

cbond_price = pd.DataFrame([])
for code in cbond_list:
    price_df = w.wsi(code, "close", start_date, end_date,usedf=True)[1]   #只要了收盘价
    price_df.columns = [code]
    cbond_price = pd.concat([cbond_price,price_df],axis=1)
cbond_price = cbond_price.ffill()    
# cbond_rtn = cbond_price[cbond_price.index.time!=time(15,0,0)]
# cbond_price = cbond_price.loc['2022-09-09 15:00:00':] #从前一个交易日的收盘价开始截取
cbond_price_begin_time = before_trade_date[:4]+'-' + \
                    before_trade_date[4:6]+'-' + \
                    before_trade_date[6:8]+' 15:00:00'
cbond_price = cbond_price.loc[cbond_price_begin_time:]
cbond_price
# Out:
#                      123046.SZ  300587.SZ  113642.SH  603185.SH  110061.SH  \
# 2022-11-24 15:00:00    371.988      12.97        NaN     122.98    135.399
# 2022-11-25 09:30:00    372.992      12.74        NaN     121.07    135.192
# 2022-11-25 09:31:00    372.778      12.82        NaN     121.12    135.032
# 2022-11-25 09:32:00    374.000      12.89        NaN     120.70    135.066
# 2022-11-25 09:33:00    368.859      12.79        NaN     120.65    134.959
# ...                        ...        ...        ...        ...        ...
# 2022-11-25 14:56:00    367.207      12.88        NaN     119.00    136.507
# 2022-11-25 14:57:00    367.413      12.86        NaN     119.00    136.599
# 2022-11-25 14:58:00    367.413      12.86        NaN     119.00    136.600
# 2022-11-25 14:59:00    367.413      12.86        NaN     119.00    136.600
# 2022-11-25 15:00:00    368.500      12.90        NaN     119.00    136.604
#
#                      600674.SH  128081.SZ  002203.SZ  113016.SH  601127.SH  \
# 2022-11-24 15:00:00      11.80    127.300      12.20    329.512      47.50
# 2022-11-25 09:30:00      11.80    126.743      12.10    329.719      47.32
# 2022-11-25 09:31:00      11.80    126.507      12.06    329.494      47.10
# 2022-11-25 09:32:00      11.79    126.573      12.07    328.584      46.70
# 2022-11-25 09:33:00      11.80    126.619      12.08    329.067      46.89
# ...                        ...        ...        ...        ...        ...
# 2022-11-25 14:56:00      11.94    126.699      12.10    319.975      45.82
# 2022-11-25 14:57:00      11.94    126.699      12.11    319.978      45.82
# 2022-11-25 14:58:00      11.94    126.699      12.11    319.860      45.82
# 2022-11-25 14:59:00      11.94    126.699      12.11    319.589      45.82
# 2022-11-25 15:00:00      11.95    126.699      12.09    319.743      45.80
#
#                      ...  113626.SH  603596.SH  123092.SZ  300332.SZ  \
# 2022-11-24 15:00:00  ...    224.863      80.65    268.389      13.24
# 2022-11-25 09:30:00  ...    224.063      80.13    269.498      13.20
# 2022-11-25 09:31:00  ...    223.677      80.05    268.776      13.23
# 2022-11-25 09:32:00  ...    223.702      80.18    267.855      13.18
# 2022-11-25 09:33:00  ...    222.033      79.77    268.744      13.21
# ...                  ...        ...        ...        ...        ...
# 2022-11-25 14:56:00  ...    219.382      78.70    268.886      13.21
# 2022-11-25 14:57:00  ...    219.382      78.71    268.939      13.19
# 2022-11-25 14:58:00  ...    219.292      78.71    268.939      13.19
# 2022-11-25 14:59:00  ...    219.289      78.71    268.939      13.19
# 2022-11-25 15:00:00  ...    219.255      78.71    268.400      13.19
#
#                      123057.SZ  300586.SZ  123067.SZ  300382.SZ  128106.SZ  \
# 2022-11-24 15:00:00    242.990      21.89    230.400      22.24    194.120
# 2022-11-25 09:30:00    236.522      21.29    229.221      21.88    193.863
# 2022-11-25 09:31:00    237.744      21.22    228.076      21.70    192.924
# 2022-11-25 09:32:00    236.500      21.11    227.361      21.58    193.011
# 2022-11-25 09:33:00    235.223      21.21    226.825      21.58    193.920
# ...                        ...        ...        ...        ...        ...
# 2022-11-25 14:56:00    225.995      20.60    223.651      21.59    194.594
# 2022-11-25 14:57:00    225.999      20.60    223.802      21.58    194.594
# 2022-11-25 14:58:00    225.999      20.60    223.802      21.58    194.594
# 2022-11-25 14:59:00    225.999      20.60    223.802      21.58    194.594
# 2022-11-25 15:00:00    225.800      20.62    223.500      21.48    195.000
#
#                      002840.SZ
# 2022-11-24 15:00:00      16.69
# 2022-11-25 09:30:00      16.58
# 2022-11-25 09:31:00      16.51
# 2022-11-25 09:32:00      16.53
# 2022-11-25 09:33:00      16.63
# ...                        ...
# 2022-11-25 14:56:00      16.70
# 2022-11-25 14:57:00      16.70
# 2022-11-25 14:58:00      16.70
# 2022-11-25 14:59:00      16.70
# 2022-11-25 15:00:00      16.72
#
# [243 rows x 38 columns]

# %%
# assert False

# %% [markdown]
# # stock pre status

# %%
df_stk_pre_return = w.wss("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return
# Out:
#             PCT_CHG
# 300587.SZ  7.634855
# 603185.SH -1.371401
# 600674.SH  1.027397
# 002203.SZ  0.577082
# 601127.SH  0.635593
# 002597.SZ  0.786026
# 603348.SH -0.683579
# 300487.SZ  1.976178
# 603876.SH -2.207273
# 601677.SH  1.206434
# 300655.SZ  0.470865
# 002078.SZ -0.374181
# 002738.SZ  1.432292
# 002812.SZ  3.007057
# 603596.SH -0.554871
# 300332.SZ  0.303030
# 300586.SZ  6.417112
# 300382.SZ -1.636444
# 002840.SZ  1.458967

# %%
df_bond_pre_return = w.wss("123046.SZ,113642.SH,110061.SH,128081.SZ,113016.SH,128017.SZ,113537.SH,123027.SZ,113534.SH,113025.SH,123031.SZ,128029.SZ,128111.SZ,128095.SZ,113626.SH,123092.SZ,123057.SZ,123067.SZ,128106.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_bond_pre_return
# Out:
#             PCT_CHG
# 123046.SZ  6.320865
# 113642.SH       NaN
# 110061.SH  0.877657
# 128081.SZ  0.552923
# 113016.SH  1.718502
# 128017.SZ  0.567252
# 113537.SH  0.961417
# 123027.SZ       NaN
# 113534.SH -0.720657
# 113025.SH  2.864833
# 123031.SZ  0.032846
# 128029.SZ -0.254587
# 128111.SZ  1.405927
# 128095.SZ  1.423469
# 113626.SH -0.145211
# 123092.SZ  0.332336
# 123057.SZ  3.824133
# 123067.SZ -2.372881
# 128106.SZ  1.793927

# %%
before_trade_date_trade_status = before_trade_date[:4] +'-'+ before_trade_date[4:6] +'-'+ before_trade_date[6:]
# present_date_trade_status = present_date[:4] +'-'+ present_date[4:6] +'-'+ present_date[6:]
df_stk_pre_trade_status = w.wsd("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ", 
"trade_status", f"{before_trade_date_trade_status}", f"{before_trade_date_trade_status}", "",usedf=True)[1]
df_stk_pre_trade_status
# Out:
#           TRADE_STATUS
# 300587.SZ           交易
# 603185.SH           交易
# 600674.SH           交易
# 002203.SZ           交易
# 601127.SH           交易
# 002597.SZ           交易
# 603348.SH           交易
# 300487.SZ           交易
# 603876.SH           交易
# 601677.SH           交易
# 300655.SZ           交易
# 002078.SZ           交易
# 002738.SZ           交易
# 002812.SZ           交易
# 603596.SH           交易
# 300332.SZ           交易
# 300586.SZ           交易
# 300382.SZ           交易
# 002840.SZ           交易

# %%
# assert False

# %% [markdown]
# # bond-stock pair

# %%
# cbond_pair = ['113642.SH','603185.SH']  #后面筛选的结果，这组也在里面 转债停止交易了
# open_threshold = 0.023
# close_threshold = 0
# convert_price = 102.4
# operate = True

# cbond_pair = ['123027.SZ','300487.SZ',] # 1019 1020 1021 这几天转债停止交易了
# open_threshold = 0.022
# close_threshold = 0
# convert_price = 19.07
# operate = True

# %%
cbond_pair = ['123046.SZ','300587.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.015
close_threshold = 0
convert_price = 3.94
operate = True

cbond_pair = ['110061.SH','600674.SH']
open_threshold = 0.006
close_threshold = 0
convert_price = 8.8
operate = True

cbond_pair = ['128081.SZ','002203.SZ']
open_threshold = 0.012
close_threshold = 0.002
convert_price = 9.62
operate = True

cbond_pair = ['113016.SH','601127.SH'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.017
close_threshold = 0.003
convert_price = 20.17
operate = True

cbond_pair = ['128017.SZ','002597.SZ']
open_threshold = 0.012
close_threshold = 0
convert_price = 21.33
operate = True

# # # # # # # $$$$$$$$$$$$$$$$$$$$$$$$以下是新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['113537.SH','603348.SH',]
open_threshold = 0.027
close_threshold = 0.002
convert_price = 19.13
operate = True

cbond_pair = ['113534.SH','603876.SH',]
open_threshold = 0.019
close_threshold = 0.002
convert_price = 14.98
operate = True

cbond_pair = ['113025.SH','601677.SH',]
open_threshold = 0.018
close_threshold = 0
convert_price = 7.66
operate = True

cbond_pair = ['123031.SZ','300655.SZ',]   #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.019
close_threshold = 0
convert_price = 6.25
operate = True

cbond_pair = ['128029.SZ','002078.SZ']
open_threshold = 0.013
close_threshold = 0.002
convert_price = 8.25
operate = True

# # # # # # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-10-14】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['128111.SZ','002738.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.011
close_threshold = 0.001
convert_price = 10.96
operate = True

cbond_pair = ['128095.SZ','002812.SZ']
open_threshold = 0.013
close_threshold = 0
convert_price = 64.62
operate = False

cbond_pair = ['113626.SH','603596.SH']
open_threshold = 0.02
close_threshold = 0
convert_price = 35.88
operate = True

cbond_pair = ['123092.SZ','300332.SZ']
open_threshold = 0.025
close_threshold = 0.001
convert_price = 5.14
operate = True

# # # # # # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-11-18】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair =  ['123057.SZ','300586.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.009 
close_threshold = 0.003
convert_price = 9.5
operate = True

cbond_pair =  ['123067.SZ','300382.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.004
close_threshold = 0.002
convert_price = 9.96
operate = True

cbond_pair =  ['128106.SZ','002840.SZ']
open_threshold = 0.01
close_threshold = 0
convert_price = 8.85
operate = True

# %%
# df_signal

# %% [markdown]
# # clip price series

# %%
#从前一个交易日的收盘价开始截取
# cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]].loc['2022-09-08 15:00:00':]
cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]]

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-24 15:00:00    194.120      16.69
# 2022-11-25 09:30:00    193.863      16.58
# 2022-11-25 09:31:00    192.924      16.51
# 2022-11-25 09:32:00    193.011      16.53
# 2022-11-25 09:33:00    193.920      16.63

# %%
cbond_return = pd.DataFrame([])

cbond_preclose = cbond_pair_price.iloc[0,0] # 初始时刻的bond前收盘价
stock_preclose = cbond_pair_price.iloc[0,1] # 初始时刻的stock前收盘价

for index,row in cbond_pair_price.iterrows():
    
    cbond_return.loc[index,cbond_pair[0]] = row[cbond_pair[0]]/cbond_preclose - 1 # 算日内的return
    cbond_return.loc[index,cbond_pair[1]] = row[cbond_pair[1]]/stock_preclose - 1

    if index.time()==time(15,0,0):  #算完日内return，迭代到今日价格的最后一个time bar的时候，将其设为前收盘价
        cbond_preclose = row[cbond_pair[0]]    # 日内return指标用 现价/昨日收盘价 计算
        stock_preclose = row[cbond_pair[1]]
        
# 检查df是否有空值
cbond_return.isnull().sum(axis=0)  # 按列统计
cbond_return.isnull().sum(axis=1) # 按行统计
cbond_return.isnull().sum(axis=1).sum() # 统计整张表
# Out:
# 0

# %%
pd.set_option('display.max_rows', None)
cbond_return['diff'] = cbond_return[cbond_pair[0]] - cbond_return[cbond_pair[1]]
cbond_return.head()
# Out:
#                      128106.SZ  002840.SZ      diff
# 2022-11-24 15:00:00   0.000000   0.000000  0.000000
# 2022-11-25 09:30:00  -0.001324  -0.006591  0.005267
# 2022-11-25 09:31:00  -0.006161  -0.010785  0.004624
# 2022-11-25 09:32:00  -0.005713  -0.009587  0.003874
# 2022-11-25 09:33:00  -0.001030  -0.003595  0.002565

# %% [markdown]
# # signal calculate

# %%
################################################################################################
stk_pre_return = df_stk_pre_return.loc[cbond_pair[1]].values[0]
bond_pre_return = df_bond_pre_return.loc[cbond_pair[0]].values[0]
pre_diff = bond_pre_return - stk_pre_return
stk_pre_trade_status = df_stk_pre_trade_status.loc[cbond_pair[1]].values[0]
print(stk_pre_trade_status)
print('pre diff:',pre_diff)
# if abs(stk_pre_return) > 10 or stk_pre_trade_status!='交易':
if abs(pre_diff) > 5 or stk_pre_trade_status!='交易':
    # 如果前一天股票的跌幅小于-10，则今日不做操作
    intraday_open_times = 1
else:
    intraday_open_times = 0
################################################################################################    
open_close_spread = open_threshold - close_threshold
# intraday_open_times = 0
max_open = 1

pos_open_flag = 0
neg_open_flag = 0
cbond_position = pd.DataFrame([])
cbond_position.index = cbond_return.index
for index,row in cbond_return.iterrows():

    if row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff落在A区间，且无仓位，正开
            pos_open_flag = 1
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==1:
        if intraday_open_times < max_open:
            #diff落在A区间，且有负仓，平仓再正开
            pos_open_flag=1
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            print('reverse open +1')
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff落在A区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在B区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在B区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在B区间，且无仓，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在C区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在C区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在C区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在D区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在D区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在D区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且无仓位，反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==1 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且有正仓，平仓反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在E区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    if abs(row['diff'])>2 * open_close_spread and cbond_return.columns[0]!='123057.SZ' and cbond_return.columns[0]!='123067.SZ': 
        #盘中diff超过2倍spread时平仓（价格止损信号）,有两个spread特别小的对子则不用此逻辑进行止损
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if index.time()==time(15,0,0): # 每日收盘时必须平仓（时间止损信号）
    # if index.time()==time(14,59,0): # 每日收盘时必须平仓（时间止损信号）
        intraday_open_times = 0 # 下一天开盘前，把当日记录下来的开仓次数清零
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
# Out:
# 交易
# pre diff: 0.3349599890634103

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-24 15:00:00    194.120      16.69
# 2022-11-25 09:30:00    193.863      16.58
# 2022-11-25 09:31:00    192.924      16.51
# 2022-11-25 09:32:00    193.011      16.53
# 2022-11-25 09:33:00    193.920      16.63

# %%
df_signal = pd.concat([cbond_pair_price,cbond_return,cbond_position],axis=1)
df_signal.columns = ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
print('open threshold',open_threshold,'close threshold',close_threshold)
# df_signal.to_csv('tmp_signal.csv')
# df_signal
# Out:
# open threshold 0.01 close threshold 0

# %% [markdown]
# # backtest

# %%
# 用来记录交易流水的表格,一边遍历df_signal，一边填入内容到流水表格里

import numpy as np
cols = ['balance','signal','bond price','stock price','bond hold','stock hold','commission','tax','reverse open','diff','asset value']
df_trade = pd.DataFrame(
    data = [[0,np.nan,np.nan,np.nan,0,0,0,0,np.nan,np.nan,0]],
    columns=cols
    ) 

balance_last = 0 # 现金账户初始余额

bond_hold = 0 # 债券持有数量
stock_hold = 0 # 股票持有数量


commission_rate = 2/10000 + 0 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 0.5/1000 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 1/1000 # 佣金买卖万二 + 交易滑点

tax_rate = 1/1000 # 卖股票才收印花税千一

# commission_rate = 0/10000 # 佣金买卖万二
# tax_rate = 0/1000 #

for i in range(len(df_signal)-1):
    if df_signal.index[i].time() == time(15,0,0):
    # if df_signal.index[i].time() == time(14,59,0):
        # 修改stock volume 每天固定一个stock volume 应该用债的前收盘价/股票的前收盘价
        stock_volume = df_signal['bond_price'][i]/df_signal['stock_price'][i]

    if df_signal.values[i][-1] != df_signal.values[i+1][-1]:

        index = df_signal.index[i+1]        
        diff = df_signal.values[i+1][-3] #diff在df_signal中的倒数第三列
        
    # df_signal的columns
    # ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
        signal = str(int(df_signal.values[i+1][-2]))+str(int(df_signal.values[i+1][-1]))
        
        bond_price = df_signal.values[i+1][0] 

        stock_price = df_signal.values[i+1][1]

        # stock_volume =  bond_price/stock_price # 修改stock volume 每天固定一个stock volume应该用债的前收盘价/股票的前收盘价

        commission = (bond_price + stock_price * stock_volume) * commission_rate

        reverse_open = False #表明这笔交易，是否包含平仓后再反向开仓的操作

        if signal == '00' and stock_hold == stock_volume: #有股票持仓并且需要卖出平仓时，有印花税
            tax = stock_price * tax_rate * stock_volume
        else:
            tax = 0

        if signal == '00':
            balance_last += bond_hold*bond_price
            balance_last += stock_hold*stock_price
            
            bond_hold = 0
            stock_hold = 0
            

        if signal == '1-1':
            '''
            加一个检测之前持仓的模块,如果之前因为-11的信号有持仓,需要先平掉(即买债卖股票),同时再反向开仓
            '''
            reverse_flag = False
            if bond_hold == -1 and stock_hold == 1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last -= bond_price 
                balance_last += stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税
                reverse_flag = True
                reverse_open = True

            bond_hold += 1
            stock_hold += (-1 * stock_volume)
            # stock_hold += stock_volume
            balance_last -= bond_price
            balance_last += stock_price * stock_volume
            
            if reverse_flag:
                tax *= 2 #平仓然后反向开仓的时候 已经计算过tax了，直接double
            else:
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税

        if signal == '-11':
            '''
            加一个检测之前持仓的模块,如果之前因为1-1的信号有持仓,需要先平掉(卖债买股票),同时再反向开仓
            '''
            if bond_hold == 1 and stock_hold == -1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last += bond_price
                balance_last -= stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                                # 买股票无印花税
                reverse_open = True
            bond_hold += -1
            stock_hold += (1 * stock_volume)
            # stock_hold += stock_volume
            balance_last += bond_price
            balance_last -= stock_price * stock_volume
        
        balance_last = balance_last - commission - tax
        balance = balance_last
        asset_value = bond_price*bond_hold + stock_price*stock_hold
        line = [balance,signal,bond_price,stock_price,bond_hold,stock_hold,commission,tax,reverse_open,diff,asset_value]
        # df_trade.loc[index,['balance','asset','signal','bond price','stock price','commission','tax']] = line
        # df_trade.loc[index,cols] = [0,0,np.nan,np.nan,np.nan,0,0,0,0]
        df_trade.loc[index,cols] = line

df_trade.rename(columns={'balance':'cash'},inplace=True)       
df_trade['net value'] = df_trade['cash'] + df_trade['asset value']

# %%
df_trade['operate'] = [operate]*len(df_trade)

# %%
df_trade
# Out:
#                          cash signal  bond price  stock price  bond hold  \
# 0                    0.000000    NaN         NaN          NaN        0.0
# 2022-11-25 09:53:00  1.975122    -11     193.497        16.46       -1.0
# 2022-11-25 13:26:00  2.049473     00     195.400        16.83        0.0
#
#                      stock hold  commission       tax reverse open      diff  \
# 0                      0.000000    0.000000  0.000000          NaN       NaN
# 2022-11-25 09:53:00   11.630917    0.076988  0.000000        False  0.010571
# 2022-11-25 13:26:00    0.000000    0.078230  0.195748        False -0.001794
#
#                      asset value  net value  operate
# 0                       0.000000   0.000000     True
# 2022-11-25 09:53:00    -2.052111  -0.076988     True
# 2022-11-25 13:26:00     0.000000   2.049473     True

# %% [markdown]
# # output to csv

# %%
excel_file_name = './daily_track/'+ present_date+'/' + cbond_pair[0] + '@' + cbond_pair[1] + '.csv'

excel_file_name

df_to_excel = df_trade
df_to_excel['open/close'] = [str(open_threshold)+','+str(close_threshold)]*len(df_to_excel)
df_to_excel['pair'] = [cbond_pair[0] + '@' + cbond_pair[1]]*len(df_to_excel)
df_to_excel = df_to_excel[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_to_excel.to_csv(excel_file_name,)

# %%
present_date
# Out:
# '20221125'

# %% [markdown]
# # conclusion

# %%
import os
single_trade_files = os.listdir('./daily_track'+'/'+present_date)

df_trade_conclusion = pd.DataFrame([])
for file in single_trade_files:
    if file == 'diff':
        continue
    if file == '.DS_Store' or file.split('.')[1] == 'xlsx':
        continue
    tmp_path = './daily_track'+'/'+present_date+'/'+file
    df_tmp = pd.read_csv(tmp_path,index_col=0)
    tmp_col = list(df_tmp.columns)
    df_tmp_head = pd.DataFrame(data=[tmp_col],columns=tmp_col)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp_head)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp)
df_trade_conclusion.columns
df_trade_conclusion = df_trade_conclusion[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_trade_conclusion
tmp_path = './daily_track'+'/'+present_date+'/'+f'{present_date}_conclusion.csv'

df_trade_conclusion.to_csv(tmp_path)

# %% [markdown]
# # intraday signal

# %%
import matplotlib.pyplot as plt

signal_plot_begin_time = present_date[:4]+'-' + \
                         present_date[4:6]+'-' + \
                         present_date[6:8]+' 09:30:00'
df_signal['diff'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' diff',grid=True)

#如果当日有开平仓记录，在图上画出开平仓时刻的标注
if len(df_trade) == 3:
    open_tick = df_trade.index.to_list()[1]
    open_diff = df_trade['diff'].to_list()[1]
    close_tick = df_trade.index.to_list()[2]
    close_diff =  df_trade['diff'].to_list()[2]
    plt.text(open_tick,open_diff,'open')
    plt.text(close_tick,close_diff,'close')
    plt.scatter([open_tick],[open_diff],color='r')

    tmp_nv = df_trade['net value'].to_list()[2]
    if tmp_nv > 0: 
        close_color = 'g' #当天赚钱的话，平仓点位标记为绿色
    else:
        close_color = 'orange' #当天亏钱的话，平仓点位标记为橙色
    plt.scatter([close_tick],[close_diff],color=close_color)
fig_file_name = './daily_track/'+ present_date+'/'+'diff/' + cbond_pair[0] + '@' + cbond_pair[1] + '.png'
plt.savefig(fig_file_name)

plt.show()
df_signal['bond_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+' rtn',grid=True)
plt.show()
df_signal['stock_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[1]+' rtn',grid=True)
plt.show()

# %%
df_tmp = 100/convert_price*df_signal['stock_price']
df_signal['premium rate'] = (df_signal['bond_price'] - df_tmp)/df_tmp
df_signal['premium rate'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' premium rate',grid=True)
# Out:
# <AxesSubplot:title={'center':'128106.SZ@002840.SZ premium rate'}>

# %%
df_signal
# Out:
#                      bond_price  stock_price  bond_rtn  stock_rtn      diff  \
# 2022-11-24 15:00:00     194.120        16.69  0.000000   0.000000  0.000000
# 2022-11-25 09:30:00     193.863        16.58 -0.001324  -0.006591  0.005267
# 2022-11-25 09:31:00     192.924        16.51 -0.006161  -0.010785  0.004624
# 2022-11-25 09:32:00     193.011        16.53 -0.005713  -0.009587  0.003874
# 2022-11-25 09:33:00     193.920        16.63 -0.001030  -0.003595  0.002565
# 2022-11-25 09:34:00     192.595        16.55 -0.007856  -0.008388  0.000532
# 2022-11-25 09:35:00     192.200        16.49 -0.009891  -0.011983  0.002092
# 2022-11-25 09:36:00     192.211        16.53 -0.009834  -0.009587 -0.000248
# 2022-11-25 09:37:00     191.821        16.44 -0.011843  -0.014979  0.003136
# 2022-11-25 09:38:00     192.307        16.46 -0.009340  -0.013781  0.004441
# 2022-11-25 09:39:00     191.874        16.41 -0.011570  -0.016777  0.005206
# 2022-11-25 09:40:00     192.300        16.44 -0.009376  -0.014979  0.005603
# 2022-11-25 09:41:00     192.100        16.45 -0.010406  -0.014380  0.003974
# 2022-11-25 09:42:00     192.068        16.46 -0.010571  -0.013781  0.003210
# 2022-11-25 09:43:00     193.000        16.50 -0.005770  -0.011384  0.005614
# 2022-11-25 09:44:00     193.492        16.55 -0.003235  -0.008388  0.005153
# 2022-11-25 09:45:00     193.681        16.52 -0.002261  -0.010186  0.007924
# 2022-11-25 09:46:00     193.192        16.50 -0.004781  -0.011384  0.006604
# 2022-11-25 09:47:00     193.166        16.52 -0.004914  -0.010186  0.005271
# 2022-11-25 09:48:00     192.500        16.45 -0.008345  -0.014380  0.006035
# 2022-11-25 09:49:00     192.542        16.43 -0.008129  -0.015578  0.007449
# 2022-11-25 09:50:00     192.270        16.46 -0.009530  -0.013781  0.004251
# 2022-11-25 09:51:00     192.881        16.43 -0.006383  -0.015578  0.009196
# 2022-11-25 09:52:00     192.715        16.44 -0.007238  -0.014979  0.007741
# 2022-11-25 09:53:00     193.497        16.46 -0.003209  -0.013781  0.010571
# 2022-11-25 09:54:00     193.500        16.47 -0.003194  -0.013182  0.009988
# 2022-11-25 09:55:00     193.200        16.47 -0.004739  -0.013182  0.008442
# 2022-11-25 09:56:00     193.314        16.46 -0.004152  -0.013781  0.009629
# 2022-11-25 09:57:00     193.323        16.51 -0.004106  -0.010785  0.006679
# 2022-11-25 09:58:00     193.022        16.46 -0.005656  -0.013781  0.008124
# 2022-11-25 09:59:00     192.803        16.47 -0.006784  -0.013182  0.006397
# 2022-11-25 10:00:00     193.069        16.44 -0.005414  -0.014979  0.009565
# 2022-11-25 10:01:00     192.975        16.44 -0.005898  -0.014979  0.009081
# 2022-11-25 10:02:00     193.000        16.43 -0.005770  -0.015578  0.009809
# 2022-11-25 10:03:00     193.116        16.47 -0.005172  -0.013182  0.008009
# 2022-11-25 10:04:00     193.322        16.47 -0.004111  -0.013182  0.009071
# 2022-11-25 10:05:00     193.212        16.47 -0.004678  -0.013182  0.008504
# 2022-11-25 10:06:00     192.937        16.46 -0.006094  -0.013781  0.007687
# 2022-11-25 10:07:00     193.744        16.52 -0.001937  -0.010186  0.008249
# 2022-11-25 10:08:00     193.625        16.51 -0.002550  -0.010785  0.008235
# 2022-11-25 10:09:00     193.571        16.51 -0.002828  -0.010785  0.007957
# 2022-11-25 10:10:00     194.687        16.57  0.002921  -0.007190  0.010111
# 2022-11-25 10:11:00     194.545        16.58  0.002189  -0.006591  0.008780
# 2022-11-25 10:12:00     194.600        16.57  0.002473  -0.007190  0.009663
# 2022-11-25 10:13:00     194.121        16.53  0.000005  -0.009587  0.009592
# 2022-11-25 10:14:00     194.185        16.51  0.000335  -0.010785  0.011120
# 2022-11-25 10:15:00     194.446        16.57  0.001679  -0.007190  0.008869
# 2022-11-25 10:16:00     194.584        16.56  0.002390  -0.007789  0.010179
# 2022-11-25 10:17:00     195.000        16.59  0.004533  -0.005992  0.010525
# 2022-11-25 10:18:00     194.996        16.62  0.004513  -0.004194  0.008707
# 2022-11-25 10:19:00     194.361        16.59  0.001242  -0.005992  0.007233
# 2022-11-25 10:20:00     194.500        16.59  0.001958  -0.005992  0.007949
# 2022-11-25 10:21:00     194.692        16.60  0.002947  -0.005392  0.008339
# 2022-11-25 10:22:00     194.199        16.58  0.000407  -0.006591  0.006998
# 2022-11-25 10:23:00     194.639        16.64  0.002674  -0.002996  0.005669
# 2022-11-25 10:24:00     194.979        16.60  0.004425  -0.005392  0.009818
# 2022-11-25 10:25:00     194.828        16.65  0.003647  -0.002397  0.006044
# 2022-11-25 10:26:00     195.381        16.62  0.006496  -0.004194  0.010690
# 2022-11-25 10:27:00     195.051        16.62  0.004796  -0.004194  0.008990
# 2022-11-25 10:28:00     195.273        16.63  0.005940  -0.003595  0.009535
# 2022-11-25 10:29:00     196.332        16.73  0.011395   0.002397  0.008998
# 2022-11-25 10:30:00     196.241        16.78  0.010926   0.005392  0.005534
# 2022-11-25 10:31:00     196.150        16.73  0.010457   0.002397  0.008061
# 2022-11-25 10:32:00     196.151        16.73  0.010463   0.002397  0.008066
# 2022-11-25 10:33:00     196.499        16.77  0.012255   0.004793  0.007462
# 2022-11-25 10:34:00     195.899        16.75  0.009164   0.003595  0.005569
# 2022-11-25 10:35:00     195.590        16.71  0.007573   0.001198  0.006374
# 2022-11-25 10:36:00     195.700        16.72  0.008139   0.001797  0.006342
# 2022-11-25 10:37:00     195.512        16.72  0.007171   0.001797  0.005373
# 2022-11-25 10:38:00     195.125        16.67  0.005177  -0.001198  0.006376
# 2022-11-25 10:39:00     195.280        16.67  0.005976  -0.001198  0.007174
# 2022-11-25 10:40:00     195.750        16.70  0.008397   0.000599  0.007798
# 2022-11-25 10:41:00     195.988        16.72  0.009623   0.001797  0.007825
# 2022-11-25 10:42:00     195.493        16.68  0.007073  -0.000599  0.007672
# 2022-11-25 10:43:00     195.383        16.69  0.006506   0.000000  0.006506
# 2022-11-25 10:44:00     195.120        16.66  0.005151  -0.001797  0.006949
# 2022-11-25 10:45:00     194.694        16.61  0.002957  -0.004793  0.007750
# 2022-11-25 10:46:00     194.997        16.64  0.004518  -0.002996  0.007514
# 2022-11-25 10:47:00     194.600        16.65  0.002473  -0.002397  0.004869
# 2022-11-25 10:48:00     194.603        16.63  0.002488  -0.003595  0.006083
# 2022-11-25 10:49:00     194.596        16.63  0.002452  -0.003595  0.006047
# 2022-11-25 10:50:00     194.528        16.60  0.002102  -0.005392  0.007494
# 2022-11-25 10:51:00     195.029        16.63  0.004683  -0.003595  0.008278
# 2022-11-25 10:52:00     194.800        16.62  0.003503  -0.004194  0.007697
# 2022-11-25 10:53:00     194.798        16.62  0.003493  -0.004194  0.007687
# 2022-11-25 10:54:00     194.971        16.61  0.004384  -0.004793  0.009177
# 2022-11-25 10:55:00     195.101        16.60  0.005054  -0.005392  0.010446
# 2022-11-25 10:56:00     195.077        16.62  0.004930  -0.004194  0.009124
# 2022-11-25 10:57:00     195.253        16.61  0.005837  -0.004793  0.010630
# 2022-11-25 10:58:00     195.388        16.61  0.006532  -0.004793  0.011325
# 2022-11-25 10:59:00     195.160        16.64  0.005358  -0.002996  0.008353
# 2022-11-25 11:00:00     195.324        16.66  0.006202  -0.001797  0.008000
# 2022-11-25 11:01:00     194.875        16.64  0.003889  -0.002996  0.006885
# 2022-11-25 11:02:00     194.900        16.62  0.004018  -0.004194  0.008212
# 2022-11-25 11:03:00     194.565        16.58  0.002292  -0.006591  0.008883
# 2022-11-25 11:04:00     194.612        16.58  0.002535  -0.006591  0.009125
# 2022-11-25 11:05:00     194.600        16.59  0.002473  -0.005992  0.008464
# 2022-11-25 11:06:00     194.702        16.61  0.002998  -0.004793  0.007791
# 2022-11-25 11:07:00     194.795        16.60  0.003477  -0.005392  0.008870
# 2022-11-25 11:08:00     194.371        16.57  0.001293  -0.007190  0.008483
# 2022-11-25 11:09:00     194.373        16.56  0.001303  -0.007789  0.009092
# 2022-11-25 11:10:00     194.312        16.57  0.000989  -0.007190  0.008179
# 2022-11-25 11:11:00     194.204        16.54  0.000433  -0.008987  0.009420
# 2022-11-25 11:12:00     194.094        16.51 -0.000134  -0.010785  0.010651
# 2022-11-25 11:13:00     194.000        16.52 -0.000618  -0.010186  0.009568
# 2022-11-25 11:14:00     194.186        16.54  0.000340  -0.008987  0.009327
# 2022-11-25 11:15:00     194.486        16.59  0.001885  -0.005992  0.007877
# 2022-11-25 11:16:00     194.424        16.56  0.001566  -0.007789  0.009355
# 2022-11-25 11:17:00     194.457        16.54  0.001736  -0.008987  0.010723
# 2022-11-25 11:18:00     194.594        16.56  0.002442  -0.007789  0.010231
# 2022-11-25 11:19:00     194.650        16.56  0.002730  -0.007789  0.010519
# 2022-11-25 11:20:00     194.693        16.61  0.002952  -0.004793  0.007745
# 2022-11-25 11:21:00     194.260        16.60  0.000721  -0.005392  0.006114
# 2022-11-25 11:22:00     194.244        16.61  0.000639  -0.004793  0.005432
# 2022-11-25 11:23:00     193.979        16.58 -0.000726  -0.006591  0.005864
# 2022-11-25 11:24:00     194.099        16.58 -0.000108  -0.006591  0.006483
# 2022-11-25 11:25:00     194.209        16.59  0.000458  -0.005992  0.006450
# 2022-11-25 11:26:00     194.429        16.58  0.001592  -0.006591  0.008183
# 2022-11-25 11:27:00     194.032        16.57 -0.000453  -0.007190  0.006737
# 2022-11-25 11:28:00     193.950        16.57 -0.000876  -0.007190  0.006314
# 2022-11-25 11:29:00     193.887        16.58 -0.001200  -0.006591  0.005390
# 2022-11-25 11:30:00     193.887        16.58 -0.001200  -0.006591  0.005390
# 2022-11-25 13:00:00     193.683        16.52 -0.002251  -0.010186  0.007935
# 2022-11-25 13:01:00     193.896        16.52 -0.001154  -0.010186  0.009032
# 2022-11-25 13:02:00     193.662        16.54 -0.002359  -0.008987  0.006628
# 2022-11-25 13:03:00     193.750        16.55 -0.001906  -0.008388  0.006482
# 2022-11-25 13:04:00     193.900        16.56 -0.001133  -0.007789  0.006656
# 2022-11-25 13:05:00     194.467        16.57  0.001788  -0.007190  0.008977
# 2022-11-25 13:06:00     194.162        16.55  0.000216  -0.008388  0.008605
# 2022-11-25 13:07:00     194.420        16.58  0.001545  -0.006591  0.008136
# 2022-11-25 13:08:00     194.460        16.58  0.001751  -0.006591  0.008342
# 2022-11-25 13:09:00     194.318        16.62  0.001020  -0.004194  0.005214
# 2022-11-25 13:10:00     194.458        16.63  0.001741  -0.003595  0.005336
# 2022-11-25 13:11:00     194.391        16.61  0.001396  -0.004793  0.006189
# 2022-11-25 13:12:00     194.404        16.60  0.001463  -0.005392  0.006855
# 2022-11-25 13:13:00     194.381        16.60  0.001345  -0.005392  0.006737
# 2022-11-25 13:14:00     194.201        16.60  0.000417  -0.005392  0.005810
# 2022-11-25 13:15:00     193.973        16.58 -0.000757  -0.006591  0.005834
# 2022-11-25 13:16:00     194.055        16.57 -0.000335  -0.007190  0.006855
# 2022-11-25 13:17:00     193.800        16.55 -0.001648  -0.008388  0.006740
# 2022-11-25 13:18:00     194.158        16.56  0.000196  -0.007789  0.007985
# 2022-11-25 13:19:00     194.280        16.65  0.000824  -0.002397  0.003221
# 2022-11-25 13:20:00     195.238        16.71  0.005759   0.001198  0.004561
# 2022-11-25 13:21:00     195.600        16.77  0.007624   0.004793  0.002831
# 2022-11-25 13:22:00     195.330        16.70  0.006233   0.000599  0.005634
# 2022-11-25 13:23:00     196.002        16.84  0.009695   0.008987  0.000708
# 2022-11-25 13:24:00     195.943        16.83  0.009391   0.008388  0.001003
# 2022-11-25 13:25:00     195.487        16.78  0.007042   0.005392  0.001650
# 2022-11-25 13:26:00     195.400        16.83  0.006594   0.008388 -0.001794
# 2022-11-25 13:27:00     195.151        16.80  0.005311   0.006591 -0.001280
# 2022-11-25 13:28:00     195.027        16.77  0.004672   0.004793 -0.000121
# 2022-11-25 13:29:00     194.800        16.76  0.003503   0.004194 -0.000691
# 2022-11-25 13:30:00     194.638        16.72  0.002668   0.001797  0.000871
# 2022-11-25 13:31:00     194.447        16.71  0.001685   0.001198  0.000486
# 2022-11-25 13:32:00     194.317        16.70  0.001015   0.000599  0.000416
# 2022-11-25 13:33:00     194.784        16.76  0.003421   0.004194 -0.000774
# 2022-11-25 13:34:00     194.363        16.74  0.001252   0.002996 -0.001744
# 2022-11-25 13:35:00     194.365        16.71  0.001262   0.001198  0.000064
# 2022-11-25 13:36:00     194.160        16.70  0.000206   0.000599 -0.000393
# 2022-11-25 13:37:00     194.280        16.70  0.000824   0.000599  0.000225
# 2022-11-25 13:38:00     194.100        16.71 -0.000103   0.001198 -0.001301
# 2022-11-25 13:39:00     194.135        16.69  0.000077   0.000000  0.000077
# 2022-11-25 13:40:00     193.750        16.66 -0.001906  -0.001797 -0.000109
# 2022-11-25 13:41:00     194.060        16.65 -0.000309  -0.002397  0.002088
# 2022-11-25 13:42:00     193.937        16.65 -0.000943  -0.002397  0.001454
# 2022-11-25 13:43:00     194.214        16.66  0.000484  -0.001797  0.002282
# 2022-11-25 13:44:00     194.200        16.66  0.000412  -0.001797  0.002210
# 2022-11-25 13:45:00     194.042        16.66 -0.000402  -0.001797  0.001396
# 2022-11-25 13:46:00     194.370        16.76  0.001288   0.004194 -0.002906
# 2022-11-25 13:47:00     194.239        16.72  0.000613   0.001797 -0.001184
# 2022-11-25 13:48:00     194.531        16.71  0.002117   0.001198  0.000919
# 2022-11-25 13:49:00     194.456        16.72  0.001731   0.001797 -0.000067
# 2022-11-25 13:50:00     194.301        16.69  0.000932   0.000000  0.000932
# 2022-11-25 13:51:00     194.403        16.72  0.001458   0.001797 -0.000340
# 2022-11-25 13:52:00     194.328        16.72  0.001072   0.001797 -0.000726
# 2022-11-25 13:53:00     194.163        16.69  0.000222   0.000000  0.000222
# 2022-11-25 13:54:00     194.165        16.69  0.000232   0.000000  0.000232
# 2022-11-25 13:55:00     194.451        16.69  0.001705   0.000000  0.001705
# 2022-11-25 13:56:00     194.230        16.69  0.000567   0.000000  0.000567
# 2022-11-25 13:57:00     194.480        16.71  0.001855   0.001198  0.000656
# 2022-11-25 13:58:00     194.419        16.69  0.001540   0.000000  0.001540
# 2022-11-25 13:59:00     194.382        16.70  0.001350   0.000599  0.000751
# 2022-11-25 14:00:00     194.500        16.69  0.001958   0.000000  0.001958
# 2022-11-25 14:01:00     194.620        16.70  0.002576   0.000599  0.001977
# 2022-11-25 14:02:00     194.794        16.70  0.003472   0.000599  0.002873
# 2022-11-25 14:03:00     194.600        16.69  0.002473   0.000000  0.002473
# 2022-11-25 14:04:00     194.604        16.70  0.002493   0.000599  0.001894
# 2022-11-25 14:05:00     194.330        16.69  0.001082   0.000000  0.001082
# 2022-11-25 14:06:00     194.168        16.67  0.000247  -0.001198  0.001446
# 2022-11-25 14:07:00     194.126        16.66  0.000031  -0.001797  0.001828
# 2022-11-25 14:08:00     194.100        16.66 -0.000103  -0.001797  0.001694
# 2022-11-25 14:09:00     194.387        16.66  0.001375  -0.001797  0.003173
# 2022-11-25 14:10:00     194.250        16.66  0.000670  -0.001797  0.002467
# 2022-11-25 14:11:00     194.348        16.66  0.001175  -0.001797  0.002972
# 2022-11-25 14:12:00     194.211        16.66  0.000469  -0.001797  0.002266
# 2022-11-25 14:13:00     194.287        16.65  0.000860  -0.002397  0.003257
# 2022-11-25 14:14:00     194.400        16.67  0.001442  -0.001198  0.002641
# 2022-11-25 14:15:00     194.599        16.69  0.002468   0.000000  0.002468
# 2022-11-25 14:16:00     194.503        16.68  0.001973  -0.000599  0.002572
# 2022-11-25 14:17:00     194.800        16.69  0.003503   0.000000  0.003503
# 2022-11-25 14:18:00     194.800        16.69  0.003503   0.000000  0.003503
# 2022-11-25 14:19:00     194.580        16.70  0.002370   0.000599  0.001771
# 2022-11-25 14:20:00     194.614        16.70  0.002545   0.000599  0.001946
# 2022-11-25 14:21:00     194.672        16.68  0.002844  -0.000599  0.003443
# 2022-11-25 14:22:00     194.565        16.68  0.002292  -0.000599  0.002892
# 2022-11-25 14:23:00     194.686        16.68  0.002916  -0.000599  0.003515
# 2022-11-25 14:24:00     194.451        16.68  0.001705  -0.000599  0.002304
# 2022-11-25 14:25:00     194.664        16.68  0.002802  -0.000599  0.003402
# 2022-11-25 14:26:00     194.922        16.69  0.004131   0.000000  0.004131
# 2022-11-25 14:27:00     195.048        16.68  0.004781  -0.000599  0.005380
# 2022-11-25 14:28:00     195.366        16.69  0.006419   0.000000  0.006419
# 2022-11-25 14:29:00     194.966        16.69  0.004358   0.000000  0.004358
# 2022-11-25 14:30:00     195.018        16.67  0.004626  -0.001198  0.005824
# 2022-11-25 14:31:00     194.897        16.66  0.004003  -0.001797  0.005800
# 2022-11-25 14:32:00     194.939        16.67  0.004219  -0.001198  0.005417
# 2022-11-25 14:33:00     194.880        16.66  0.003915  -0.001797  0.005713
# 2022-11-25 14:34:00     194.880        16.66  0.003915  -0.001797  0.005713
# 2022-11-25 14:35:00     195.000        16.66  0.004533  -0.001797  0.006331
# 2022-11-25 14:36:00     194.915        16.67  0.004095  -0.001198  0.005294
# 2022-11-25 14:37:00     195.095        16.66  0.005023  -0.001797  0.006820
# 2022-11-25 14:38:00     194.827        16.66  0.003642  -0.001797  0.005440
# 2022-11-25 14:39:00     194.800        16.67  0.003503  -0.001198  0.004701
# 2022-11-25 14:40:00     194.965        16.67  0.004353  -0.001198  0.005551
# 2022-11-25 14:41:00     195.161        16.67  0.005363  -0.001198  0.006561
# 2022-11-25 14:42:00     195.240        16.69  0.005770   0.000000  0.005770
# 2022-11-25 14:43:00     195.236        16.68  0.005749  -0.000599  0.006348
# 2022-11-25 14:44:00     195.020        16.69  0.004636   0.000000  0.004636
# 2022-11-25 14:45:00     195.042        16.69  0.004750   0.000000  0.004750
# 2022-11-25 14:46:00     194.938        16.67  0.004214  -0.001198  0.005412
# 2022-11-25 14:47:00     194.892        16.68  0.003977  -0.000599  0.004576
# 2022-11-25 14:48:00     194.893        16.69  0.003982   0.000000  0.003982
# 2022-11-25 14:49:00     194.980        16.69  0.004430   0.000000  0.004430
# 2022-11-25 14:50:00     194.956        16.68  0.004307  -0.000599  0.004906
# 2022-11-25 14:51:00     194.879        16.68  0.003910  -0.000599  0.004509
# 2022-11-25 14:52:00     194.700        16.67  0.002988  -0.001198  0.004186
# 2022-11-25 14:53:00     194.601        16.67  0.002478  -0.001198  0.003676
# 2022-11-25 14:54:00     194.868        16.68  0.003853  -0.000599  0.004452
# 2022-11-25 14:55:00     194.968        16.68  0.004368  -0.000599  0.004968
# 2022-11-25 14:56:00     194.594        16.70  0.002442   0.000599  0.001843
# 2022-11-25 14:57:00     194.594        16.70  0.002442   0.000599  0.001843
# 2022-11-25 14:58:00     194.594        16.70  0.002442   0.000599  0.001843
# 2022-11-25 14:59:00     194.594        16.70  0.002442   0.000599  0.001843
# 2022-11-25 15:00:00     195.000        16.72  0.004533   0.001797  0.002736
#
#                      bond_pos  stock_pos  premium rate
# 2022-11-24 15:00:00       0.0        0.0      0.029336
# 2022-11-25 09:30:00       0.0        0.0      0.034793
# 2022-11-25 09:31:00       0.0        0.0      0.034147
# 2022-11-25 09:32:00       0.0        0.0      0.033362
# 2022-11-25 09:33:00       0.0        0.0      0.031986
# 2022-11-25 09:34:00       0.0        0.0      0.029889
# 2022-11-25 09:35:00       0.0        0.0      0.031516
# 2022-11-25 09:36:00       0.0        0.0      0.029079
# 2022-11-25 09:37:00       0.0        0.0      0.032613
# 2022-11-25 09:38:00       0.0        0.0      0.033971
# 2022-11-25 09:39:00       0.0        0.0      0.034787
# 2022-11-25 09:40:00       0.0        0.0      0.035192
# 2022-11-25 09:41:00       0.0        0.0      0.033486
# 2022-11-25 09:42:00       0.0        0.0      0.032686
# 2022-11-25 09:43:00       0.0        0.0      0.035182
# 2022-11-25 09:44:00       0.0        0.0      0.034685
# 2022-11-25 09:45:00       0.0        0.0      0.037577
# 2022-11-25 09:46:00       0.0        0.0      0.036212
# 2022-11-25 09:47:00       0.0        0.0      0.034818
# 2022-11-25 09:48:00       0.0        0.0      0.035638
# 2022-11-25 09:49:00       0.0        0.0      0.037125
# 2022-11-25 09:50:00       0.0        0.0      0.033772
# 2022-11-25 09:51:00       0.0        0.0      0.038951
# 2022-11-25 09:52:00       0.0        0.0      0.037426
# 2022-11-25 09:53:00      -1.0        1.0      0.040370
# 2022-11-25 09:54:00      -1.0        1.0      0.039754
# 2022-11-25 09:55:00      -1.0        1.0      0.038142
# 2022-11-25 09:56:00      -1.0        1.0      0.039386
# 2022-11-25 09:57:00      -1.0        1.0      0.036286
# 2022-11-25 09:58:00      -1.0        1.0      0.037816
# 2022-11-25 09:59:00      -1.0        1.0      0.036009
# 2022-11-25 10:00:00      -1.0        1.0      0.039331
# 2022-11-25 10:01:00      -1.0        1.0      0.038825
# 2022-11-25 10:02:00      -1.0        1.0      0.039592
# 2022-11-25 10:03:00      -1.0        1.0      0.037691
# 2022-11-25 10:04:00      -1.0        1.0      0.038798
# 2022-11-25 10:05:00      -1.0        1.0      0.038207
# 2022-11-25 10:06:00      -1.0        1.0      0.037359
# 2022-11-25 10:07:00      -1.0        1.0      0.037914
# 2022-11-25 10:08:00      -1.0        1.0      0.037905
# 2022-11-25 10:09:00      -1.0        1.0      0.037616
# 2022-11-25 10:10:00      -1.0        1.0      0.039819
# 2022-11-25 10:11:00      -1.0        1.0      0.038434
# 2022-11-25 10:12:00      -1.0        1.0      0.039354
# 2022-11-25 10:13:00      -1.0        1.0      0.039305
# 2022-11-25 10:14:00      -1.0        1.0      0.040907
# 2022-11-25 10:15:00      -1.0        1.0      0.038532
# 2022-11-25 10:16:00      -1.0        1.0      0.039896
# 2022-11-25 10:17:00      -1.0        1.0      0.040235
# 2022-11-25 10:18:00      -1.0        1.0      0.038336
# 2022-11-25 10:19:00      -1.0        1.0      0.036826
# 2022-11-25 10:20:00      -1.0        1.0      0.037568
# 2022-11-25 10:21:00      -1.0        1.0      0.037966
# 2022-11-25 10:22:00      -1.0        1.0      0.036587
# 2022-11-25 10:23:00      -1.0        1.0      0.035189
# 2022-11-25 10:24:00      -1.0        1.0      0.039496
# 2022-11-25 10:25:00      -1.0        1.0      0.035572
# 2022-11-25 10:26:00      -1.0        1.0      0.040386
# 2022-11-25 10:27:00      -1.0        1.0      0.038629
# 2022-11-25 10:28:00      -1.0        1.0      0.039186
# 2022-11-25 10:29:00      -1.0        1.0      0.038576
# 2022-11-25 10:30:00      -1.0        1.0      0.035002
# 2022-11-25 10:31:00      -1.0        1.0      0.037614
# 2022-11-25 10:32:00      -1.0        1.0      0.037619
# 2022-11-25 10:33:00      -1.0        1.0      0.036980
# 2022-11-25 10:34:00      -1.0        1.0      0.035048
# 2022-11-25 10:35:00      -1.0        1.0      0.035890
# 2022-11-25 10:36:00      -1.0        1.0      0.035852
# 2022-11-25 10:37:00      -1.0        1.0      0.034857
# 2022-11-25 10:38:00      -1.0        1.0      0.035907
# 2022-11-25 10:39:00      -1.0        1.0      0.036729
# 2022-11-25 10:40:00      -1.0        1.0      0.037358
# 2022-11-25 10:41:00      -1.0        1.0      0.037377
# 2022-11-25 10:42:00      -1.0        1.0      0.037238
# 2022-11-25 10:43:00      -1.0        1.0      0.036033
# 2022-11-25 10:44:00      -1.0        1.0      0.036502
# 2022-11-25 10:45:00      -1.0        1.0      0.037352
# 2022-11-25 10:46:00      -1.0        1.0      0.037093
# 2022-11-25 10:47:00      -1.0        1.0      0.034360
# 2022-11-25 10:48:00      -1.0        1.0      0.035620
# 2022-11-25 10:49:00      -1.0        1.0      0.035583
# 2022-11-25 10:50:00      -1.0        1.0      0.037092
# 2022-11-25 10:51:00      -1.0        1.0      0.037887
# 2022-11-25 10:52:00      -1.0        1.0      0.037292
# 2022-11-25 10:53:00      -1.0        1.0      0.037282
# 2022-11-25 10:54:00      -1.0        1.0      0.038828
# 2022-11-25 10:55:00      -1.0        1.0      0.040147
# 2022-11-25 10:56:00      -1.0        1.0      0.038767
# 2022-11-25 10:57:00      -1.0        1.0      0.040331
# 2022-11-25 10:58:00      -1.0        1.0      0.041050
# 2022-11-25 10:59:00      -1.0        1.0      0.037960
# 2022-11-25 11:00:00      -1.0        1.0      0.037585
# 2022-11-25 11:01:00      -1.0        1.0      0.036445
# 2022-11-25 11:02:00      -1.0        1.0      0.037825
# 2022-11-25 11:03:00      -1.0        1.0      0.038541
# 2022-11-25 11:04:00      -1.0        1.0      0.038791
# 2022-11-25 11:05:00      -1.0        1.0      0.038101
# 2022-11-25 11:06:00      -1.0        1.0      0.037395
# 2022-11-25 11:07:00      -1.0        1.0      0.038516
# 2022-11-25 11:08:00      -1.0        1.0      0.038131
# 2022-11-25 11:09:00      -1.0        1.0      0.038769
# 2022-11-25 11:10:00      -1.0        1.0      0.037816
# 2022-11-25 11:11:00      -1.0        1.0      0.039121
# 2022-11-25 11:12:00      -1.0        1.0      0.040419
# 2022-11-25 11:13:00      -1.0        1.0      0.039286
# 2022-11-25 11:14:00      -1.0        1.0      0.039024
# 2022-11-25 11:15:00      -1.0        1.0      0.037493
# 2022-11-25 11:16:00      -1.0        1.0      0.039041
# 2022-11-25 11:17:00      -1.0        1.0      0.040474
# 2022-11-25 11:18:00      -1.0        1.0      0.039950
# 2022-11-25 11:19:00      -1.0        1.0      0.040249
# 2022-11-25 11:20:00      -1.0        1.0      0.037347
# 2022-11-25 11:21:00      -1.0        1.0      0.035663
# 2022-11-25 11:22:00      -1.0        1.0      0.034954
# 2022-11-25 11:23:00      -1.0        1.0      0.035413
# 2022-11-25 11:24:00      -1.0        1.0      0.036053
# 2022-11-25 11:25:00      -1.0        1.0      0.036015
# 2022-11-25 11:26:00      -1.0        1.0      0.037815
# 2022-11-25 11:27:00      -1.0        1.0      0.036321
# 2022-11-25 11:28:00      -1.0        1.0      0.035883
# 2022-11-25 11:29:00      -1.0        1.0      0.034922
# 2022-11-25 11:30:00      -1.0        1.0      0.034922
# 2022-11-25 13:00:00      -1.0        1.0      0.037587
# 2022-11-25 13:01:00      -1.0        1.0      0.038729
# 2022-11-25 13:02:00      -1.0        1.0      0.036220
# 2022-11-25 13:03:00      -1.0        1.0      0.036065
# 2022-11-25 13:04:00      -1.0        1.0      0.036241
# 2022-11-25 13:05:00      -1.0        1.0      0.038644
# 2022-11-25 13:06:00      -1.0        1.0      0.038268
# 2022-11-25 13:07:00      -1.0        1.0      0.037767
# 2022-11-25 13:08:00      -1.0        1.0      0.037980
# 2022-11-25 13:09:00      -1.0        1.0      0.034726
# 2022-11-25 13:10:00      -1.0        1.0      0.034849
# 2022-11-25 13:11:00      -1.0        1.0      0.035738
# 2022-11-25 13:12:00      -1.0        1.0      0.036431
# 2022-11-25 13:13:00      -1.0        1.0      0.036308
# 2022-11-25 13:14:00      -1.0        1.0      0.035349
# 2022-11-25 13:15:00      -1.0        1.0      0.035381
# 2022-11-25 13:16:00      -1.0        1.0      0.036443
# 2022-11-25 13:17:00      -1.0        1.0      0.036332
# 2022-11-25 13:18:00      -1.0        1.0      0.037620
# 2022-11-25 13:19:00      -1.0        1.0      0.032659
# 2022-11-25 13:20:00      -1.0        1.0      0.034025
# 2022-11-25 13:21:00      -1.0        1.0      0.032236
# 2022-11-25 13:22:00      -1.0        1.0      0.035132
# 2022-11-25 13:23:00      -1.0        1.0      0.030058
# 2022-11-25 13:24:00      -1.0        1.0      0.030360
# 2022-11-25 13:25:00      -1.0        1.0      0.031025
# 2022-11-25 13:26:00       0.0        0.0      0.027504
# 2022-11-25 13:27:00       0.0        0.0      0.028028
# 2022-11-25 13:28:00       0.0        0.0      0.029212
# 2022-11-25 13:29:00       0.0        0.0      0.028628
# 2022-11-25 13:30:00       0.0        0.0      0.030231
# 2022-11-25 13:31:00       0.0        0.0      0.029836
# 2022-11-25 13:32:00       0.0        0.0      0.029764
# 2022-11-25 13:33:00       0.0        0.0      0.028543
# 2022-11-25 13:34:00       0.0        0.0      0.027546
# 2022-11-25 13:35:00       0.0        0.0      0.029402
# 2022-11-25 13:36:00       0.0        0.0      0.028932
# 2022-11-25 13:37:00       0.0        0.0      0.029568
# 2022-11-25 13:38:00       0.0        0.0      0.027998
# 2022-11-25 13:39:00       0.0        0.0      0.029416
# 2022-11-25 13:40:00       0.0        0.0      0.029224
# 2022-11-25 13:41:00       0.0        0.0      0.031490
# 2022-11-25 13:42:00       0.0        0.0      0.030836
# 2022-11-25 13:43:00       0.0        0.0      0.031689
# 2022-11-25 13:44:00       0.0        0.0      0.031615
# 2022-11-25 13:45:00       0.0        0.0      0.030775
# 2022-11-25 13:46:00       0.0        0.0      0.026357
# 2022-11-25 13:47:00       0.0        0.0      0.028119
# 2022-11-25 13:48:00       0.0        0.0      0.030281
# 2022-11-25 13:49:00       0.0        0.0      0.029268
# 2022-11-25 13:50:00       0.0        0.0      0.030296
# 2022-11-25 13:51:00       0.0        0.0      0.028987
# 2022-11-25 13:52:00       0.0        0.0      0.028590
# 2022-11-25 13:53:00       0.0        0.0      0.029564
# 2022-11-25 13:54:00       0.0        0.0      0.029575
# 2022-11-25 13:55:00       0.0        0.0      0.031091
# 2022-11-25 13:56:00       0.0        0.0      0.029919
# 2022-11-25 13:57:00       0.0        0.0      0.030011
# 2022-11-25 13:58:00       0.0        0.0      0.030922
# 2022-11-25 13:59:00       0.0        0.0      0.030108
# 2022-11-25 14:00:00       0.0        0.0      0.031351
# 2022-11-25 14:01:00       0.0        0.0      0.031369
# 2022-11-25 14:02:00       0.0        0.0      0.032292
# 2022-11-25 14:03:00       0.0        0.0      0.031881
# 2022-11-25 14:04:00       0.0        0.0      0.031285
# 2022-11-25 14:05:00       0.0        0.0      0.030450
# 2022-11-25 14:06:00       0.0        0.0      0.030826
# 2022-11-25 14:07:00       0.0        0.0      0.031222
# 2022-11-25 14:08:00       0.0        0.0      0.031083
# 2022-11-25 14:09:00       0.0        0.0      0.032608
# 2022-11-25 14:10:00       0.0        0.0      0.031880
# 2022-11-25 14:11:00       0.0        0.0      0.032401
# 2022-11-25 14:12:00       0.0        0.0      0.031673
# 2022-11-25 14:13:00       0.0        0.0      0.032697
# 2022-11-25 14:14:00       0.0        0.0      0.032058
# 2022-11-25 14:15:00       0.0        0.0      0.031876
# 2022-11-25 14:16:00       0.0        0.0      0.031985
# 2022-11-25 14:17:00       0.0        0.0      0.032942
# 2022-11-25 14:18:00       0.0        0.0      0.032942
# 2022-11-25 14:19:00       0.0        0.0      0.031157
# 2022-11-25 14:20:00       0.0        0.0      0.031338
# 2022-11-25 14:21:00       0.0        0.0      0.032882
# 2022-11-25 14:22:00       0.0        0.0      0.032314
# 2022-11-25 14:23:00       0.0        0.0      0.032956
# 2022-11-25 14:24:00       0.0        0.0      0.031709
# 2022-11-25 14:25:00       0.0        0.0      0.032840
# 2022-11-25 14:26:00       0.0        0.0      0.033589
# 2022-11-25 14:27:00       0.0        0.0      0.034877
# 2022-11-25 14:28:00       0.0        0.0      0.035943
# 2022-11-25 14:29:00       0.0        0.0      0.033822
# 2022-11-25 14:30:00       0.0        0.0      0.035339
# 2022-11-25 14:31:00       0.0        0.0      0.035317
# 2022-11-25 14:32:00       0.0        0.0      0.034919
# 2022-11-25 14:33:00       0.0        0.0      0.035227
# 2022-11-25 14:34:00       0.0        0.0      0.035227
# 2022-11-25 14:35:00       0.0        0.0      0.035864
# 2022-11-25 14:36:00       0.0        0.0      0.034792
# 2022-11-25 14:37:00       0.0        0.0      0.036369
# 2022-11-25 14:38:00       0.0        0.0      0.034945
# 2022-11-25 14:39:00       0.0        0.0      0.034181
# 2022-11-25 14:40:00       0.0        0.0      0.035057
# 2022-11-25 14:41:00       0.0        0.0      0.036098
# 2022-11-25 14:42:00       0.0        0.0      0.035275
# 2022-11-25 14:43:00       0.0        0.0      0.035874
# 2022-11-25 14:44:00       0.0        0.0      0.034108
# 2022-11-25 14:45:00       0.0        0.0      0.034225
# 2022-11-25 14:46:00       0.0        0.0      0.034914
# 2022-11-25 14:47:00       0.0        0.0      0.034049
# 2022-11-25 14:48:00       0.0        0.0      0.033435
# 2022-11-25 14:49:00       0.0        0.0      0.033896
# 2022-11-25 14:50:00       0.0        0.0      0.034389
# 2022-11-25 14:51:00       0.0        0.0      0.033980
# 2022-11-25 14:52:00       0.0        0.0      0.033650
# 2022-11-25 14:53:00       0.0        0.0      0.033125
# 2022-11-25 14:54:00       0.0        0.0      0.033922
# 2022-11-25 14:55:00       0.0        0.0      0.034453
# 2022-11-25 14:56:00       0.0        0.0      0.031232
# 2022-11-25 14:57:00       0.0        0.0      0.031232
# 2022-11-25 14:58:00       0.0        0.0      0.031232
# 2022-11-25 14:59:00       0.0        0.0      0.031232
# 2022-11-25 15:00:00       0.0        0.0      0.032147

# %%
# 到期时间很短，且价内50%的时候，转债近似等价于正股
def cal_premium_rate(bond_price,stock_price,convert_price):
    tmp = 100/convert_price*stock_price
    res = (bond_price - tmp)/tmp
    return res
cal_premium_rate(200,140,70)
# Out:
# 0.0
