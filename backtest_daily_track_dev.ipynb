# %% [markdown]
# # import data

# %%
from WindPy import *

#Wind API 使用W账户密码登录
w.start() 

#return True and then can go to next operation.
w.isconnected()

import pandas as pd
# Out:
# 22.11.1.52440
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2021 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
# w.wsi("123046.SZ,300587.SZ,113642.SH,603185.SH,110061.SH,600674.SH,128081.SZ,002203.SZ,113016.SH,601127.SH,128017.SZ,002597.SZ",  "close",  "2022-09-06 09:00:00",  "2022-09-09 16:28:08",  "")

# %%
cbond_list = ['123046.SZ','300587.SZ',
# '113642.SH','603185.SH', #转债已退市
'110061.SH','600674.SH',
'128081.SZ','002203.SZ',
'113016.SH','601127.SH',
'128017.SZ','002597.SZ',
'113537.SH','603348.SH',
'123027.SZ','300487.SZ', #转债已退市
'113534.SH','603876.SH',
'113025.SH','601677.SH',
'123031.SZ','300655.SZ',
'128029.SZ','002078.SZ',
'128111.SZ','002738.SZ', #2022-10-14新增4个对子
'128095.SZ','002812.SZ',
'113626.SH','603596.SH',
'123092.SZ','300332.SZ',
'123057.SZ','300586.SZ',#2020-11-18新增3个对子
'123067.SZ','300382.SZ',
'128106.SZ','002840.SZ',
]

# %% [markdown]
# # history trade days

# %%
# ###############################################################
# before_trade_date = '20220908'#监测当日前一个交易日
# present_date = '20220909' #监测当日
# next_trade_date = '20220910' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220909'#监测当日前一个交易日
# present_date = '20220913' #监测当日
# next_trade_date = '20220914' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220913'#监测当日前一个交易日
# present_date = '20220914' #监测当日
# next_trade_date = '20220915' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220914'#监测当日前一个交易日
# present_date = '20220915' #监测当日
# next_trade_date = '20220916' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220915'#监测当日前一个交易日
# present_date = '20220916' #监测当日
# next_trade_date = '20220917' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220916'#监测当日前一个交易日
# present_date = '20220919' #监测当日
# next_trade_date = '20220920' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220919'#监测当日前一个交易日
# present_date = '20220920' #监测当日
# next_trade_date = '20220921' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220920'#监测当日前一个交易日
# present_date = '20220921' #监测当日
# next_trade_date = '20220922' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220921'#监测当日前一个交易日
# present_date = '20220922' #监测当日
# next_trade_date = '20220923' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220922'#监测当日前一个交易日
# present_date = '20220923' #监测当日
# next_trade_date = '20220924' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220923'#监测当日前一个交易日
# present_date = '20220926' #监测当日
# next_trade_date = '20220927' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220926'#监测当日前一个交易日
# present_date = '20220927' #监测当日
# next_trade_date = '20220928' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220927'#监测当日前一个交易日
# present_date = '20220928' #监测当日
# next_trade_date = '20220929' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220928'#监测当日前一个交易日
# present_date = '20220929' #监测当日
# next_trade_date = '20220930' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220929'#监测当日前一个交易日
# present_date = '20220930' #监测当日
# next_trade_date = '20221001' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220930'#监测当日前一个交易日
# present_date = '20221010' #监测当日
# next_trade_date = '20221011' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221010'#监测当日前一个交易日
# present_date = '20221011' #监测当日
# next_trade_date = '20221012' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221011'#监测当日前一个交易日
# present_date = '20221012' #监测当日
# next_trade_date = '20221013' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221012'#监测当日前一个交易日
# present_date = '20221013' #监测当日
# next_trade_date = '20221014' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221013'#监测当日前一个交易日
# present_date = '20221014' #监测当日
# next_trade_date = '20221015' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221014'#监测当日前一个交易日
# present_date = '20221017' #监测当日
# next_trade_date = '20221018' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221017'#监测当日前一个交易日
# present_date = '20221018' #监测当日
# next_trade_date = '20221019' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221018'#监测当日前一个交易日
# present_date = '20221019' #监测当日
# next_trade_date = '20221020' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221019'#监测当日前一个交易日
# present_date = '20221020' #监测当日
# next_trade_date = '20221021' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221020'#监测当日前一个交易日
# present_date = '20221021' #监测当日
# next_trade_date = '20221022' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221021'#监测当日前一个交易日
# present_date = '20221024' #监测当日
# next_trade_date = '20221025' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221024'#监测当日前一个交易日
# present_date = '20221025' #监测当日
# next_trade_date = '20221026' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221025'#监测当日前一个交易日
# present_date = '20221026' #监测当日
# next_trade_date = '20221027' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221026'#监测当日前一个交易日
# present_date = '20221027' #监测当日
# next_trade_date = '20221028' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221027'#监测当日前一个交易日
# present_date = '20221028' #监测当日
# next_trade_date = '20221029' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221028'#监测当日前一个交易日
# present_date = '20221031' #监测当日
# next_trade_date = '20221101' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221031'#监测当日前一个交易日
# present_date = '20221101' #监测当日
# next_trade_date = '20221102' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221101'#监测当日前一个交易日
# present_date = '20221102' #监测当日
# next_trade_date = '20221103' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221102'#监测当日前一个交易日
# present_date = '20221103' #监测当日
# next_trade_date = '20221104' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221103'#监测当日前一个交易日
# present_date = '20221104' #监测当日
# next_trade_date = '20221105' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221104'#监测当日前一个交易日
# present_date = '20221107' #监测当日
# next_trade_date = '20221108' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221107'#监测当日前一个交易日
# present_date = '20221108' #监测当日
# next_trade_date = '20221109' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221108'#监测当日前一个交易日
# present_date = '20221109' #监测当日
# next_trade_date = '20221110' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221109'#监测当日前一个交易日
# present_date = '20221110' #监测当日
# next_trade_date = '20221111' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221110'#监测当日前一个交易日
# present_date = '20221111' #监测当日
# next_trade_date = '20221112' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221111'#监测当日前一个交易日
# present_date = '20221114' #监测当日
# next_trade_date = '20221115' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221114'#监测当日前一个交易日
# present_date = '20221115' #监测当日
# next_trade_date = '20221116' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221115'#监测当日前一个交易日
# present_date = '20221116' #监测当日
# next_trade_date = '20221117' #监测当日下一个自然日
# ###############################################################

# %%
# ###############################################################
# before_trade_date = '20221116'#监测当日前一个交易日
# present_date = '20221117' #监测当日
# next_trade_date = '20221118' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221117'#监测当日前一个交易日
# present_date = '20221118' #监测当日
# next_trade_date = '20221119' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221118'#监测当日前一个交易日
# present_date = '20221121' #监测当日
# next_trade_date = '20221122' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221121'#监测当日前一个交易日
# present_date = '20221122' #监测当日
# next_trade_date = '20221123' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221122'#监测当日前一个交易日
# present_date = '20221123' #监测当日
# next_trade_date = '20221124' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221123'#监测当日前一个交易日
# present_date = '20221124' #监测当日
# next_trade_date = '20221125' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221124'#监测当日前一个交易日
# present_date = '20221125' #监测当日
# next_trade_date = '20221126' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221125'#监测当日前一个交易日
# present_date = '20221128' #监测当日
# next_trade_date = '20221129' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221128'#监测当日前一个交易日
# present_date = '20221129' #监测当日
# next_trade_date = '20221130' #监测当日下一个自然日
# ###############################################################

# ###############################################################
before_trade_date = '20221129'#监测当日前一个交易日
present_date = '20221130' #监测当日
next_trade_date = '20221201' #监测当日下一个自然日
# ###############################################################

# %%
start_date = pd.to_datetime(before_trade_date) 
end_date = pd.to_datetime(next_trade_date)

cbond_price = pd.DataFrame([])
for code in cbond_list:
    price_df = w.wsi(code, "close", start_date, end_date,usedf=True)[1]   #只要了收盘价
    price_df.columns = [code]
    cbond_price = pd.concat([cbond_price,price_df],axis=1)
cbond_price = cbond_price.ffill()    
# cbond_rtn = cbond_price[cbond_price.index.time!=time(15,0,0)]
# cbond_price = cbond_price.loc['2022-09-09 15:00:00':] #从前一个交易日的收盘价开始截取
cbond_price_begin_time = before_trade_date[:4]+'-' + \
                    before_trade_date[4:6]+'-' + \
                    before_trade_date[6:8]+' 15:00:00'
cbond_price = cbond_price.loc[cbond_price_begin_time:]
cbond_price
# Out:
#                      123046.SZ  300587.SZ  110061.SH  600674.SH  128081.SZ  \
# 2022-11-29 15:00:00    361.476      12.60    136.000      11.94    129.201
# 2022-11-30 09:30:00    359.774      12.59    135.906      11.97    128.976
# 2022-11-30 09:31:00    358.004      12.58    136.240      11.99    128.705
# 2022-11-30 09:32:00    361.206      12.59    136.409      11.99    128.930
# 2022-11-30 09:33:00    359.265      12.55    136.520      12.00    128.513
# ...                        ...        ...        ...        ...        ...
# 2022-11-30 14:56:00    367.760      12.58    135.530      11.95    129.299
# 2022-11-30 14:57:00    367.502      12.58    135.501      11.95    129.299
# 2022-11-30 14:58:00    367.502      12.58    135.310      11.95    129.299
# 2022-11-30 14:59:00    367.502      12.58    135.122      11.95    129.299
# 2022-11-30 15:00:00    367.798      12.58    135.271      11.93    129.299
#
#                      002203.SZ  113016.SH  601127.SH  128017.SZ  002597.SZ  \
# 2022-11-29 15:00:00      12.30    322.011      47.00    187.250      35.00
# 2022-11-30 09:30:00      12.27    321.804      46.95    188.817      34.98
# 2022-11-30 09:31:00      12.26    325.615      47.50    187.656      34.93
# 2022-11-30 09:32:00      12.27    326.999      47.70    187.968      34.92
# 2022-11-30 09:33:00      12.25    325.810      47.57    187.337      34.85
# ...                        ...        ...        ...        ...        ...
# 2022-11-30 14:56:00      12.30    344.710      50.25    182.800      34.20
# 2022-11-30 14:57:00      12.30    345.540      50.25    182.799      34.20
# 2022-11-30 14:58:00      12.30    345.880      50.25    182.799      34.20
# 2022-11-30 14:59:00      12.30    346.888      50.25    182.799      34.20
# 2022-11-30 15:00:00      12.27    346.500      50.25    184.000      34.23
#
#                      ...  113626.SH  603596.SH  123092.SZ  300332.SZ  \
# 2022-11-29 15:00:00  ...    219.296      78.29    273.000      13.26
# 2022-11-30 09:30:00  ...    218.283      77.45    272.499      13.21
# 2022-11-30 09:31:00  ...    217.497      77.25    272.400      13.25
# 2022-11-30 09:32:00  ...    217.686      77.27    273.870      13.27
# 2022-11-30 09:33:00  ...    217.022      77.02    273.625      13.31
# ...                  ...        ...        ...        ...        ...
# 2022-11-30 14:56:00  ...    231.215      83.17    286.477      13.84
# 2022-11-30 14:57:00  ...    231.450      83.17    286.400      13.84
# 2022-11-30 14:58:00  ...    232.350      83.17    286.400      13.84
# 2022-11-30 14:59:00  ...    232.300      83.17    286.400      13.84
# 2022-11-30 15:00:00  ...    232.195      84.83    286.479      13.84
#
#                      123057.SZ  300586.SZ  123067.SZ  300382.SZ  128106.SZ  \
# 2022-11-29 15:00:00    222.848      20.21    223.881      21.27    195.205
# 2022-11-30 09:30:00    227.690      20.43    220.896      21.22    195.313
# 2022-11-30 09:31:00    229.121      20.66    220.199      21.21    197.925
# 2022-11-30 09:32:00    230.399      20.87    222.130      21.24    199.587
# 2022-11-30 09:33:00    229.938      20.74    221.447      21.11    201.658
# ...                        ...        ...        ...        ...        ...
# 2022-11-30 14:56:00    224.500      20.27    221.501      20.84    195.127
# 2022-11-30 14:57:00    224.499      20.29    221.500      20.88    195.144
# 2022-11-30 14:58:00    224.499      20.29    221.500      20.88    195.144
# 2022-11-30 14:59:00    224.499      20.29    221.500      20.88    195.144
# 2022-11-30 15:00:00    224.800      20.37    221.500      20.90    194.921
#
#                      002840.SZ
# 2022-11-29 15:00:00      16.68
# 2022-11-30 09:30:00      16.70
# 2022-11-30 09:31:00      16.93
# 2022-11-30 09:32:00      17.07
# 2022-11-30 09:33:00      17.30
# ...                        ...
# 2022-11-30 14:56:00      16.41
# 2022-11-30 14:57:00      16.41
# 2022-11-30 14:58:00      16.41
# 2022-11-30 14:59:00      16.41
# 2022-11-30 15:00:00      16.42
#
# [243 rows x 36 columns]

# %%
# assert False

# %% [markdown]
# # stock pre status

# %%
df_stk_pre_return = w.wss("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return = w.wss("300587.SZ,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
"pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return
df_stk_pre_return
# Out:
#             PCT_CHG
# 300587.SZ -0.709220
# 600674.SH -0.500000
# 002203.SZ  1.068200
# 601127.SH  4.166667
# 002597.SZ  4.011887
# 603348.SH -3.393055
# 300487.SZ  1.205654
# 603876.SH -3.894180
# 601677.SH  6.846610
# 300655.SZ  0.319489
# 002078.SZ  1.785714
# 002738.SZ  0.120741
# 002812.SZ -5.220418
# 603596.SH -3.702337
# 300332.SZ -0.822737
# 300586.SZ -1.076848
# 300382.SZ  0.047037
# 002840.SZ  1.955990

# %%
df_bond_pre_return = w.wss("123046.SZ,113642.SH,110061.SH,128081.SZ,113016.SH,128017.SZ,113537.SH,123027.SZ,113534.SH,113025.SH,123031.SZ,128029.SZ,128111.SZ,128095.SZ,113626.SH,123092.SZ,123057.SZ,123067.SZ,128106.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_bond_pre_return
# Out:
#              PCT_CHG
# 123046.SZ   0.048713
# 113642.SH        NaN
# 110061.SH  -0.442883
# 128081.SZ   1.581099
# 113016.SH   2.831933
# 128017.SZ   5.199584
# 113537.SH  -2.932064
# 123027.SZ        NaN
# 113534.SH  -1.937133
# 113025.SH  10.953450
# 123031.SZ   0.220403
# 128029.SZ   1.614179
# 128111.SZ  -0.214597
# 128095.SZ  -4.998728
# 113626.SH  -2.794757
# 123092.SZ   0.737636
# 123057.SZ  -1.742504
# 123067.SZ   0.320389
# 128106.SZ   1.629043

# %%
before_trade_date_trade_status = before_trade_date[:4] +'-'+ before_trade_date[4:6] +'-'+ before_trade_date[6:]
# present_date_trade_status = present_date[:4] +'-'+ present_date[4:6] +'-'+ present_date[6:]
df_stk_pre_trade_status = w.wsd("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ", 
"trade_status", f"{before_trade_date_trade_status}", f"{before_trade_date_trade_status}", "",usedf=True)[1]
df_stk_pre_trade_status
# Out:
#           TRADE_STATUS
# 300587.SZ           交易
# 603185.SH           交易
# 600674.SH           交易
# 002203.SZ           交易
# 601127.SH           交易
# 002597.SZ           交易
# 603348.SH           交易
# 300487.SZ           交易
# 603876.SH           交易
# 601677.SH           交易
# 300655.SZ           交易
# 002078.SZ           交易
# 002738.SZ           交易
# 002812.SZ           交易
# 603596.SH           交易
# 300332.SZ           交易
# 300586.SZ           交易
# 300382.SZ           交易
# 002840.SZ           交易

# %%
df_stk_pre_trade_status.iloc[0,0]
# Out:
# '交易'

# %%
# assert False

# %% [markdown]
# # bond-stock pair

# %%
# cbond_pair = ['113642.SH','603185.SH']  #后面筛选的结果，这组也在里面 转债停止交易了
# open_threshold = 0.023
# close_threshold = 0
# convert_price = 102.4
# operate = True

# cbond_pair = ['123027.SZ','300487.SZ',] # 1019 1020 1021 这几天转债停止交易了
# open_threshold = 0.022
# close_threshold = 0
# convert_price = 19.07
# operate = True

# %%
cbond_pair = ['123046.SZ','300587.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.015
close_threshold = 0
convert_price = 3.94
operate = True

cbond_pair = ['110061.SH','600674.SH']
open_threshold = 0.006
close_threshold = 0
convert_price = 8.8
operate = True

cbond_pair = ['128081.SZ','002203.SZ']
open_threshold = 0.012
close_threshold = 0.002
convert_price = 9.62
operate = True

cbond_pair = ['113016.SH','601127.SH'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.017
close_threshold = 0.003
convert_price = 20.17
operate = True

cbond_pair = ['128017.SZ','002597.SZ']
open_threshold = 0.012
close_threshold = 0
convert_price = 21.33
operate = True

# # # # $$$$$$$$$$$$$$$$$$$$$$$$以下是新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['113537.SH','603348.SH',]
open_threshold = 0.027
close_threshold = 0.002
convert_price = 19.13
operate = True

cbond_pair = ['113534.SH','603876.SH',]
open_threshold = 0.019
close_threshold = 0.002
convert_price = 14.98
operate = True

cbond_pair = ['113025.SH','601677.SH',]
open_threshold = 0.018
close_threshold = 0
convert_price = 7.66
operate = True

cbond_pair = ['123031.SZ','300655.SZ',]   #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.019
close_threshold = 0
convert_price = 6.25
operate = True

cbond_pair = ['128029.SZ','002078.SZ']
open_threshold = 0.013
close_threshold = 0.002
convert_price = 8.25
operate = True

# # # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-10-14】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['128111.SZ','002738.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.011
close_threshold = 0.001
convert_price = 10.96
operate = True

cbond_pair = ['128095.SZ','002812.SZ']
open_threshold = 0.013
close_threshold = 0
convert_price = 64.62
operate = True

cbond_pair = ['113626.SH','603596.SH']
open_threshold = 0.02
close_threshold = 0
convert_price = 35.88
operate = True

cbond_pair = ['123092.SZ','300332.SZ']
open_threshold = 0.025
close_threshold = 0.001
convert_price = 5.14
operate = True

# # # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-11-18】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair =  ['123057.SZ','300586.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.009 
close_threshold = 0.003
convert_price = 9.5
operate = True

cbond_pair =  ['123067.SZ','300382.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.004
close_threshold = 0.002
convert_price = 9.96
operate = True

cbond_pair =  ['128106.SZ','002840.SZ']
open_threshold = 0.01
close_threshold = 0
convert_price = 8.85
operate = True

# %%
# df_signal

# %% [markdown]
# # clip price series

# %%
#从前一个交易日的收盘价开始截取
# cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]].loc['2022-09-08 15:00:00':]
cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]]

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-29 15:00:00    195.205      16.68
# 2022-11-30 09:30:00    195.313      16.70
# 2022-11-30 09:31:00    197.925      16.93
# 2022-11-30 09:32:00    199.587      17.07
# 2022-11-30 09:33:00    201.658      17.30

# %%
cbond_return = pd.DataFrame([])

cbond_preclose = cbond_pair_price.iloc[0,0] # 初始时刻的bond前收盘价
stock_preclose = cbond_pair_price.iloc[0,1] # 初始时刻的stock前收盘价

for index,row in cbond_pair_price.iterrows():
    
    cbond_return.loc[index,cbond_pair[0]] = row[cbond_pair[0]]/cbond_preclose - 1 # 算日内的return
    cbond_return.loc[index,cbond_pair[1]] = row[cbond_pair[1]]/stock_preclose - 1

    if index.time()==time(15,0,0):  #算完日内return，迭代到今日价格的最后一个time bar的时候，将其设为前收盘价
        cbond_preclose = row[cbond_pair[0]]    # 日内return指标用 现价/昨日收盘价 计算
        stock_preclose = row[cbond_pair[1]]
        
# 检查df是否有空值
cbond_return.isnull().sum(axis=0)  # 按列统计
cbond_return.isnull().sum(axis=1) # 按行统计
cbond_return.isnull().sum(axis=1).sum() # 统计整张表
# Out:
# 0

# %%
pd.set_option('display.max_rows', None)
cbond_return['diff'] = cbond_return[cbond_pair[0]] - cbond_return[cbond_pair[1]]
cbond_return.head()
# Out:
#                      128106.SZ  002840.SZ      diff
# 2022-11-29 15:00:00   0.000000   0.000000  0.000000
# 2022-11-30 09:30:00   0.000553   0.001199 -0.000646
# 2022-11-30 09:31:00   0.013934   0.014988 -0.001054
# 2022-11-30 09:32:00   0.022448   0.023381 -0.000933
# 2022-11-30 09:33:00   0.033058   0.037170 -0.004113

# %% [markdown]
# # signal calculate

# %%
################################################################################################
stk_pre_return = df_stk_pre_return.loc[cbond_pair[1]].values[0]
bond_pre_return = df_bond_pre_return.loc[cbond_pair[0]].values[0]
pre_diff = bond_pre_return - stk_pre_return
stk_pre_trade_status = df_stk_pre_trade_status.loc[cbond_pair[1]].values[0]
print(stk_pre_trade_status)
print('pre diff:',pre_diff)
# if abs(stk_pre_return) > 10 or stk_pre_trade_status!='交易':
if abs(pre_diff) > 5 or stk_pre_trade_status!='交易':
    # 如果前一天股票的跌幅小于-10，则今日不做操作
    intraday_open_times = 1
else:
    intraday_open_times = 0
################################################################################################    
open_close_spread = open_threshold - close_threshold
# intraday_open_times = 0
max_open = 1

pos_open_flag = 0
neg_open_flag = 0
cbond_position = pd.DataFrame([])
cbond_position.index = cbond_return.index
for index,row in cbond_return.iterrows():

    if row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff落在A区间，且无仓位，正开
            pos_open_flag = 1
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==1:
        if intraday_open_times < max_open:
            #diff落在A区间，且有负仓，平仓再正开
            pos_open_flag=1
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            print('reverse open +1')
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff落在A区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在B区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在B区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在B区间，且无仓，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在C区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在C区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在C区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在D区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在D区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在D区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且无仓位，反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==1 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且有正仓，平仓反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在E区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    if abs(row['diff'])>2 * open_close_spread and cbond_return.columns[0]!='123057.SZ' and cbond_return.columns[0]!='123067.SZ': 
        #盘中diff超过2倍spread时平仓（价格止损信号）,有两个spread特别小的对子则不用此逻辑进行止损
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if index.time()==time(15,0,0): # 每日收盘时必须平仓（时间止损信号）
    # if index.time()==time(14,59,0): # 每日收盘时必须平仓（时间止损信号）
        intraday_open_times = 0 # 下一天开盘前，把当日记录下来的开仓次数清零
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
# Out:
# 交易
# pre diff: -0.3269475494393317

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-29 15:00:00    195.205      16.68
# 2022-11-30 09:30:00    195.313      16.70
# 2022-11-30 09:31:00    197.925      16.93
# 2022-11-30 09:32:00    199.587      17.07
# 2022-11-30 09:33:00    201.658      17.30

# %%
df_signal = pd.concat([cbond_pair_price,cbond_return,cbond_position],axis=1)
df_signal.columns = ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
print('open threshold',open_threshold,'close threshold',close_threshold)
# df_signal.to_csv('tmp_signal.csv')
# df_signal
# Out:
# open threshold 0.01 close threshold 0

# %% [markdown]
# # backtest

# %%
# 用来记录交易流水的表格,一边遍历df_signal，一边填入内容到流水表格里

import numpy as np
cols = ['balance','signal','bond price','stock price','bond hold','stock hold','commission','tax','reverse open','diff','asset value']
df_trade = pd.DataFrame(
    data = [[0,np.nan,np.nan,np.nan,0,0,0,0,np.nan,np.nan,0]],
    columns=cols
    ) 

balance_last = 0 # 现金账户初始余额

bond_hold = 0 # 债券持有数量
stock_hold = 0 # 股票持有数量


commission_rate = 2/10000 + 0 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 0.5/1000 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 1/1000 # 佣金买卖万二 + 交易滑点

tax_rate = 1/1000 # 卖股票才收印花税千一

# commission_rate = 0/10000 # 佣金买卖万二
# tax_rate = 0/1000 #

for i in range(len(df_signal)-1):
    if df_signal.index[i].time() == time(15,0,0):
    # if df_signal.index[i].time() == time(14,59,0):
        # 修改stock volume 每天固定一个stock volume 应该用债的前收盘价/股票的前收盘价
        stock_volume = df_signal['bond_price'][i]/df_signal['stock_price'][i]

    if df_signal.values[i][-1] != df_signal.values[i+1][-1]:

        index = df_signal.index[i+1]        
        diff = df_signal.values[i+1][-3] #diff在df_signal中的倒数第三列
        
    # df_signal的columns
    # ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
        signal = str(int(df_signal.values[i+1][-2]))+str(int(df_signal.values[i+1][-1]))
        
        bond_price = df_signal.values[i+1][0] 

        stock_price = df_signal.values[i+1][1]

        # stock_volume =  bond_price/stock_price # 修改stock volume 每天固定一个stock volume应该用债的前收盘价/股票的前收盘价

        commission = (bond_price + stock_price * stock_volume) * commission_rate

        reverse_open = False #表明这笔交易，是否包含平仓后再反向开仓的操作

        if signal == '00' and stock_hold == stock_volume: #有股票持仓并且需要卖出平仓时，有印花税
            tax = stock_price * tax_rate * stock_volume
        else:
            tax = 0

        if signal == '00':
            balance_last += bond_hold*bond_price
            balance_last += stock_hold*stock_price
            
            bond_hold = 0
            stock_hold = 0
            

        if signal == '1-1':
            '''
            加一个检测之前持仓的模块,如果之前因为-11的信号有持仓,需要先平掉(即买债卖股票),同时再反向开仓
            '''
            reverse_flag = False
            if bond_hold == -1 and stock_hold == 1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last -= bond_price 
                balance_last += stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税
                reverse_flag = True
                reverse_open = True

            bond_hold += 1
            stock_hold += (-1 * stock_volume)
            # stock_hold += stock_volume
            balance_last -= bond_price
            balance_last += stock_price * stock_volume
            
            if reverse_flag:
                tax *= 2 #平仓然后反向开仓的时候 已经计算过tax了，直接double
            else:
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税

        if signal == '-11':
            '''
            加一个检测之前持仓的模块,如果之前因为1-1的信号有持仓,需要先平掉(卖债买股票),同时再反向开仓
            '''
            if bond_hold == 1 and stock_hold == -1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last += bond_price
                balance_last -= stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                                # 买股票无印花税
                reverse_open = True
            bond_hold += -1
            stock_hold += (1 * stock_volume)
            # stock_hold += stock_volume
            balance_last += bond_price
            balance_last -= stock_price * stock_volume
        
        balance_last = balance_last - commission - tax
        balance = balance_last
        asset_value = bond_price*bond_hold + stock_price*stock_hold
        line = [balance,signal,bond_price,stock_price,bond_hold,stock_hold,commission,tax,reverse_open,diff,asset_value]
        # df_trade.loc[index,['balance','asset','signal','bond price','stock price','commission','tax']] = line
        # df_trade.loc[index,cols] = [0,0,np.nan,np.nan,np.nan,0,0,0,0]
        df_trade.loc[index,cols] = line

df_trade.rename(columns={'balance':'cash'},inplace=True)       
df_trade['net value'] = df_trade['cash'] + df_trade['asset value']

# %%
df_trade['operate'] = [operate]*len(df_trade)

# %%
df_trade
# Out:
#                          cash signal  bond price  stock price  bond hold  \
# 0                    0.000000    NaN         NaN          NaN        0.0
# 2022-11-30 09:40:00  2.018584    -11     198.707        16.80       -1.0
# 2022-11-30 15:00:00 -1.009758     00     194.921        16.42        0.0
#
#                      stock hold  commission       tax reverse open      diff  \
# 0                      0.000000    0.000000  0.000000          NaN       NaN
# 2022-11-30 09:40:00   11.702938    0.079063  0.000000        False  0.010746
# 2022-11-30 15:00:00    0.000000    0.077417  0.192162        False  0.014133
#
#                      asset value  net value  operate
# 0                       0.000000   0.000000     True
# 2022-11-30 09:40:00    -2.097647  -0.079063     True
# 2022-11-30 15:00:00     0.000000  -1.009758     True

# %% [markdown]
# # output to csv

# %%
excel_file_name = './daily_track/'+ present_date+'/' + cbond_pair[0] + '@' + cbond_pair[1] + '.csv'

excel_file_name

df_to_excel = df_trade
df_to_excel['open/close'] = [str(open_threshold)+','+str(close_threshold)]*len(df_to_excel)
df_to_excel['pair'] = [cbond_pair[0] + '@' + cbond_pair[1]]*len(df_to_excel)
df_to_excel = df_to_excel[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_to_excel.to_csv(excel_file_name,)

# %%
present_date
# Out:
# '20221130'

# %% [markdown]
# # conclusion

# %%
import os
single_trade_files = os.listdir('./daily_track'+'/'+present_date)

df_trade_conclusion = pd.DataFrame([])
for file in single_trade_files:
    if file == 'diff':
        continue
    if file == '.DS_Store' or file.split('.')[1] == 'xlsx':
        continue
    tmp_path = './daily_track'+'/'+present_date+'/'+file
    df_tmp = pd.read_csv(tmp_path,index_col=0)
    tmp_col = list(df_tmp.columns)
    df_tmp_head = pd.DataFrame(data=[tmp_col],columns=tmp_col)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp_head)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp)
df_trade_conclusion.columns
df_trade_conclusion = df_trade_conclusion[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_trade_conclusion
tmp_path = './daily_track'+'/'+present_date+'/'+f'{present_date}_conclusion.csv'

df_trade_conclusion.to_csv(tmp_path)

# %% [markdown]
# # intraday signal

# %%
import matplotlib.pyplot as plt

signal_plot_begin_time = present_date[:4]+'-' + \
                         present_date[4:6]+'-' + \
                         present_date[6:8]+' 09:30:00'
df_signal['diff'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' diff',grid=True)

#如果当日有开平仓记录，在图上画出开平仓时刻的标注
if len(df_trade) == 3:
    open_tick = df_trade.index.to_list()[1]
    open_diff = df_trade['diff'].to_list()[1]
    close_tick = df_trade.index.to_list()[2]
    close_diff =  df_trade['diff'].to_list()[2]
    plt.text(open_tick,open_diff,'open')
    plt.text(close_tick,close_diff,'close')
    plt.scatter([open_tick],[open_diff],color='r')

    tmp_nv = df_trade['net value'].to_list()[2]
    if tmp_nv > 0: 
        close_color = 'g' #当天赚钱的话，平仓点位标记为绿色
    else:
        close_color = 'orange' #当天亏钱的话，平仓点位标记为橙色
    plt.scatter([close_tick],[close_diff],color=close_color)
fig_file_name = './daily_track/'+ present_date+'/'+'diff/' + cbond_pair[0] + '@' + cbond_pair[1] + '.png'
plt.savefig(fig_file_name)

plt.show()
df_signal['bond_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+' rtn',grid=True)
plt.show()
df_signal['stock_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[1]+' rtn',grid=True)
plt.show()

# %%
df_tmp = 100/convert_price*df_signal['stock_price']
df_signal['premium rate'] = (df_signal['bond_price'] - df_tmp)/df_tmp
df_signal['premium rate'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' premium rate',grid=True)
# Out:
# <AxesSubplot:title={'center':'128106.SZ@002840.SZ premium rate'}>

# %%
df_signal
# Out:
#                      bond_price  stock_price  bond_rtn  stock_rtn      diff  \
# 2022-11-29 15:00:00     195.205        16.68  0.000000   0.000000  0.000000
# 2022-11-30 09:30:00     195.313        16.70  0.000553   0.001199 -0.000646
# 2022-11-30 09:31:00     197.925        16.93  0.013934   0.014988 -0.001054
# 2022-11-30 09:32:00     199.587        17.07  0.022448   0.023381 -0.000933
# 2022-11-30 09:33:00     201.658        17.30  0.033058   0.037170 -0.004113
# 2022-11-30 09:34:00     200.152        17.03  0.025343   0.020983  0.004359
# 2022-11-30 09:35:00     201.048        17.09  0.029933   0.024580  0.005352
# 2022-11-30 09:36:00     199.384        16.90  0.021408   0.013189  0.008219
# 2022-11-30 09:37:00     197.820        16.74  0.013396   0.003597  0.009799
# 2022-11-30 09:38:00     197.835        16.80  0.013473   0.007194  0.006279
# 2022-11-30 09:39:00     198.083        16.86  0.014743   0.010791  0.003952
# 2022-11-30 09:40:00     198.707        16.80  0.017940   0.007194  0.010746
# 2022-11-30 09:41:00     199.431        16.89  0.021649   0.012590  0.009059
# 2022-11-30 09:42:00     199.685        16.85  0.022950   0.010192  0.012758
# 2022-11-30 09:43:00     198.930        16.80  0.019083   0.007194  0.011888
# 2022-11-30 09:44:00     198.096        16.70  0.014810   0.001199  0.013611
# 2022-11-30 09:45:00     199.109        16.76  0.019999   0.004796  0.015203
# 2022-11-30 09:46:00     199.198        16.80  0.020455   0.007194  0.013261
# 2022-11-30 09:47:00     198.925        16.76  0.019057   0.004796  0.014261
# 2022-11-30 09:48:00     199.354        16.79  0.021255   0.006595  0.014660
# 2022-11-30 09:49:00     198.991        16.77  0.019395   0.005396  0.013999
# 2022-11-30 09:50:00     198.605        16.74  0.017418   0.003597  0.013820
# 2022-11-30 09:51:00     199.000        16.77  0.019441   0.005396  0.014045
# 2022-11-30 09:52:00     199.013        16.77  0.019508   0.005396  0.014112
# 2022-11-30 09:53:00     198.247        16.70  0.015584   0.001199  0.014385
# 2022-11-30 09:54:00     199.106        16.72  0.019984   0.002398  0.017586
# 2022-11-30 09:55:00     200.200        16.80  0.025588   0.007194  0.018394
# 2022-11-30 09:56:00     201.001        16.90  0.029692   0.013189  0.016502
# 2022-11-30 09:57:00     201.158        17.00  0.030496   0.019185  0.011311
# 2022-11-30 09:58:00     200.073        16.89  0.024938   0.012590  0.012348
# 2022-11-30 09:59:00     200.070        16.88  0.024923   0.011990  0.012932
# 2022-11-30 10:00:00     199.887        16.83  0.023985   0.008993  0.014992
# 2022-11-30 10:01:00     200.501        16.85  0.027130   0.010192  0.016939
# 2022-11-30 10:02:00     200.744        16.87  0.028375   0.011391  0.016984
# 2022-11-30 10:03:00     200.400        16.90  0.026613   0.013189  0.013424
# 2022-11-30 10:04:00     200.258        16.92  0.025886   0.014388  0.011497
# 2022-11-30 10:05:00     199.408        16.82  0.021531   0.008393  0.013138
# 2022-11-30 10:06:00     199.819        16.84  0.023637   0.009592  0.014044
# 2022-11-30 10:07:00     199.911        16.87  0.024108   0.011391  0.012717
# 2022-11-30 10:08:00     199.770        16.85  0.023386   0.010192  0.013194
# 2022-11-30 10:09:00     200.096        16.90  0.025056   0.013189  0.011866
# 2022-11-30 10:10:00     199.770        16.87  0.023386   0.011391  0.011995
# 2022-11-30 10:11:00     199.500        16.87  0.022003   0.011391  0.010612
# 2022-11-30 10:12:00     199.388        16.84  0.021429   0.009592  0.011836
# 2022-11-30 10:13:00     199.600        16.83  0.022515   0.008993  0.013522
# 2022-11-30 10:14:00     199.792        16.82  0.023498   0.008393  0.015105
# 2022-11-30 10:15:00     199.647        16.86  0.022756   0.010791  0.011964
# 2022-11-30 10:16:00     199.969        16.87  0.024405   0.011391  0.013014
# 2022-11-30 10:17:00     200.125        16.88  0.025204   0.011990  0.013214
# 2022-11-30 10:18:00     199.888        16.87  0.023990   0.011391  0.012599
# 2022-11-30 10:19:00     199.977        16.85  0.024446   0.010192  0.014254
# 2022-11-30 10:20:00     199.699        16.83  0.023022   0.008993  0.014029
# 2022-11-30 10:21:00     200.038        16.90  0.024759   0.013189  0.011569
# 2022-11-30 10:22:00     200.776        16.91  0.028539   0.013789  0.014750
# 2022-11-30 10:23:00     201.300        16.91  0.031224   0.013789  0.017435
# 2022-11-30 10:24:00     201.214        16.90  0.030783   0.013189  0.017594
# 2022-11-30 10:25:00     200.853        16.92  0.028934   0.014388  0.014545
# 2022-11-30 10:26:00     201.111        16.95  0.030255   0.016187  0.014068
# 2022-11-30 10:27:00     201.183        16.96  0.030624   0.016787  0.013838
# 2022-11-30 10:28:00     201.400        16.98  0.031736   0.017986  0.013750
# 2022-11-30 10:29:00     201.063        16.99  0.030009   0.018585  0.011424
# 2022-11-30 10:30:00     200.201        16.93  0.025594   0.014988  0.010606
# 2022-11-30 10:31:00     200.302        16.92  0.026111   0.014388  0.011723
# 2022-11-30 10:32:00     199.996        16.88  0.024543   0.011990  0.012553
# 2022-11-30 10:33:00     200.010        16.88  0.024615   0.011990  0.012625
# 2022-11-30 10:34:00     199.896        16.86  0.024031   0.010791  0.013240
# 2022-11-30 10:35:00     199.869        16.87  0.023893   0.011391  0.012502
# 2022-11-30 10:36:00     199.487        16.85  0.021936   0.010192  0.011744
# 2022-11-30 10:37:00     199.200        16.84  0.020466   0.009592  0.010873
# 2022-11-30 10:38:00     199.200        16.84  0.020466   0.009592  0.010873
# 2022-11-30 10:39:00     198.755        16.81  0.018186   0.007794  0.010392
# 2022-11-30 10:40:00     198.990        16.82  0.019390   0.008393  0.010997
# 2022-11-30 10:41:00     199.200        16.82  0.020466   0.008393  0.012072
# 2022-11-30 10:42:00     199.018        16.83  0.019533   0.008993  0.010541
# 2022-11-30 10:43:00     198.900        16.84  0.018929   0.009592  0.009336
# 2022-11-30 10:44:00     198.911        16.84  0.018985   0.009592  0.009393
# 2022-11-30 10:45:00     199.019        16.85  0.019538   0.010192  0.009347
# 2022-11-30 10:46:00     199.232        16.83  0.020630   0.008993  0.011637
# 2022-11-30 10:47:00     199.299        16.82  0.020973   0.008393  0.012580
# 2022-11-30 10:48:00     199.025        16.80  0.019569   0.007194  0.012375
# 2022-11-30 10:49:00     198.758        16.75  0.018201   0.004197  0.014005
# 2022-11-30 10:50:00     198.801        16.76  0.018422   0.004796  0.013625
# 2022-11-30 10:51:00     198.888        16.78  0.018867   0.005995  0.012872
# 2022-11-30 10:52:00     198.900        16.79  0.018929   0.006595  0.012334
# 2022-11-30 10:53:00     198.900        16.80  0.018929   0.007194  0.011735
# 2022-11-30 10:54:00     199.110        16.82  0.020005   0.008393  0.011611
# 2022-11-30 10:55:00     199.200        16.82  0.020466   0.008393  0.012072
# 2022-11-30 10:56:00     199.038        16.82  0.019636   0.008393  0.011242
# 2022-11-30 10:57:00     198.929        16.81  0.019077   0.007794  0.011284
# 2022-11-30 10:58:00     199.000        16.80  0.019441   0.007194  0.012247
# 2022-11-30 10:59:00     198.939        16.80  0.019129   0.007194  0.011934
# 2022-11-30 11:00:00     199.057        16.81  0.019733   0.007794  0.011939
# 2022-11-30 11:01:00     199.222        16.82  0.020578   0.008393  0.012185
# 2022-11-30 11:02:00     199.100        16.82  0.019953   0.008393  0.011560
# 2022-11-30 11:03:00     199.357        16.80  0.021270   0.007194  0.014076
# 2022-11-30 11:04:00     199.200        16.80  0.020466   0.007194  0.013271
# 2022-11-30 11:05:00     199.396        16.77  0.021470   0.005396  0.016074
# 2022-11-30 11:06:00     199.200        16.78  0.020466   0.005995  0.014470
# 2022-11-30 11:07:00     199.000        16.77  0.019441   0.005396  0.014045
# 2022-11-30 11:08:00     198.900        16.76  0.018929   0.004796  0.014133
# 2022-11-30 11:09:00     198.920        16.76  0.019031   0.004796  0.014235
# 2022-11-30 11:10:00     198.595        16.73  0.017366   0.002998  0.014369
# 2022-11-30 11:11:00     198.434        16.74  0.016542   0.003597  0.012944
# 2022-11-30 11:12:00     198.914        16.74  0.019001   0.003597  0.015403
# 2022-11-30 11:13:00     198.700        16.76  0.017904   0.004796  0.013108
# 2022-11-30 11:14:00     198.573        16.77  0.017254   0.005396  0.011858
# 2022-11-30 11:15:00     198.400        16.76  0.016367   0.004796  0.011571
# 2022-11-30 11:16:00     198.480        16.75  0.016777   0.004197  0.012581
# 2022-11-30 11:17:00     198.652        16.74  0.017658   0.003597  0.014061
# 2022-11-30 11:18:00     198.552        16.75  0.017146   0.004197  0.012949
# 2022-11-30 11:19:00     198.439        16.75  0.016567   0.004197  0.012371
# 2022-11-30 11:20:00     198.519        16.74  0.016977   0.003597  0.013380
# 2022-11-30 11:21:00     198.351        16.74  0.016116   0.003597  0.012519
# 2022-11-30 11:22:00     198.200        16.73  0.015343   0.002998  0.012345
# 2022-11-30 11:23:00     198.260        16.73  0.015650   0.002998  0.012653
# 2022-11-30 11:24:00     198.325        16.74  0.015983   0.003597  0.012386
# 2022-11-30 11:25:00     198.477        16.76  0.016762   0.004796  0.011966
# 2022-11-30 11:26:00     198.260        16.77  0.015650   0.005396  0.010255
# 2022-11-30 11:27:00     198.359        16.77  0.016157   0.005396  0.010762
# 2022-11-30 11:28:00     198.150        16.74  0.015087   0.003597  0.011490
# 2022-11-30 11:29:00     198.154        16.74  0.015107   0.003597  0.011510
# 2022-11-30 11:30:00     198.266        16.74  0.015681   0.003597  0.012084
# 2022-11-30 13:00:00     198.005        16.69  0.014344   0.000600  0.013744
# 2022-11-30 13:01:00     197.958        16.71  0.014103   0.001799  0.012305
# 2022-11-30 13:02:00     198.190        16.72  0.015292   0.002398  0.012894
# 2022-11-30 13:03:00     198.274        16.73  0.015722   0.002998  0.012724
# 2022-11-30 13:04:00     197.874        16.70  0.013673   0.001199  0.012474
# 2022-11-30 13:05:00     197.616        16.70  0.012351   0.001199  0.011152
# 2022-11-30 13:06:00     197.400        16.68  0.011245   0.000000  0.011245
# 2022-11-30 13:07:00     197.210        16.63  0.010271  -0.002998  0.013269
# 2022-11-30 13:08:00     197.473        16.65  0.011619  -0.001799  0.013417
# 2022-11-30 13:09:00     197.193        16.63  0.010184  -0.002998  0.013182
# 2022-11-30 13:10:00     197.379        16.63  0.011137  -0.002998  0.014135
# 2022-11-30 13:11:00     197.446        16.65  0.011480  -0.001799  0.013279
# 2022-11-30 13:12:00     197.500        16.66  0.011757  -0.001199  0.012956
# 2022-11-30 13:13:00     197.841        16.67  0.013504  -0.000600  0.014103
# 2022-11-30 13:14:00     197.830        16.69  0.013447   0.000600  0.012848
# 2022-11-30 13:15:00     197.811        16.69  0.013350   0.000600  0.012751
# 2022-11-30 13:16:00     197.897        16.69  0.013791   0.000600  0.013191
# 2022-11-30 13:17:00     197.780        16.68  0.013191   0.000000  0.013191
# 2022-11-30 13:18:00     197.700        16.69  0.012781   0.000600  0.012182
# 2022-11-30 13:19:00     197.720        16.67  0.012884  -0.000600  0.013483
# 2022-11-30 13:20:00     197.624        16.68  0.012392   0.000000  0.012392
# 2022-11-30 13:21:00     197.575        16.69  0.012141   0.000600  0.011542
# 2022-11-30 13:22:00     197.500        16.70  0.011757   0.001199  0.010558
# 2022-11-30 13:23:00     197.138        16.65  0.009902  -0.001799  0.011701
# 2022-11-30 13:24:00     197.416        16.67  0.011327  -0.000600  0.011926
# 2022-11-30 13:25:00     197.307        16.67  0.010768  -0.000600  0.011368
# 2022-11-30 13:26:00     197.200        16.67  0.010220  -0.000600  0.010820
# 2022-11-30 13:27:00     196.950        16.66  0.008939  -0.001199  0.010138
# 2022-11-30 13:28:00     196.854        16.67  0.008448  -0.000600  0.009047
# 2022-11-30 13:29:00     197.000        16.67  0.009195  -0.000600  0.009795
# 2022-11-30 13:30:00     196.980        16.65  0.009093  -0.001799  0.010892
# 2022-11-30 13:31:00     196.890        16.65  0.008632  -0.001799  0.010431
# 2022-11-30 13:32:00     196.972        16.64  0.009052  -0.002398  0.011450
# 2022-11-30 13:33:00     197.028        16.65  0.009339  -0.001799  0.011137
# 2022-11-30 13:34:00     196.900        16.65  0.008683  -0.001799  0.010482
# 2022-11-30 13:35:00     196.727        16.65  0.007797  -0.001799  0.009595
# 2022-11-30 13:36:00     196.400        16.62  0.006122  -0.003597  0.009719
# 2022-11-30 13:37:00     196.329        16.61  0.005758  -0.004197  0.009955
# 2022-11-30 13:38:00     196.444        16.62  0.006347  -0.003597  0.009944
# 2022-11-30 13:39:00     196.300        16.62  0.005609  -0.003597  0.009207
# 2022-11-30 13:40:00     196.120        16.55  0.004687  -0.007794  0.012481
# 2022-11-30 13:41:00     196.476        16.56  0.006511  -0.007194  0.013705
# 2022-11-30 13:42:00     196.420        16.59  0.006224  -0.005396  0.011620
# 2022-11-30 13:43:00     196.310        16.59  0.005661  -0.005396  0.011056
# 2022-11-30 13:44:00     196.301        16.57  0.005615  -0.006595  0.012209
# 2022-11-30 13:45:00     196.359        16.55  0.005912  -0.007794  0.013705
# 2022-11-30 13:46:00     196.001        16.53  0.004078  -0.008993  0.013071
# 2022-11-30 13:47:00     195.997        16.51  0.004057  -0.010192  0.014249
# 2022-11-30 13:48:00     196.100        16.52  0.004585  -0.009592  0.014177
# 2022-11-30 13:49:00     196.174        16.53  0.004964  -0.008993  0.013957
# 2022-11-30 13:50:00     196.000        16.51  0.004073  -0.010192  0.014264
# 2022-11-30 13:51:00     195.822        16.50  0.003161  -0.010791  0.013952
# 2022-11-30 13:52:00     195.694        16.47  0.002505  -0.012590  0.015095
# 2022-11-30 13:53:00     195.424        16.44  0.001122  -0.014388  0.015510
# 2022-11-30 13:54:00     195.221        16.45  0.000082  -0.013789  0.013871
# 2022-11-30 13:55:00     195.439        16.46  0.001199  -0.013189  0.014388
# 2022-11-30 13:56:00     195.598        16.48  0.002013  -0.011990  0.014004
# 2022-11-30 13:57:00     195.410        16.49  0.001050  -0.011391  0.012441
# 2022-11-30 13:58:00     195.358        16.50  0.000784  -0.010791  0.011575
# 2022-11-30 13:59:00     195.050        16.46 -0.000794  -0.013189  0.012395
# 2022-11-30 14:00:00     195.232        16.43  0.000138  -0.014988  0.015126
# 2022-11-30 14:01:00     195.491        16.47  0.001465  -0.012590  0.014055
# 2022-11-30 14:02:00     195.487        16.44  0.001445  -0.014388  0.015833
# 2022-11-30 14:03:00     195.316        16.44  0.000569  -0.014388  0.014957
# 2022-11-30 14:04:00     195.250        16.44  0.000231  -0.014388  0.014619
# 2022-11-30 14:05:00     195.200        16.44 -0.000026  -0.014388  0.014363
# 2022-11-30 14:06:00     195.380        16.45  0.000896  -0.013789  0.014685
# 2022-11-30 14:07:00     195.550        16.46  0.001767  -0.013189  0.014957
# 2022-11-30 14:08:00     195.640        16.47  0.002228  -0.012590  0.014818
# 2022-11-30 14:09:00     195.500        16.47  0.001511  -0.012590  0.014101
# 2022-11-30 14:10:00     195.419        16.46  0.001096  -0.013189  0.014286
# 2022-11-30 14:11:00     195.205        16.43  0.000000  -0.014988  0.014988
# 2022-11-30 14:12:00     195.491        16.44  0.001465  -0.014388  0.015854
# 2022-11-30 14:13:00     195.400        16.45  0.000999  -0.013789  0.014788
# 2022-11-30 14:14:00     195.347        16.44  0.000727  -0.014388  0.015116
# 2022-11-30 14:15:00     195.307        16.44  0.000523  -0.014388  0.014911
# 2022-11-30 14:16:00     195.173        16.43 -0.000164  -0.014988  0.014824
# 2022-11-30 14:17:00     195.183        16.41 -0.000113  -0.016187  0.016074
# 2022-11-30 14:18:00     195.297        16.41  0.000471  -0.016187  0.016658
# 2022-11-30 14:19:00     195.311        16.42  0.000543  -0.015588  0.016131
# 2022-11-30 14:20:00     195.486        16.41  0.001440  -0.016187  0.017627
# 2022-11-30 14:21:00     195.513        16.42  0.001578  -0.015588  0.017165
# 2022-11-30 14:22:00     195.512        16.41  0.001573  -0.016187  0.017760
# 2022-11-30 14:23:00     195.487        16.41  0.001445  -0.016187  0.017632
# 2022-11-30 14:24:00     195.564        16.42  0.001839  -0.015588  0.017427
# 2022-11-30 14:25:00     195.799        16.43  0.003043  -0.014988  0.018031
# 2022-11-30 14:26:00     195.800        16.44  0.003048  -0.014388  0.017437
# 2022-11-30 14:27:00     195.812        16.45  0.003110  -0.013789  0.016899
# 2022-11-30 14:28:00     195.801        16.45  0.003053  -0.013789  0.016842
# 2022-11-30 14:29:00     195.604        16.43  0.002044  -0.014988  0.017032
# 2022-11-30 14:30:00     195.214        16.41  0.000046  -0.016187  0.016233
# 2022-11-30 14:31:00     195.290        16.38  0.000435  -0.017986  0.018421
# 2022-11-30 14:32:00     195.218        16.38  0.000067  -0.017986  0.018052
# 2022-11-30 14:33:00     195.511        16.40  0.001568  -0.016787  0.018354
# 2022-11-30 14:34:00     195.500        16.39  0.001511  -0.017386  0.018897
# 2022-11-30 14:35:00     195.499        16.40  0.001506  -0.016787  0.018293
# 2022-11-30 14:36:00     195.594        16.40  0.001993  -0.016787  0.018779
# 2022-11-30 14:37:00     195.636        16.40  0.002208  -0.016787  0.018995
# 2022-11-30 14:38:00     195.600        16.40  0.002024  -0.016787  0.018810
# 2022-11-30 14:39:00     195.507        16.40  0.001547  -0.016787  0.018334
# 2022-11-30 14:40:00     195.597        16.41  0.002008  -0.016187  0.018195
# 2022-11-30 14:41:00     195.500        16.40  0.001511  -0.016787  0.018298
# 2022-11-30 14:42:00     195.674        16.40  0.002403  -0.016787  0.019189
# 2022-11-30 14:43:00     195.650        16.42  0.002280  -0.015588  0.017867
# 2022-11-30 14:44:00     195.719        16.45  0.002633  -0.013789  0.016422
# 2022-11-30 14:45:00     195.595        16.43  0.001998  -0.014988  0.016986
# 2022-11-30 14:46:00     195.499        16.44  0.001506  -0.014388  0.015895
# 2022-11-30 14:47:00     195.300        16.43  0.000487  -0.014988  0.015475
# 2022-11-30 14:48:00     195.300        16.42  0.000487  -0.015588  0.016074
# 2022-11-30 14:49:00     195.291        16.41  0.000441  -0.016187  0.016628
# 2022-11-30 14:50:00     195.432        16.41  0.001163  -0.016187  0.017350
# 2022-11-30 14:51:00     195.028        16.41 -0.000907  -0.016187  0.015280
# 2022-11-30 14:52:00     194.818        16.42 -0.001983  -0.015588  0.013605
# 2022-11-30 14:53:00     194.820        16.42 -0.001972  -0.015588  0.013615
# 2022-11-30 14:54:00     194.988        16.43 -0.001112  -0.014988  0.013876
# 2022-11-30 14:55:00     195.098        16.42 -0.000548  -0.015588  0.015039
# 2022-11-30 14:56:00     195.127        16.41 -0.000400  -0.016187  0.015787
# 2022-11-30 14:57:00     195.144        16.41 -0.000312  -0.016187  0.015875
# 2022-11-30 14:58:00     195.144        16.41 -0.000312  -0.016187  0.015875
# 2022-11-30 14:59:00     195.144        16.41 -0.000312  -0.016187  0.015875
# 2022-11-30 15:00:00     194.921        16.42 -0.001455  -0.015588  0.014133
#
#                      bond_pos  stock_pos  premium rate
# 2022-11-29 15:00:00       0.0        0.0      0.035710
# 2022-11-30 09:30:00       0.0        0.0      0.035042
# 2022-11-30 09:31:00       0.0        0.0      0.034635
# 2022-11-30 09:32:00       0.0        0.0      0.034766
# 2022-11-30 09:33:00       0.0        0.0      0.031603
# 2022-11-30 09:34:00       0.0        0.0      0.040132
# 2022-11-30 09:35:00       0.0        0.0      0.041120
# 2022-11-30 09:36:00       0.0        0.0      0.044111
# 2022-11-30 09:37:00       0.0        0.0      0.045823
# 2022-11-30 09:38:00       0.0        0.0      0.042167
# 2022-11-30 09:39:00       0.0        0.0      0.039760
# 2022-11-30 09:40:00      -1.0        1.0      0.046760
# 2022-11-30 09:41:00      -1.0        1.0      0.044976
# 2022-11-30 09:42:00      -1.0        1.0      0.048791
# 2022-11-30 09:43:00      -1.0        1.0      0.047935
# 2022-11-30 09:44:00      -1.0        1.0      0.049790
# 2022-11-30 09:45:00      -1.0        1.0      0.051381
# 2022-11-30 09:46:00      -1.0        1.0      0.049347
# 2022-11-30 09:47:00      -1.0        1.0      0.050409
# 2022-11-30 09:48:00      -1.0        1.0      0.050794
# 2022-11-30 09:49:00      -1.0        1.0      0.050131
# 2022-11-30 09:50:00      -1.0        1.0      0.049973
# 2022-11-30 09:51:00      -1.0        1.0      0.050179
# 2022-11-30 09:52:00      -1.0        1.0      0.050247
# 2022-11-30 09:53:00      -1.0        1.0      0.050590
# 2022-11-30 09:54:00      -1.0        1.0      0.053880
# 2022-11-30 09:55:00      -1.0        1.0      0.054625
# 2022-11-30 09:56:00      -1.0        1.0      0.052579
# 2022-11-30 09:57:00      -1.0        1.0      0.047205
# 2022-11-30 09:58:00      -1.0        1.0      0.048340
# 2022-11-30 09:59:00      -1.0        1.0      0.048945
# 2022-11-30 10:00:00      -1.0        1.0      0.051099
# 2022-11-30 10:01:00      -1.0        1.0      0.053076
# 2022-11-30 10:02:00      -1.0        1.0      0.053103
# 2022-11-30 10:03:00      -1.0        1.0      0.049432
# 2022-11-30 10:04:00      -1.0        1.0      0.047449
# 2022-11-30 10:05:00      -1.0        1.0      0.049204
# 2022-11-30 10:06:00      -1.0        1.0      0.050118
# 2022-11-30 10:07:00      -1.0        1.0      0.048733
# 2022-11-30 10:08:00      -1.0        1.0      0.049237
# 2022-11-30 10:09:00      -1.0        1.0      0.047840
# 2022-11-30 10:10:00      -1.0        1.0      0.047993
# 2022-11-30 10:11:00      -1.0        1.0      0.046577
# 2022-11-30 10:12:00      -1.0        1.0      0.047853
# 2022-11-30 10:13:00      -1.0        1.0      0.049590
# 2022-11-30 10:14:00      -1.0        1.0      0.051224
# 2022-11-30 10:15:00      -1.0        1.0      0.047969
# 2022-11-30 10:16:00      -1.0        1.0      0.049037
# 2022-11-30 10:17:00      -1.0        1.0      0.049234
# 2022-11-30 10:18:00      -1.0        1.0      0.048612
# 2022-11-30 10:19:00      -1.0        1.0      0.050324
# 2022-11-30 10:20:00      -1.0        1.0      0.050111
# 2022-11-30 10:21:00      -1.0        1.0      0.047536
# 2022-11-30 10:22:00      -1.0        1.0      0.050779
# 2022-11-30 10:23:00      -1.0        1.0      0.053522
# 2022-11-30 10:24:00      -1.0        1.0      0.053695
# 2022-11-30 10:25:00      -1.0        1.0      0.050561
# 2022-11-30 10:26:00      -1.0        1.0      0.050049
# 2022-11-30 10:27:00      -1.0        1.0      0.049805
# 2022-11-30 10:28:00      -1.0        1.0      0.049700
# 2022-11-30 10:29:00      -1.0        1.0      0.047326
# 2022-11-30 10:30:00      -1.0        1.0      0.046532
# 2022-11-30 10:31:00      -1.0        1.0      0.047679
# 2022-11-30 10:32:00      -1.0        1.0      0.048557
# 2022-11-30 10:33:00      -1.0        1.0      0.048631
# 2022-11-30 10:34:00      -1.0        1.0      0.049276
# 2022-11-30 10:35:00      -1.0        1.0      0.048513
# 2022-11-30 10:36:00      -1.0        1.0      0.047751
# 2022-11-30 10:37:00      -1.0        1.0      0.046865
# 2022-11-30 10:38:00      -1.0        1.0      0.046865
# 2022-11-30 10:39:00      -1.0        1.0      0.046390
# 2022-11-30 10:40:00      -1.0        1.0      0.047004
# 2022-11-30 10:41:00      -1.0        1.0      0.048109
# 2022-11-30 10:42:00      -1.0        1.0      0.046530
# 2022-11-30 10:43:00      -1.0        1.0      0.045288
# 2022-11-30 10:44:00      -1.0        1.0      0.045346
# 2022-11-30 10:45:00      -1.0        1.0      0.045293
# 2022-11-30 10:46:00      -1.0        1.0      0.047655
# 2022-11-30 10:47:00      -1.0        1.0      0.048630
# 2022-11-30 10:48:00      -1.0        1.0      0.048435
# 2022-11-30 10:49:00      -1.0        1.0      0.050154
# 2022-11-30 10:50:00      -1.0        1.0      0.049755
# 2022-11-30 10:51:00      -1.0        1.0      0.048962
# 2022-11-30 10:52:00      -1.0        1.0      0.048401
# 2022-11-30 10:53:00      -1.0        1.0      0.047777
# 2022-11-30 10:54:00      -1.0        1.0      0.047636
# 2022-11-30 10:55:00      -1.0        1.0      0.048109
# 2022-11-30 10:56:00      -1.0        1.0      0.047257
# 2022-11-30 10:57:00      -1.0        1.0      0.047306
# 2022-11-30 10:58:00      -1.0        1.0      0.048304
# 2022-11-30 10:59:00      -1.0        1.0      0.047982
# 2022-11-30 11:00:00      -1.0        1.0      0.047980
# 2022-11-30 11:01:00      -1.0        1.0      0.048225
# 2022-11-30 11:02:00      -1.0        1.0      0.047583
# 2022-11-30 11:03:00      -1.0        1.0      0.050184
# 2022-11-30 11:04:00      -1.0        1.0      0.049357
# 2022-11-30 11:05:00      -1.0        1.0      0.052269
# 2022-11-30 11:06:00      -1.0        1.0      0.050608
# 2022-11-30 11:07:00      -1.0        1.0      0.050179
# 2022-11-30 11:08:00      -1.0        1.0      0.050277
# 2022-11-30 11:09:00      -1.0        1.0      0.050383
# 2022-11-30 11:10:00      -1.0        1.0      0.050547
# 2022-11-30 11:11:00      -1.0        1.0      0.049069
# 2022-11-30 11:12:00      -1.0        1.0      0.051606
# 2022-11-30 11:13:00      -1.0        1.0      0.049221
# 2022-11-30 11:14:00      -1.0        1.0      0.047925
# 2022-11-30 11:15:00      -1.0        1.0      0.047637
# 2022-11-30 11:16:00      -1.0        1.0      0.048685
# 2022-11-30 11:17:00      -1.0        1.0      0.050221
# 2022-11-30 11:18:00      -1.0        1.0      0.049066
# 2022-11-30 11:19:00      -1.0        1.0      0.048469
# 2022-11-30 11:20:00      -1.0        1.0      0.049518
# 2022-11-30 11:21:00      -1.0        1.0      0.048630
# 2022-11-30 11:22:00      -1.0        1.0      0.048458
# 2022-11-30 11:23:00      -1.0        1.0      0.048775
# 2022-11-30 11:24:00      -1.0        1.0      0.048492
# 2022-11-30 11:25:00      -1.0        1.0      0.048044
# 2022-11-30 11:26:00      -1.0        1.0      0.046274
# 2022-11-30 11:27:00      -1.0        1.0      0.046796
# 2022-11-30 11:28:00      -1.0        1.0      0.047567
# 2022-11-30 11:29:00      -1.0        1.0      0.047588
# 2022-11-30 11:30:00      -1.0        1.0      0.048180
# 2022-11-30 13:00:00      -1.0        1.0      0.049937
# 2022-11-30 13:01:00      -1.0        1.0      0.048431
# 2022-11-30 13:02:00      -1.0        1.0      0.049032
# 2022-11-30 13:03:00      -1.0        1.0      0.048849
# 2022-11-30 13:04:00      -1.0        1.0      0.048614
# 2022-11-30 13:05:00      -1.0        1.0      0.047246
# 2022-11-30 13:06:00      -1.0        1.0      0.047356
# 2022-11-30 13:07:00      -1.0        1.0      0.049494
# 2022-11-30 13:08:00      -1.0        1.0      0.049631
# 2022-11-30 13:09:00      -1.0        1.0      0.049404
# 2022-11-30 13:10:00      -1.0        1.0      0.050393
# 2022-11-30 13:11:00      -1.0        1.0      0.049488
# 2022-11-30 13:12:00      -1.0        1.0      0.049145
# 2022-11-30 13:13:00      -1.0        1.0      0.050326
# 2022-11-30 13:14:00      -1.0        1.0      0.049009
# 2022-11-30 13:15:00      -1.0        1.0      0.048908
# 2022-11-30 13:16:00      -1.0        1.0      0.049364
# 2022-11-30 13:17:00      -1.0        1.0      0.049372
# 2022-11-30 13:18:00      -1.0        1.0      0.048319
# 2022-11-30 13:19:00      -1.0        1.0      0.049683
# 2022-11-30 13:20:00      -1.0        1.0      0.048545
# 2022-11-30 13:21:00      -1.0        1.0      0.047657
# 2022-11-30 13:22:00      -1.0        1.0      0.046632
# 2022-11-30 13:23:00      -1.0        1.0      0.047851
# 2022-11-30 13:24:00      -1.0        1.0      0.048069
# 2022-11-30 13:25:00      -1.0        1.0      0.047491
# 2022-11-30 13:26:00      -1.0        1.0      0.046923
# 2022-11-30 13:27:00      -1.0        1.0      0.046223
# 2022-11-30 13:28:00      -1.0        1.0      0.045086
# 2022-11-30 13:29:00      -1.0        1.0      0.045861
# 2022-11-30 13:30:00      -1.0        1.0      0.047011
# 2022-11-30 13:31:00      -1.0        1.0      0.046532
# 2022-11-30 13:32:00      -1.0        1.0      0.047597
# 2022-11-30 13:33:00      -1.0        1.0      0.047266
# 2022-11-30 13:34:00      -1.0        1.0      0.046586
# 2022-11-30 13:35:00      -1.0        1.0      0.045666
# 2022-11-30 13:36:00      -1.0        1.0      0.045812
# 2022-11-30 13:37:00      -1.0        1.0      0.046064
# 2022-11-30 13:38:00      -1.0        1.0      0.046047
# 2022-11-30 13:39:00      -1.0        1.0      0.045280
# 2022-11-30 13:40:00      -1.0        1.0      0.048738
# 2022-11-30 13:41:00      -1.0        1.0      0.050008
# 2022-11-30 13:42:00      -1.0        1.0      0.047810
# 2022-11-30 13:43:00      -1.0        1.0      0.047223
# 2022-11-30 13:44:00      -1.0        1.0      0.048439
# 2022-11-30 13:45:00      -1.0        1.0      0.050016
# 2022-11-30 13:46:00      -1.0        1.0      0.049370
# 2022-11-30 13:47:00      -1.0        1.0      0.050620
# 2022-11-30 13:48:00      -1.0        1.0      0.050536
# 2022-11-30 13:49:00      -1.0        1.0      0.050296
# 2022-11-30 13:50:00      -1.0        1.0      0.050636
# 2022-11-30 13:51:00      -1.0        1.0      0.050318
# 2022-11-30 13:52:00      -1.0        1.0      0.051543
# 2022-11-30 13:53:00      -1.0        1.0      0.052009
# 2022-11-30 13:54:00      -1.0        1.0      0.050277
# 2022-11-30 13:55:00      -1.0        1.0      0.050811
# 2022-11-30 13:56:00      -1.0        1.0      0.050390
# 2022-11-30 13:57:00      -1.0        1.0      0.048744
# 2022-11-30 13:58:00      -1.0        1.0      0.047829
# 2022-11-30 13:59:00      -1.0        1.0      0.048720
# 2022-11-30 14:00:00      -1.0        1.0      0.051615
# 2022-11-30 14:01:00      -1.0        1.0      0.050453
# 2022-11-30 14:02:00      -1.0        1.0      0.052348
# 2022-11-30 14:03:00      -1.0        1.0      0.051427
# 2022-11-30 14:04:00      -1.0        1.0      0.051072
# 2022-11-30 14:05:00      -1.0        1.0      0.050803
# 2022-11-30 14:06:00      -1.0        1.0      0.051133
# 2022-11-30 14:07:00      -1.0        1.0      0.051408
# 2022-11-30 14:08:00      -1.0        1.0      0.051253
# 2022-11-30 14:09:00      -1.0        1.0      0.050501
# 2022-11-30 14:10:00      -1.0        1.0      0.050704
# 2022-11-30 14:11:00      -1.0        1.0      0.051469
# 2022-11-30 14:12:00      -1.0        1.0      0.052369
# 2022-11-30 14:13:00      -1.0        1.0      0.051240
# 2022-11-30 14:14:00      -1.0        1.0      0.051594
# 2022-11-30 14:15:00      -1.0        1.0      0.051379
# 2022-11-30 14:16:00      -1.0        1.0      0.051297
# 2022-11-30 14:17:00      -1.0        1.0      0.052632
# 2022-11-30 14:18:00      -1.0        1.0      0.053247
# 2022-11-30 14:19:00      -1.0        1.0      0.052681
# 2022-11-30 14:20:00      -1.0        1.0      0.054266
# 2022-11-30 14:21:00      -1.0        1.0      0.053770
# 2022-11-30 14:22:00      -1.0        1.0      0.054407
# 2022-11-30 14:23:00      -1.0        1.0      0.054272
# 2022-11-30 14:24:00      -1.0        1.0      0.054045
# 2022-11-30 14:25:00      -1.0        1.0      0.054669
# 2022-11-30 14:26:00      -1.0        1.0      0.054033
# 2022-11-30 14:27:00      -1.0        1.0      0.053457
# 2022-11-30 14:28:00      -1.0        1.0      0.053397
# 2022-11-30 14:29:00      -1.0        1.0      0.053619
# 2022-11-30 14:30:00      -1.0        1.0      0.052799
# 2022-11-30 14:31:00      -1.0        1.0      0.055138
# 2022-11-30 14:32:00      -1.0        1.0      0.054749
# 2022-11-30 14:33:00      -1.0        1.0      0.055044
# 2022-11-30 14:34:00      -1.0        1.0      0.055628
# 2022-11-30 14:35:00      -1.0        1.0      0.054979
# 2022-11-30 14:36:00      -1.0        1.0      0.055492
# 2022-11-30 14:37:00      -1.0        1.0      0.055719
# 2022-11-30 14:38:00      -1.0        1.0      0.055524
# 2022-11-30 14:39:00      -1.0        1.0      0.055023
# 2022-11-30 14:40:00      -1.0        1.0      0.054865
# 2022-11-30 14:41:00      -1.0        1.0      0.054985
# 2022-11-30 14:42:00      -1.0        1.0      0.055924
# 2022-11-30 14:43:00      -1.0        1.0      0.054508
# 2022-11-30 14:44:00      -1.0        1.0      0.052956
# 2022-11-30 14:45:00      -1.0        1.0      0.053570
# 2022-11-30 14:46:00      -1.0        1.0      0.052412
# 2022-11-30 14:47:00      -1.0        1.0      0.051981
# 2022-11-30 14:48:00      -1.0        1.0      0.052622
# 2022-11-30 14:49:00      -1.0        1.0      0.053215
# 2022-11-30 14:50:00      -1.0        1.0      0.053975
# 2022-11-30 14:51:00      -1.0        1.0      0.051796
# 2022-11-30 14:52:00      -1.0        1.0      0.050024
# 2022-11-30 14:53:00      -1.0        1.0      0.050035
# 2022-11-30 14:54:00      -1.0        1.0      0.050301
# 2022-11-30 14:55:00      -1.0        1.0      0.051533
# 2022-11-30 14:56:00      -1.0        1.0      0.052330
# 2022-11-30 14:57:00      -1.0        1.0      0.052422
# 2022-11-30 14:58:00      -1.0        1.0      0.052422
# 2022-11-30 14:59:00      -1.0        1.0      0.052422
# 2022-11-30 15:00:00       0.0        0.0      0.050579

# %%
# 到期时间很短，且价内50%的时候，转债近似等价于正股
def cal_premium_rate(bond_price,stock_price,convert_price):
    tmp = 100/convert_price*stock_price
    res = (bond_price - tmp)/tmp
    return res
cal_premium_rate(200,140,70)
# Out:
# 0.0
