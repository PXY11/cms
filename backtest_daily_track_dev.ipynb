# %% [markdown]
# # import data

# %%
from WindPy import *

#Wind API 使用W账户密码登录
w.start() 

#return True and then can go to next operation.
w.isconnected()

import pandas as pd
# Out:
# 22.11.1.52440
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2021 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
# w.wsi("123046.SZ,300587.SZ,113642.SH,603185.SH,110061.SH,600674.SH,128081.SZ,002203.SZ,113016.SH,601127.SH,128017.SZ,002597.SZ",  "close",  "2022-09-06 09:00:00",  "2022-09-09 16:28:08",  "")

# %%
cbond_list = ['123046.SZ','300587.SZ',
# '113642.SH','603185.SH', #转债已退市
'110061.SH','600674.SH',
'128081.SZ','002203.SZ',
'113016.SH','601127.SH',
'128017.SZ','002597.SZ',
'113537.SH','603348.SH',
'123027.SZ','300487.SZ', #转债已退市
'113534.SH','603876.SH',
'113025.SH','601677.SH',
'123031.SZ','300655.SZ',
'128029.SZ','002078.SZ',
'128111.SZ','002738.SZ', #2022-10-14新增4个对子
'128095.SZ','002812.SZ',
'113626.SH','603596.SH',
'123092.SZ','300332.SZ',
'123057.SZ','300586.SZ',#2020-11-18新增3个对子
'123067.SZ','300382.SZ',
'128106.SZ','002840.SZ',
]

# %% [markdown]
# # history trade days

# %%
# ###############################################################
# before_trade_date = '20220908'#监测当日前一个交易日
# present_date = '20220909' #监测当日
# next_trade_date = '20220910' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220909'#监测当日前一个交易日
# present_date = '20220913' #监测当日
# next_trade_date = '20220914' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220913'#监测当日前一个交易日
# present_date = '20220914' #监测当日
# next_trade_date = '20220915' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220914'#监测当日前一个交易日
# present_date = '20220915' #监测当日
# next_trade_date = '20220916' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220915'#监测当日前一个交易日
# present_date = '20220916' #监测当日
# next_trade_date = '20220917' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220916'#监测当日前一个交易日
# present_date = '20220919' #监测当日
# next_trade_date = '20220920' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220919'#监测当日前一个交易日
# present_date = '20220920' #监测当日
# next_trade_date = '20220921' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220920'#监测当日前一个交易日
# present_date = '20220921' #监测当日
# next_trade_date = '20220922' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220921'#监测当日前一个交易日
# present_date = '20220922' #监测当日
# next_trade_date = '20220923' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220922'#监测当日前一个交易日
# present_date = '20220923' #监测当日
# next_trade_date = '20220924' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220923'#监测当日前一个交易日
# present_date = '20220926' #监测当日
# next_trade_date = '20220927' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220926'#监测当日前一个交易日
# present_date = '20220927' #监测当日
# next_trade_date = '20220928' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220927'#监测当日前一个交易日
# present_date = '20220928' #监测当日
# next_trade_date = '20220929' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220928'#监测当日前一个交易日
# present_date = '20220929' #监测当日
# next_trade_date = '20220930' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220929'#监测当日前一个交易日
# present_date = '20220930' #监测当日
# next_trade_date = '20221001' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220930'#监测当日前一个交易日
# present_date = '20221010' #监测当日
# next_trade_date = '20221011' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221010'#监测当日前一个交易日
# present_date = '20221011' #监测当日
# next_trade_date = '20221012' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221011'#监测当日前一个交易日
# present_date = '20221012' #监测当日
# next_trade_date = '20221013' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221012'#监测当日前一个交易日
# present_date = '20221013' #监测当日
# next_trade_date = '20221014' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221013'#监测当日前一个交易日
# present_date = '20221014' #监测当日
# next_trade_date = '20221015' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221014'#监测当日前一个交易日
# present_date = '20221017' #监测当日
# next_trade_date = '20221018' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221017'#监测当日前一个交易日
# present_date = '20221018' #监测当日
# next_trade_date = '20221019' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221018'#监测当日前一个交易日
# present_date = '20221019' #监测当日
# next_trade_date = '20221020' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221019'#监测当日前一个交易日
# present_date = '20221020' #监测当日
# next_trade_date = '20221021' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221020'#监测当日前一个交易日
# present_date = '20221021' #监测当日
# next_trade_date = '20221022' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221021'#监测当日前一个交易日
# present_date = '20221024' #监测当日
# next_trade_date = '20221025' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221024'#监测当日前一个交易日
# present_date = '20221025' #监测当日
# next_trade_date = '20221026' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221025'#监测当日前一个交易日
# present_date = '20221026' #监测当日
# next_trade_date = '20221027' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221026'#监测当日前一个交易日
# present_date = '20221027' #监测当日
# next_trade_date = '20221028' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221027'#监测当日前一个交易日
# present_date = '20221028' #监测当日
# next_trade_date = '20221029' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221028'#监测当日前一个交易日
# present_date = '20221031' #监测当日
# next_trade_date = '20221101' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221031'#监测当日前一个交易日
# present_date = '20221101' #监测当日
# next_trade_date = '20221102' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221101'#监测当日前一个交易日
# present_date = '20221102' #监测当日
# next_trade_date = '20221103' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221102'#监测当日前一个交易日
# present_date = '20221103' #监测当日
# next_trade_date = '20221104' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221103'#监测当日前一个交易日
# present_date = '20221104' #监测当日
# next_trade_date = '20221105' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221104'#监测当日前一个交易日
# present_date = '20221107' #监测当日
# next_trade_date = '20221108' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221107'#监测当日前一个交易日
# present_date = '20221108' #监测当日
# next_trade_date = '20221109' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221108'#监测当日前一个交易日
# present_date = '20221109' #监测当日
# next_trade_date = '20221110' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221109'#监测当日前一个交易日
# present_date = '20221110' #监测当日
# next_trade_date = '20221111' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221110'#监测当日前一个交易日
# present_date = '20221111' #监测当日
# next_trade_date = '20221112' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221111'#监测当日前一个交易日
# present_date = '20221114' #监测当日
# next_trade_date = '20221115' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221114'#监测当日前一个交易日
# present_date = '20221115' #监测当日
# next_trade_date = '20221116' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221115'#监测当日前一个交易日
# present_date = '20221116' #监测当日
# next_trade_date = '20221117' #监测当日下一个自然日
# ###############################################################

# %%
# ###############################################################
# before_trade_date = '20221116'#监测当日前一个交易日
# present_date = '20221117' #监测当日
# next_trade_date = '20221118' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221117'#监测当日前一个交易日
# present_date = '20221118' #监测当日
# next_trade_date = '20221119' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221118'#监测当日前一个交易日
# present_date = '20221121' #监测当日
# next_trade_date = '20221122' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221121'#监测当日前一个交易日
# present_date = '20221122' #监测当日
# next_trade_date = '20221123' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221122'#监测当日前一个交易日
# present_date = '20221123' #监测当日
# next_trade_date = '20221124' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221123'#监测当日前一个交易日
# present_date = '20221124' #监测当日
# next_trade_date = '20221125' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221124'#监测当日前一个交易日
# present_date = '20221125' #监测当日
# next_trade_date = '20221126' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221125'#监测当日前一个交易日
# present_date = '20221128' #监测当日
# next_trade_date = '20221129' #监测当日下一个自然日
# ###############################################################

# ###############################################################
before_trade_date = '20221128'#监测当日前一个交易日
present_date = '20221129' #监测当日
next_trade_date = '20221130' #监测当日下一个自然日
# ###############################################################

# %%
start_date = pd.to_datetime(before_trade_date) 
end_date = pd.to_datetime(next_trade_date)

cbond_price = pd.DataFrame([])
for code in cbond_list:
    price_df = w.wsi(code, "close", start_date, end_date,usedf=True)[1]   #只要了收盘价
    price_df.columns = [code]
    cbond_price = pd.concat([cbond_price,price_df],axis=1)
cbond_price = cbond_price.ffill()    
# cbond_rtn = cbond_price[cbond_price.index.time!=time(15,0,0)]
# cbond_price = cbond_price.loc['2022-09-09 15:00:00':] #从前一个交易日的收盘价开始截取
cbond_price_begin_time = before_trade_date[:4]+'-' + \
                    before_trade_date[4:6]+'-' + \
                    before_trade_date[6:8]+' 15:00:00'
cbond_price = cbond_price.loc[cbond_price_begin_time:]
cbond_price
# Out:
#                      123046.SZ  300587.SZ  110061.SH  600674.SH  128081.SZ  \
# 2022-11-28 15:00:00    361.300      12.69    136.605      12.00    127.190
# 2022-11-29 09:30:00    363.931      12.77    136.447      12.01    127.531
# 2022-11-29 09:31:00    363.249      12.67    136.575      11.97    127.780
# 2022-11-29 09:32:00    363.559      12.70    136.553      11.97    127.719
# 2022-11-29 09:33:00    363.594      12.71    136.140      11.93    127.700
# ...                        ...        ...        ...        ...        ...
# 2022-11-29 14:56:00    361.483      12.62    135.952      11.95    129.134
# 2022-11-29 14:57:00    361.100      12.64    135.956      11.95    129.201
# 2022-11-29 14:58:00    361.100      12.64    136.000      11.95    129.201
# 2022-11-29 14:59:00    361.100      12.64    136.000      11.95    129.201
# 2022-11-29 15:00:00    361.476      12.60    136.000      11.94    129.201
#
#                      002203.SZ  113016.SH  601127.SH  128017.SZ  002597.SZ  \
# 2022-11-28 15:00:00      12.17    313.143      45.12    177.995      33.65
# 2022-11-29 09:30:00      12.21    317.280      45.68    179.511      34.09
# 2022-11-29 09:31:00      12.22    318.000      45.66    179.849      34.03
# 2022-11-29 09:32:00      12.21    317.965      45.64    179.583      34.15
# 2022-11-29 09:33:00      12.22    316.995      45.55    179.301      34.09
# ...                        ...        ...        ...        ...        ...
# 2022-11-29 14:56:00      12.33    321.902      46.98    186.138      34.99
# 2022-11-29 14:57:00      12.30    321.990      47.00    186.250      34.99
# 2022-11-29 14:58:00      12.30    321.999      47.00    186.250      34.99
# 2022-11-29 14:59:00      12.30    322.130      47.00    186.250      34.99
# 2022-11-29 15:00:00      12.30    322.011      47.00    187.250      35.00
#
#                      ...  113626.SH  603596.SH  123092.SZ  300332.SZ  \
# 2022-11-28 15:00:00  ...    225.601      81.30    271.001      13.37
# 2022-11-29 09:30:00  ...    226.425      81.49    272.014      13.34
# 2022-11-29 09:31:00  ...    225.885      81.09    271.714      13.38
# 2022-11-29 09:32:00  ...    225.039      80.76    272.221      13.38
# 2022-11-29 09:33:00  ...    223.674      80.24    271.304      13.33
# ...                  ...        ...        ...        ...        ...
# 2022-11-29 14:56:00  ...    219.368      78.31    273.223      13.27
# 2022-11-29 14:57:00  ...    219.400      78.30    273.000      13.26
# 2022-11-29 14:58:00  ...    219.315      78.30    273.000      13.26
# 2022-11-29 14:59:00  ...    219.271      78.30    273.000      13.26
# 2022-11-29 15:00:00  ...    219.296      78.29    273.000      13.26
#
#                      123057.SZ  300586.SZ  123067.SZ  300382.SZ  128106.SZ  \
# 2022-11-28 15:00:00    226.800      20.43    223.166      21.26    192.076
# 2022-11-29 09:30:00    227.456      20.36    224.754      21.38    193.043
# 2022-11-29 09:31:00    225.985      20.32    224.012      21.30    193.500
# 2022-11-29 09:32:00    228.051      20.43    224.000      21.23    193.481
# 2022-11-29 09:33:00    226.632      20.36    223.443      21.13    192.725
# ...                        ...        ...        ...        ...        ...
# 2022-11-29 14:56:00    222.899      20.18    223.863      21.25    194.991
# 2022-11-29 14:57:00    222.894      20.18    223.881      21.27    194.811
# 2022-11-29 14:58:00    222.894      20.18    223.881      21.27    194.811
# 2022-11-29 14:59:00    222.894      20.18    223.881      21.27    194.811
# 2022-11-29 15:00:00    222.848      20.21    223.881      21.27    195.205
#
#                      002840.SZ
# 2022-11-28 15:00:00      16.36
# 2022-11-29 09:30:00      16.44
# 2022-11-29 09:31:00      16.48
# 2022-11-29 09:32:00      16.47
# 2022-11-29 09:33:00      16.40
# ...                        ...
# 2022-11-29 14:56:00      16.69
# 2022-11-29 14:57:00      16.68
# 2022-11-29 14:58:00      16.68
# 2022-11-29 14:59:00      16.68
# 2022-11-29 15:00:00      16.68
#
# [243 rows x 36 columns]

# %%
# assert False

# %% [markdown]
# # stock pre status

# %%
df_stk_pre_return = w.wss("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return = w.wss("300587.SZ,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
"pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return
df_stk_pre_return
# Out:
#             PCT_CHG
# 300587.SZ -1.627907
# 600674.SH  0.418410
# 002203.SZ  0.661704
# 601127.SH -1.484716
# 002597.SZ -2.407193
# 603348.SH -0.536193
# 300487.SZ -0.810997
# 603876.SH  3.709394
# 601677.SH  1.469606
# 300655.SZ -5.666064
# 002078.SZ -1.572618
# 002738.SZ -1.035582
# 002812.SZ  0.552142
# 603596.SH  3.290560
# 300332.SZ  1.364670
# 300586.SZ -0.921435
# 300382.SZ -1.024209
# 002840.SZ -2.153110

# %%
df_bond_pre_return = w.wss("123046.SZ,113642.SH,110061.SH,128081.SZ,113016.SH,128017.SZ,113537.SH,123027.SZ,113534.SH,113025.SH,123031.SZ,128029.SZ,128111.SZ,128095.SZ,113626.SH,123092.SZ,123057.SZ,123067.SZ,128106.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_bond_pre_return
# Out:
#             PCT_CHG
# 123046.SZ -1.953867
# 113642.SH       NaN
# 110061.SH  0.000732
# 128081.SZ  0.387533
# 113016.SH -2.064158
# 128017.SZ -1.703667
# 113537.SH  0.012362
# 123027.SZ       NaN
# 113534.SH  1.875896
# 113025.SH  1.718039
# 123031.SZ -2.121863
# 128029.SZ -1.290150
# 128111.SZ -1.594566
# 128095.SZ -0.224498
# 113626.SH  2.894347
# 123092.SZ  0.969076
# 123057.SZ  0.442870
# 123067.SZ -0.149441
# 128106.SZ -1.499487

# %%
before_trade_date_trade_status = before_trade_date[:4] +'-'+ before_trade_date[4:6] +'-'+ before_trade_date[6:]
# present_date_trade_status = present_date[:4] +'-'+ present_date[4:6] +'-'+ present_date[6:]
df_stk_pre_trade_status = w.wsd("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ", 
"trade_status", f"{before_trade_date_trade_status}", f"{before_trade_date_trade_status}", "",usedf=True)[1]
df_stk_pre_trade_status
# Out:
#           TRADE_STATUS
# 300587.SZ           交易
# 603185.SH           交易
# 600674.SH           交易
# 002203.SZ           交易
# 601127.SH           交易
# 002597.SZ           交易
# 603348.SH           交易
# 300487.SZ           交易
# 603876.SH           交易
# 601677.SH           交易
# 300655.SZ           交易
# 002078.SZ           交易
# 002738.SZ           交易
# 002812.SZ           交易
# 603596.SH           交易
# 300332.SZ           交易
# 300586.SZ           交易
# 300382.SZ           交易
# 002840.SZ           交易

# %%
df_stk_pre_trade_status.iloc[0,0]
# Out:
# '交易'

# %%
# assert False

# %% [markdown]
# # bond-stock pair

# %%
# cbond_pair = ['113642.SH','603185.SH']  #后面筛选的结果，这组也在里面 转债停止交易了
# open_threshold = 0.023
# close_threshold = 0
# convert_price = 102.4
# operate = True

# cbond_pair = ['123027.SZ','300487.SZ',] # 1019 1020 1021 这几天转债停止交易了
# open_threshold = 0.022
# close_threshold = 0
# convert_price = 19.07
# operate = True

# %%
cbond_pair = ['123046.SZ','300587.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.015
close_threshold = 0
convert_price = 3.94
operate = True

cbond_pair = ['110061.SH','600674.SH']
open_threshold = 0.006
close_threshold = 0
convert_price = 8.8
operate = True

cbond_pair = ['128081.SZ','002203.SZ']
open_threshold = 0.012
close_threshold = 0.002
convert_price = 9.62
operate = True

cbond_pair = ['113016.SH','601127.SH'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.017
close_threshold = 0.003
convert_price = 20.17
operate = True

cbond_pair = ['128017.SZ','002597.SZ']
open_threshold = 0.012
close_threshold = 0
convert_price = 21.33
operate = True

# # # $$$$$$$$$$$$$$$$$$$$$$$$以下是新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['113537.SH','603348.SH',]
open_threshold = 0.027
close_threshold = 0.002
convert_price = 19.13
operate = True

cbond_pair = ['113534.SH','603876.SH',]
open_threshold = 0.019
close_threshold = 0.002
convert_price = 14.98
operate = True

cbond_pair = ['113025.SH','601677.SH',]
open_threshold = 0.018
close_threshold = 0
convert_price = 7.66
operate = True

cbond_pair = ['123031.SZ','300655.SZ',]   #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.019
close_threshold = 0
convert_price = 6.25
operate = True

cbond_pair = ['128029.SZ','002078.SZ']
open_threshold = 0.013
close_threshold = 0.002
convert_price = 8.25
operate = True

# # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-10-14】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['128111.SZ','002738.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.011
close_threshold = 0.001
convert_price = 10.96
operate = True

cbond_pair = ['128095.SZ','002812.SZ']
open_threshold = 0.013
close_threshold = 0
convert_price = 64.62
operate = True

cbond_pair = ['113626.SH','603596.SH']
open_threshold = 0.02
close_threshold = 0
convert_price = 35.88
operate = True

cbond_pair = ['123092.SZ','300332.SZ']
open_threshold = 0.025
close_threshold = 0.001
convert_price = 5.14
operate = True

# # # $$$$$$$$$$$$$$$$$$$$$$$$【2022-11-18】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair =  ['123057.SZ','300586.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.009 
close_threshold = 0.003
convert_price = 9.5
operate = True

cbond_pair =  ['123067.SZ','300382.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.004
close_threshold = 0.002
convert_price = 9.96
operate = True

cbond_pair =  ['128106.SZ','002840.SZ']
open_threshold = 0.01
close_threshold = 0
convert_price = 8.85
operate = True

# %%
# df_signal

# %% [markdown]
# # clip price series

# %%
#从前一个交易日的收盘价开始截取
# cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]].loc['2022-09-08 15:00:00':]
cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]]

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-28 15:00:00    192.076      16.36
# 2022-11-29 09:30:00    193.043      16.44
# 2022-11-29 09:31:00    193.500      16.48
# 2022-11-29 09:32:00    193.481      16.47
# 2022-11-29 09:33:00    192.725      16.40

# %%
cbond_return = pd.DataFrame([])

cbond_preclose = cbond_pair_price.iloc[0,0] # 初始时刻的bond前收盘价
stock_preclose = cbond_pair_price.iloc[0,1] # 初始时刻的stock前收盘价

for index,row in cbond_pair_price.iterrows():
    
    cbond_return.loc[index,cbond_pair[0]] = row[cbond_pair[0]]/cbond_preclose - 1 # 算日内的return
    cbond_return.loc[index,cbond_pair[1]] = row[cbond_pair[1]]/stock_preclose - 1

    if index.time()==time(15,0,0):  #算完日内return，迭代到今日价格的最后一个time bar的时候，将其设为前收盘价
        cbond_preclose = row[cbond_pair[0]]    # 日内return指标用 现价/昨日收盘价 计算
        stock_preclose = row[cbond_pair[1]]
        
# 检查df是否有空值
cbond_return.isnull().sum(axis=0)  # 按列统计
cbond_return.isnull().sum(axis=1) # 按行统计
cbond_return.isnull().sum(axis=1).sum() # 统计整张表
# Out:
# 0

# %%
pd.set_option('display.max_rows', None)
cbond_return['diff'] = cbond_return[cbond_pair[0]] - cbond_return[cbond_pair[1]]
cbond_return.head()
# Out:
#                      128106.SZ  002840.SZ      diff
# 2022-11-28 15:00:00   0.000000   0.000000  0.000000
# 2022-11-29 09:30:00   0.005034   0.004890  0.000144
# 2022-11-29 09:31:00   0.007414   0.007335  0.000079
# 2022-11-29 09:32:00   0.007315   0.006724  0.000591
# 2022-11-29 09:33:00   0.003379   0.002445  0.000934

# %% [markdown]
# # signal calculate

# %%
################################################################################################
stk_pre_return = df_stk_pre_return.loc[cbond_pair[1]].values[0]
bond_pre_return = df_bond_pre_return.loc[cbond_pair[0]].values[0]
pre_diff = bond_pre_return - stk_pre_return
stk_pre_trade_status = df_stk_pre_trade_status.loc[cbond_pair[1]].values[0]
print(stk_pre_trade_status)
print('pre diff:',pre_diff)
# if abs(stk_pre_return) > 10 or stk_pre_trade_status!='交易':
if abs(pre_diff) > 5 or stk_pre_trade_status!='交易':
    # 如果前一天股票的跌幅小于-10，则今日不做操作
    intraday_open_times = 1
else:
    intraday_open_times = 0
################################################################################################    
open_close_spread = open_threshold - close_threshold
# intraday_open_times = 0
max_open = 1

pos_open_flag = 0
neg_open_flag = 0
cbond_position = pd.DataFrame([])
cbond_position.index = cbond_return.index
for index,row in cbond_return.iterrows():

    if row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff落在A区间，且无仓位，正开
            pos_open_flag = 1
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==1:
        if intraday_open_times < max_open:
            #diff落在A区间，且有负仓，平仓再正开
            pos_open_flag=1
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            print('reverse open +1')
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff落在A区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在B区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在B区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在B区间，且无仓，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在C区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在C区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在C区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在D区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在D区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在D区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且无仓位，反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==1 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且有正仓，平仓反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在E区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    if abs(row['diff'])>2 * open_close_spread and cbond_return.columns[0]!='123057.SZ' and cbond_return.columns[0]!='123067.SZ': 
        #盘中diff超过2倍spread时平仓（价格止损信号）,有两个spread特别小的对子则不用此逻辑进行止损
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if index.time()==time(15,0,0): # 每日收盘时必须平仓（时间止损信号）
    # if index.time()==time(14,59,0): # 每日收盘时必须平仓（时间止损信号）
        intraday_open_times = 0 # 下一天开盘前，把当日记录下来的开仓次数清零
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
# Out:
# 交易
# pre diff: 0.6536228683597056

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-28 15:00:00    192.076      16.36
# 2022-11-29 09:30:00    193.043      16.44
# 2022-11-29 09:31:00    193.500      16.48
# 2022-11-29 09:32:00    193.481      16.47
# 2022-11-29 09:33:00    192.725      16.40

# %%
df_signal = pd.concat([cbond_pair_price,cbond_return,cbond_position],axis=1)
df_signal.columns = ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
print('open threshold',open_threshold,'close threshold',close_threshold)
# df_signal.to_csv('tmp_signal.csv')
# df_signal
# Out:
# open threshold 0.01 close threshold 0

# %% [markdown]
# # backtest

# %%
# 用来记录交易流水的表格,一边遍历df_signal，一边填入内容到流水表格里

import numpy as np
cols = ['balance','signal','bond price','stock price','bond hold','stock hold','commission','tax','reverse open','diff','asset value']
df_trade = pd.DataFrame(
    data = [[0,np.nan,np.nan,np.nan,0,0,0,0,np.nan,np.nan,0]],
    columns=cols
    ) 

balance_last = 0 # 现金账户初始余额

bond_hold = 0 # 债券持有数量
stock_hold = 0 # 股票持有数量


commission_rate = 2/10000 + 0 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 0.5/1000 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 1/1000 # 佣金买卖万二 + 交易滑点

tax_rate = 1/1000 # 卖股票才收印花税千一

# commission_rate = 0/10000 # 佣金买卖万二
# tax_rate = 0/1000 #

for i in range(len(df_signal)-1):
    if df_signal.index[i].time() == time(15,0,0):
    # if df_signal.index[i].time() == time(14,59,0):
        # 修改stock volume 每天固定一个stock volume 应该用债的前收盘价/股票的前收盘价
        stock_volume = df_signal['bond_price'][i]/df_signal['stock_price'][i]

    if df_signal.values[i][-1] != df_signal.values[i+1][-1]:

        index = df_signal.index[i+1]        
        diff = df_signal.values[i+1][-3] #diff在df_signal中的倒数第三列
        
    # df_signal的columns
    # ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
        signal = str(int(df_signal.values[i+1][-2]))+str(int(df_signal.values[i+1][-1]))
        
        bond_price = df_signal.values[i+1][0] 

        stock_price = df_signal.values[i+1][1]

        # stock_volume =  bond_price/stock_price # 修改stock volume 每天固定一个stock volume应该用债的前收盘价/股票的前收盘价

        commission = (bond_price + stock_price * stock_volume) * commission_rate

        reverse_open = False #表明这笔交易，是否包含平仓后再反向开仓的操作

        if signal == '00' and stock_hold == stock_volume: #有股票持仓并且需要卖出平仓时，有印花税
            tax = stock_price * tax_rate * stock_volume
        else:
            tax = 0

        if signal == '00':
            balance_last += bond_hold*bond_price
            balance_last += stock_hold*stock_price
            
            bond_hold = 0
            stock_hold = 0
            

        if signal == '1-1':
            '''
            加一个检测之前持仓的模块,如果之前因为-11的信号有持仓,需要先平掉(即买债卖股票),同时再反向开仓
            '''
            reverse_flag = False
            if bond_hold == -1 and stock_hold == 1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last -= bond_price 
                balance_last += stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税
                reverse_flag = True
                reverse_open = True

            bond_hold += 1
            stock_hold += (-1 * stock_volume)
            # stock_hold += stock_volume
            balance_last -= bond_price
            balance_last += stock_price * stock_volume
            
            if reverse_flag:
                tax *= 2 #平仓然后反向开仓的时候 已经计算过tax了，直接double
            else:
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税

        if signal == '-11':
            '''
            加一个检测之前持仓的模块,如果之前因为1-1的信号有持仓,需要先平掉(卖债买股票),同时再反向开仓
            '''
            if bond_hold == 1 and stock_hold == -1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last += bond_price
                balance_last -= stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                                # 买股票无印花税
                reverse_open = True
            bond_hold += -1
            stock_hold += (1 * stock_volume)
            # stock_hold += stock_volume
            balance_last += bond_price
            balance_last -= stock_price * stock_volume
        
        balance_last = balance_last - commission - tax
        balance = balance_last
        asset_value = bond_price*bond_hold + stock_price*stock_hold
        line = [balance,signal,bond_price,stock_price,bond_hold,stock_hold,commission,tax,reverse_open,diff,asset_value]
        # df_trade.loc[index,['balance','asset','signal','bond price','stock price','commission','tax']] = line
        # df_trade.loc[index,cols] = [0,0,np.nan,np.nan,np.nan,0,0,0,0]
        df_trade.loc[index,cols] = line

df_trade.rename(columns={'balance':'cash'},inplace=True)       
df_trade['net value'] = df_trade['cash'] + df_trade['asset value']

# %%
df_trade['operate'] = [operate]*len(df_trade)

# %%
df_trade
# Out:
#    cash  signal  bond price  stock price  bond hold  stock hold  commission  \
# 0     0     NaN         NaN          NaN          0           0           0
#
#    tax  reverse open  diff  asset value  net value  operate
# 0    0           NaN   NaN            0          0     True

# %% [markdown]
# # output to csv

# %%
excel_file_name = './daily_track/'+ present_date+'/' + cbond_pair[0] + '@' + cbond_pair[1] + '.csv'

excel_file_name

df_to_excel = df_trade
df_to_excel['open/close'] = [str(open_threshold)+','+str(close_threshold)]*len(df_to_excel)
df_to_excel['pair'] = [cbond_pair[0] + '@' + cbond_pair[1]]*len(df_to_excel)
df_to_excel = df_to_excel[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_to_excel.to_csv(excel_file_name,)

# %%
present_date
# Out:
# '20221129'

# %% [markdown]
# # conclusion

# %%
import os
single_trade_files = os.listdir('./daily_track'+'/'+present_date)

df_trade_conclusion = pd.DataFrame([])
for file in single_trade_files:
    if file == 'diff':
        continue
    if file == '.DS_Store' or file.split('.')[1] == 'xlsx':
        continue
    tmp_path = './daily_track'+'/'+present_date+'/'+file
    df_tmp = pd.read_csv(tmp_path,index_col=0)
    tmp_col = list(df_tmp.columns)
    df_tmp_head = pd.DataFrame(data=[tmp_col],columns=tmp_col)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp_head)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp)
df_trade_conclusion.columns
df_trade_conclusion = df_trade_conclusion[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_trade_conclusion
tmp_path = './daily_track'+'/'+present_date+'/'+f'{present_date}_conclusion.csv'

df_trade_conclusion.to_csv(tmp_path)
# Out:
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61
# Connect to Sky fail. errCode:61

# %% [markdown]
# # intraday signal

# %%
import matplotlib.pyplot as plt

signal_plot_begin_time = present_date[:4]+'-' + \
                         present_date[4:6]+'-' + \
                         present_date[6:8]+' 09:30:00'
df_signal['diff'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' diff',grid=True)

#如果当日有开平仓记录，在图上画出开平仓时刻的标注
if len(df_trade) == 3:
    open_tick = df_trade.index.to_list()[1]
    open_diff = df_trade['diff'].to_list()[1]
    close_tick = df_trade.index.to_list()[2]
    close_diff =  df_trade['diff'].to_list()[2]
    plt.text(open_tick,open_diff,'open')
    plt.text(close_tick,close_diff,'close')
    plt.scatter([open_tick],[open_diff],color='r')

    tmp_nv = df_trade['net value'].to_list()[2]
    if tmp_nv > 0: 
        close_color = 'g' #当天赚钱的话，平仓点位标记为绿色
    else:
        close_color = 'orange' #当天亏钱的话，平仓点位标记为橙色
    plt.scatter([close_tick],[close_diff],color=close_color)
fig_file_name = './daily_track/'+ present_date+'/'+'diff/' + cbond_pair[0] + '@' + cbond_pair[1] + '.png'
plt.savefig(fig_file_name)

plt.show()
df_signal['bond_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+' rtn',grid=True)
plt.show()
df_signal['stock_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[1]+' rtn',grid=True)
plt.show()

# %%
df_tmp = 100/convert_price*df_signal['stock_price']
df_signal['premium rate'] = (df_signal['bond_price'] - df_tmp)/df_tmp
df_signal['premium rate'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' premium rate',grid=True)
# Out:
# <AxesSubplot:title={'center':'128106.SZ@002840.SZ premium rate'}>

# %%
df_signal
# Out:
#                      bond_price  stock_price  bond_rtn  stock_rtn      diff  \
# 2022-11-28 15:00:00     192.076        16.36  0.000000   0.000000  0.000000
# 2022-11-29 09:30:00     193.043        16.44  0.005034   0.004890  0.000144
# 2022-11-29 09:31:00     193.500        16.48  0.007414   0.007335  0.000079
# 2022-11-29 09:32:00     193.481        16.47  0.007315   0.006724  0.000591
# 2022-11-29 09:33:00     192.725        16.40  0.003379   0.002445  0.000934
# 2022-11-29 09:34:00     192.978        16.41  0.004696   0.003056  0.001640
# 2022-11-29 09:35:00     192.708        16.34  0.003290  -0.001222  0.004513
# 2022-11-29 09:36:00     192.918        16.37  0.004384   0.000611  0.003772
# 2022-11-29 09:37:00     192.532        16.36  0.002374   0.000000  0.002374
# 2022-11-29 09:38:00     192.747        16.38  0.003493   0.001222  0.002271
# 2022-11-29 09:39:00     192.677        16.40  0.003129   0.002445  0.000684
# 2022-11-29 09:40:00     193.100        16.43  0.005331   0.004279  0.001052
# 2022-11-29 09:41:00     193.195        16.42  0.005826   0.003667  0.002158
# 2022-11-29 09:42:00     192.968        16.41  0.004644   0.003056  0.001588
# 2022-11-29 09:43:00     192.320        16.38  0.001270   0.001222  0.000048
# 2022-11-29 09:44:00     192.231        16.39  0.000807   0.001834 -0.001027
# 2022-11-29 09:45:00     193.287        16.45  0.006305   0.005501  0.000804
# 2022-11-29 09:46:00     192.856        16.46  0.004061   0.006112 -0.002052
# 2022-11-29 09:47:00     193.469        16.49  0.007252   0.007946 -0.000694
# 2022-11-29 09:48:00     193.020        16.45  0.004915   0.005501 -0.000587
# 2022-11-29 09:49:00     192.676        16.41  0.003124   0.003056  0.000068
# 2022-11-29 09:50:00     192.600        16.43  0.002728   0.004279 -0.001551
# 2022-11-29 09:51:00     192.636        16.44  0.002916   0.004890 -0.001974
# 2022-11-29 09:52:00     192.709        16.41  0.003296   0.003056  0.000239
# 2022-11-29 09:53:00     192.786        16.41  0.003696   0.003056  0.000640
# 2022-11-29 09:54:00     192.990        16.43  0.004759   0.004279  0.000480
# 2022-11-29 09:55:00     193.226        16.49  0.005987   0.007946 -0.001959
# 2022-11-29 09:56:00     193.110        16.47  0.005383   0.006724 -0.001340
# 2022-11-29 09:57:00     193.440        16.52  0.007101   0.009780 -0.002679
# 2022-11-29 09:58:00     193.483        16.53  0.007325   0.010391 -0.003066
# 2022-11-29 09:59:00     193.650        16.51  0.008195   0.009169 -0.000974
# 2022-11-29 10:00:00     194.116        16.57  0.010621   0.012836 -0.002215
# 2022-11-29 10:01:00     194.483        16.57  0.012531   0.012836 -0.000305
# 2022-11-29 10:02:00     195.000        16.68  0.015223   0.019560 -0.004337
# 2022-11-29 10:03:00     194.979        16.68  0.015114   0.019560 -0.004446
# 2022-11-29 10:04:00     195.132        16.75  0.015910   0.023839 -0.007928
# 2022-11-29 10:05:00     194.700        16.73  0.013661   0.022616 -0.008955
# 2022-11-29 10:06:00     194.548        16.71  0.012870   0.021394 -0.008524
# 2022-11-29 10:07:00     194.242        16.65  0.011277   0.017726 -0.006449
# 2022-11-29 10:08:00     194.560        16.67  0.012932   0.018949 -0.006016
# 2022-11-29 10:09:00     194.757        16.68  0.013958   0.019560 -0.005602
# 2022-11-29 10:10:00     194.612        16.69  0.013203   0.020171 -0.006968
# 2022-11-29 10:11:00     194.369        16.65  0.011938   0.017726 -0.005788
# 2022-11-29 10:12:00     194.210        16.62  0.011110   0.015892 -0.004782
# 2022-11-29 10:13:00     194.585        16.65  0.013063   0.017726 -0.004664
# 2022-11-29 10:14:00     194.354        16.61  0.011860   0.015281 -0.003421
# 2022-11-29 10:15:00     194.000        16.59  0.010017   0.014059 -0.004042
# 2022-11-29 10:16:00     194.066        16.60  0.010360   0.014670 -0.004309
# 2022-11-29 10:17:00     194.300        16.63  0.011579   0.016504 -0.004925
# 2022-11-29 10:18:00     194.261        16.63  0.011376   0.016504 -0.005128
# 2022-11-29 10:19:00     194.057        16.61  0.010314   0.015281 -0.004968
# 2022-11-29 10:20:00     193.991        16.58  0.009970   0.013447 -0.003477
# 2022-11-29 10:21:00     194.131        16.59  0.010699   0.014059 -0.003360
# 2022-11-29 10:22:00     194.397        16.63  0.012084   0.016504 -0.004420
# 2022-11-29 10:23:00     194.490        16.63  0.012568   0.016504 -0.003936
# 2022-11-29 10:24:00     194.503        16.63  0.012636   0.016504 -0.003868
# 2022-11-29 10:25:00     194.257        16.61  0.011355   0.015281 -0.003926
# 2022-11-29 10:26:00     194.019        16.58  0.010116   0.013447 -0.003332
# 2022-11-29 10:27:00     193.830        16.56  0.009132   0.012225 -0.003093
# 2022-11-29 10:28:00     194.196        16.60  0.011037   0.014670 -0.003633
# 2022-11-29 10:29:00     193.992        16.55  0.009975   0.011614 -0.001638
# 2022-11-29 10:30:00     193.880        16.56  0.009392   0.012225 -0.002833
# 2022-11-29 10:31:00     193.502        16.55  0.007424   0.011614 -0.004190
# 2022-11-29 10:32:00     193.620        16.55  0.008038   0.011614 -0.003575
# 2022-11-29 10:33:00     193.645        16.53  0.008169   0.010391 -0.002223
# 2022-11-29 10:34:00     193.600        16.52  0.007934   0.009780 -0.001846
# 2022-11-29 10:35:00     193.739        16.54  0.008658   0.011002 -0.002344
# 2022-11-29 10:36:00     193.854        16.57  0.009257   0.012836 -0.003579
# 2022-11-29 10:37:00     193.827        16.58  0.009116   0.013447 -0.004331
# 2022-11-29 10:38:00     193.587        16.55  0.007867   0.011614 -0.003747
# 2022-11-29 10:39:00     193.808        16.53  0.009017   0.010391 -0.001374
# 2022-11-29 10:40:00     193.657        16.53  0.008231   0.010391 -0.002160
# 2022-11-29 10:41:00     193.674        16.53  0.008320   0.010391 -0.002072
# 2022-11-29 10:42:00     193.533        16.51  0.007586   0.009169 -0.001583
# 2022-11-29 10:43:00     193.637        16.55  0.008127   0.011614 -0.003487
# 2022-11-29 10:44:00     193.674        16.53  0.008320   0.010391 -0.002072
# 2022-11-29 10:45:00     193.726        16.53  0.008590   0.010391 -0.001801
# 2022-11-29 10:46:00     193.767        16.53  0.008804   0.010391 -0.001587
# 2022-11-29 10:47:00     194.234        16.56  0.011235   0.012225 -0.000990
# 2022-11-29 10:48:00     194.432        16.60  0.012266   0.014670 -0.002404
# 2022-11-29 10:49:00     194.502        16.58  0.012630   0.013447 -0.000817
# 2022-11-29 10:50:00     194.502        16.58  0.012630   0.013447 -0.000817
# 2022-11-29 10:51:00     194.600        16.63  0.013141   0.016504 -0.003363
# 2022-11-29 10:52:00     194.674        16.63  0.013526   0.016504 -0.002978
# 2022-11-29 10:53:00     194.408        16.62  0.012141   0.015892 -0.003751
# 2022-11-29 10:54:00     194.389        16.60  0.012042   0.014670 -0.002628
# 2022-11-29 10:55:00     194.539        16.60  0.012823   0.014670 -0.001847
# 2022-11-29 10:56:00     195.006        16.65  0.015254   0.017726 -0.002472
# 2022-11-29 10:57:00     194.694        16.64  0.013630   0.017115 -0.003485
# 2022-11-29 10:58:00     194.910        16.63  0.014755   0.016504 -0.001749
# 2022-11-29 10:59:00     194.700        16.63  0.013661   0.016504 -0.002842
# 2022-11-29 11:00:00     194.619        16.63  0.013240   0.016504 -0.003264
# 2022-11-29 11:01:00     194.580        16.62  0.013037   0.015892 -0.002856
# 2022-11-29 11:02:00     194.491        16.62  0.012573   0.015892 -0.003319
# 2022-11-29 11:03:00     194.968        16.65  0.015057   0.017726 -0.002670
# 2022-11-29 11:04:00     194.756        16.63  0.013953   0.016504 -0.002551
# 2022-11-29 11:05:00     194.590        16.61  0.013089   0.015281 -0.002193
# 2022-11-29 11:06:00     194.701        16.61  0.013666   0.015281 -0.001615
# 2022-11-29 11:07:00     194.567        16.60  0.012969   0.014670 -0.001701
# 2022-11-29 11:08:00     194.675        16.60  0.013531   0.014670 -0.001139
# 2022-11-29 11:09:00     194.550        16.57  0.012880   0.012836  0.000044
# 2022-11-29 11:10:00     194.392        16.60  0.012058   0.014670 -0.002612
# 2022-11-29 11:11:00     194.621        16.58  0.013250   0.013447 -0.000197
# 2022-11-29 11:12:00     194.618        16.58  0.013234   0.013447 -0.000213
# 2022-11-29 11:13:00     194.473        16.57  0.012479   0.012836 -0.000357
# 2022-11-29 11:14:00     194.618        16.58  0.013234   0.013447 -0.000213
# 2022-11-29 11:15:00     194.649        16.58  0.013396   0.013447 -0.000052
# 2022-11-29 11:16:00     194.700        16.60  0.013661   0.014670 -0.001009
# 2022-11-29 11:17:00     194.649        16.58  0.013396   0.013447 -0.000052
# 2022-11-29 11:18:00     194.500        16.58  0.012620   0.013447 -0.000827
# 2022-11-29 11:19:00     194.444        16.56  0.012328   0.012225  0.000104
# 2022-11-29 11:20:00     194.500        16.56  0.012620   0.012225  0.000395
# 2022-11-29 11:21:00     194.647        16.58  0.013385   0.013447 -0.000062
# 2022-11-29 11:22:00     194.471        16.57  0.012469   0.012836 -0.000367
# 2022-11-29 11:23:00     194.426        16.55  0.012235   0.011614  0.000621
# 2022-11-29 11:24:00     194.370        16.55  0.011943   0.011614  0.000329
# 2022-11-29 11:25:00     194.250        16.53  0.011318   0.010391  0.000927
# 2022-11-29 11:26:00     194.340        16.55  0.011787   0.011614  0.000173
# 2022-11-29 11:27:00     194.533        16.58  0.012792   0.013447 -0.000656
# 2022-11-29 11:28:00     194.524        16.58  0.012745   0.013447 -0.000702
# 2022-11-29 11:29:00     194.609        16.57  0.013187   0.012836  0.000351
# 2022-11-29 11:30:00     194.609        16.57  0.013187   0.012836  0.000351
# 2022-11-29 13:00:00     194.881        16.60  0.014604   0.014670 -0.000066
# 2022-11-29 13:01:00     194.749        16.58  0.013916   0.013447  0.000469
# 2022-11-29 13:02:00     194.870        16.57  0.014546   0.012836  0.001710
# 2022-11-29 13:03:00     195.062        16.59  0.015546   0.014059  0.001487
# 2022-11-29 13:04:00     194.902        16.60  0.014713   0.014670  0.000043
# 2022-11-29 13:05:00     194.701        16.58  0.013666   0.013447  0.000219
# 2022-11-29 13:06:00     194.697        16.55  0.013646   0.011614  0.002032
# 2022-11-29 13:07:00     194.729        16.57  0.013812   0.012836  0.000976
# 2022-11-29 13:08:00     194.805        16.58  0.014208   0.013447  0.000760
# 2022-11-29 13:09:00     194.909        16.57  0.014749   0.012836  0.001913
# 2022-11-29 13:10:00     194.900        16.57  0.014703   0.012836  0.001866
# 2022-11-29 13:11:00     194.802        16.57  0.014192   0.012836  0.001356
# 2022-11-29 13:12:00     194.612        16.56  0.013203   0.012225  0.000978
# 2022-11-29 13:13:00     194.500        16.55  0.012620   0.011614  0.001006
# 2022-11-29 13:14:00     194.437        16.54  0.012292   0.011002  0.001290
# 2022-11-29 13:15:00     194.695        16.55  0.013635   0.011614  0.002022
# 2022-11-29 13:16:00     194.650        16.52  0.013401   0.009780  0.003621
# 2022-11-29 13:17:00     194.360        16.51  0.011891   0.009169  0.002722
# 2022-11-29 13:18:00     194.363        16.50  0.011907   0.008557  0.003349
# 2022-11-29 13:19:00     194.415        16.52  0.012177   0.009780  0.002398
# 2022-11-29 13:20:00     194.262        16.52  0.011381   0.009780  0.001601
# 2022-11-29 13:21:00     194.250        16.48  0.011318   0.007335  0.003983
# 2022-11-29 13:22:00     194.240        16.49  0.011266   0.007946  0.003320
# 2022-11-29 13:23:00     194.292        16.49  0.011537   0.007946  0.003591
# 2022-11-29 13:24:00     194.300        16.50  0.011579   0.008557  0.003021
# 2022-11-29 13:25:00     194.283        16.48  0.011490   0.007335  0.004155
# 2022-11-29 13:26:00     194.150        16.50  0.010798   0.008557  0.002240
# 2022-11-29 13:27:00     194.321        16.49  0.011688   0.007946  0.003742
# 2022-11-29 13:28:00     194.400        16.52  0.012099   0.009780  0.002319
# 2022-11-29 13:29:00     194.348        16.54  0.011829   0.011002  0.000826
# 2022-11-29 13:30:00     194.250        16.53  0.011318   0.010391  0.000927
# 2022-11-29 13:31:00     194.201        16.51  0.011063   0.009169  0.001895
# 2022-11-29 13:32:00     194.568        16.55  0.012974   0.011614  0.001360
# 2022-11-29 13:33:00     194.411        16.53  0.012157   0.010391  0.001765
# 2022-11-29 13:34:00     194.324        16.53  0.011704   0.010391  0.001313
# 2022-11-29 13:35:00     194.365        16.53  0.011917   0.010391  0.001526
# 2022-11-29 13:36:00     194.325        16.52  0.011709   0.009780  0.001929
# 2022-11-29 13:37:00     194.268        16.54  0.011412   0.011002  0.000410
# 2022-11-29 13:38:00     194.268        16.53  0.011412   0.010391  0.001021
# 2022-11-29 13:39:00     194.142        16.54  0.010756   0.011002 -0.000246
# 2022-11-29 13:40:00     194.204        16.54  0.011079   0.011002  0.000077
# 2022-11-29 13:41:00     194.300        16.55  0.011579   0.011614 -0.000035
# 2022-11-29 13:42:00     194.369        16.55  0.011938   0.011614  0.000324
# 2022-11-29 13:43:00     194.300        16.54  0.011579   0.011002  0.000576
# 2022-11-29 13:44:00     194.379        16.53  0.011990   0.010391  0.001599
# 2022-11-29 13:45:00     194.300        16.53  0.011579   0.010391  0.001188
# 2022-11-29 13:46:00     194.250        16.54  0.011318   0.011002  0.000316
# 2022-11-29 13:47:00     194.234        16.55  0.011235   0.011614 -0.000379
# 2022-11-29 13:48:00     194.365        16.54  0.011917   0.011002  0.000915
# 2022-11-29 13:49:00     194.340        16.54  0.011787   0.011002  0.000785
# 2022-11-29 13:50:00     194.250        16.54  0.011318   0.011002  0.000316
# 2022-11-29 13:51:00     194.234        16.53  0.011235   0.010391  0.000844
# 2022-11-29 13:52:00     194.234        16.51  0.011235   0.009169  0.002066
# 2022-11-29 13:53:00     194.270        16.51  0.011423   0.009169  0.002254
# 2022-11-29 13:54:00     194.271        16.52  0.011428   0.009780  0.001648
# 2022-11-29 13:55:00     194.420        16.52  0.012204   0.009780  0.002424
# 2022-11-29 13:56:00     194.364        16.53  0.011912   0.010391  0.001521
# 2022-11-29 13:57:00     194.860        16.55  0.014494   0.011614  0.002881
# 2022-11-29 13:58:00     194.670        16.55  0.013505   0.011614  0.001891
# 2022-11-29 13:59:00     194.525        16.53  0.012750   0.010391  0.002359
# 2022-11-29 14:00:00     194.401        16.53  0.012105   0.010391  0.001713
# 2022-11-29 14:01:00     194.500        16.53  0.012620   0.010391  0.002229
# 2022-11-29 14:02:00     194.550        16.53  0.012880   0.010391  0.002489
# 2022-11-29 14:03:00     194.580        16.53  0.013037   0.010391  0.002645
# 2022-11-29 14:04:00     194.500        16.55  0.012620   0.011614  0.001006
# 2022-11-29 14:05:00     194.570        16.55  0.012984   0.011614  0.001371
# 2022-11-29 14:06:00     194.510        16.54  0.012672   0.011002  0.001670
# 2022-11-29 14:07:00     194.526        16.54  0.012755   0.011002  0.001753
# 2022-11-29 14:08:00     194.441        16.55  0.012313   0.011614  0.000699
# 2022-11-29 14:09:00     194.635        16.55  0.013323   0.011614  0.001709
# 2022-11-29 14:10:00     194.847        16.57  0.014427   0.012836  0.001590
# 2022-11-29 14:11:00     194.844        16.60  0.014411   0.014670 -0.000259
# 2022-11-29 14:12:00     194.714        16.60  0.013734   0.014670 -0.000936
# 2022-11-29 14:13:00     194.591        16.59  0.013094   0.014059 -0.000965
# 2022-11-29 14:14:00     194.704        16.58  0.013682   0.013447  0.000235
# 2022-11-29 14:15:00     194.780        16.58  0.014078   0.013447  0.000630
# 2022-11-29 14:16:00     194.777        16.57  0.014062   0.012836  0.001226
# 2022-11-29 14:17:00     194.662        16.57  0.013463   0.012836  0.000627
# 2022-11-29 14:18:00     194.699        16.58  0.013656   0.013447  0.000209
# 2022-11-29 14:19:00     194.618        16.56  0.013234   0.012225  0.001009
# 2022-11-29 14:20:00     194.685        16.56  0.013583   0.012225  0.001358
# 2022-11-29 14:21:00     194.669        16.55  0.013500   0.011614  0.001886
# 2022-11-29 14:22:00     194.600        16.55  0.013141   0.011614  0.001527
# 2022-11-29 14:23:00     194.610        16.55  0.013193   0.011614  0.001579
# 2022-11-29 14:24:00     194.630        16.57  0.013297   0.012836  0.000461
# 2022-11-29 14:25:00     194.680        16.57  0.013557   0.012836  0.000721
# 2022-11-29 14:26:00     194.631        16.58  0.013302   0.013447 -0.000145
# 2022-11-29 14:27:00     194.745        16.60  0.013896   0.014670 -0.000774
# 2022-11-29 14:28:00     194.900        16.59  0.014703   0.014059  0.000644
# 2022-11-29 14:29:00     194.830        16.59  0.014338   0.014059  0.000279
# 2022-11-29 14:30:00     194.779        16.59  0.014073   0.014059  0.000014
# 2022-11-29 14:31:00     194.770        16.60  0.014026   0.014670 -0.000644
# 2022-11-29 14:32:00     194.900        16.60  0.014703   0.014670  0.000033
# 2022-11-29 14:33:00     194.990        16.59  0.015171   0.014059  0.001112
# 2022-11-29 14:34:00     194.997        16.60  0.015208   0.014670  0.000538
# 2022-11-29 14:35:00     194.912        16.61  0.014765   0.015281 -0.000516
# 2022-11-29 14:36:00     194.893        16.62  0.014666   0.015892 -0.001226
# 2022-11-29 14:37:00     194.843        16.63  0.014406   0.016504 -0.002098
# 2022-11-29 14:38:00     194.896        16.63  0.014682   0.016504 -0.001822
# 2022-11-29 14:39:00     194.981        16.62  0.015124   0.015892 -0.000768
# 2022-11-29 14:40:00     194.890        16.63  0.014650   0.016504 -0.001853
# 2022-11-29 14:41:00     194.868        16.63  0.014536   0.016504 -0.001968
# 2022-11-29 14:42:00     194.936        16.64  0.014890   0.017115 -0.002225
# 2022-11-29 14:43:00     194.846        16.69  0.014421   0.020171 -0.005750
# 2022-11-29 14:44:00     195.040        16.70  0.015431   0.020782 -0.005351
# 2022-11-29 14:45:00     194.992        16.69  0.015181   0.020171 -0.004990
# 2022-11-29 14:46:00     194.931        16.70  0.014864   0.020782 -0.005918
# 2022-11-29 14:47:00     195.150        16.69  0.016004   0.020171 -0.004167
# 2022-11-29 14:48:00     195.000        16.68  0.015223   0.019560 -0.004337
# 2022-11-29 14:49:00     195.190        16.66  0.016212   0.018337 -0.002125
# 2022-11-29 14:50:00     195.006        16.66  0.015254   0.018337 -0.003083
# 2022-11-29 14:51:00     195.151        16.65  0.016009   0.017726 -0.001717
# 2022-11-29 14:52:00     195.200        16.66  0.016264   0.018337 -0.002073
# 2022-11-29 14:53:00     195.197        16.65  0.016249   0.017726 -0.001477
# 2022-11-29 14:54:00     195.201        16.64  0.016270   0.017115 -0.000845
# 2022-11-29 14:55:00     195.353        16.66  0.017061   0.018337 -0.001276
# 2022-11-29 14:56:00     194.991        16.69  0.015176   0.020171 -0.004995
# 2022-11-29 14:57:00     194.811        16.68  0.014239   0.019560 -0.005321
# 2022-11-29 14:58:00     194.811        16.68  0.014239   0.019560 -0.005321
# 2022-11-29 14:59:00     194.811        16.68  0.014239   0.019560 -0.005321
# 2022-11-29 15:00:00     195.205        16.68  0.016290   0.019560 -0.003269
#
#                      bond_pos  stock_pos  premium rate
# 2022-11-28 15:00:00       0.0        0.0      0.039042
# 2022-11-29 09:30:00       0.0        0.0      0.039191
# 2022-11-29 09:31:00       0.0        0.0      0.039123
# 2022-11-29 09:32:00       0.0        0.0      0.039652
# 2022-11-29 09:33:00       0.0        0.0      0.040010
# 2022-11-29 09:34:00       0.0        0.0      0.040741
# 2022-11-29 09:35:00       0.0        0.0      0.043737
# 2022-11-29 09:36:00       0.0        0.0      0.042959
# 2022-11-29 09:37:00       0.0        0.0      0.041509
# 2022-11-29 09:38:00       0.0        0.0      0.041399
# 2022-11-29 09:39:00       0.0        0.0      0.039751
# 2022-11-29 09:40:00       0.0        0.0      0.040131
# 2022-11-29 09:41:00       0.0        0.0      0.041276
# 2022-11-29 09:42:00       0.0        0.0      0.040687
# 2022-11-29 09:43:00       0.0        0.0      0.039092
# 2022-11-29 09:44:00       0.0        0.0      0.037977
# 2022-11-29 09:45:00       0.0        0.0      0.039872
# 2022-11-29 09:46:00       0.0        0.0      0.036923
# 2022-11-29 09:47:00       0.0        0.0      0.038327
# 2022-11-29 09:48:00       0.0        0.0      0.038436
# 2022-11-29 09:49:00       0.0        0.0      0.039112
# 2022-11-29 09:50:00       0.0        0.0      0.037438
# 2022-11-29 09:51:00       0.0        0.0      0.037000
# 2022-11-29 09:52:00       0.0        0.0      0.039290
# 2022-11-29 09:53:00       0.0        0.0      0.039705
# 2022-11-29 09:54:00       0.0        0.0      0.039538
# 2022-11-29 09:55:00       0.0        0.0      0.037022
# 2022-11-29 09:56:00       0.0        0.0      0.037658
# 2022-11-29 09:57:00       0.0        0.0      0.036286
# 2022-11-29 09:58:00       0.0        0.0      0.035889
# 2022-11-29 09:59:00       0.0        0.0      0.038039
# 2022-11-29 10:00:00       0.0        0.0      0.036769
# 2022-11-29 10:01:00       0.0        0.0      0.038729
# 2022-11-29 10:02:00       0.0        0.0      0.034622
# 2022-11-29 10:03:00       0.0        0.0      0.034511
# 2022-11-29 10:04:00       0.0        0.0      0.030996
# 2022-11-29 10:05:00       0.0        0.0      0.029943
# 2022-11-29 10:06:00       0.0        0.0      0.030371
# 2022-11-29 10:07:00       0.0        0.0      0.032457
# 2022-11-29 10:08:00       0.0        0.0      0.032907
# 2022-11-29 10:09:00       0.0        0.0      0.033333
# 2022-11-29 10:10:00       0.0        0.0      0.031945
# 2022-11-29 10:11:00       0.0        0.0      0.033133
# 2022-11-29 10:12:00       0.0        0.0      0.034151
# 2022-11-29 10:13:00       0.0        0.0      0.034281
# 2022-11-29 10:14:00       0.0        0.0      0.035541
# 2022-11-29 10:15:00       0.0        0.0      0.034901
# 2022-11-29 10:16:00       0.0        0.0      0.034629
# 2022-11-29 10:17:00       0.0        0.0      0.034008
# 2022-11-29 10:18:00       0.0        0.0      0.033800
# 2022-11-29 10:19:00       0.0        0.0      0.033958
# 2022-11-29 10:20:00       0.0        0.0      0.035477
# 2022-11-29 10:21:00       0.0        0.0      0.035599
# 2022-11-29 10:22:00       0.0        0.0      0.034524
# 2022-11-29 10:23:00       0.0        0.0      0.035019
# 2022-11-29 10:24:00       0.0        0.0      0.035088
# 2022-11-29 10:25:00       0.0        0.0      0.035024
# 2022-11-29 10:26:00       0.0        0.0      0.035626
# 2022-11-29 10:27:00       0.0        0.0      0.035867
# 2022-11-29 10:28:00       0.0        0.0      0.035322
# 2022-11-29 10:29:00       0.0        0.0      0.037359
# 2022-11-29 10:30:00       0.0        0.0      0.036134
# 2022-11-29 10:31:00       0.0        0.0      0.034739
# 2022-11-29 10:32:00       0.0        0.0      0.035370
# 2022-11-29 10:33:00       0.0        0.0      0.036756
# 2022-11-29 10:34:00       0.0        0.0      0.037143
# 2022-11-29 10:35:00       0.0        0.0      0.036632
# 2022-11-29 10:36:00       0.0        0.0      0.035370
# 2022-11-29 10:37:00       0.0        0.0      0.034601
# 2022-11-29 10:38:00       0.0        0.0      0.035193
# 2022-11-29 10:39:00       0.0        0.0      0.037629
# 2022-11-29 10:40:00       0.0        0.0      0.036821
# 2022-11-29 10:41:00       0.0        0.0      0.036912
# 2022-11-29 10:42:00       0.0        0.0      0.037412
# 2022-11-29 10:43:00       0.0        0.0      0.035461
# 2022-11-29 10:44:00       0.0        0.0      0.036912
# 2022-11-29 10:45:00       0.0        0.0      0.037190
# 2022-11-29 10:46:00       0.0        0.0      0.037410
# 2022-11-29 10:47:00       0.0        0.0      0.038026
# 2022-11-29 10:48:00       0.0        0.0      0.036580
# 2022-11-29 10:49:00       0.0        0.0      0.038204
# 2022-11-29 10:50:00       0.0        0.0      0.038204
# 2022-11-29 10:51:00       0.0        0.0      0.035604
# 2022-11-29 10:52:00       0.0        0.0      0.035998
# 2022-11-29 10:53:00       0.0        0.0      0.035205
# 2022-11-29 10:54:00       0.0        0.0      0.036351
# 2022-11-29 10:55:00       0.0        0.0      0.037151
# 2022-11-29 10:56:00       0.0        0.0      0.036518
# 2022-11-29 10:57:00       0.0        0.0      0.035482
# 2022-11-29 10:58:00       0.0        0.0      0.037254
# 2022-11-29 10:59:00       0.0        0.0      0.036137
# 2022-11-29 11:00:00       0.0        0.0      0.035705
# 2022-11-29 11:01:00       0.0        0.0      0.036121
# 2022-11-29 11:02:00       0.0        0.0      0.035647
# 2022-11-29 11:03:00       0.0        0.0      0.036316
# 2022-11-29 11:04:00       0.0        0.0      0.036435
# 2022-11-29 11:05:00       0.0        0.0      0.036798
# 2022-11-29 11:06:00       0.0        0.0      0.037389
# 2022-11-29 11:07:00       0.0        0.0      0.037300
# 2022-11-29 11:08:00       0.0        0.0      0.037876
# 2022-11-29 11:09:00       0.0        0.0      0.039087
# 2022-11-29 11:10:00       0.0        0.0      0.036367
# 2022-11-29 11:11:00       0.0        0.0      0.038839
# 2022-11-29 11:12:00       0.0        0.0      0.038823
# 2022-11-29 11:13:00       0.0        0.0      0.038676
# 2022-11-29 11:14:00       0.0        0.0      0.038823
# 2022-11-29 11:15:00       0.0        0.0      0.038989
# 2022-11-29 11:16:00       0.0        0.0      0.038009
# 2022-11-29 11:17:00       0.0        0.0      0.038989
# 2022-11-29 11:18:00       0.0        0.0      0.038194
# 2022-11-29 11:19:00       0.0        0.0      0.039148
# 2022-11-29 11:20:00       0.0        0.0      0.039447
# 2022-11-29 11:21:00       0.0        0.0      0.038978
# 2022-11-29 11:22:00       0.0        0.0      0.038665
# 2022-11-29 11:23:00       0.0        0.0      0.039680
# 2022-11-29 11:24:00       0.0        0.0      0.039380
# 2022-11-29 11:25:00       0.0        0.0      0.039995
# 2022-11-29 11:26:00       0.0        0.0      0.039220
# 2022-11-29 11:27:00       0.0        0.0      0.038370
# 2022-11-29 11:28:00       0.0        0.0      0.038322
# 2022-11-29 11:29:00       0.0        0.0      0.039402
# 2022-11-29 11:30:00       0.0        0.0      0.039402
# 2022-11-29 13:00:00       0.0        0.0      0.038974
# 2022-11-29 13:01:00       0.0        0.0      0.039523
# 2022-11-29 13:02:00       0.0        0.0      0.040796
# 2022-11-29 13:03:00       0.0        0.0      0.040566
# 2022-11-29 13:04:00       0.0        0.0      0.039086
# 2022-11-29 13:05:00       0.0        0.0      0.039266
# 2022-11-29 13:06:00       0.0        0.0      0.041129
# 2022-11-29 13:07:00       0.0        0.0      0.040043
# 2022-11-29 13:08:00       0.0        0.0      0.039822
# 2022-11-29 13:09:00       0.0        0.0      0.041005
# 2022-11-29 13:10:00       0.0        0.0      0.040957
# 2022-11-29 13:11:00       0.0        0.0      0.040433
# 2022-11-29 13:12:00       0.0        0.0      0.040046
# 2022-11-29 13:13:00       0.0        0.0      0.040076
# 2022-11-29 13:14:00       0.0        0.0      0.040367
# 2022-11-29 13:15:00       0.0        0.0      0.041118
# 2022-11-29 13:16:00       0.0        0.0      0.042768
# 2022-11-29 13:17:00       0.0        0.0      0.041845
# 2022-11-29 13:18:00       0.0        0.0      0.042492
# 2022-11-29 13:19:00       0.0        0.0      0.041509
# 2022-11-29 13:20:00       0.0        0.0      0.040689
# 2022-11-29 13:21:00       0.0        0.0      0.043151
# 2022-11-29 13:22:00       0.0        0.0      0.042465
# 2022-11-29 13:23:00       0.0        0.0      0.042744
# 2022-11-29 13:24:00       0.0        0.0      0.042155
# 2022-11-29 13:25:00       0.0        0.0      0.043328
# 2022-11-29 13:26:00       0.0        0.0      0.041350
# 2022-11-29 13:27:00       0.0        0.0      0.042899
# 2022-11-29 13:28:00       0.0        0.0      0.041429
# 2022-11-29 13:29:00       0.0        0.0      0.039891
# 2022-11-29 13:30:00       0.0        0.0      0.039995
# 2022-11-29 13:31:00       0.0        0.0      0.040993
# 2022-11-29 13:32:00       0.0        0.0      0.040439
# 2022-11-29 13:33:00       0.0        0.0      0.040857
# 2022-11-29 13:34:00       0.0        0.0      0.040392
# 2022-11-29 13:35:00       0.0        0.0      0.040611
# 2022-11-29 13:36:00       0.0        0.0      0.041027
# 2022-11-29 13:37:00       0.0        0.0      0.039463
# 2022-11-29 13:38:00       0.0        0.0      0.040092
# 2022-11-29 13:39:00       0.0        0.0      0.038789
# 2022-11-29 13:40:00       0.0        0.0      0.039121
# 2022-11-29 13:41:00       0.0        0.0      0.039006
# 2022-11-29 13:42:00       0.0        0.0      0.039375
# 2022-11-29 13:43:00       0.0        0.0      0.039634
# 2022-11-29 13:44:00       0.0        0.0      0.040686
# 2022-11-29 13:45:00       0.0        0.0      0.040263
# 2022-11-29 13:46:00       0.0        0.0      0.039367
# 2022-11-29 13:47:00       0.0        0.0      0.038653
# 2022-11-29 13:48:00       0.0        0.0      0.039982
# 2022-11-29 13:49:00       0.0        0.0      0.039848
# 2022-11-29 13:50:00       0.0        0.0      0.039367
# 2022-11-29 13:51:00       0.0        0.0      0.039910
# 2022-11-29 13:52:00       0.0        0.0      0.041170
# 2022-11-29 13:53:00       0.0        0.0      0.041363
# 2022-11-29 13:54:00       0.0        0.0      0.040737
# 2022-11-29 13:55:00       0.0        0.0      0.041536
# 2022-11-29 13:56:00       0.0        0.0      0.040606
# 2022-11-29 13:57:00       0.0        0.0      0.042001
# 2022-11-29 13:58:00       0.0        0.0      0.040985
# 2022-11-29 13:59:00       0.0        0.0      0.041468
# 2022-11-29 14:00:00       0.0        0.0      0.040804
# 2022-11-29 14:01:00       0.0        0.0      0.041334
# 2022-11-29 14:02:00       0.0        0.0      0.041602
# 2022-11-29 14:03:00       0.0        0.0      0.041762
# 2022-11-29 14:04:00       0.0        0.0      0.040076
# 2022-11-29 14:05:00       0.0        0.0      0.040450
# 2022-11-29 14:06:00       0.0        0.0      0.040758
# 2022-11-29 14:07:00       0.0        0.0      0.040843
# 2022-11-29 14:08:00       0.0        0.0      0.039760
# 2022-11-29 14:09:00       0.0        0.0      0.040797
# 2022-11-29 14:10:00       0.0        0.0      0.040673
# 2022-11-29 14:11:00       0.0        0.0      0.038777
# 2022-11-29 14:12:00       0.0        0.0      0.038084
# 2022-11-29 14:13:00       0.0        0.0      0.038053
# 2022-11-29 14:14:00       0.0        0.0      0.039283
# 2022-11-29 14:15:00       0.0        0.0      0.039688
# 2022-11-29 14:16:00       0.0        0.0      0.040300
# 2022-11-29 14:17:00       0.0        0.0      0.039685
# 2022-11-29 14:18:00       0.0        0.0      0.039256
# 2022-11-29 14:19:00       0.0        0.0      0.040078
# 2022-11-29 14:20:00       0.0        0.0      0.040436
# 2022-11-29 14:21:00       0.0        0.0      0.040979
# 2022-11-29 14:22:00       0.0        0.0      0.040610
# 2022-11-29 14:23:00       0.0        0.0      0.040664
# 2022-11-29 14:24:00       0.0        0.0      0.039514
# 2022-11-29 14:25:00       0.0        0.0      0.039782
# 2022-11-29 14:26:00       0.0        0.0      0.038893
# 2022-11-29 14:27:00       0.0        0.0      0.038249
# 2022-11-29 14:28:00       0.0        0.0      0.039702
# 2022-11-29 14:29:00       0.0        0.0      0.039328
# 2022-11-29 14:30:00       0.0        0.0      0.039056
# 2022-11-29 14:31:00       0.0        0.0      0.038382
# 2022-11-29 14:32:00       0.0        0.0      0.039075
# 2022-11-29 14:33:00       0.0        0.0      0.040182
# 2022-11-29 14:34:00       0.0        0.0      0.039592
# 2022-11-29 14:35:00       0.0        0.0      0.038514
# 2022-11-29 14:36:00       0.0        0.0      0.037788
# 2022-11-29 14:37:00       0.0        0.0      0.036898
# 2022-11-29 14:38:00       0.0        0.0      0.037180
# 2022-11-29 14:39:00       0.0        0.0      0.038256
# 2022-11-29 14:40:00       0.0        0.0      0.037148
# 2022-11-29 14:41:00       0.0        0.0      0.037031
# 2022-11-29 14:42:00       0.0        0.0      0.036769
# 2022-11-29 14:43:00       0.0        0.0      0.033186
# 2022-11-29 14:44:00       0.0        0.0      0.033595
# 2022-11-29 14:45:00       0.0        0.0      0.033960
# 2022-11-29 14:46:00       0.0        0.0      0.033018
# 2022-11-29 14:47:00       0.0        0.0      0.034798
# 2022-11-29 14:48:00       0.0        0.0      0.034622
# 2022-11-29 14:49:00       0.0        0.0      0.036874
# 2022-11-29 14:50:00       0.0        0.0      0.035896
# 2022-11-29 14:51:00       0.0        0.0      0.037289
# 2022-11-29 14:52:00       0.0        0.0      0.036927
# 2022-11-29 14:53:00       0.0        0.0      0.037534
# 2022-11-29 14:54:00       0.0        0.0      0.038178
# 2022-11-29 14:55:00       0.0        0.0      0.037740
# 2022-11-29 14:56:00       0.0        0.0      0.033955
# 2022-11-29 14:57:00       0.0        0.0      0.033620
# 2022-11-29 14:58:00       0.0        0.0      0.033620
# 2022-11-29 14:59:00       0.0        0.0      0.033620
# 2022-11-29 15:00:00       0.0        0.0      0.035710

# %%
# 到期时间很短，且价内50%的时候，转债近似等价于正股
def cal_premium_rate(bond_price,stock_price,convert_price):
    tmp = 100/convert_price*stock_price
    res = (bond_price - tmp)/tmp
    return res
cal_premium_rate(200,140,70)
# Out:
# 0.0
