# %% [markdown]
# # import data

# %%
from WindPy import *

#Wind API 使用W账户密码登录
w.start() 

#return True and then can go to next operation.
w.isconnected()

import pandas as pd
# Out:
# 22.11.1.52440
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2021 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
# w.wsi("123046.SZ,300587.SZ,113642.SH,603185.SH,110061.SH,600674.SH,128081.SZ,002203.SZ,113016.SH,601127.SH,128017.SZ,002597.SZ",  "close",  "2022-09-06 09:00:00",  "2022-09-09 16:28:08",  "")

# %%
cbond_list = ['123046.SZ','300587.SZ',
# '113642.SH','603185.SH', #转债已退市
'110061.SH','600674.SH',
'128081.SZ','002203.SZ',
'113016.SH','601127.SH',
'128017.SZ','002597.SZ',
'113537.SH','603348.SH',
'123027.SZ','300487.SZ', #转债已退市
'113534.SH','603876.SH',
'113025.SH','601677.SH',
'123031.SZ','300655.SZ',
'128029.SZ','002078.SZ',
'128111.SZ','002738.SZ', #2022-10-14新增4个对子
'128095.SZ','002812.SZ',
'113626.SH','603596.SH',
'123092.SZ','300332.SZ',
'123057.SZ','300586.SZ',#2020-11-18新增3个对子
'123067.SZ','300382.SZ',
'128106.SZ','002840.SZ',
]

# %% [markdown]
# # history trade days

# %%
# ###############################################################
# before_trade_date = '20220908'#监测当日前一个交易日
# present_date = '20220909' #监测当日
# next_trade_date = '20220910' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220909'#监测当日前一个交易日
# present_date = '20220913' #监测当日
# next_trade_date = '20220914' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220913'#监测当日前一个交易日
# present_date = '20220914' #监测当日
# next_trade_date = '20220915' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220914'#监测当日前一个交易日
# present_date = '20220915' #监测当日
# next_trade_date = '20220916' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220915'#监测当日前一个交易日
# present_date = '20220916' #监测当日
# next_trade_date = '20220917' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220916'#监测当日前一个交易日
# present_date = '20220919' #监测当日
# next_trade_date = '20220920' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220919'#监测当日前一个交易日
# present_date = '20220920' #监测当日
# next_trade_date = '20220921' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220920'#监测当日前一个交易日
# present_date = '20220921' #监测当日
# next_trade_date = '20220922' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220921'#监测当日前一个交易日
# present_date = '20220922' #监测当日
# next_trade_date = '20220923' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220922'#监测当日前一个交易日
# present_date = '20220923' #监测当日
# next_trade_date = '20220924' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220923'#监测当日前一个交易日
# present_date = '20220926' #监测当日
# next_trade_date = '20220927' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220926'#监测当日前一个交易日
# present_date = '20220927' #监测当日
# next_trade_date = '20220928' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220927'#监测当日前一个交易日
# present_date = '20220928' #监测当日
# next_trade_date = '20220929' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220928'#监测当日前一个交易日
# present_date = '20220929' #监测当日
# next_trade_date = '20220930' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220929'#监测当日前一个交易日
# present_date = '20220930' #监测当日
# next_trade_date = '20221001' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20220930'#监测当日前一个交易日
# present_date = '20221010' #监测当日
# next_trade_date = '20221011' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221010'#监测当日前一个交易日
# present_date = '20221011' #监测当日
# next_trade_date = '20221012' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221011'#监测当日前一个交易日
# present_date = '20221012' #监测当日
# next_trade_date = '20221013' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221012'#监测当日前一个交易日
# present_date = '20221013' #监测当日
# next_trade_date = '20221014' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221013'#监测当日前一个交易日
# present_date = '20221014' #监测当日
# next_trade_date = '20221015' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221014'#监测当日前一个交易日
# present_date = '20221017' #监测当日
# next_trade_date = '20221018' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221017'#监测当日前一个交易日
# present_date = '20221018' #监测当日
# next_trade_date = '20221019' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221018'#监测当日前一个交易日
# present_date = '20221019' #监测当日
# next_trade_date = '20221020' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221019'#监测当日前一个交易日
# present_date = '20221020' #监测当日
# next_trade_date = '20221021' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221020'#监测当日前一个交易日
# present_date = '20221021' #监测当日
# next_trade_date = '20221022' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221021'#监测当日前一个交易日
# present_date = '20221024' #监测当日
# next_trade_date = '20221025' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221024'#监测当日前一个交易日
# present_date = '20221025' #监测当日
# next_trade_date = '20221026' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221025'#监测当日前一个交易日
# present_date = '20221026' #监测当日
# next_trade_date = '20221027' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221026'#监测当日前一个交易日
# present_date = '20221027' #监测当日
# next_trade_date = '20221028' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221027'#监测当日前一个交易日
# present_date = '20221028' #监测当日
# next_trade_date = '20221029' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221028'#监测当日前一个交易日
# present_date = '20221031' #监测当日
# next_trade_date = '20221101' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221031'#监测当日前一个交易日
# present_date = '20221101' #监测当日
# next_trade_date = '20221102' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221101'#监测当日前一个交易日
# present_date = '20221102' #监测当日
# next_trade_date = '20221103' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221102'#监测当日前一个交易日
# present_date = '20221103' #监测当日
# next_trade_date = '20221104' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221103'#监测当日前一个交易日
# present_date = '20221104' #监测当日
# next_trade_date = '20221105' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221104'#监测当日前一个交易日
# present_date = '20221107' #监测当日
# next_trade_date = '20221108' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221107'#监测当日前一个交易日
# present_date = '20221108' #监测当日
# next_trade_date = '20221109' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221108'#监测当日前一个交易日
# present_date = '20221109' #监测当日
# next_trade_date = '20221110' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221109'#监测当日前一个交易日
# present_date = '20221110' #监测当日
# next_trade_date = '20221111' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221110'#监测当日前一个交易日
# present_date = '20221111' #监测当日
# next_trade_date = '20221112' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221111'#监测当日前一个交易日
# present_date = '20221114' #监测当日
# next_trade_date = '20221115' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221114'#监测当日前一个交易日
# present_date = '20221115' #监测当日
# next_trade_date = '20221116' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221115'#监测当日前一个交易日
# present_date = '20221116' #监测当日
# next_trade_date = '20221117' #监测当日下一个自然日
# ###############################################################

# %%
# ###############################################################
# before_trade_date = '20221116'#监测当日前一个交易日
# present_date = '20221117' #监测当日
# next_trade_date = '20221118' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221117'#监测当日前一个交易日
# present_date = '20221118' #监测当日
# next_trade_date = '20221119' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221118'#监测当日前一个交易日
# present_date = '20221121' #监测当日
# next_trade_date = '20221122' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221121'#监测当日前一个交易日
# present_date = '20221122' #监测当日
# next_trade_date = '20221123' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221122'#监测当日前一个交易日
# present_date = '20221123' #监测当日
# next_trade_date = '20221124' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221123'#监测当日前一个交易日
# present_date = '20221124' #监测当日
# next_trade_date = '20221125' #监测当日下一个自然日
# ###############################################################

# ###############################################################
# before_trade_date = '20221124'#监测当日前一个交易日
# present_date = '20221125' #监测当日
# next_trade_date = '20221126' #监测当日下一个自然日
# ###############################################################

# ###############################################################
before_trade_date = '20221125'#监测当日前一个交易日
present_date = '20221128' #监测当日
next_trade_date = '20221129' #监测当日下一个自然日
# ###############################################################

# %%
start_date = pd.to_datetime(before_trade_date) 
end_date = pd.to_datetime(next_trade_date)

cbond_price = pd.DataFrame([])
for code in cbond_list:
    price_df = w.wsi(code, "close", start_date, end_date,usedf=True)[1]   #只要了收盘价
    price_df.columns = [code]
    cbond_price = pd.concat([cbond_price,price_df],axis=1)
cbond_price = cbond_price.ffill()    
# cbond_rtn = cbond_price[cbond_price.index.time!=time(15,0,0)]
# cbond_price = cbond_price.loc['2022-09-09 15:00:00':] #从前一个交易日的收盘价开始截取
cbond_price_begin_time = before_trade_date[:4]+'-' + \
                    before_trade_date[4:6]+'-' + \
                    before_trade_date[6:8]+' 15:00:00'
cbond_price = cbond_price.loc[cbond_price_begin_time:]
cbond_price
# Out:
#                      123046.SZ  300587.SZ  110061.SH  600674.SH  128081.SZ  \
# 2022-11-25 15:00:00    368.500      12.90    136.604      11.95    126.699
# 2022-11-28 09:30:00    365.540      12.73    136.132      11.91    125.517
# 2022-11-28 09:31:00    366.220      12.79    136.000      11.89    125.792
# 2022-11-28 09:32:00    367.205      12.79    135.877      11.91    126.028
# 2022-11-28 09:33:00    364.926      12.70    136.041      11.93    126.070
# ...                        ...        ...        ...        ...        ...
# 2022-11-28 14:56:00    360.004      12.69    136.736      12.01    127.139
# 2022-11-28 14:57:00    360.004      12.68    136.800      12.00    127.139
# 2022-11-28 14:58:00    360.004      12.68    136.880      12.00    127.139
# 2022-11-28 14:59:00    360.004      12.68    136.500      12.00    127.139
# 2022-11-28 15:00:00    361.300      12.69    136.605      12.00    127.190
#
#                      002203.SZ  113016.SH  601127.SH  128017.SZ  002597.SZ  \
# 2022-11-25 15:00:00      12.09    319.743      45.80    181.080      34.48
# 2022-11-28 09:30:00      11.93    312.100      44.28    177.071      33.32
# 2022-11-28 09:31:00      11.97    316.000      44.64    176.475      33.39
# 2022-11-28 09:32:00      11.99    316.346      44.95    178.001      33.59
# 2022-11-28 09:33:00      12.01    315.145      44.59    176.760      33.40
# ...                        ...        ...        ...        ...        ...
# 2022-11-28 14:56:00      12.17    312.821      45.10    177.322      33.63
# 2022-11-28 14:57:00      12.16    312.998      45.10    177.996      33.63
# 2022-11-28 14:58:00      12.16    313.021      45.10    177.996      33.63
# 2022-11-28 14:59:00      12.16    313.280      45.10    177.996      33.63
# 2022-11-28 15:00:00      12.17    313.143      45.12    177.995      33.65
#
#                      ...  113626.SH  603596.SH  123092.SZ  300332.SZ  \
# 2022-11-25 15:00:00  ...    219.255      78.71    268.400      13.19
# 2022-11-28 09:30:00  ...    218.046      78.25    267.876      13.02
# 2022-11-28 09:31:00  ...    219.002      78.76    267.648      13.14
# 2022-11-28 09:32:00  ...    218.971      78.97    268.937      13.14
# 2022-11-28 09:33:00  ...    219.894      79.25    266.836      13.09
# ...                  ...        ...        ...        ...        ...
# 2022-11-28 14:56:00  ...    225.590      81.20    271.330      13.35
# 2022-11-28 14:57:00  ...    225.299      81.19    271.504      13.35
# 2022-11-28 14:58:00  ...    225.537      81.19    271.504      13.35
# 2022-11-28 14:59:00  ...    225.646      81.19    271.504      13.35
# 2022-11-28 15:00:00  ...    225.601      81.30    271.001      13.37
#
#                      123057.SZ  300586.SZ  123067.SZ  300382.SZ  128106.SZ  \
# 2022-11-25 15:00:00    225.800      20.62    223.500      21.48    195.000
# 2022-11-28 09:30:00    222.630      20.36    221.193      21.35    192.633
# 2022-11-28 09:31:00    224.412      20.50    222.223      21.39    193.270
# 2022-11-28 09:32:00    227.013      20.60    223.327      21.35    194.696
# 2022-11-28 09:33:00    225.186      20.45    221.644      21.23    193.662
# ...                        ...        ...        ...        ...        ...
# 2022-11-28 14:56:00    227.027      20.35    223.110      21.29    192.084
# 2022-11-28 14:57:00    227.014      20.36    223.110      21.27    192.075
# 2022-11-28 14:58:00    227.014      20.36    223.110      21.27    192.075
# 2022-11-28 14:59:00    227.014      20.36    223.110      21.27    192.075
# 2022-11-28 15:00:00    226.800      20.43    223.166      21.26    192.076
#
#                      002840.SZ
# 2022-11-25 15:00:00      16.72
# 2022-11-28 09:30:00      16.31
# 2022-11-28 09:31:00      16.44
# 2022-11-28 09:32:00      16.53
# 2022-11-28 09:33:00      16.49
# ...                        ...
# 2022-11-28 14:56:00      16.36
# 2022-11-28 14:57:00      16.36
# 2022-11-28 14:58:00      16.36
# 2022-11-28 14:59:00      16.36
# 2022-11-28 15:00:00      16.36
#
# [243 rows x 36 columns]

# %%
# assert False

# %% [markdown]
# # stock pre status

# %%
df_stk_pre_return = w.wss("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return = w.wss("300587.SZ,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ",
"pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_stk_pre_return
df_stk_pre_return
# Out:
#             PCT_CHG
# 300587.SZ -0.539707
# 600674.SH  1.271186
# 002203.SZ -0.901639
# 601127.SH -3.578947
# 002597.SZ -0.404391
# 603348.SH -3.013154
# 300487.SZ -3.437749
# 603876.SH -2.063629
# 601677.SH -0.860927
# 300655.SZ -2.811951
# 002078.SZ  1.502347
# 002738.SZ -3.311938
# 002812.SZ -4.237414
# 603596.SH -2.405456
# 300332.SZ -0.377644
# 300586.SZ -5.801736
# 300382.SZ -3.417266
# 002840.SZ  0.179748

# %%
df_bond_pre_return = w.wss("123046.SZ,113642.SH,110061.SH,128081.SZ,113016.SH,128017.SZ,113537.SH,123027.SZ,113534.SH,113025.SH,123031.SZ,128029.SZ,128111.SZ,128095.SZ,113626.SH,123092.SZ,123057.SZ,123067.SZ,128106.SZ",
 "pct_chg", f"tradeDate={before_trade_date};cycle=D;",usedf=True)[1]
df_bond_pre_return
# Out:
#             PCT_CHG
# 123046.SZ -0.937665
# 113642.SH       NaN
# 110061.SH  0.889962
# 128081.SZ -0.472113
# 113016.SH -2.964687
# 128017.SZ -0.449703
# 113537.SH -3.331058
# 123027.SZ       NaN
# 113534.SH -2.953562
# 113025.SH -1.061591
# 123031.SZ -0.512821
# 128029.SZ  1.322731
# 128111.SZ -2.678537
# 128095.SZ -2.390021
# 113626.SH -2.493963
# 123092.SZ  0.004099
# 123057.SZ -7.074365
# 123067.SZ -2.994792
# 128106.SZ  0.453328

# %%
before_trade_date_trade_status = before_trade_date[:4] +'-'+ before_trade_date[4:6] +'-'+ before_trade_date[6:]
# present_date_trade_status = present_date[:4] +'-'+ present_date[4:6] +'-'+ present_date[6:]
df_stk_pre_trade_status = w.wsd("300587.SZ,603185.SH,600674.SH,002203.SZ,601127.SH,002597.SZ,603348.SH,300487.SZ,603876.SH,601677.SH,300655.SZ,002078.SZ,002738.SZ,002812.SZ,603596.SH,300332.SZ,300586.SZ,300382.SZ,002840.SZ", 
"trade_status", f"{before_trade_date_trade_status}", f"{before_trade_date_trade_status}", "",usedf=True)[1]
df_stk_pre_trade_status
# Out:
#           TRADE_STATUS
# 300587.SZ           交易
# 603185.SH           交易
# 600674.SH           交易
# 002203.SZ           交易
# 601127.SH           交易
# 002597.SZ           交易
# 603348.SH           交易
# 300487.SZ           交易
# 603876.SH           交易
# 601677.SH           交易
# 300655.SZ           交易
# 002078.SZ           交易
# 002738.SZ           交易
# 002812.SZ           交易
# 603596.SH           交易
# 300332.SZ           交易
# 300586.SZ           交易
# 300382.SZ           交易
# 002840.SZ           交易

# %%
df_stk_pre_trade_status.iloc[0,0]
# Out:
# '交易'

# %%
# assert False

# %% [markdown]
# # bond-stock pair

# %%
# cbond_pair = ['113642.SH','603185.SH']  #后面筛选的结果，这组也在里面 转债停止交易了
# open_threshold = 0.023
# close_threshold = 0
# convert_price = 102.4
# operate = True

# cbond_pair = ['123027.SZ','300487.SZ',] # 1019 1020 1021 这几天转债停止交易了
# open_threshold = 0.022
# close_threshold = 0
# convert_price = 19.07
# operate = True

# %%
cbond_pair = ['123046.SZ','300587.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.015
close_threshold = 0
convert_price = 3.94
operate = True

cbond_pair = ['110061.SH','600674.SH']
open_threshold = 0.006
close_threshold = 0
convert_price = 8.8
operate = True

cbond_pair = ['128081.SZ','002203.SZ']
open_threshold = 0.012
close_threshold = 0.002
convert_price = 9.62
operate = True

cbond_pair = ['113016.SH','601127.SH'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.017
close_threshold = 0.003
convert_price = 20.17
operate = True

cbond_pair = ['128017.SZ','002597.SZ']
open_threshold = 0.012
close_threshold = 0
convert_price = 21.33
operate = True

# # $$$$$$$$$$$$$$$$$$$$$$$$以下是新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['113537.SH','603348.SH',]
open_threshold = 0.027
close_threshold = 0.002
convert_price = 19.13
operate = True

cbond_pair = ['113534.SH','603876.SH',]
open_threshold = 0.019
close_threshold = 0.002
convert_price = 14.98
operate = True

cbond_pair = ['113025.SH','601677.SH',]
open_threshold = 0.018
close_threshold = 0
convert_price = 7.66
operate = True

cbond_pair = ['123031.SZ','300655.SZ',]   #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.019
close_threshold = 0
convert_price = 6.25
operate = True

cbond_pair = ['128029.SZ','002078.SZ']
open_threshold = 0.013
close_threshold = 0.002
convert_price = 8.25
operate = True

# # $$$$$$$$$$$$$$$$$$$$$$$$【2022-10-14】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair = ['128111.SZ','002738.SZ'] #这个被操纵了，每日总结的时候剔除掉
open_threshold = 0.011
close_threshold = 0.001
convert_price = 10.96
operate = True

cbond_pair = ['128095.SZ','002812.SZ']
open_threshold = 0.013
close_threshold = 0
convert_price = 64.62
operate = True

cbond_pair = ['113626.SH','603596.SH']
open_threshold = 0.02
close_threshold = 0
convert_price = 35.88
operate = True

cbond_pair = ['123092.SZ','300332.SZ']
open_threshold = 0.025
close_threshold = 0.001
convert_price = 5.14
operate = True

# # $$$$$$$$$$$$$$$$$$$$$$$$【2022-11-18】新增的对子$$$$$$$$$$$$$$$$$$$$$$$$
cbond_pair =  ['123057.SZ','300586.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.009 
close_threshold = 0.003
convert_price = 9.5
operate = True

cbond_pair =  ['123067.SZ','300382.SZ'] #这个对子的spread较小，不用diff超过2倍spread强制平仓的止损逻辑
open_threshold = 0.004
close_threshold = 0.002
convert_price = 9.96
operate = True

cbond_pair =  ['128106.SZ','002840.SZ']
open_threshold = 0.01
close_threshold = 0
convert_price = 8.85
operate = True

# %%
# df_signal

# %% [markdown]
# # clip price series

# %%
#从前一个交易日的收盘价开始截取
# cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]].loc['2022-09-08 15:00:00':]
cbond_pair_price = cbond_price[[cbond_pair[0],cbond_pair[1]]]

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-25 15:00:00    195.000      16.72
# 2022-11-28 09:30:00    192.633      16.31
# 2022-11-28 09:31:00    193.270      16.44
# 2022-11-28 09:32:00    194.696      16.53
# 2022-11-28 09:33:00    193.662      16.49

# %%
cbond_return = pd.DataFrame([])

cbond_preclose = cbond_pair_price.iloc[0,0] # 初始时刻的bond前收盘价
stock_preclose = cbond_pair_price.iloc[0,1] # 初始时刻的stock前收盘价

for index,row in cbond_pair_price.iterrows():
    
    cbond_return.loc[index,cbond_pair[0]] = row[cbond_pair[0]]/cbond_preclose - 1 # 算日内的return
    cbond_return.loc[index,cbond_pair[1]] = row[cbond_pair[1]]/stock_preclose - 1

    if index.time()==time(15,0,0):  #算完日内return，迭代到今日价格的最后一个time bar的时候，将其设为前收盘价
        cbond_preclose = row[cbond_pair[0]]    # 日内return指标用 现价/昨日收盘价 计算
        stock_preclose = row[cbond_pair[1]]
        
# 检查df是否有空值
cbond_return.isnull().sum(axis=0)  # 按列统计
cbond_return.isnull().sum(axis=1) # 按行统计
cbond_return.isnull().sum(axis=1).sum() # 统计整张表
# Out:
# 0

# %%
pd.set_option('display.max_rows', None)
cbond_return['diff'] = cbond_return[cbond_pair[0]] - cbond_return[cbond_pair[1]]
cbond_return.head()
# Out:
#                      128106.SZ  002840.SZ      diff
# 2022-11-25 15:00:00   0.000000   0.000000  0.000000
# 2022-11-28 09:30:00  -0.012138  -0.024522  0.012383
# 2022-11-28 09:31:00  -0.008872  -0.016746  0.007875
# 2022-11-28 09:32:00  -0.001559  -0.011364  0.009805
# 2022-11-28 09:33:00  -0.006862  -0.013756  0.006894

# %% [markdown]
# # signal calculate

# %%
################################################################################################
stk_pre_return = df_stk_pre_return.loc[cbond_pair[1]].values[0]
bond_pre_return = df_bond_pre_return.loc[cbond_pair[0]].values[0]
pre_diff = bond_pre_return - stk_pre_return
stk_pre_trade_status = df_stk_pre_trade_status.loc[cbond_pair[1]].values[0]
print(stk_pre_trade_status)
print('pre diff:',pre_diff)
# if abs(stk_pre_return) > 10 or stk_pre_trade_status!='交易':
if abs(pre_diff) > 5 or stk_pre_trade_status!='交易':
    # 如果前一天股票的跌幅小于-10，则今日不做操作
    intraday_open_times = 1
else:
    intraday_open_times = 0
################################################################################################    
open_close_spread = open_threshold - close_threshold
# intraday_open_times = 0
max_open = 1

pos_open_flag = 0
neg_open_flag = 0
cbond_position = pd.DataFrame([])
cbond_position.index = cbond_return.index
for index,row in cbond_return.iterrows():

    if row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff落在A区间，且无仓位，正开
            pos_open_flag = 1
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==0 and neg_open_flag==1:
        if intraday_open_times < max_open:
            #diff落在A区间，且有负仓，平仓再正开
            pos_open_flag=1
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
            print('reverse open +1')
            intraday_open_times += 1
        else:
            pos_open_flag = 0
            neg_open_flag = 0
            cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
            cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff落在A区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在B区间，且有正仓，keep
        pos_open_flag=1
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = -1*pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在B区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] > close_threshold and row['diff'] < open_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在B区间，且无仓，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在C区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在C区间，且有负仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    elif row['diff'] >= -1*close_threshold and row['diff'] <= close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在C区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = neg_open_flag
    
    if row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在D区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==1 and neg_open_flag==0:
        #diff 落在D区间，且有正仓，平仓
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
    elif row['diff'] > -1*open_threshold and row['diff'] < -1*close_threshold and pos_open_flag==0 and neg_open_flag==0:
        #diff 落在D区间，且无仓位，keep
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且无仓位，反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==1 and neg_open_flag==0:
        if intraday_open_times < max_open:
            #diff 落在E区间，且有正仓，平仓反开
            pos_open_flag=0
            neg_open_flag=1
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
            intraday_open_times += 1
        else:
            pos_open_flag=0
            neg_open_flag=0
            cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
            cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag
    elif row['diff'] <= -1*open_threshold and pos_open_flag==0 and neg_open_flag==1:
        #diff 落在E区间，且有负仓，keep
        pos_open_flag=0
        neg_open_flag=1
        cbond_position.loc[index,cbond_pair[0]] = neg_open_flag
        cbond_position.loc[index,cbond_pair[1]] = -1*neg_open_flag

    if abs(row['diff'])>2 * open_close_spread and cbond_return.columns[0]!='123057.SZ' and cbond_return.columns[0]!='123067.SZ': 
        #盘中diff超过2倍spread时平仓（价格止损信号）,有两个spread特别小的对子则不用此逻辑进行止损
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag

    if index.time()==time(15,0,0): # 每日收盘时必须平仓（时间止损信号）
    # if index.time()==time(14,59,0): # 每日收盘时必须平仓（时间止损信号）
        intraday_open_times = 0 # 下一天开盘前，把当日记录下来的开仓次数清零
        pos_open_flag=0
        neg_open_flag=0
        cbond_position.loc[index,cbond_pair[0]] = pos_open_flag
        cbond_position.loc[index,cbond_pair[1]] = pos_open_flag
# Out:
# 交易
# pre diff: 0.27357948614367905

# %%
cbond_pair_price.head()
# Out:
#                      128106.SZ  002840.SZ
# 2022-11-25 15:00:00    195.000      16.72
# 2022-11-28 09:30:00    192.633      16.31
# 2022-11-28 09:31:00    193.270      16.44
# 2022-11-28 09:32:00    194.696      16.53
# 2022-11-28 09:33:00    193.662      16.49

# %%
df_signal = pd.concat([cbond_pair_price,cbond_return,cbond_position],axis=1)
df_signal.columns = ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
print('open threshold',open_threshold,'close threshold',close_threshold)
# df_signal.to_csv('tmp_signal.csv')
# df_signal
# Out:
# open threshold 0.01 close threshold 0

# %% [markdown]
# # backtest

# %%
# 用来记录交易流水的表格,一边遍历df_signal，一边填入内容到流水表格里

import numpy as np
cols = ['balance','signal','bond price','stock price','bond hold','stock hold','commission','tax','reverse open','diff','asset value']
df_trade = pd.DataFrame(
    data = [[0,np.nan,np.nan,np.nan,0,0,0,0,np.nan,np.nan,0]],
    columns=cols
    ) 

balance_last = 0 # 现金账户初始余额

bond_hold = 0 # 债券持有数量
stock_hold = 0 # 股票持有数量


commission_rate = 2/10000 + 0 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 0.5/1000 # 佣金买卖万二 + 交易滑点
# commission_rate = 2/10000 + 1/1000 # 佣金买卖万二 + 交易滑点

tax_rate = 1/1000 # 卖股票才收印花税千一

# commission_rate = 0/10000 # 佣金买卖万二
# tax_rate = 0/1000 #

for i in range(len(df_signal)-1):
    if df_signal.index[i].time() == time(15,0,0):
    # if df_signal.index[i].time() == time(14,59,0):
        # 修改stock volume 每天固定一个stock volume 应该用债的前收盘价/股票的前收盘价
        stock_volume = df_signal['bond_price'][i]/df_signal['stock_price'][i]

    if df_signal.values[i][-1] != df_signal.values[i+1][-1]:

        index = df_signal.index[i+1]        
        diff = df_signal.values[i+1][-3] #diff在df_signal中的倒数第三列
        
    # df_signal的columns
    # ['bond_price','stock_price','bond_rtn','stock_rtn','diff','bond_pos','stock_pos']
        signal = str(int(df_signal.values[i+1][-2]))+str(int(df_signal.values[i+1][-1]))
        
        bond_price = df_signal.values[i+1][0] 

        stock_price = df_signal.values[i+1][1]

        # stock_volume =  bond_price/stock_price # 修改stock volume 每天固定一个stock volume应该用债的前收盘价/股票的前收盘价

        commission = (bond_price + stock_price * stock_volume) * commission_rate

        reverse_open = False #表明这笔交易，是否包含平仓后再反向开仓的操作

        if signal == '00' and stock_hold == stock_volume: #有股票持仓并且需要卖出平仓时，有印花税
            tax = stock_price * tax_rate * stock_volume
        else:
            tax = 0

        if signal == '00':
            balance_last += bond_hold*bond_price
            balance_last += stock_hold*stock_price
            
            bond_hold = 0
            stock_hold = 0
            

        if signal == '1-1':
            '''
            加一个检测之前持仓的模块,如果之前因为-11的信号有持仓,需要先平掉(即买债卖股票),同时再反向开仓
            '''
            reverse_flag = False
            if bond_hold == -1 and stock_hold == 1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last -= bond_price 
                balance_last += stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税
                reverse_flag = True
                reverse_open = True

            bond_hold += 1
            stock_hold += (-1 * stock_volume)
            # stock_hold += stock_volume
            balance_last -= bond_price
            balance_last += stock_price * stock_volume
            
            if reverse_flag:
                tax *= 2 #平仓然后反向开仓的时候 已经计算过tax了，直接double
            else:
                tax = stock_price * tax_rate * stock_volume # 卖股票要收印花税

        if signal == '-11':
            '''
            加一个检测之前持仓的模块,如果之前因为1-1的信号有持仓,需要先平掉(卖债买股票),同时再反向开仓
            '''
            if bond_hold == 1 and stock_hold == -1*stock_volume:
                bond_hold = 0
                stock_hold = 0
                balance_last += bond_price
                balance_last -= stock_price * stock_volume
                commission *= 2 # 因为平掉之后再反向开仓，手续费double
                                # 买股票无印花税
                reverse_open = True
            bond_hold += -1
            stock_hold += (1 * stock_volume)
            # stock_hold += stock_volume
            balance_last += bond_price
            balance_last -= stock_price * stock_volume
        
        balance_last = balance_last - commission - tax
        balance = balance_last
        asset_value = bond_price*bond_hold + stock_price*stock_hold
        line = [balance,signal,bond_price,stock_price,bond_hold,stock_hold,commission,tax,reverse_open,diff,asset_value]
        # df_trade.loc[index,['balance','asset','signal','bond price','stock price','commission','tax']] = line
        # df_trade.loc[index,cols] = [0,0,np.nan,np.nan,np.nan,0,0,0,0]
        df_trade.loc[index,cols] = line

df_trade.rename(columns={'balance':'cash'},inplace=True)       
df_trade['net value'] = df_trade['cash'] + df_trade['asset value']

# %%
df_trade['operate'] = [operate]*len(df_trade)

# %%
df_trade
# Out:
#                          cash signal  bond price  stock price  bond hold  \
# 0                    0.000000    NaN         NaN          NaN        0.0
# 2022-11-28 09:30:00  2.338128    -11     192.633        16.31       -1.0
# 2022-11-28 15:00:00  0.796187     00     192.076        16.36        0.0
#
#                      stock hold  commission       tax reverse open      diff  \
# 0                      0.000000    0.000000  0.000000          NaN       NaN
# 2022-11-28 09:30:00   11.662679    0.076570  0.000000        False  0.012383
# 2022-11-28 15:00:00    0.000000    0.076575  0.190801        False  0.006536
#
#                      asset value  net value  operate
# 0                       0.000000   0.000000     True
# 2022-11-28 09:30:00    -2.414699  -0.076570     True
# 2022-11-28 15:00:00     0.000000   0.796187     True

# %% [markdown]
# # output to csv

# %%
excel_file_name = './daily_track/'+ present_date+'/' + cbond_pair[0] + '@' + cbond_pair[1] + '.csv'

excel_file_name

df_to_excel = df_trade
df_to_excel['open/close'] = [str(open_threshold)+','+str(close_threshold)]*len(df_to_excel)
df_to_excel['pair'] = [cbond_pair[0] + '@' + cbond_pair[1]]*len(df_to_excel)
df_to_excel = df_to_excel[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_to_excel.to_csv(excel_file_name,)

# %%
present_date
# Out:
# '20221128'

# %% [markdown]
# # conclusion

# %%
import os
single_trade_files = os.listdir('./daily_track'+'/'+present_date)

df_trade_conclusion = pd.DataFrame([])
for file in single_trade_files:
    if file == 'diff':
        continue
    if file == '.DS_Store' or file.split('.')[1] == 'xlsx':
        continue
    tmp_path = './daily_track'+'/'+present_date+'/'+file
    df_tmp = pd.read_csv(tmp_path,index_col=0)
    tmp_col = list(df_tmp.columns)
    df_tmp_head = pd.DataFrame(data=[tmp_col],columns=tmp_col)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp_head)
    df_trade_conclusion = df_trade_conclusion.append(df_tmp)
df_trade_conclusion.columns
df_trade_conclusion = df_trade_conclusion[['pair','cash', 'signal', 'bond price', 'stock price', 'bond hold',
                                            'stock hold', 'commission', 'tax', 'reverse open', 'diff',
                                            'asset value', 'net value', 'open/close','operate']]
df_trade_conclusion
tmp_path = './daily_track'+'/'+present_date+'/'+f'{present_date}_conclusion.csv'

df_trade_conclusion.to_csv(tmp_path)

# %% [markdown]
# # intraday signal

# %%
import matplotlib.pyplot as plt

signal_plot_begin_time = present_date[:4]+'-' + \
                         present_date[4:6]+'-' + \
                         present_date[6:8]+' 09:30:00'
df_signal['diff'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' diff',grid=True)

#如果当日有开平仓记录，在图上画出开平仓时刻的标注
if len(df_trade) == 3:
    open_tick = df_trade.index.to_list()[1]
    open_diff = df_trade['diff'].to_list()[1]
    close_tick = df_trade.index.to_list()[2]
    close_diff =  df_trade['diff'].to_list()[2]
    plt.text(open_tick,open_diff,'open')
    plt.text(close_tick,close_diff,'close')
    plt.scatter([open_tick],[open_diff],color='r')

    tmp_nv = df_trade['net value'].to_list()[2]
    if tmp_nv > 0: 
        close_color = 'g' #当天赚钱的话，平仓点位标记为绿色
    else:
        close_color = 'orange' #当天亏钱的话，平仓点位标记为橙色
    plt.scatter([close_tick],[close_diff],color=close_color)
fig_file_name = './daily_track/'+ present_date+'/'+'diff/' + cbond_pair[0] + '@' + cbond_pair[1] + '.png'
plt.savefig(fig_file_name)

plt.show()
df_signal['bond_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+' rtn',grid=True)
plt.show()
df_signal['stock_rtn'].loc[signal_plot_begin_time:].plot(title=cbond_pair[1]+' rtn',grid=True)
plt.show()

# %%
df_tmp = 100/convert_price*df_signal['stock_price']
df_signal['premium rate'] = (df_signal['bond_price'] - df_tmp)/df_tmp
df_signal['premium rate'].loc[signal_plot_begin_time:].plot(title=cbond_pair[0]+'@'+cbond_pair[1]+' premium rate',grid=True)
# Out:
# <AxesSubplot:title={'center':'128106.SZ@002840.SZ premium rate'}>

# %%
df_signal
# Out:
#                      bond_price  stock_price  bond_rtn  stock_rtn      diff  \
# 2022-11-25 15:00:00     195.000        16.72  0.000000   0.000000  0.000000
# 2022-11-28 09:30:00     192.633        16.31 -0.012138  -0.024522  0.012383
# 2022-11-28 09:31:00     193.270        16.44 -0.008872  -0.016746  0.007875
# 2022-11-28 09:32:00     194.696        16.53 -0.001559  -0.011364  0.009805
# 2022-11-28 09:33:00     193.662        16.49 -0.006862  -0.013756  0.006894
# 2022-11-28 09:34:00     192.876        16.45 -0.010892  -0.016148  0.005256
# 2022-11-28 09:35:00     194.014        16.51 -0.005056  -0.012560  0.007503
# 2022-11-28 09:36:00     192.662        16.42 -0.011990  -0.017943  0.005953
# 2022-11-28 09:37:00     192.871        16.39 -0.010918  -0.019737  0.008819
# 2022-11-28 09:38:00     192.592        16.35 -0.012349  -0.022129  0.009780
# 2022-11-28 09:39:00     192.500        16.36 -0.012821  -0.021531  0.008711
# 2022-11-28 09:40:00     192.311        16.30 -0.013790  -0.025120  0.011330
# 2022-11-28 09:41:00     192.679        16.29 -0.011903  -0.025718  0.013815
# 2022-11-28 09:42:00     192.246        16.27 -0.014123  -0.026914  0.012791
# 2022-11-28 09:43:00     191.300        16.16 -0.018974  -0.033493  0.014518
# 2022-11-28 09:44:00     191.808        16.21 -0.016369  -0.030502  0.014133
# 2022-11-28 09:45:00     191.300        16.13 -0.018974  -0.035287  0.016313
# 2022-11-28 09:46:00     191.108        16.08 -0.019959  -0.038278  0.018319
# 2022-11-28 09:47:00     191.172        16.16 -0.019631  -0.033493  0.013862
# 2022-11-28 09:48:00     191.002        16.12 -0.020503  -0.035885  0.015383
# 2022-11-28 09:49:00     190.261        16.06 -0.024303  -0.039474  0.015171
# 2022-11-28 09:50:00     190.433        16.11 -0.023421  -0.036483  0.013063
# 2022-11-28 09:51:00     190.993        16.15 -0.020549  -0.034091  0.013542
# 2022-11-28 09:52:00     191.007        16.13 -0.020477  -0.035287  0.014810
# 2022-11-28 09:53:00     191.733        16.20 -0.016754  -0.031100  0.014347
# 2022-11-28 09:54:00     191.190        16.18 -0.019538  -0.032297  0.012758
# 2022-11-28 09:55:00     191.006        16.16 -0.020482  -0.033493  0.013011
# 2022-11-28 09:56:00     191.396        16.22 -0.018482  -0.029904  0.011422
# 2022-11-28 09:57:00     191.217        16.24 -0.019400  -0.028708  0.009308
# 2022-11-28 09:58:00     190.649        16.20 -0.022313  -0.031100  0.008788
# 2022-11-28 09:59:00     191.083        16.19 -0.020087  -0.031699  0.011611
# 2022-11-28 10:00:00     191.390        16.23 -0.018513  -0.029306  0.010793
# 2022-11-28 10:01:00     191.200        16.22 -0.019487  -0.029904  0.010417
# 2022-11-28 10:02:00     191.500        16.24 -0.017949  -0.028708  0.010759
# 2022-11-28 10:03:00     191.309        16.23 -0.018928  -0.029306  0.010378
# 2022-11-28 10:04:00     191.010        16.17 -0.020462  -0.032895  0.012433
# 2022-11-28 10:05:00     191.600        16.24 -0.017436  -0.028708  0.011272
# 2022-11-28 10:06:00     191.738        16.25 -0.016728  -0.028110  0.011382
# 2022-11-28 10:07:00     191.721        16.21 -0.016815  -0.030502  0.013687
# 2022-11-28 10:08:00     191.504        16.20 -0.017928  -0.031100  0.013172
# 2022-11-28 10:09:00     191.400        16.19 -0.018462  -0.031699  0.013237
# 2022-11-28 10:10:00     191.642        16.23 -0.017221  -0.029306  0.012086
# 2022-11-28 10:11:00     191.600        16.22 -0.017436  -0.029904  0.012468
# 2022-11-28 10:12:00     191.523        16.24 -0.017831  -0.028708  0.010877
# 2022-11-28 10:13:00     192.200        16.28 -0.014359  -0.026316  0.011957
# 2022-11-28 10:14:00     192.200        16.29 -0.014359  -0.025718  0.011359
# 2022-11-28 10:15:00     191.900        16.30 -0.015897  -0.025120  0.009222
# 2022-11-28 10:16:00     192.184        16.32 -0.014441  -0.023923  0.009482
# 2022-11-28 10:17:00     192.258        16.30 -0.014062  -0.025120  0.011058
# 2022-11-28 10:18:00     192.722        16.34 -0.011682  -0.022727  0.011045
# 2022-11-28 10:19:00     192.933        16.38 -0.010600  -0.020335  0.009735
# 2022-11-28 10:20:00     193.025        16.35 -0.010128  -0.022129  0.012001
# 2022-11-28 10:21:00     192.575        16.33 -0.012436  -0.023325  0.010889
# 2022-11-28 10:22:00     192.249        16.29 -0.014108  -0.025718  0.011610
# 2022-11-28 10:23:00     192.506        16.32 -0.012790  -0.023923  0.011134
# 2022-11-28 10:24:00     192.400        16.30 -0.013333  -0.025120  0.011786
# 2022-11-28 10:25:00     192.641        16.35 -0.012097  -0.022129  0.010032
# 2022-11-28 10:26:00     192.536        16.37 -0.012636  -0.020933  0.008297
# 2022-11-28 10:27:00     192.370        16.33 -0.013487  -0.023325  0.009838
# 2022-11-28 10:28:00     191.935        16.31 -0.015718  -0.024522  0.008804
# 2022-11-28 10:29:00     192.187        16.31 -0.014426  -0.024522  0.010096
# 2022-11-28 10:30:00     192.308        16.33 -0.013805  -0.023325  0.009520
# 2022-11-28 10:31:00     192.331        16.33 -0.013687  -0.023325  0.009638
# 2022-11-28 10:32:00     192.356        16.32 -0.013559  -0.023923  0.010364
# 2022-11-28 10:33:00     192.246        16.31 -0.014123  -0.024522  0.010398
# 2022-11-28 10:34:00     192.500        16.32 -0.012821  -0.023923  0.011103
# 2022-11-28 10:35:00     192.140        16.28 -0.014667  -0.026316  0.011649
# 2022-11-28 10:36:00     192.213        16.33 -0.014292  -0.023325  0.009033
# 2022-11-28 10:37:00     192.400        16.32 -0.013333  -0.023923  0.010590
# 2022-11-28 10:38:00     192.422        16.32 -0.013221  -0.023923  0.010703
# 2022-11-28 10:39:00     192.342        16.31 -0.013631  -0.024522  0.010891
# 2022-11-28 10:40:00     192.375        16.31 -0.013462  -0.024522  0.011060
# 2022-11-28 10:41:00     192.295        16.29 -0.013872  -0.025718  0.011846
# 2022-11-28 10:42:00     192.249        16.27 -0.014108  -0.026914  0.012806
# 2022-11-28 10:43:00     192.128        16.28 -0.014728  -0.026316  0.011588
# 2022-11-28 10:44:00     192.199        16.27 -0.014364  -0.026914  0.012550
# 2022-11-28 10:45:00     192.356        16.29 -0.013559  -0.025718  0.012159
# 2022-11-28 10:46:00     192.399        16.29 -0.013338  -0.025718  0.012379
# 2022-11-28 10:47:00     192.258        16.28 -0.014062  -0.026316  0.012254
# 2022-11-28 10:48:00     192.200        16.27 -0.014359  -0.026914  0.012555
# 2022-11-28 10:49:00     192.292        16.26 -0.013887  -0.027512  0.013625
# 2022-11-28 10:50:00     192.100        16.26 -0.014872  -0.027512  0.012640
# 2022-11-28 10:51:00     192.122        16.24 -0.014759  -0.028708  0.013949
# 2022-11-28 10:52:00     192.290        16.24 -0.013897  -0.028708  0.014811
# 2022-11-28 10:53:00     192.350        16.25 -0.013590  -0.028110  0.014520
# 2022-11-28 10:54:00     192.350        16.24 -0.013590  -0.028708  0.015118
# 2022-11-28 10:55:00     192.421        16.24 -0.013226  -0.028708  0.015482
# 2022-11-28 10:56:00     192.335        16.23 -0.013667  -0.029306  0.015640
# 2022-11-28 10:57:00     192.536        16.28 -0.012636  -0.026316  0.013680
# 2022-11-28 10:58:00     192.593        16.28 -0.012344  -0.026316  0.013972
# 2022-11-28 10:59:00     192.502        16.27 -0.012810  -0.026914  0.014104
# 2022-11-28 11:00:00     192.500        16.26 -0.012821  -0.027512  0.014691
# 2022-11-28 11:01:00     192.780        16.29 -0.011385  -0.025718  0.014333
# 2022-11-28 11:02:00     193.274        16.34 -0.008851  -0.022727  0.013876
# 2022-11-28 11:03:00     192.963        16.35 -0.010446  -0.022129  0.011683
# 2022-11-28 11:04:00     193.285        16.34 -0.008795  -0.022727  0.013932
# 2022-11-28 11:05:00     193.498        16.37 -0.007703  -0.020933  0.013230
# 2022-11-28 11:06:00     193.585        16.41 -0.007256  -0.018541  0.011284
# 2022-11-28 11:07:00     193.340        16.41 -0.008513  -0.018541  0.010028
# 2022-11-28 11:08:00     193.400        16.42 -0.008205  -0.017943  0.009737
# 2022-11-28 11:09:00     193.159        16.43 -0.009441  -0.017344  0.007903
# 2022-11-28 11:10:00     193.469        16.48 -0.007851  -0.014354  0.006503
# 2022-11-28 11:11:00     193.266        16.46 -0.008892  -0.015550  0.006658
# 2022-11-28 11:12:00     193.562        16.49 -0.007374  -0.013756  0.006382
# 2022-11-28 11:13:00     194.037        16.50 -0.004938  -0.013158  0.008219
# 2022-11-28 11:14:00     193.989        16.49 -0.005185  -0.013756  0.008571
# 2022-11-28 11:15:00     193.800        16.44 -0.006154  -0.016746  0.010593
# 2022-11-28 11:16:00     193.501        16.41 -0.007687  -0.018541  0.010853
# 2022-11-28 11:17:00     193.391        16.39 -0.008251  -0.019737  0.011486
# 2022-11-28 11:18:00     193.385        16.38 -0.008282  -0.020335  0.012053
# 2022-11-28 11:19:00     193.580        16.39 -0.007282  -0.019737  0.012455
# 2022-11-28 11:20:00     193.881        16.42 -0.005738  -0.017943  0.012204
# 2022-11-28 11:21:00     193.948        16.48 -0.005395  -0.014354  0.008959
# 2022-11-28 11:22:00     193.952        16.46 -0.005374  -0.015550  0.010176
# 2022-11-28 11:23:00     193.756        16.45 -0.006379  -0.016148  0.009769
# 2022-11-28 11:24:00     193.545        16.47 -0.007462  -0.014952  0.007491
# 2022-11-28 11:25:00     193.521        16.48 -0.007585  -0.014354  0.006769
# 2022-11-28 11:26:00     193.532        16.47 -0.007528  -0.014952  0.007424
# 2022-11-28 11:27:00     193.484        16.47 -0.007774  -0.014952  0.007178
# 2022-11-28 11:28:00     193.941        16.50 -0.005431  -0.013158  0.007727
# 2022-11-28 11:29:00     193.830        16.51 -0.006000  -0.012560  0.006560
# 2022-11-28 11:30:00     193.760        16.51 -0.006359  -0.012560  0.006201
# 2022-11-28 13:00:00     193.049        16.42 -0.010005  -0.017943  0.007937
# 2022-11-28 13:01:00     193.061        16.39 -0.009944  -0.019737  0.009793
# 2022-11-28 13:02:00     192.700        16.35 -0.011795  -0.022129  0.010334
# 2022-11-28 13:03:00     192.759        16.41 -0.011492  -0.018541  0.007048
# 2022-11-28 13:04:00     192.683        16.38 -0.011882  -0.020335  0.008453
# 2022-11-28 13:05:00     192.640        16.38 -0.012103  -0.020335  0.008232
# 2022-11-28 13:06:00     192.700        16.37 -0.011795  -0.020933  0.009138
# 2022-11-28 13:07:00     192.200        16.33 -0.014359  -0.023325  0.008966
# 2022-11-28 13:08:00     192.400        16.35 -0.013333  -0.022129  0.008796
# 2022-11-28 13:09:00     192.571        16.38 -0.012456  -0.020335  0.007879
# 2022-11-28 13:10:00     192.350        16.36 -0.013590  -0.021531  0.007941
# 2022-11-28 13:11:00     192.355        16.36 -0.013564  -0.021531  0.007967
# 2022-11-28 13:12:00     192.352        16.34 -0.013579  -0.022727  0.009148
# 2022-11-28 13:13:00     192.485        16.35 -0.012897  -0.022129  0.009232
# 2022-11-28 13:14:00     192.500        16.34 -0.012821  -0.022727  0.009907
# 2022-11-28 13:15:00     192.573        16.35 -0.012446  -0.022129  0.009683
# 2022-11-28 13:16:00     192.694        16.36 -0.011826  -0.021531  0.009705
# 2022-11-28 13:17:00     192.542        16.35 -0.012605  -0.022129  0.009524
# 2022-11-28 13:18:00     192.500        16.34 -0.012821  -0.022727  0.009907
# 2022-11-28 13:19:00     192.420        16.34 -0.013231  -0.022727  0.009497
# 2022-11-28 13:20:00     192.655        16.36 -0.012026  -0.021531  0.009505
# 2022-11-28 13:21:00     192.470        16.34 -0.012974  -0.022727  0.009753
# 2022-11-28 13:22:00     192.554        16.34 -0.012544  -0.022727  0.010184
# 2022-11-28 13:23:00     192.350        16.34 -0.013590  -0.022727  0.009138
# 2022-11-28 13:24:00     192.050        16.32 -0.015128  -0.023923  0.008795
# 2022-11-28 13:25:00     191.713        16.32 -0.016856  -0.023923  0.007067
# 2022-11-28 13:26:00     191.800        16.32 -0.016410  -0.023923  0.007513
# 2022-11-28 13:27:00     191.700        16.29 -0.016923  -0.025718  0.008795
# 2022-11-28 13:28:00     191.884        16.29 -0.015979  -0.025718  0.009738
# 2022-11-28 13:29:00     191.720        16.27 -0.016821  -0.026914  0.010093
# 2022-11-28 13:30:00     191.723        16.27 -0.016805  -0.026914  0.010109
# 2022-11-28 13:31:00     191.711        16.26 -0.016867  -0.027512  0.010645
# 2022-11-28 13:32:00     191.943        16.28 -0.015677  -0.026316  0.010639
# 2022-11-28 13:33:00     192.079        16.27 -0.014979  -0.026914  0.011934
# 2022-11-28 13:34:00     192.000        16.30 -0.015385  -0.025120  0.009735
# 2022-11-28 13:35:00     191.997        16.29 -0.015400  -0.025718  0.010318
# 2022-11-28 13:36:00     191.906        16.31 -0.015867  -0.024522  0.008655
# 2022-11-28 13:37:00     191.953        16.30 -0.015626  -0.025120  0.009494
# 2022-11-28 13:38:00     191.866        16.29 -0.016072  -0.025718  0.009646
# 2022-11-28 13:39:00     191.823        16.27 -0.016292  -0.026914  0.010622
# 2022-11-28 13:40:00     191.987        16.25 -0.015451  -0.028110  0.012659
# 2022-11-28 13:41:00     192.062        16.26 -0.015067  -0.027512  0.012445
# 2022-11-28 13:42:00     192.190        16.25 -0.014410  -0.028110  0.013700
# 2022-11-28 13:43:00     192.240        16.27 -0.014154  -0.026914  0.012760
# 2022-11-28 13:44:00     192.475        16.28 -0.012949  -0.026316  0.013367
# 2022-11-28 13:45:00     192.183        16.29 -0.014446  -0.025718  0.011272
# 2022-11-28 13:46:00     192.130        16.26 -0.014718  -0.027512  0.012794
# 2022-11-28 13:47:00     192.307        16.27 -0.013810  -0.026914  0.013104
# 2022-11-28 13:48:00     192.264        16.27 -0.014031  -0.026914  0.012883
# 2022-11-28 13:49:00     192.231        16.29 -0.014200  -0.025718  0.011518
# 2022-11-28 13:50:00     192.230        16.26 -0.014205  -0.027512  0.013307
# 2022-11-28 13:51:00     192.110        16.25 -0.014821  -0.028110  0.013290
# 2022-11-28 13:52:00     191.898        16.23 -0.015908  -0.029306  0.013399
# 2022-11-28 13:53:00     191.963        16.22 -0.015574  -0.029904  0.014330
# 2022-11-28 13:54:00     191.900        16.20 -0.015897  -0.031100  0.015203
# 2022-11-28 13:55:00     191.742        16.22 -0.016708  -0.029904  0.013197
# 2022-11-28 13:56:00     192.075        16.21 -0.015000  -0.030502  0.015502
# 2022-11-28 13:57:00     191.866        16.22 -0.016072  -0.029904  0.013833
# 2022-11-28 13:58:00     192.120        16.24 -0.014769  -0.028708  0.013939
# 2022-11-28 13:59:00     192.000        16.23 -0.015385  -0.029306  0.013922
# 2022-11-28 14:00:00     192.220        16.25 -0.014256  -0.028110  0.013854
# 2022-11-28 14:01:00     192.105        16.26 -0.014846  -0.027512  0.012666
# 2022-11-28 14:02:00     192.092        16.24 -0.014913  -0.028708  0.013795
# 2022-11-28 14:03:00     192.416        16.28 -0.013251  -0.026316  0.013065
# 2022-11-28 14:04:00     192.432        16.28 -0.013169  -0.026316  0.013147
# 2022-11-28 14:05:00     192.340        16.26 -0.013641  -0.027512  0.013871
# 2022-11-28 14:06:00     192.349        16.25 -0.013595  -0.028110  0.014515
# 2022-11-28 14:07:00     192.458        16.26 -0.013036  -0.027512  0.014476
# 2022-11-28 14:08:00     192.315        16.23 -0.013769  -0.029306  0.015537
# 2022-11-28 14:09:00     192.300        16.24 -0.013846  -0.028708  0.014862
# 2022-11-28 14:10:00     192.273        16.23 -0.013985  -0.029306  0.015322
# 2022-11-28 14:11:00     192.078        16.23 -0.014985  -0.029306  0.014322
# 2022-11-28 14:12:00     192.078        16.22 -0.014985  -0.029904  0.014920
# 2022-11-28 14:13:00     192.184        16.24 -0.014441  -0.028708  0.014267
# 2022-11-28 14:14:00     192.113        16.23 -0.014805  -0.029306  0.014501
# 2022-11-28 14:15:00     192.354        16.23 -0.013569  -0.029306  0.015737
# 2022-11-28 14:16:00     192.300        16.23 -0.013846  -0.029306  0.015460
# 2022-11-28 14:17:00     192.223        16.23 -0.014241  -0.029306  0.015065
# 2022-11-28 14:18:00     192.350        16.26 -0.013590  -0.027512  0.013922
# 2022-11-28 14:19:00     192.338        16.25 -0.013651  -0.028110  0.014459
# 2022-11-28 14:20:00     192.235        16.24 -0.014179  -0.028708  0.014529
# 2022-11-28 14:21:00     192.360        16.27 -0.013538  -0.026914  0.013375
# 2022-11-28 14:22:00     192.302        16.28 -0.013836  -0.026316  0.012480
# 2022-11-28 14:23:00     192.499        16.28 -0.012826  -0.026316  0.013490
# 2022-11-28 14:24:00     192.449        16.28 -0.013082  -0.026316  0.013234
# 2022-11-28 14:25:00     192.690        16.30 -0.011846  -0.025120  0.013273
# 2022-11-28 14:26:00     192.516        16.29 -0.012738  -0.025718  0.012979
# 2022-11-28 14:27:00     192.457        16.29 -0.013041  -0.025718  0.012677
# 2022-11-28 14:28:00     192.584        16.29 -0.012390  -0.025718  0.013328
# 2022-11-28 14:29:00     192.572        16.29 -0.012451  -0.025718  0.013266
# 2022-11-28 14:30:00     192.655        16.27 -0.012026  -0.026914  0.014888
# 2022-11-28 14:31:00     192.627        16.28 -0.012169  -0.026316  0.014147
# 2022-11-28 14:32:00     193.264        16.32 -0.008903  -0.023923  0.015021
# 2022-11-28 14:33:00     193.268        16.35 -0.008882  -0.022129  0.013247
# 2022-11-28 14:34:00     192.710        16.36 -0.011744  -0.021531  0.009788
# 2022-11-28 14:35:00     192.792        16.34 -0.011323  -0.022727  0.011404
# 2022-11-28 14:36:00     192.850        16.40 -0.011026  -0.019139  0.008113
# 2022-11-28 14:37:00     192.901        16.45 -0.010764  -0.016148  0.005384
# 2022-11-28 14:38:00     192.792        16.38 -0.011323  -0.020335  0.009012
# 2022-11-28 14:39:00     192.754        16.41 -0.011518  -0.018541  0.007023
# 2022-11-28 14:40:00     192.555        16.40 -0.012538  -0.019139  0.006600
# 2022-11-28 14:41:00     192.611        16.44 -0.012251  -0.016746  0.004495
# 2022-11-28 14:42:00     192.579        16.41 -0.012415  -0.018541  0.006125
# 2022-11-28 14:43:00     192.572        16.40 -0.012451  -0.019139  0.006687
# 2022-11-28 14:44:00     192.400        16.38 -0.013333  -0.020335  0.007002
# 2022-11-28 14:45:00     192.223        16.40 -0.014241  -0.019139  0.004898
# 2022-11-28 14:46:00     192.402        16.37 -0.013323  -0.020933  0.007610
# 2022-11-28 14:47:00     192.400        16.36 -0.013333  -0.021531  0.008198
# 2022-11-28 14:48:00     192.307        16.36 -0.013810  -0.021531  0.007721
# 2022-11-28 14:49:00     192.341        16.36 -0.013636  -0.021531  0.007895
# 2022-11-28 14:50:00     192.301        16.35 -0.013841  -0.022129  0.008288
# 2022-11-28 14:51:00     192.455        16.36 -0.013051  -0.021531  0.008480
# 2022-11-28 14:52:00     192.521        16.37 -0.012713  -0.020933  0.008220
# 2022-11-28 14:53:00     192.324        16.37 -0.013723  -0.020933  0.007210
# 2022-11-28 14:54:00     192.392        16.37 -0.013374  -0.020933  0.007559
# 2022-11-28 14:55:00     192.420        16.37 -0.013231  -0.020933  0.007702
# 2022-11-28 14:56:00     192.084        16.36 -0.014954  -0.021531  0.006577
# 2022-11-28 14:57:00     192.075        16.36 -0.015000  -0.021531  0.006531
# 2022-11-28 14:58:00     192.075        16.36 -0.015000  -0.021531  0.006531
# 2022-11-28 14:59:00     192.075        16.36 -0.015000  -0.021531  0.006531
# 2022-11-28 15:00:00     192.076        16.36 -0.014995  -0.021531  0.006536
#
#                      bond_pos  stock_pos  premium rate
# 2022-11-25 15:00:00       0.0        0.0      0.032147
# 2022-11-28 09:30:00      -1.0        1.0      0.045250
# 2022-11-28 09:31:00      -1.0        1.0      0.040413
# 2022-11-28 09:32:00      -1.0        1.0      0.042383
# 2022-11-28 09:33:00      -1.0        1.0      0.039362
# 2022-11-28 09:34:00      -1.0        1.0      0.037661
# 2022-11-28 09:35:00      -1.0        1.0      0.039990
# 2022-11-28 09:36:00      -1.0        1.0      0.038404
# 2022-11-28 09:37:00      -1.0        1.0      0.041433
# 2022-11-28 09:38:00      -1.0        1.0      0.042470
# 2022-11-28 09:39:00      -1.0        1.0      0.041336
# 2022-11-28 09:40:00      -1.0        1.0      0.044143
# 2022-11-28 09:41:00      -1.0        1.0      0.046783
# 2022-11-28 09:42:00      -1.0        1.0      0.045714
# 2022-11-28 09:43:00      -1.0        1.0      0.047652
# 2022-11-28 09:44:00      -1.0        1.0      0.047194
# 2022-11-28 09:45:00      -1.0        1.0      0.049600
# 2022-11-28 09:46:00      -1.0        1.0      0.051807
# 2022-11-28 09:47:00      -1.0        1.0      0.046951
# 2022-11-28 09:48:00      -1.0        1.0      0.048615
# 2022-11-28 09:49:00      -1.0        1.0      0.048449
# 2022-11-28 09:50:00      -1.0        1.0      0.046140
# 2022-11-28 09:51:00      -1.0        1.0      0.046618
# 2022-11-28 09:52:00      -1.0        1.0      0.047993
# 2022-11-28 09:53:00      -1.0        1.0      0.047430
# 2022-11-28 09:54:00      -1.0        1.0      0.045755
# 2022-11-28 09:55:00      -1.0        1.0      0.046042
# 2022-11-28 09:56:00      -1.0        1.0      0.044300
# 2022-11-28 09:57:00      -1.0        1.0      0.042038
# 2022-11-28 09:58:00      -1.0        1.0      0.041508
# 2022-11-28 09:59:00      -1.0        1.0      0.044524
# 2022-11-28 10:00:00      -1.0        1.0      0.043624
# 2022-11-28 10:01:00      -1.0        1.0      0.043231
# 2022-11-28 10:02:00      -1.0        1.0      0.043581
# 2022-11-28 10:03:00      -1.0        1.0      0.043182
# 2022-11-28 10:04:00      -1.0        1.0      0.045417
# 2022-11-28 10:05:00      -1.0        1.0      0.044126
# 2022-11-28 10:06:00      -1.0        1.0      0.044235
# 2022-11-28 10:07:00      -1.0        1.0      0.046719
# 2022-11-28 10:08:00      -1.0        1.0      0.046179
# 2022-11-28 10:09:00      -1.0        1.0      0.046257
# 2022-11-28 10:10:00      -1.0        1.0      0.044998
# 2022-11-28 10:11:00      -1.0        1.0      0.045413
# 2022-11-28 10:12:00      -1.0        1.0      0.043706
# 2022-11-28 10:13:00      -1.0        1.0      0.044822
# 2022-11-28 10:14:00      -1.0        1.0      0.044180
# 2022-11-28 10:15:00      -1.0        1.0      0.041911
# 2022-11-28 10:16:00      -1.0        1.0      0.042174
# 2022-11-28 10:17:00      -1.0        1.0      0.043855
# 2022-11-28 10:18:00      -1.0        1.0      0.043813
# 2022-11-28 10:19:00      -1.0        1.0      0.042404
# 2022-11-28 10:20:00      -1.0        1.0      0.044814
# 2022-11-28 10:21:00      -1.0        1.0      0.043655
# 2022-11-28 10:22:00      -1.0        1.0      0.044447
# 2022-11-28 10:23:00      -1.0        1.0      0.043920
# 2022-11-28 10:24:00      -1.0        1.0      0.044626
# 2022-11-28 10:25:00      -1.0        1.0      0.042736
# 2022-11-28 10:26:00      -1.0        1.0      0.040894
# 2022-11-28 10:27:00      -1.0        1.0      0.042544
# 2022-11-28 10:28:00      -1.0        1.0      0.041462
# 2022-11-28 10:29:00      -1.0        1.0      0.042830
# 2022-11-28 10:30:00      -1.0        1.0      0.042208
# 2022-11-28 10:31:00      -1.0        1.0      0.042333
# 2022-11-28 10:32:00      -1.0        1.0      0.043107
# 2022-11-28 10:33:00      -1.0        1.0      0.043150
# 2022-11-28 10:34:00      -1.0        1.0      0.043888
# 2022-11-28 10:35:00      -1.0        1.0      0.044496
# 2022-11-28 10:36:00      -1.0        1.0      0.041693
# 2022-11-28 10:37:00      -1.0        1.0      0.043346
# 2022-11-28 10:38:00      -1.0        1.0      0.043465
# 2022-11-28 10:39:00      -1.0        1.0      0.043671
# 2022-11-28 10:40:00      -1.0        1.0      0.043850
# 2022-11-28 10:41:00      -1.0        1.0      0.044697
# 2022-11-28 10:42:00      -1.0        1.0      0.045731
# 2022-11-28 10:43:00      -1.0        1.0      0.044430
# 2022-11-28 10:44:00      -1.0        1.0      0.045459
# 2022-11-28 10:45:00      -1.0        1.0      0.045028
# 2022-11-28 10:46:00      -1.0        1.0      0.045262
# 2022-11-28 10:47:00      -1.0        1.0      0.045137
# 2022-11-28 10:48:00      -1.0        1.0      0.045464
# 2022-11-28 10:49:00      -1.0        1.0      0.046608
# 2022-11-28 10:50:00      -1.0        1.0      0.045563
# 2022-11-28 10:51:00      -1.0        1.0      0.046970
# 2022-11-28 10:52:00      -1.0        1.0      0.047886
# 2022-11-28 10:53:00      -1.0        1.0      0.047568
# 2022-11-28 10:54:00      -1.0        1.0      0.048213
# 2022-11-28 10:55:00      -1.0        1.0      0.048600
# 2022-11-28 10:56:00      -1.0        1.0      0.048777
# 2022-11-28 10:57:00      -1.0        1.0      0.046648
# 2022-11-28 10:58:00      -1.0        1.0      0.046958
# 2022-11-28 10:59:00      -1.0        1.0      0.047107
# 2022-11-28 11:00:00      -1.0        1.0      0.047740
# 2022-11-28 11:01:00      -1.0        1.0      0.047331
# 2022-11-28 11:02:00      -1.0        1.0      0.046802
# 2022-11-28 11:03:00      -1.0        1.0      0.044479
# 2022-11-28 11:04:00      -1.0        1.0      0.046862
# 2022-11-28 11:05:00      -1.0        1.0      0.046095
# 2022-11-28 11:06:00      -1.0        1.0      0.044014
# 2022-11-28 11:07:00      -1.0        1.0      0.042693
# 2022-11-28 11:08:00      -1.0        1.0      0.042381
# 2022-11-28 11:09:00      -1.0        1.0      0.040449
# 2022-11-28 11:10:00      -1.0        1.0      0.038957
# 2022-11-28 11:11:00      -1.0        1.0      0.039128
# 2022-11-28 11:12:00      -1.0        1.0      0.038826
# 2022-11-28 11:13:00      -1.0        1.0      0.040744
# 2022-11-28 11:14:00      -1.0        1.0      0.041117
# 2022-11-28 11:15:00      -1.0        1.0      0.043266
# 2022-11-28 11:16:00      -1.0        1.0      0.043561
# 2022-11-28 11:17:00      -1.0        1.0      0.044241
# 2022-11-28 11:18:00      -1.0        1.0      0.044846
# 2022-11-28 11:19:00      -1.0        1.0      0.045261
# 2022-11-28 11:20:00      -1.0        1.0      0.044974
# 2022-11-28 11:21:00      -1.0        1.0      0.041529
# 2022-11-28 11:22:00      -1.0        1.0      0.042816
# 2022-11-28 11:23:00      -1.0        1.0      0.042396
# 2022-11-28 11:24:00      -1.0        1.0      0.039996
# 2022-11-28 11:25:00      -1.0        1.0      0.039236
# 2022-11-28 11:26:00      -1.0        1.0      0.039926
# 2022-11-28 11:27:00      -1.0        1.0      0.039668
# 2022-11-28 11:28:00      -1.0        1.0      0.040229
# 2022-11-28 11:29:00      -1.0        1.0      0.039004
# 2022-11-28 11:30:00      -1.0        1.0      0.038629
# 2022-11-28 13:00:00      -1.0        1.0      0.040489
# 2022-11-28 13:01:00      -1.0        1.0      0.042459
# 2022-11-28 13:02:00      -1.0        1.0      0.043055
# 2022-11-28 13:03:00      -1.0        1.0      0.039560
# 2022-11-28 13:04:00      -1.0        1.0      0.041053
# 2022-11-28 13:05:00      -1.0        1.0      0.040821
# 2022-11-28 13:06:00      -1.0        1.0      0.041781
# 2022-11-28 13:07:00      -1.0        1.0      0.041623
# 2022-11-28 13:08:00      -1.0        1.0      0.041431
# 2022-11-28 13:09:00      -1.0        1.0      0.040448
# 2022-11-28 13:10:00      -1.0        1.0      0.040524
# 2022-11-28 13:11:00      -1.0        1.0      0.040551
# 2022-11-28 13:12:00      -1.0        1.0      0.041809
# 2022-11-28 13:13:00      -1.0        1.0      0.041891
# 2022-11-28 13:14:00      -1.0        1.0      0.042610
# 2022-11-28 13:15:00      -1.0        1.0      0.042368
# 2022-11-28 13:16:00      -1.0        1.0      0.042385
# 2022-11-28 13:17:00      -1.0        1.0      0.042200
# 2022-11-28 13:18:00      -1.0        1.0      0.042610
# 2022-11-28 13:19:00      -1.0        1.0      0.042177
# 2022-11-28 13:20:00      -1.0        1.0      0.042174
# 2022-11-28 13:21:00      -1.0        1.0      0.042448
# 2022-11-28 13:22:00      -1.0        1.0      0.042903
# 2022-11-28 13:23:00      -1.0        1.0      0.041798
# 2022-11-28 13:24:00      -1.0        1.0      0.041448
# 2022-11-28 13:25:00      -1.0        1.0      0.039620
# 2022-11-28 13:26:00      -1.0        1.0      0.040092
# 2022-11-28 13:27:00      -1.0        1.0      0.041464
# 2022-11-28 13:28:00      -1.0        1.0      0.042464
# 2022-11-28 13:29:00      -1.0        1.0      0.042853
# 2022-11-28 13:30:00      -1.0        1.0      0.042869
# 2022-11-28 13:31:00      -1.0        1.0      0.043445
# 2022-11-28 13:32:00      -1.0        1.0      0.043425
# 2022-11-28 13:33:00      -1.0        1.0      0.044806
# 2022-11-28 13:34:00      -1.0        1.0      0.042454
# 2022-11-28 13:35:00      -1.0        1.0      0.043078
# 2022-11-28 13:36:00      -1.0        1.0      0.041305
# 2022-11-28 13:37:00      -1.0        1.0      0.042199
# 2022-11-28 13:38:00      -1.0        1.0      0.042366
# 2022-11-28 13:39:00      -1.0        1.0      0.043413
# 2022-11-28 13:40:00      -1.0        1.0      0.045591
# 2022-11-28 13:41:00      -1.0        1.0      0.045356
# 2022-11-28 13:42:00      -1.0        1.0      0.046696
# 2022-11-28 13:43:00      -1.0        1.0      0.045682
# 2022-11-28 13:44:00      -1.0        1.0      0.046317
# 2022-11-28 13:45:00      -1.0        1.0      0.044088
# 2022-11-28 13:46:00      -1.0        1.0      0.045726
# 2022-11-28 13:47:00      -1.0        1.0      0.046046
# 2022-11-28 13:48:00      -1.0        1.0      0.045812
# 2022-11-28 13:49:00      -1.0        1.0      0.044349
# 2022-11-28 13:50:00      -1.0        1.0      0.046270
# 2022-11-28 13:51:00      -1.0        1.0      0.046261
# 2022-11-28 13:52:00      -1.0        1.0      0.046394
# 2022-11-28 13:53:00      -1.0        1.0      0.047394
# 2022-11-28 13:54:00      -1.0        1.0      0.048343
# 2022-11-28 13:55:00      -1.0        1.0      0.046188
# 2022-11-28 13:56:00      -1.0        1.0      0.048651
# 2022-11-28 13:57:00      -1.0        1.0      0.046864
# 2022-11-28 13:58:00      -1.0        1.0      0.046959
# 2022-11-28 13:59:00      -1.0        1.0      0.046950
# 2022-11-28 14:00:00      -1.0        1.0      0.046860
# 2022-11-28 14:01:00      -1.0        1.0      0.045590
# 2022-11-28 14:02:00      -1.0        1.0      0.046807
# 2022-11-28 14:03:00      -1.0        1.0      0.045996
# 2022-11-28 14:04:00      -1.0        1.0      0.046083
# 2022-11-28 14:05:00      -1.0        1.0      0.046869
# 2022-11-28 14:06:00      -1.0        1.0      0.047562
# 2022-11-28 14:07:00      -1.0        1.0      0.047511
# 2022-11-28 14:08:00      -1.0        1.0      0.048668
# 2022-11-28 14:09:00      -1.0        1.0      0.047940
# 2022-11-28 14:10:00      -1.0        1.0      0.048439
# 2022-11-28 14:11:00      -1.0        1.0      0.047375
# 2022-11-28 14:12:00      -1.0        1.0      0.048021
# 2022-11-28 14:13:00      -1.0        1.0      0.047308
# 2022-11-28 14:14:00      -1.0        1.0      0.047566
# 2022-11-28 14:15:00      -1.0        1.0      0.048880
# 2022-11-28 14:16:00      -1.0        1.0      0.048586
# 2022-11-28 14:17:00      -1.0        1.0      0.048166
# 2022-11-28 14:18:00      -1.0        1.0      0.046923
# 2022-11-28 14:19:00      -1.0        1.0      0.047502
# 2022-11-28 14:20:00      -1.0        1.0      0.047586
# 2022-11-28 14:21:00      -1.0        1.0      0.046334
# 2022-11-28 14:22:00      -1.0        1.0      0.045376
# 2022-11-28 14:23:00      -1.0        1.0      0.046447
# 2022-11-28 14:24:00      -1.0        1.0      0.046175
# 2022-11-28 14:25:00      -1.0        1.0      0.046200
# 2022-11-28 14:26:00      -1.0        1.0      0.045897
# 2022-11-28 14:27:00      -1.0        1.0      0.045577
# 2022-11-28 14:28:00      -1.0        1.0      0.046267
# 2022-11-28 14:29:00      -1.0        1.0      0.046201
# 2022-11-28 14:30:00      -1.0        1.0      0.047939
# 2022-11-28 14:31:00      -1.0        1.0      0.047143
# 2022-11-28 14:32:00      -1.0        1.0      0.048031
# 2022-11-28 14:33:00      -1.0        1.0      0.046130
# 2022-11-28 14:34:00      -1.0        1.0      0.042472
# 2022-11-28 14:35:00      -1.0        1.0      0.044192
# 2022-11-28 14:36:00      -1.0        1.0      0.040684
# 2022-11-28 14:37:00      -1.0        1.0      0.037796
# 2022-11-28 14:38:00      -1.0        1.0      0.041642
# 2022-11-28 14:39:00      -1.0        1.0      0.039533
# 2022-11-28 14:40:00      -1.0        1.0      0.039093
# 2022-11-28 14:41:00      -1.0        1.0      0.036866
# 2022-11-28 14:42:00      -1.0        1.0      0.038589
# 2022-11-28 14:43:00      -1.0        1.0      0.039184
# 2022-11-28 14:44:00      -1.0        1.0      0.039524
# 2022-11-28 14:45:00      -1.0        1.0      0.037301
# 2022-11-28 14:46:00      -1.0        1.0      0.040170
# 2022-11-28 14:47:00      -1.0        1.0      0.040795
# 2022-11-28 14:48:00      -1.0        1.0      0.040292
# 2022-11-28 14:49:00      -1.0        1.0      0.040475
# 2022-11-28 14:50:00      -1.0        1.0      0.040895
# 2022-11-28 14:51:00      -1.0        1.0      0.041092
# 2022-11-28 14:52:00      -1.0        1.0      0.040813
# 2022-11-28 14:53:00      -1.0        1.0      0.039748
# 2022-11-28 14:54:00      -1.0        1.0      0.040116
# 2022-11-28 14:55:00      -1.0        1.0      0.040267
# 2022-11-28 14:56:00      -1.0        1.0      0.039085
# 2022-11-28 14:57:00      -1.0        1.0      0.039037
# 2022-11-28 14:58:00      -1.0        1.0      0.039037
# 2022-11-28 14:59:00      -1.0        1.0      0.039037
# 2022-11-28 15:00:00       0.0        0.0      0.039042

# %%
# 到期时间很短，且价内50%的时候，转债近似等价于正股
def cal_premium_rate(bond_price,stock_price,convert_price):
    tmp = 100/convert_price*stock_price
    res = (bond_price - tmp)/tmp
    return res
cal_premium_rate(200,140,70)
# Out:
# 0.0
